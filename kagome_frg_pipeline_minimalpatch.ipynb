# %% [markdown]
# # Kagome fRG sanity-check pipeline
#
# This notebook builds a **standard spinful kagome model** using the corrected `channels.py` and `frg_flow.py`, then runs two benchmark interaction points inspired by the PRL phase diagram:
#
# - **FM benchmark:** `U=6, V=0`
# - **PI benchmark:** `U=0, V=10`
#
# Target setup:
# - no flux
# - van Hove filling proxy: `mu = 0`
# - `Npatch = 12`
#
# The purpose is simple:
#
# 1. verify the corrected longitudinal channel construction in a full end-to-end pipeline
# 2. check whether the final leading instability looks **FM-like** for large `U`
# 3. check whether it looks **PI-like** for large `V`
#
# If the second case still does **not** show PI-like structure, the next place to inspect is likely:
# - `form_factor.py`
# - `kagome_order_diagnosis.py`
#
# ---

# %%
import sys
from pathlib import Path
from pprint import pprint
import numpy as np
import numpy as np
import matplotlib.pyplot as plt

# Make sure the uploaded modules are importable
sys.path.insert(0, "/mnt/data")

from noninteracting import KagomeNagaosa
from patching import FSPatcher, plot_patchset
from interaction import BareExtendedHubbard
from frg_flow import BareVertexFromInteraction, FRGFlowSolver
import sys
sys.path.insert(0, "/mnt/data")

# %% [markdown]
# ## 1. Global parameters
#
# You can tune the flow resolution here.
#
# Notes:
# - `mu=0` matches the PRL convention for kagome VHF.
# - `band_index=1` is the dispersive band crossing `mu=0` inside each 3x3 spin block.
# - `Npatch=12` is intentionally small, just for a fast pipeline sanity check.
# - For a more reliable final physics check, increase `Npatch`, `nfreq`, and `n_steps`.

# %%
# ---------- noninteracting / patching ----------
MODEL_PARAMS = dict(t=1.0, phi=0.0)   # standard kagome = phi=0
MU = 0.0
NPATCH = 24
GRID_SIZE = 320
CONTOUR_MIN_POINTS = 40

# Each spin block is 3x3 inside the full 6x6 spinful Hamiltonian
UP_SLICE = slice(0, 3)
DN_SLICE = slice(3, 6)
LOCAL_BAND_INDEX = 1   # dispersive band crossing mu=0

# ---------- flow ----------
FLOW_KWARGS = dict(
    T_start=20,
    T_stop=2,
    n_steps=1600,
    nfreq=60,
    diagnose_every=10,
    temperature_grid="log",
    include_explicit_T_prefactor=True,
    max_relative_update=1,
    min_substep_fraction=0.1,
    channel_divergence_threshold=1e4,
    eigenvalue_threshold=1e4,
    diagnosis_sort_by="abs",
    track_crossed_channel=True,
    diagnosis_Qs = [np.array([0.0, 0.0]), np.array([0.0,  np.pi/np.sqrt(3)]), np.array([ np.pi/2,  np.pi/(2*np.sqrt(3))]), np.array([-np.pi/2,  np.pi/(2*np.sqrt(3))])]
)

# %% [markdown]
# ## 2. Build the standard spinful kagome model and the two spin patchsets

# %%
# ============================================================
# Manual exact-M patchsets on standard centered 1BZ hexagon
# ============================================================

import numpy as np
import matplotlib.pyplot as plt
from patching import PatchPoint, PatchSet, plot_patchset

model = KagomeNagaosa(MODEL_PARAMS, spin=True, B=None)

# ------------------------------------------------------------
# basic helpers
# ------------------------------------------------------------
def _sector_eig(model, k_cart, orbital_slice, band_index):
    kx, ky = float(k_cart[0]), float(k_cart[1])
    H = np.asarray(model.Hk(kx, ky), dtype=complex)
    Hs = H[orbital_slice, orbital_slice]
    evals, evecs = np.linalg.eigh(Hs)
    u = np.asarray(evecs[:, band_index], dtype=complex)
    u = u / np.linalg.norm(u)
    return float(evals[band_index]), u

def _orbital_weight(u):
    w = np.abs(np.asarray(u, dtype=complex))**2
    return w / np.sum(w)

def _cart_to_red(model, k):
    B = np.column_stack([
        np.asarray(model.b1, dtype=float),
        np.asarray(model.b2, dtype=float),
    ])
    return np.linalg.solve(B, np.asarray(k, dtype=float))

def _finite_diff_velocity(model, k_cart, orbital_slice, band_index, h=1e-6):
    kx, ky = float(k_cart[0]), float(k_cart[1])

    def band_energy(x, y):
        H = np.asarray(model.Hk(x, y), dtype=complex)
        Hs = H[orbital_slice, orbital_slice]
        evals, _ = np.linalg.eigh(Hs)
        return float(evals[band_index])

    vx = (band_energy(kx + h, ky) - band_energy(kx - h, ky)) / (2*h)
    vy = (band_energy(kx, ky + h) - band_energy(kx, ky - h)) / (2*h)
    return np.array([vx, vy], dtype=float)


# ------------------------------------------------------------
# 1BZ geometry
# ------------------------------------------------------------
def hex_bz_vertices(model):
    """
    Standard centered 1BZ hexagon vertices for triangular/kagome reciprocal lattice.

    For reciprocal vectors b1, b2, the Wigner-Seitz 1BZ vertices are:
        ±(2b1-b2)/3, ±(b1+b2)/3, ±(-b1+2b2)/3
    """
    b1 = np.asarray(model.b1, dtype=float)
    b2 = np.asarray(model.b2, dtype=float)

    verts = np.array([
        (2*b1 - b2) / 3.0,
        (b1 + b2) / 3.0,
        (-b1 + 2*b2) / 3.0,
        -(2*b1 - b2) / 3.0,
        -(b1 + b2) / 3.0,
        -(-b1 + 2*b2) / 3.0,
    ], dtype=float)

    ang = np.arctan2(verts[:, 1], verts[:, 0])
    order = np.argsort(ang)
    return verts[order]


def exact_M6_points_1bz(model):
    """
    6 geometric M points on the boundary of the standard centered 1BZ hexagon.
    Each M point is the midpoint of one hexagon edge.
    """
    V = hex_bz_vertices(model)
    M = []

    n = len(V)
    for i in range(n):
        v0 = V[i]
        v1 = V[(i + 1) % n]
        M.append(0.5 * (v0 + v1))

    M = np.asarray(M, dtype=float)

    # keep consistent cyclic order
    ang = np.arctan2(M[:, 1], M[:, 0])
    order = np.argsort(ang)
    return M[order]


def exact_M_hex_loop_points(model, points_per_edge=1):
    """
    Build a manual hex loop from the 6 exact M points on the centered 1BZ.

    points_per_edge = 1  ->  6 patches  (6 exact M points)
    points_per_edge = 2  -> 12 patches
    points_per_edge = 4  -> 24 patches

    Total patch number = 6 * points_per_edge
    """
    if points_per_edge < 1:
        raise ValueError("points_per_edge must be >= 1")

    M6 = exact_M6_points_1bz(model)
    pts = []

    n = len(M6)
    for i in range(n):
        k0 = M6[i]
        k1 = M6[(i + 1) % n]

        # put points_per_edge points on each M-to-M segment:
        # t = 0, 1/p, 2/p, ..., (p-1)/p
        # exclude t=1 to avoid duplicating the next M point
        for m in range(points_per_edge):
            t = m / points_per_edge
            k = (1.0 - t) * k0 + t * k1
            pts.append(k)

    return np.asarray(pts, dtype=float)


def _hex_bz_vertices_for_plot(model):
    return hex_bz_vertices(model)


# ------------------------------------------------------------
# patchset builder
# ------------------------------------------------------------
def build_exactM_patchset(model, orbital_slice, band_index, points_per_edge=1):
    K = exact_M_hex_loop_points(model, points_per_edge=points_per_edge)
    bz_vertices = _hex_bz_vertices_for_plot(model)

    patches = []
    for pid, k in enumerate(K):
        e, u = _sector_eig(model, k, orbital_slice, band_index)
        vF = _finite_diff_velocity(model, k, orbital_slice, band_index)

        patches.append(
            PatchPoint(
                patch_id=pid,
                k_cart=np.asarray(k, dtype=float),
                k_red=_cart_to_red(model, k),
                energy=e,
                vF=vF,
                vF_norm=float(np.linalg.norm(vF)),
                eigvec=u,
                orbital_weight=_orbital_weight(u),
            )
        )

    npatch = len(K)
    return PatchSet(
        mu=0.0,
        mu_used_for_contour=0.0,
        band_index=int(band_index),
        filling=np.nan,
        patches=patches,
        fs_contour_k=np.asarray(K, dtype=float),
        bz_vertices=np.asarray(bz_vertices, dtype=float),
        b1=np.asarray(model.b1, dtype=float),
        b2=np.asarray(model.b2, dtype=float),
        gauge_method=f"manual_exact_M_hex_{npatch}",
        gauge_loop_phase=0.0,
    )


# ------------------------------------------------------------
# choose patch density here
# ------------------------------------------------------------
POINTS_PER_EDGE = 1   # 1->6, 2->12, 4->24
NPATCH = 6 * POINTS_PER_EDGE

patchsets = {
    "up": build_exactM_patchset(
        model, UP_SLICE, LOCAL_BAND_INDEX, points_per_edge=POINTS_PER_EDGE
    ),
    "dn": build_exactM_patchset(
        model, DN_SLICE, LOCAL_BAND_INDEX, points_per_edge=POINTS_PER_EDGE
    ),
}


# ------------------------------------------------------------
# print info
# ------------------------------------------------------------
print("Patch counts:", {k: v.Npatch for k, v in patchsets.items()})
print("mu used for contour (up/dn):", patchsets["up"].mu_used_for_contour, patchsets["dn"].mu_used_for_contour)
print("gauge method (up/dn):", patchsets["up"].gauge_method, patchsets["dn"].gauge_method)

print("\n===== exact M6 anchors in centered 1BZ =====")
M6 = exact_M6_points_1bz(model)
for i, k in enumerate(M6):
    e_up, _ = _sector_eig(model, k, UP_SLICE, LOCAL_BAND_INDEX)
    e_dn, _ = _sector_eig(model, k, DN_SLICE, LOCAL_BAND_INDEX)
    print(
        f"M{i}: k={np.round(k, 6)} | "
        f"E_up={e_up:.10e} | E_dn={e_dn:.10e}"
    )

for spin in ["up", "dn"]:
    print(f"\n===== {spin} exact-M{NPATCH} patches =====")
    for p in patchsets[spin].patches:
        print(
            f"id={p.patch_id:2d} | "
            f"k={np.round(p.k_cart, 6)} | "
            f"E={p.energy:.10e} | "
            f"|vF|={p.vF_norm:.6e} | "
            f"w={np.round(p.orbital_weight, 6)}"
        )


# ------------------------------------------------------------
# neighbor distance sanity check
# ------------------------------------------------------------
for spin in ["up", "dn"]:
    ks = np.array([p.k_cart for p in patchsets[spin].patches], dtype=float)
    d = np.linalg.norm(np.roll(ks, -1, axis=0) - ks, axis=1)
    print(f"\n===== {spin} neighbor distances =====")
    print(np.round(d, 8))


# ------------------------------------------------------------
# plot
# ------------------------------------------------------------
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

for ax, spin in zip(axes, ["up", "dn"]):
    plot_patchset(patchsets[spin], ax=ax, show_contour=True, show_velocity=False, show_bz=True)
    ks = np.array([p.k_cart for p in patchsets[spin].patches], dtype=float)

    for i, k in enumerate(ks):
        ax.text(k[0], k[1], str(i), fontsize=8, ha="left", va="bottom")

    ax.set_title(f"{spin} exact-M{NPATCH} patchset")

plt.tight_layout()
plt.show()
# Out:
# Patch counts: {'up': 6, 'dn': 6}
# mu used for contour (up/dn): 0.0 0.0
# gauge method (up/dn): manual_exact_M_hex_6 manual_exact_M_hex_6
#
# ===== exact M6 anchors in centered 1BZ =====
# M0: k=[-1.570796 -0.9069  ] | E_up=1.0947644253e-47 | E_dn=1.0947644253e-47
# M1: k=[ 0.       -1.813799] | E_up=1.0344233826e-31 | E_dn=1.0344233826e-31
# M2: k=[ 1.570796 -0.9069  ] | E_up=1.4997597827e-32 | E_dn=1.4997597827e-32
# M3: k=[1.570796 0.9069  ] | E_up=1.0947644253e-47 | E_dn=1.0947644253e-47
# M4: k=[0.       1.813799] | E_up=1.0344233826e-31 | E_dn=1.0344233826e-31
# M5: k=[-1.570796  0.9069  ] | E_up=1.4997597827e-32 | E_dn=1.4997597827e-32
#
# ===== up exact-M6 patches =====
# id= 0 | k=[-1.570796 -0.9069  ] | E=1.0947644253e-47 | |vF|=7.747470e-16 | w=[0. 1. 0.]
# id= 1 | k=[ 0.       -1.813799] | E=1.0344233826e-31 | |vF|=3.449543e-16 | w=[1. 0. 0.]
# id= 2 | k=[ 1.570796 -0.9069  ] | E=1.4997597827e-32 | |vF|=2.255553e-16 | w=[0. 0. 1.]
# id= 3 | k=[1.570796 0.9069  ] | E=1.0947644253e-47 | |vF|=7.747470e-16 | w=[0. 1. 0.]
# id= 4 | k=[0.       1.813799] | E=1.0344233826e-31 | |vF|=3.449543e-16 | w=[1. 0. 0.]
# id= 5 | k=[-1.570796  0.9069  ] | E=1.4997597827e-32 | |vF|=2.255553e-16 | w=[0. 0. 1.]
#
# ===== dn exact-M6 patches =====
# id= 0 | k=[-1.570796 -0.9069  ] | E=1.0947644253e-47 | |vF|=7.747470e-16 | w=[0. 1. 0.]
# id= 1 | k=[ 0.       -1.813799] | E=1.0344233826e-31 | |vF|=3.449543e-16 | w=[1. 0. 0.]
# id= 2 | k=[ 1.570796 -0.9069  ] | E=1.4997597827e-32 | |vF|=2.255553e-16 | w=[0. 0. 1.]
# id= 3 | k=[1.570796 0.9069  ] | E=1.0947644253e-47 | |vF|=7.747470e-16 | w=[0. 1. 0.]
# id= 4 | k=[0.       1.813799] | E=1.0344233826e-31 | |vF|=3.449543e-16 | w=[1. 0. 0.]
# id= 5 | k=[-1.570796  0.9069  ] | E=1.4997597827e-32 | |vF|=2.255553e-16 | w=[0. 0. 1.]
#
# ===== up neighbor distances =====
# [1.81379936 1.81379936 1.81379936 1.81379936 1.81379936 1.81379936]
#
# ===== dn neighbor distances =====
# [1.81379936 1.81379936 1.81379936 1.81379936 1.81379936 1.81379936]

# %% [markdown]
# ## 3. Helpers for running a benchmark interaction point  Debug FRG Solver

# %%
from frg_flow import FRGFlowSolver

_old_step = FRGFlowSolver.step
_old_run = FRGFlowSolver.run

def _debug_step(self, T_old, dT):
    print(f"[DEBUG] entering step: T_old={T_old:.8f}, dT={dT:.8e}")
    try:
        rec = _old_step(self, T_old, dT)
        print(
            f"[DEBUG] leaving step: "
            f"T_new={getattr(rec, 'temperature', float(T_old + dT)):.8f}, "
            f"rhs_norm={getattr(rec, 'rhs_norm', None)}, "
            f"channel_norm={getattr(rec, 'channel_norm', None)}, "
            f"accepted_substeps={getattr(rec, 'accepted_substeps', None)}, "
            f"max_rel_update={getattr(rec, 'max_rel_update', None)}"
        )
        return rec
    except Exception as e:
        print(f"[DEBUG] exception in step:")
        print(f"        T_old = {T_old:.8f}")
        print(f"        dT    = {dT:.8e}")
        print(f"        T_new = {T_old + dT:.8f}")
        raise

def _debug_run(self):
    # print("[DEBUG] temperature path:")
    # for i, T in enumerate(self.temperature_path):
    #     print(f"  i={i:03d}, T={float(T):.8f}")
    return _old_run(self)

FRGFlowSolver.step = _debug_step
FRGFlowSolver.run = _debug_run

def build_solver(model, patchsets, U, V, flow_kwargs=None):
    flow_kwargs = {} if flow_kwargs is None else dict(flow_kwargs)
    interaction = BareExtendedHubbard.from_kagome_model(model, U=U, V=V)
    bare_gamma = BareVertexFromInteraction(interaction, patchsets)
    solver = FRGFlowSolver(
        patchsets=patchsets,
        bare_gamma=bare_gamma,
        **flow_kwargs,
    )
    return interaction, bare_gamma, solver


def summarize_history(history):
    rows = []
    for rec in history:
        rows.append({
            "step": rec.step_index,
            "T": rec.temperature,
            "channel_norm": rec.channel_norm,
            "rhs_norm": rec.rhs_norm,
            "leading_channel": rec.leading_channel_name,
            "leading_order": rec.leading_order_label,
            "leading_abs_eval": rec.leading_eigenvalue_abs,
            "instability": rec.instability,
            "reason": rec.instability_reason,
        })
    return rows


def pretty_print_final_record(history):
    rec = history[-1]
    print("===== Final record =====")
    pprint(rec.summary_dict())
    return rec


def plot_history(history, title):
    steps = [h.step_index for h in history]
    Ts = [h.temperature for h in history]
    evals = [np.nan if h.leading_eigenvalue_abs is None else h.leading_eigenvalue_abs for h in history]
    norms = [h.channel_norm for h in history]

    fig, axes = plt.subplots(1, 2, figsize=(11, 4))
    axes[0].plot(steps, evals, marker="o")
    axes[0].set_xlabel("step")
    axes[0].set_ylabel("leading |eigenvalue|")
    axes[0].set_title(f"{title}: leading eigenvalue")

    axes[1].plot(steps, norms, marker="o")
    axes[1].set_xlabel("step")
    axes[1].set_ylabel("channel norm")
    axes[1].set_title(f"{title}: channel norm")

    plt.tight_layout()
    plt.show()


def run_case(case_name, U, V, flow_kwargs=None):
    print(f"\n===== Running case: {case_name} (U={U}, V={V}) =====")
    interaction, bare_gamma, solver = build_solver(
        model=model,
        patchsets=patchsets,
        U=U,
        V=V,
        flow_kwargs=flow_kwargs if flow_kwargs is not None else FLOW_KWARGS,
    )
    history = solver.run()
    print(f"history length = {len(history)}")
    print(f"instability record = {None if solver.instability_record is None else solver.instability_record.step_index}")
    final_rec = pretty_print_final_record(history)
    plot_history(history, case_name)
    return {
        "case_name": case_name,
        "U": U,
        "V": V,
        "interaction": interaction,
        "solver": solver,
        "history": history,
        "final_record": final_rec,
    }

# %% [markdown]
# ## 4. FM benchmark: `U=6, V=0`
#
# Expectation from the PRL benchmark at van Hove filling:
# - dominant onsite interaction should favor **ferromagnetism (FM)**.

# %%
fm_result = run_case("FM benchmark", U=6.0, V=.0, flow_kwargs=FLOW_KWARGS)
# Out:
# ===== Running case: FM benchmark (U=6.0, V=0.0) =====
# [DEBUG] entering step: T_old=20.00000000, dT=-2.87795874e-02
# [DEBUG] leaving step: T_new=19.97122041, rhs_norm=0.08969853481892519, channel_norm=0.0025814868185843392, accepted_substeps=1, max_rel_update=0.0004302478030973899
# [DEBUG] entering step: T_old=19.97122041, dT=-2.87381741e-02
# [DEBUG] leaving step: T_new=19.94248224, rhs_norm=0.08995724177772749, channel_norm=0.005166693696528955, accepted_substeps=1, max_rel_update=0.0004308678129907693
# [DEBUG] entering step: T_old=19.94248224, dT=-2.86968205e-02
# [DEBUG] leaving step: T_new=19.91378542, rhs_norm=0.09021669489465464, channel_norm=0.007755625994634256, accepted_substeps=1, max_rel_update=0.00043148871635088356
# [DEBUG] entering step: T_old=19.91378542, dT=-2.86555264e-02
# [DEBUG] leaving step: T_new=19.88512989, rhs_norm=0.09047689632176317, channel_norm=0.010348289081429138, accepted_substeps=1, max_rel_update=0.00043211051446581357
# [DEBUG] entering step: T_old=19.88512989, dT=-2.86142916e-02
# [DEBUG] leaving step: T_new=19.85651560, rhs_norm=0.0907378482173155, channel_norm=0.012944688333178016, accepted_substeps=1, max_rel_update=0.00043273320862481304
# [DEBUG] entering step: T_old=19.85651560, dT=-2.85731163e-02
# [DEBUG] leaving step: T_new=19.82794248, rhs_norm=0.09099955274580059, channel_norm=0.015544829133893413, accepted_substeps=1, max_rel_update=0.00043335680011923305
# [DEBUG] entering step: T_old=19.82794248, dT=-2.85320001e-02
# [DEBUG] leaving step: T_new=19.79941048, rhs_norm=0.09126201207794883, channel_norm=0.01814871687534397, accepted_substeps=1, max_rel_update=0.0004339812902417596
# [DEBUG] entering step: T_old=19.79941048, dT=-2.84909432e-02
# [DEBUG] leaving step: T_new=19.77091954, rhs_norm=0.09152522839075194, channel_norm=0.020756356957071273, accepted_substeps=1, max_rel_update=0.0004346066802878836
# [DEBUG] entering step: T_old=19.77091954, dT=-2.84499453e-02
# [DEBUG] leaving step: T_new=19.74246960, rhs_norm=0.09178920386748039, channel_norm=0.02336775478639569, accepted_substeps=1, max_rel_update=0.00043523297155406915
# [DEBUG] entering step: T_old=19.74246960, dT=-2.84090064e-02
# [DEBUG] leaving step: T_new=19.71406059, rhs_norm=0.09205394069770186, channel_norm=0.025982915778432314, accepted_substeps=1, max_rel_update=0.00043586016533943734
# [DEBUG] entering step: T_old=19.71406059, dT=-2.83681264e-02
# [DEBUG] leaving step: T_new=19.68569246, rhs_norm=0.09231944107729849, channel_norm=0.028601845356096164, accepted_substeps=1, max_rel_update=0.0004364882629439748
# [DEBUG] entering step: T_old=19.68569246, dT=-2.83273053e-02
# [DEBUG] leaving step: T_new=19.65736516, rhs_norm=0.09258570720848618, channel_norm=0.031224548950119512, accepted_substeps=1, max_rel_update=0.000437117265670558
# [DEBUG] entering step: T_old=19.65736516, dT=-2.82865429e-02
# [DEBUG] leaving step: T_new=19.62907861, rhs_norm=0.09285274129983277, channel_norm=0.03385103199906044, accepted_substeps=1, max_rel_update=0.0004377471748234887
# [DEBUG] entering step: T_old=19.62907861, dT=-2.82458391e-02
# [DEBUG] leaving step: T_new=19.60083277, rhs_norm=0.0931205455662751, channel_norm=0.03648129994931434, accepted_substeps=1, max_rel_update=0.00043837799170898294
# [DEBUG] entering step: T_old=19.60083277, dT=-2.82051940e-02
# [DEBUG] leaving step: T_new=19.57262758, rhs_norm=0.09338912222913943, channel_norm=0.03911535825512347, accepted_substeps=1, max_rel_update=0.0004390097176348551
# [DEBUG] entering step: T_old=19.57262758, dT=-2.81646073e-02
# [DEBUG] leaving step: T_new=19.54446297, rhs_norm=0.09365847351615765, channel_norm=0.04175321237859118, accepted_substeps=1, max_rel_update=0.00043964235391128484
# [DEBUG] entering step: T_old=19.54446297, dT=-2.81240790e-02
# [DEBUG] leaving step: T_new=19.51633889, rhs_norm=0.09392860166148773, channel_norm=0.04439486778969254, accepted_substeps=1, max_rel_update=0.0004402759018502273
# [DEBUG] entering step: T_old=19.51633889, dT=-2.80836090e-02
# [DEBUG] leaving step: T_new=19.48825529, rhs_norm=0.09419950890573048, channel_norm=0.04704032996628566, accepted_substeps=1, max_rel_update=0.0004409103627655202
# [DEBUG] entering step: T_old=19.48825529, dT=-2.80431973e-02
# [DEBUG] leaving step: T_new=19.46021209, rhs_norm=0.09447119749594986, channel_norm=0.04968960439411868, accepted_substeps=1, max_rel_update=0.00044154573797216976
# [DEBUG] entering step: T_old=19.46021209, dT=-2.80028437e-02
# [DEBUG] leaving step: T_new=19.43220924, rhs_norm=0.09474366968568997, channel_norm=0.0523426965668495, accepted_substeps=1, max_rel_update=0.0004421820287884701
# [DEBUG] entering step: T_old=19.43220924, dT=-2.79625482e-02
# [DEBUG] leaving step: T_new=19.40424670, rhs_norm=0.09501692773499539, channel_norm=0.05499961198605086, accepted_substeps=1, max_rel_update=0.00044281923653356086
# [DEBUG] entering step: T_old=19.40424670, dT=-2.79223106e-02
# [DEBUG] leaving step: T_new=19.37632439, rhs_norm=0.0952909739104283, channel_norm=0.05766035616122379, accepted_substeps=1, max_rel_update=0.00044345736252882057
# [DEBUG] entering step: T_old=19.37632439, dT=-2.78821310e-02
# [DEBUG] leaving step: T_new=19.34844225, rhs_norm=0.09556581048508885, channel_norm=0.060324934609807694, accepted_substeps=1, max_rel_update=0.0004440964080973183
# [DEBUG] entering step: T_old=19.34844225, dT=-2.78420092e-02
# [DEBUG] leaving step: T_new=19.32060025, rhs_norm=0.09584143973863234, channel_norm=0.06299335285719429, accepted_substeps=1, max_rel_update=0.00044473637456443285
# [DEBUG] entering step: T_old=19.32060025, dT=-2.78019451e-02
# [DEBUG] leaving step: T_new=19.29279830, rhs_norm=0.0961178639572896, channel_norm=0.06566561643673707, accepted_substeps=1, max_rel_update=0.0004453772632571308
# [DEBUG] entering step: T_old=19.29279830, dT=-2.77619387e-02
# [DEBUG] leaving step: T_new=19.26503636, rhs_norm=0.09639508543388538, channel_norm=0.06834173088976463, accepted_substeps=1, max_rel_update=0.0004460190755045925
# [DEBUG] entering step: T_old=19.26503636, dT=-2.77219898e-02
# [DEBUG] leaving step: T_new=19.23731437, rhs_norm=0.09667310646785733, channel_norm=0.07102170176558813, accepted_substeps=1, max_rel_update=0.00044666181263724905
# [DEBUG] entering step: T_old=19.23731437, dT=-2.76820985e-02
# [DEBUG] leaving step: T_new=19.20963227, rhs_norm=0.09695192936527455, channel_norm=0.07370553462151808, accepted_substeps=1, max_rel_update=0.0004473054759883254
# [DEBUG] entering step: T_old=19.20963227, dT=-2.76422645e-02
# [DEBUG] leaving step: T_new=19.18199001, rhs_norm=0.09723155643885768, channel_norm=0.07639323502287228, accepted_substeps=1, max_rel_update=0.00044795006689236634
# [DEBUG] entering step: T_old=19.18199001, dT=-2.76024879e-02
# [DEBUG] leaving step: T_new=19.15438752, rhs_norm=0.09751199000799786, channel_norm=0.07908480854298991, accepted_substeps=1, max_rel_update=0.0004485955866862716
# [DEBUG] entering step: T_old=19.15438752, dT=-2.75627684e-02
# [DEBUG] leaving step: T_new=19.12682475, rhs_norm=0.09779323239877574, channel_norm=0.08178026076323845, accepted_substeps=1, max_rel_update=0.00044924203670809065
# [DEBUG] entering step: T_old=19.12682475, dT=-2.75231062e-02
# [DEBUG] leaving step: T_new=19.09930165, rhs_norm=0.09807528594398039, channel_norm=0.0844795972730317, accepted_substeps=1, max_rel_update=0.0004498894182988732
# [DEBUG] entering step: T_old=19.09930165, dT=-2.74835010e-02
# [DEBUG] leaving step: T_new=19.07181815, rhs_norm=0.09835815298312973, channel_norm=0.08718282366983635, accepted_substeps=1, max_rel_update=0.0004505377328007742
# [DEBUG] entering step: T_old=19.07181815, dT=-2.74439528e-02
# [DEBUG] leaving step: T_new=19.04437419, rhs_norm=0.09864183586248862, channel_norm=0.089889945559187, accepted_substeps=1, max_rel_update=0.0004511869815584419
# [DEBUG] entering step: T_old=19.04437419, dT=-2.74044615e-02
# [DEBUG] leaving step: T_new=19.01696973, rhs_norm=0.09892633693508897, channel_norm=0.09260096855469278, accepted_substeps=1, max_rel_update=0.0004518371659176302
# [DEBUG] entering step: T_old=19.01696973, dT=-2.73650271e-02
# [DEBUG] leaving step: T_new=18.98960470, rhs_norm=0.09921165856074983, channel_norm=0.09531589827805557, accepted_substeps=1, max_rel_update=0.00045248828722713224
# [DEBUG] entering step: T_old=18.98960470, dT=-2.73256494e-02
# [DEBUG] leaving step: T_new=18.96227905, rhs_norm=0.09949780310609636, channel_norm=0.09803474035907776, accepted_substeps=1, max_rel_update=0.00045314034683703206
# [DEBUG] entering step: T_old=18.96227905, dT=-2.72863283e-02
# [DEBUG] leaving step: T_new=18.93499273, rhs_norm=0.09978477294457877, channel_norm=0.1007575004356742, accepted_substeps=1, max_rel_update=0.0004537933460994071
# [DEBUG] entering step: T_old=18.93499273, dT=-2.72470639e-02
# [DEBUG] leaving step: T_new=18.90774566, rhs_norm=0.1000725704564938, channel_norm=0.10348418415388319, accepted_substeps=1, max_rel_update=0.00045444728636816423
# [DEBUG] entering step: T_old=18.90774566, dT=-2.72078559e-02
# [DEBUG] leaving step: T_new=18.88053781, rhs_norm=0.10036119802900212, channel_norm=0.1062147971678806, accepted_substeps=1, max_rel_update=0.0004551021689995684
# [DEBUG] entering step: T_old=18.88053781, dT=-2.71687044e-02
# [DEBUG] leaving step: T_new=18.85336910, rhs_norm=0.10065065805615038, channel_norm=0.10894934513999024, accepted_substeps=1, max_rel_update=0.00045575799535160837
# [DEBUG] entering step: T_old=18.85336910, dT=-2.71296092e-02
# [DEBUG] leaving step: T_new=18.82623949, rhs_norm=0.10094095293888992, channel_norm=0.11168783374069637, accepted_substeps=1, max_rel_update=0.00045641476678435285
# [DEBUG] entering step: T_old=18.82623949, dT=-2.70905702e-02
# [DEBUG] leaving step: T_new=18.79914892, rhs_norm=0.10123208508509703, channel_norm=0.1144302686486518, accepted_substeps=1, max_rel_update=0.00045707248465923976
# [DEBUG] entering step: T_old=18.79914892, dT=-2.70515874e-02
# [DEBUG] leaving step: T_new=18.77209734, rhs_norm=0.1015240569095919, channel_norm=0.11717665555069523, accepted_substeps=1, max_rel_update=0.0004577311503405721
# [DEBUG] entering step: T_old=18.77209734, dT=-2.70126608e-02
# [DEBUG] leaving step: T_new=18.74508467, rhs_norm=0.10181687083416012, channel_norm=0.11992700014185981, accepted_substeps=1, max_rel_update=0.000458390765194096
# [DEBUG] entering step: T_old=18.74508467, dT=-2.69737901e-02
# [DEBUG] leaving step: T_new=18.71811088, rhs_norm=0.10211052928757279, channel_norm=0.12268130812538616, accepted_substeps=1, max_rel_update=0.00045905133058772476
# [DEBUG] entering step: T_old=18.71811088, dT=-2.69349754e-02
# [DEBUG] leaving step: T_new=18.69117591, rhs_norm=0.10240503470560458, channel_norm=0.12543958521273102, accepted_substeps=1, max_rel_update=0.00045971284789081006
# [DEBUG] entering step: T_old=18.69117591, dT=-2.68962165e-02
# [DEBUG] leaving step: T_new=18.66427969, rhs_norm=0.10270038953105666, channel_norm=0.12820183712358468, accepted_substeps=1, max_rel_update=0.0004603753184756121
# [DEBUG] entering step: T_old=18.66427969, dT=-2.68575134e-02
# [DEBUG] leaving step: T_new=18.63742218, rhs_norm=0.10299659621377502, channel_norm=0.13096806958587792, accepted_substeps=1, max_rel_update=0.00046103874371554123
# [DEBUG] entering step: T_old=18.63742218, dT=-2.68188660e-02
# [DEBUG] leaving step: T_new=18.61060331, rhs_norm=0.10329365721067144, channel_norm=0.13373828833579765, accepted_substeps=1, max_rel_update=0.0004617031249866226
# [DEBUG] entering step: T_old=18.61060331, dT=-2.67802742e-02
# [DEBUG] leaving step: T_new=18.58382304, rhs_norm=0.10359157498574446, channel_norm=0.1365124991177939, accepted_substeps=1, max_rel_update=0.0004623684636660416
# [DEBUG] entering step: T_old=18.58382304, dT=-2.67417379e-02
# [DEBUG] leaving step: T_new=18.55708130, rhs_norm=0.10389035201009851, channel_norm=0.13929070768459703, accepted_substeps=1, max_rel_update=0.0004630347611338541
# [DEBUG] entering step: T_old=18.55708130, dT=-2.67032571e-02
# [DEBUG] leaving step: T_new=18.53037804, rhs_norm=0.10418999076196574, channel_norm=0.14207291979722733, accepted_substeps=1, max_rel_update=0.0004637020187717158
# [DEBUG] entering step: T_old=18.53037804, dT=-2.66648317e-02
# [DEBUG] leaving step: T_new=18.50371321, rhs_norm=0.10449049372672536, channel_norm=0.14485914122500756, accepted_substeps=1, max_rel_update=0.0004643702379633716
# [DEBUG] entering step: T_old=18.50371321, dT=-2.66264615e-02
# [DEBUG] leaving step: T_new=18.47708675, rhs_norm=0.10479186339692535, channel_norm=0.1476493777455711, accepted_substeps=1, max_rel_update=0.000465039420093923
# [DEBUG] entering step: T_old=18.47708675, dT=-2.65881466e-02
# [DEBUG] leaving step: T_new=18.45049860, rhs_norm=0.10509410227230265, channel_norm=0.15044363514488088, accepted_substeps=1, max_rel_update=0.0004657095665516274
# [DEBUG] entering step: T_old=18.45049860, dT=-2.65498868e-02
# [DEBUG] leaving step: T_new=18.42394872, rhs_norm=0.10539721285980362, channel_norm=0.15324191921723565, accepted_substeps=1, max_rel_update=0.00046638067872579753
# [DEBUG] entering step: T_old=18.42394872, dT=-2.65116821e-02
# [DEBUG] leaving step: T_new=18.39743704, rhs_norm=0.10570119767360533, channel_norm=0.15604423576528656, accepted_substeps=1, max_rel_update=0.00046705275800848516
# [DEBUG] entering step: T_old=18.39743704, dT=-2.64735323e-02
# [DEBUG] leaving step: T_new=18.37096350, rhs_norm=0.10600605923513595, channel_norm=0.15885059060004225, accepted_substeps=1, max_rel_update=0.000467725805792613
# [DEBUG] entering step: T_old=18.37096350, dT=-2.64354374e-02
# [DEBUG] leaving step: T_new=18.34452807, rhs_norm=0.10631180007309658, channel_norm=0.16166098954088953, accepted_substeps=1, max_rel_update=0.000468399823474549
# [DEBUG] entering step: T_old=18.34452807, dT=-2.63973974e-02
# [DEBUG] leaving step: T_new=18.31813067, rhs_norm=0.10661842272348035, channel_norm=0.16447543841560025, accepted_substeps=1, max_rel_update=0.00046907481245178845
# [DEBUG] entering step: T_old=18.31813067, dT=-2.63594121e-02
# [DEBUG] leaving step: T_new=18.29177126, rhs_norm=0.10692592972959578, channel_norm=0.1672939430603418, accepted_substeps=1, max_rel_update=0.00046975077412359087
# [DEBUG] entering step: T_old=18.29177126, dT=-2.63214814e-02
# [DEBUG] leaving step: T_new=18.26544977, rhs_norm=0.10723432364208631, channel_norm=0.17011650931969488, accepted_substeps=1, max_rel_update=0.00047042770989218127
# [DEBUG] entering step: T_old=18.26544977, dT=-2.62836054e-02
# [DEBUG] leaving step: T_new=18.23916617, rhs_norm=0.10754360701895171, channel_norm=0.17294314304666158, accepted_substeps=1, max_rel_update=0.00047110562116111553
# [DEBUG] entering step: T_old=18.23916617, dT=-2.62457838e-02
# [DEBUG] leaving step: T_new=18.21292039, rhs_norm=0.10785378242556994, channel_norm=0.17577385010267824, accepted_substeps=1, max_rel_update=0.0004717845093361092
# [DEBUG] entering step: T_old=18.21292039, dT=-2.62080167e-02
# [DEBUG] leaving step: T_new=18.18671237, rhs_norm=0.10816485243471773, channel_norm=0.17860863635762889, accepted_substeps=1, max_rel_update=0.0004724643758251064
# [DEBUG] entering step: T_old=18.18671237, dT=-2.61703039e-02
# [DEBUG] leaving step: T_new=18.16054207, rhs_norm=0.10847681962659216, channel_norm=0.1814475076898536, accepted_substeps=1, max_rel_update=0.00047314522203745424
# [DEBUG] entering step: T_old=18.16054207, dT=-2.61326453e-02
# [DEBUG] leaving step: T_new=18.13440942, rhs_norm=0.10878968658883187, channel_norm=0.18429046998616627, accepted_substeps=1, max_rel_update=0.00047382704938544546
# [DEBUG] entering step: T_old=18.13440942, dT=-2.60950410e-02
# [DEBUG] leaving step: T_new=18.10831438, rhs_norm=0.10910345591653925, channel_norm=0.1871375291418638, accepted_substeps=1, max_rel_update=0.0004745098592829189
# [DEBUG] entering step: T_old=18.10831438, dT=-2.60574908e-02
# [DEBUG] leaving step: T_new=18.08225689, rhs_norm=0.1094181302123011, channel_norm=0.1899886910607361, accepted_substeps=1, max_rel_update=0.00047519365314538435
# [DEBUG] entering step: T_old=18.08225689, dT=-2.60199946e-02
# [DEBUG] leaving step: T_new=18.05623689, rhs_norm=0.1097337120862103, channel_norm=0.19284396165508325, accepted_substeps=1, max_rel_update=0.00047587843239119305
# [DEBUG] entering step: T_old=18.05623689, dT=-2.59825524e-02
# [DEBUG] leaving step: T_new=18.03025434, rhs_norm=0.11005020415588807, channel_norm=0.19570334684572438, accepted_substeps=1, max_rel_update=0.0004765641984401895
# [DEBUG] entering step: T_old=18.03025434, dT=-2.59451640e-02
# [DEBUG] leaving step: T_new=18.00430918, rhs_norm=0.11036760904650574, channel_norm=0.19856685256201173, accepted_substeps=1, max_rel_update=0.000477250952714559
# [DEBUG] entering step: T_old=18.00430918, dT=-2.59078294e-02
# [DEBUG] leaving step: T_new=17.97840135, rhs_norm=0.1106859293908055, channel_norm=0.20143448474183961, accepted_substeps=1, max_rel_update=0.00047793869663798164
# [DEBUG] entering step: T_old=17.97840135, dT=-2.58705486e-02
# [DEBUG] leaving step: T_new=17.95253080, rhs_norm=0.11100516782912256, channel_norm=0.2043062493316617, accepted_substeps=1, max_rel_update=0.0004786274316370114
# [DEBUG] entering step: T_old=17.95253080, dT=-2.58333214e-02
# [DEBUG] leaving step: T_new=17.92669748, rhs_norm=0.11132532700940799, channel_norm=0.20718215228649958, accepted_substeps=1, max_rel_update=0.0004793171591396486
# [DEBUG] entering step: T_old=17.92669748, dT=-2.57961478e-02
# [DEBUG] leaving step: T_new=17.90090133, rhs_norm=0.11164640958724982, channel_norm=0.21006219956995753, accepted_substeps=1, max_rel_update=0.0004800078805763245
# [DEBUG] entering step: T_old=17.90090133, dT=-2.57590277e-02
# [DEBUG] leaving step: T_new=17.87514230, rhs_norm=0.11196841822589522, channel_norm=0.21294639715423105, accepted_substeps=1, max_rel_update=0.00048069959737891854
# [DEBUG] entering step: T_old=17.87514230, dT=-2.57219610e-02
# [DEBUG] leaving step: T_new=17.84942034, rhs_norm=0.11229135559627265, channel_norm=0.21583475102012475, accepted_substeps=1, max_rel_update=0.00048139231098228563
# [DEBUG] entering step: T_old=17.84942034, dT=-2.56849476e-02
# [DEBUG] leaving step: T_new=17.82373539, rhs_norm=0.11261522437701428, channel_norm=0.2187272671570604, accepted_substeps=1, max_rel_update=0.0004820860228226088
# [DEBUG] entering step: T_old=17.82373539, dT=-2.56479875e-02
# [DEBUG] leaving step: T_new=17.79808741, rhs_norm=0.1129400272544777, channel_norm=0.22162395156309278, accepted_substeps=1, max_rel_update=0.0004827807343387302
# [DEBUG] entering step: T_old=17.79808741, dT=-2.56110806e-02
# [DEBUG] leaving step: T_new=17.77247633, rhs_norm=0.11326576692276864, channel_norm=0.22452481024491613, accepted_substeps=1, max_rel_update=0.00048347644697055767
# [DEBUG] entering step: T_old=17.77247633, dT=-2.55742267e-02
# [DEBUG] leaving step: T_new=17.74690210, rhs_norm=0.11359244608376212, channel_norm=0.22742984921788417, accepted_substeps=1, max_rel_update=0.0004841731621613378
# [DEBUG] entering step: T_old=17.74690210, dT=-2.55374260e-02
# [DEBUG] leaving step: T_new=17.72136467, rhs_norm=0.11392006744712767, channel_norm=0.23033907450601818, accepted_substeps=1, max_rel_update=0.00048487088135566893
# [DEBUG] entering step: T_old=17.72136467, dT=-2.55006781e-02
# [DEBUG] leaving step: T_new=17.69586399, rhs_norm=0.11424863373034864, channel_norm=0.23325249214202157, accepted_substeps=1, max_rel_update=0.00048556960600056536
# [DEBUG] entering step: T_old=17.69586399, dT=-2.54639832e-02
# [DEBUG] leaving step: T_new=17.67040001, rhs_norm=0.11457814765874665, channel_norm=0.2361701081672875, accepted_substeps=1, max_rel_update=0.0004862693375443225
# [DEBUG] entering step: T_old=17.67040001, dT=-2.54273410e-02
# [DEBUG] leaving step: T_new=17.64497267, rhs_norm=0.11490861196550305, channel_norm=0.2390919286319184, accepted_substeps=1, max_rel_update=0.0004869700774384806
# [DEBUG] entering step: T_old=17.64497267, dT=-2.53907516e-02
# [DEBUG] leaving step: T_new=17.61958192, rhs_norm=0.11524002939168328, channel_norm=0.24201795959473446, accepted_substeps=1, max_rel_update=0.0004876718271360113
# [DEBUG] entering step: T_old=17.61958192, dT=-2.53542149e-02
# [DEBUG] leaving step: T_new=17.59422770, rhs_norm=0.11557240268625708, channel_norm=0.24494820712328802, accepted_substeps=1, max_rel_update=0.000488374588092262
# [DEBUG] entering step: T_old=17.59422770, dT=-2.53177307e-02
# [DEBUG] leaving step: T_new=17.56890997, rhs_norm=0.11590573460612426, channel_norm=0.2478826772938713, accepted_substeps=1, max_rel_update=0.0004890783617638805
# [DEBUG] entering step: T_old=17.56890997, dT=-2.52812990e-02
# [DEBUG] leaving step: T_new=17.54362867, rhs_norm=0.11624002791613477, channel_norm=0.2508213761915365, accepted_substeps=1, max_rel_update=0.0004897831496108624
# [DEBUG] entering step: T_old=17.54362867, dT=-2.52449197e-02
# [DEBUG] leaving step: T_new=17.51838375, rhs_norm=0.11657528538911366, channel_norm=0.25376430991010396, accepted_substeps=1, max_rel_update=0.0004904889530945817
# [DEBUG] entering step: T_old=17.51838375, dT=-2.52085928e-02
# [DEBUG] leaving step: T_new=17.49317516, rhs_norm=0.11691150980588291, channel_norm=0.25671148455217563, accepted_substeps=1, max_rel_update=0.0004911957736786132
# [DEBUG] entering step: T_old=17.49317516, dT=-2.51723181e-02
# [DEBUG] leaving step: T_new=17.46800284, rhs_norm=0.11724870395528493, channel_norm=0.2596629062291452, accepted_substeps=1, max_rel_update=0.0004919036128282546
# [DEBUG] entering step: T_old=17.46800284, dT=-2.51360957e-02
# [DEBUG] leaving step: T_new=17.44286675, rhs_norm=0.11758687063420606, channel_norm=0.2626185810612159, accepted_substeps=1, max_rel_update=0.0004926124720117828
# [DEBUG] entering step: T_old=17.44286675, dT=-2.50999254e-02
# [DEBUG] leaving step: T_new=17.41776682, rhs_norm=0.1179260126475988, channel_norm=0.2655785151774103, accepted_substeps=1, max_rel_update=0.0004933223526990709
# [DEBUG] entering step: T_old=17.41776682, dT=-2.50638071e-02
# [DEBUG] leaving step: T_new=17.39270302, rhs_norm=0.1182661328085061, channel_norm=0.2685427147155832, accepted_substeps=1, max_rel_update=0.0004940332563621526
# [DEBUG] entering step: T_old=17.39270302, dT=-2.50277408e-02
# [DEBUG] leaving step: T_new=17.36767527, rhs_norm=0.11860723393808406, channel_norm=0.2715111858224316, accepted_substeps=1, max_rel_update=0.0004947451844747337
# [DEBUG] entering step: T_old=17.36767527, dT=-2.49917264e-02
# [DEBUG] leaving step: T_new=17.34268355, rhs_norm=0.11894931886562528, channel_norm=0.27448393465351406, accepted_substeps=1, max_rel_update=0.0004954581385137412
# [DEBUG] entering step: T_old=17.34268355, dT=-2.49557638e-02
# [DEBUG] leaving step: T_new=17.31772778, rhs_norm=0.11929239042858307, channel_norm=0.27746096737325743, accepted_substeps=1, max_rel_update=0.00049617211995723
# [DEBUG] entering step: T_old=17.31772778, dT=-2.49198530e-02
# [DEBUG] leaving step: T_new=17.29280793, rhs_norm=0.11963645147259412, channel_norm=0.2804422901549734, accepted_substeps=1, max_rel_update=0.0004968871302859995
# [DEBUG] entering step: T_old=17.29280793, dT=-2.48839938e-02
# [DEBUG] leaving step: T_new=17.26792394, rhs_norm=0.11998150485150247, channel_norm=0.28342790918086697, accepted_substeps=1, max_rel_update=0.0004976031709822606
# [DEBUG] entering step: T_old=17.26792394, dT=-2.48481863e-02
# [DEBUG] leaving step: T_new=17.24307575, rhs_norm=0.12032755342738319, channel_norm=0.28641783064205456, accepted_substeps=1, max_rel_update=0.0004983202435312704
# [DEBUG] entering step: T_old=17.24307575, dT=-2.48124302e-02
# [DEBUG] leaving step: T_new=17.21826332, rhs_norm=0.12067460007056605, channel_norm=0.2894120607385737, accepted_substeps=1, max_rel_update=0.0004990383494198501
# [DEBUG] entering step: T_old=17.21826332, dT=-2.47767257e-02
# [DEBUG] leaving step: T_new=17.19348660, rhs_norm=0.12102264765965963, channel_norm=0.29241060567939714, accepted_substeps=1, max_rel_update=0.0004997574901372452
# [DEBUG] entering step: T_old=17.19348660, dT=-2.47410725e-02
# [DEBUG] leaving step: T_new=17.16874552, rhs_norm=0.1213716990815749, channel_norm=0.2954134716824423, accepted_substeps=1, max_rel_update=0.0005004776671741991
# [DEBUG] entering step: T_old=17.16874552, dT=-2.47054706e-02
# [DEBUG] leaving step: T_new=17.14404005, rhs_norm=0.12172175723154885, channel_norm=0.29842066497458997, accepted_substeps=1, max_rel_update=0.0005011988820246067
# [DEBUG] entering step: T_old=17.14404005, dT=-2.46699199e-02
# [DEBUG] leaving step: T_new=17.11937013, rhs_norm=0.12207282501316911, channel_norm=0.3014321917916932, accepted_substeps=1, max_rel_update=0.0005019211361838753
# [DEBUG] entering step: T_old=17.11937013, dT=-2.46344204e-02
# [DEBUG] leaving step: T_new=17.09473571, rhs_norm=0.12242490533839766, channel_norm=0.30444805837859196, accepted_substeps=1, max_rel_update=0.00050264443114979
# [DEBUG] entering step: T_old=17.09473571, dT=-2.45989720e-02
# [DEBUG] leaving step: T_new=17.07013674, rhs_norm=0.12277800112759578, channel_norm=0.30746827098912277, accepted_substeps=1, max_rel_update=0.0005033687684217991
# [DEBUG] entering step: T_old=17.07013674, dT=-2.45635746e-02
# [DEBUG] leaving step: T_new=17.04557317, rhs_norm=0.1231321153095459, channel_norm=0.31049283588613713, accepted_substeps=1, max_rel_update=0.0005040941495023887
# [DEBUG] entering step: T_old=17.04557317, dT=-2.45282281e-02
# [DEBUG] leaving step: T_new=17.02104494, rhs_norm=0.12348725082148006, channel_norm=0.3135217593415106, accepted_substeps=1, max_rel_update=0.0005048205758955839
# [DEBUG] entering step: T_old=17.02104494, dT=-2.44929325e-02
# [DEBUG] leaving step: T_new=16.99655201, rhs_norm=0.12384341060909987, channel_norm=0.3165550476361579, accepted_substeps=1, max_rel_update=0.0005055480491078802
# [DEBUG] entering step: T_old=16.99655201, dT=-2.44576877e-02
# [DEBUG] leaving step: T_new=16.97209432, rhs_norm=0.12420059762660354, channel_norm=0.3195927070600413, accepted_substeps=1, max_rel_update=0.000506276570647236
# [DEBUG] entering step: T_old=16.97209432, dT=-2.44224936e-02
# [DEBUG] leaving step: T_new=16.94767182, rhs_norm=0.12455881483670932, channel_norm=0.32263474391219116, accepted_substeps=1, max_rel_update=0.0005070061420249817
# [DEBUG] entering step: T_old=16.94767182, dT=-2.43873501e-02
# [DEBUG] leaving step: T_new=16.92328447, rhs_norm=0.1249180652106813, channel_norm=0.3256811645007138, accepted_substeps=1, max_rel_update=0.0005077367647537769
# [DEBUG] entering step: T_old=16.92328447, dT=-2.43522572e-02
# [DEBUG] leaving step: T_new=16.89893222, rhs_norm=0.1252783517283529, channel_norm=0.32873197514280655, accepted_substeps=1, max_rel_update=0.0005084684403487871
# [DEBUG] entering step: T_old=16.89893222, dT=-2.43172148e-02
# [DEBUG] leaving step: T_new=16.87461500, rhs_norm=0.1256396773781514, channel_norm=0.3317871821647674, accepted_substeps=1, max_rel_update=0.0005092011703268013
# [DEBUG] entering step: T_old=16.87461500, dT=-2.42822228e-02
# [DEBUG] leaving step: T_new=16.85033278, rhs_norm=0.12600204515712413, channel_norm=0.3348467919020137, accepted_substeps=1, max_rel_update=0.0005099349562077272
# [DEBUG] entering step: T_old=16.85033278, dT=-2.42472812e-02
# [DEBUG] leaving step: T_new=16.82608550, rhs_norm=0.12636545807096133, channel_norm=0.33791081069909146, accepted_substeps=1, max_rel_update=0.000510669799512958
# [DEBUG] entering step: T_old=16.82608550, dT=-2.42123899e-02
# [DEBUG] leaving step: T_new=16.80187311, rhs_norm=0.12672991913402337, channel_norm=0.3409792449096909, accepted_substeps=1, max_rel_update=0.0005114057017665771
# [DEBUG] entering step: T_old=16.80187311, dT=-2.41775487e-02
# [DEBUG] leaving step: T_new=16.77769556, rhs_norm=0.12709543136936413, channel_norm=0.34405210089665494, accepted_substeps=1, max_rel_update=0.0005121426644940119
# [DEBUG] entering step: T_old=16.77769556, dT=-2.41427577e-02
# [DEBUG] leaving step: T_new=16.75355280, rhs_norm=0.12746199780875608, channel_norm=0.34712938503199886, accepted_substeps=1, max_rel_update=0.0005128806892239895
# [DEBUG] entering step: T_old=16.75355280, dT=-2.41080168e-02
# [DEBUG] leaving step: T_new=16.72944478, rhs_norm=0.12782962149271648, channel_norm=0.35021110369692027, accepted_substeps=1, max_rel_update=0.0005136197774868972
# [DEBUG] entering step: T_old=16.72944478, dT=-2.40733259e-02
# [DEBUG] leaving step: T_new=16.70537146, rhs_norm=0.12819830547053176, channel_norm=0.3532972632818085, accepted_substeps=1, max_rel_update=0.0005143599308147033
# [DEBUG] entering step: T_old=16.70537146, dT=-2.40386849e-02
# [DEBUG] leaving step: T_new=16.68133277, rhs_norm=0.1285680528002832, channel_norm=0.356387870186267, accepted_substeps=1, max_rel_update=0.0005151011507430865
# [DEBUG] entering step: T_old=16.68133277, dT=-2.40040937e-02
# [DEBUG] leaving step: T_new=16.65732868, rhs_norm=0.12893886654887196, channel_norm=0.3594829308191179, accepted_substeps=1, max_rel_update=0.0005158434388084856
# [DEBUG] entering step: T_old=16.65732868, dT=-2.39695523e-02
# [DEBUG] leaving step: T_new=16.63335913, rhs_norm=0.12931074979204465, channel_norm=0.3625824515984207, accepted_substeps=1, max_rel_update=0.0005165867965504586
# [DEBUG] entering step: T_old=16.63335913, dT=-2.39350606e-02
# [DEBUG] leaving step: T_new=16.60942407, rhs_norm=0.12968370561441883, channel_norm=0.36568643895148306, accepted_substeps=1, max_rel_update=0.000517331225510397
# [DEBUG] entering step: T_old=16.60942407, dT=-2.39006185e-02
# [DEBUG] leaving step: T_new=16.58552345, rhs_norm=0.1300577371095092, channel_norm=0.36879489931487364, accepted_substeps=1, max_rel_update=0.0005180767272317605
# [DEBUG] entering step: T_old=16.58552345, dT=-2.38662260e-02
# [DEBUG] leaving step: T_new=16.56165722, rhs_norm=0.13043284737975236, channel_norm=0.3719078391344378, accepted_substeps=1, max_rel_update=0.0005188233032606944
# [DEBUG] entering step: T_old=16.56165722, dT=-2.38318830e-02
# [DEBUG] leaving step: T_new=16.53782534, rhs_norm=0.13080903953653278, channel_norm=0.37502526486531035, accepted_substeps=1, max_rel_update=0.0005195709551454253
# [DEBUG] entering step: T_old=16.53782534, dT=-2.37975895e-02
# [DEBUG] leaving step: T_new=16.51402775, rhs_norm=0.13118631670020864, channel_norm=0.3781471829719251, accepted_substeps=1, max_rel_update=0.0005203196844357985
# [DEBUG] entering step: T_old=16.51402775, dT=-2.37633452e-02
# [DEBUG] leaving step: T_new=16.49026440, rhs_norm=0.1315646820001382, channel_norm=0.38127359992803506, accepted_substeps=1, max_rel_update=0.0005210694926849917
# [DEBUG] entering step: T_old=16.49026440, dT=-2.37291502e-02
# [DEBUG] leaving step: T_new=16.46653525, rhs_norm=0.13194413857470513, channel_norm=0.384404522216721, accepted_substeps=1, max_rel_update=0.0005218203814476601
# [DEBUG] entering step: T_old=16.46653525, dT=-2.36950045e-02
# [DEBUG] leaving step: T_new=16.44284025, rhs_norm=0.13232468957134508, channel_norm=0.3875399563304053, accepted_substeps=1, max_rel_update=0.0005225723522807173
# [DEBUG] entering step: T_old=16.44284025, dT=-2.36609079e-02
# [DEBUG] leaving step: T_new=16.41917934, rhs_norm=0.13270633814657085, channel_norm=0.3906799087708686, accepted_substeps=1, max_rel_update=0.0005233254067438881
# [DEBUG] entering step: T_old=16.41917934, dT=-2.36268603e-02
# [DEBUG] leaving step: T_new=16.39555248, rhs_norm=0.13308908746599965, channel_norm=0.3938243860492575, accepted_substeps=1, max_rel_update=0.0005240795463981517
# [DEBUG] entering step: T_old=16.39555248, dT=-2.35928617e-02
# [DEBUG] leaving step: T_new=16.37195962, rhs_norm=0.13347294070437898, channel_norm=0.39697339468610326, accepted_substeps=1, max_rel_update=0.0005248347728076292
# [DEBUG] entering step: T_old=16.37195962, dT=-2.35589121e-02
# [DEBUG] leaving step: T_new=16.34840071, rhs_norm=0.13385790104561265, channel_norm=0.40012694121133613, accepted_substeps=1, max_rel_update=0.0005255910875388089
# [DEBUG] entering step: T_old=16.34840071, dT=-2.35250113e-02
# [DEBUG] leaving step: T_new=16.32487570, rhs_norm=0.13424397168278765, channel_norm=0.4032850321642904, accepted_substeps=1, max_rel_update=0.0005263484921590462
# [DEBUG] entering step: T_old=16.32487570, dT=-2.34911593e-02
# [DEBUG] leaving step: T_new=16.30138454, rhs_norm=0.13463115581819973, channel_norm=0.4064476740937293, accepted_substeps=1, max_rel_update=0.0005271069882398148
# [DEBUG] entering step: T_old=16.30138454, dT=-2.34573560e-02
# [DEBUG] leaving step: T_new=16.27792718, rhs_norm=0.13501945666338194, channel_norm=0.4096148735578506, accepted_substeps=1, max_rel_update=0.00052786657735355
# [DEBUG] entering step: T_old=16.27792718, dT=-2.34236014e-02
# [DEBUG] leaving step: T_new=16.25450358, rhs_norm=0.13540887743912886, channel_norm=0.41278663712430486, accepted_substeps=1, max_rel_update=0.0005286272610757116
# [DEBUG] entering step: T_old=16.25450358, dT=-2.33898953e-02
# [DEBUG] leaving step: T_new=16.23111368, rhs_norm=0.13579942137552478, channel_norm=0.4159629713702031, accepted_substeps=1, max_rel_update=0.0005293890409830379
# [DEBUG] entering step: T_old=16.23111368, dT=-2.33562377e-02
# [DEBUG] leaving step: T_new=16.20775745, rhs_norm=0.1361910917119703, channel_norm=0.4191438828821384, accepted_substeps=1, max_rel_update=0.0005301519186558766
# [DEBUG] entering step: T_old=16.20775745, dT=-2.33226286e-02
# [DEBUG] leaving step: T_new=16.18443482, rhs_norm=0.13658389169720878, channel_norm=0.4223293782561931, accepted_substeps=1, max_rel_update=0.0005309158956757816
# [DEBUG] entering step: T_old=16.18443482, dT=-2.32890678e-02
# [DEBUG] leaving step: T_new=16.16114575, rhs_norm=0.1369778245893537, channel_norm=0.4255194640979564, accepted_substeps=1, max_rel_update=0.00053168097362721
# [DEBUG] entering step: T_old=16.16114575, dT=-2.32555553e-02
# [DEBUG] leaving step: T_new=16.13789020, rhs_norm=0.1373728936559159, channel_norm=0.4287141470225343, accepted_substeps=1, max_rel_update=0.000532447154096318
# [DEBUG] entering step: T_old=16.13789020, dT=-2.32220910e-02
# [DEBUG] leaving step: T_new=16.11466810, rhs_norm=0.13776910217382934, channel_norm=0.43191343365456736, accepted_substeps=1, max_rel_update=0.0005332144386721777
# [DEBUG] entering step: T_old=16.11466810, dT=-2.31886749e-02
# [DEBUG] leaving step: T_new=16.09147943, rhs_norm=0.1381664534294801, channel_norm=0.43511733062824176, accepted_substeps=1, max_rel_update=0.000533982828945736
# [DEBUG] entering step: T_old=16.09147943, dT=-2.31553069e-02
# [DEBUG] leaving step: T_new=16.06832412, rhs_norm=0.1385649507187328, channel_norm=0.43832584458730656, accepted_substeps=1, max_rel_update=0.0005347523265107965
# [DEBUG] entering step: T_old=16.06832412, dT=-2.31219869e-02
# [DEBUG] leaving step: T_new=16.04520214, rhs_norm=0.13896459734695726, channel_norm=0.4415389821850789, accepted_substeps=1, max_rel_update=0.0005355229329620576
# [DEBUG] entering step: T_old=16.04520214, dT=-2.30887148e-02
# [DEBUG] leaving step: T_new=16.02211342, rhs_norm=0.1393653966290572, channel_norm=0.44475675008446885, accepted_substeps=1, max_rel_update=0.0005362946498983213
# [DEBUG] entering step: T_old=16.02211342, dT=-2.30554906e-02
# [DEBUG] leaving step: T_new=15.99905793, rhs_norm=0.13976735188949682, channel_norm=0.44797915495798685, accepted_substeps=1, max_rel_update=0.0005370674789196677
# [DEBUG] entering step: T_old=15.99905793, dT=-2.30223143e-02
# [DEBUG] leaving step: T_new=15.97603562, rhs_norm=0.140170466462329, channel_norm=0.45120620348775925, accepted_substeps=1, max_rel_update=0.0005378414216287353
# [DEBUG] entering step: T_old=15.97603562, dT=-2.29891856e-02
# [DEBUG] leaving step: T_new=15.95304643, rhs_norm=0.14057474369122244, channel_norm=0.4544379023655389, accepted_substeps=1, max_rel_update=0.0005386164796299393
# [DEBUG] entering step: T_old=15.95304643, dT=-2.29561047e-02
# [DEBUG] leaving step: T_new=15.93009033, rhs_norm=0.14098018692948952, channel_norm=0.45767425829272446, accepted_substeps=1, max_rel_update=0.0005393926545309308
# [DEBUG] entering step: T_old=15.93009033, dT=-2.29230713e-02
# [DEBUG] leaving step: T_new=15.90716725, rhs_norm=0.14138679954011416, channel_norm=0.46091527798037135, accepted_substeps=1, max_rel_update=0.0005401699479411533
# [DEBUG] entering step: T_old=15.90716725, dT=-2.28900855e-02
# [DEBUG] leaving step: T_new=15.88427717, rhs_norm=0.14179458489577984, channel_norm=0.46416096814920665, accepted_substeps=1, max_rel_update=0.000540948361472555
# [DEBUG] entering step: T_old=15.88427717, dT=-2.28571471e-02
# [DEBUG] leaving step: T_new=15.86142002, rhs_norm=0.14220354637889784, channel_norm=0.4674113355296392, accepted_substeps=1, max_rel_update=0.0005417278967387572
# [DEBUG] entering step: T_old=15.86142002, dT=-2.28242562e-02
# [DEBUG] leaving step: T_new=15.83859577, rhs_norm=0.14261368738163405, channel_norm=0.47066638686177986, accepted_substeps=1, max_rel_update=0.0005425085553567788
# [DEBUG] entering step: T_old=15.83859577, dT=-2.27914125e-02
# [DEBUG] leaving step: T_new=15.81580435, rhs_norm=0.1430250113059389, channel_norm=0.4739261288954516, accepted_substeps=1, max_rel_update=0.0005432903389452858
# [DEBUG] entering step: T_old=15.81580435, dT=-2.27586161e-02
# [DEBUG] leaving step: T_new=15.79304574, rhs_norm=0.14343752156357412, channel_norm=0.47719056839020496, accepted_substeps=1, max_rel_update=0.0005440732491255603
# [DEBUG] entering step: T_old=15.79304574, dT=-2.27258670e-02
# [DEBUG] leaving step: T_new=15.77031987, rhs_norm=0.14385122157614139, channel_norm=0.4804597121153279, accepted_substeps=1, max_rel_update=0.0005448572875204899
# [DEBUG] entering step: T_old=15.77031987, dT=-2.26931649e-02
# [DEBUG] leaving step: T_new=15.74762671, rhs_norm=0.14426611477511178, channel_norm=0.48373356684986735, accepted_substeps=1, max_rel_update=0.0005456424557565758
# [DEBUG] entering step: T_old=15.74762671, dT=-2.26605099e-02
# [DEBUG] leaving step: T_new=15.72496620, rhs_norm=0.14468220460185272, channel_norm=0.48701213938263715, accepted_substeps=1, max_rel_update=0.0005464287554616387
# [DEBUG] entering step: T_old=15.72496620, dT=-2.26279019e-02
# [DEBUG] leaving step: T_new=15.70233829, rhs_norm=0.1450994945076569, channel_norm=0.49029543651223634, accepted_substeps=1, max_rel_update=0.0005472161882665314
# [DEBUG] entering step: T_old=15.70233829, dT=-2.25953408e-02
# [DEBUG] leaving step: T_new=15.67974295, rhs_norm=0.14551798795377283, channel_norm=0.4935834650470567, accepted_substeps=1, max_rel_update=0.0005480047558033952
# [DEBUG] entering step: T_old=15.67974295, dT=-2.25628266e-02
# [DEBUG] leaving step: T_new=15.65718013, rhs_norm=0.1459376884114281, channel_norm=0.496876231805305, accepted_substeps=1, max_rel_update=0.0005487944597080515
# [DEBUG] entering step: T_old=15.65718013, dT=-2.25303592e-02
# [DEBUG] leaving step: T_new=15.63464977, rhs_norm=0.14635859936186685, channel_norm=0.5001737436150131, accepted_substeps=1, max_rel_update=0.0005495853016180232
# [DEBUG] entering step: T_old=15.63464977, dT=-2.24979384e-02
# [DEBUG] leaving step: T_new=15.61215183, rhs_norm=0.1467807242963701, channel_norm=0.5034760073140521, accepted_substeps=1, max_rel_update=0.000550377283173152
# [DEBUG] entering step: T_old=15.61215183, dT=-2.24655644e-02
# [DEBUG] leaving step: T_new=15.58968626, rhs_norm=0.14720406671629074, channel_norm=0.5067830297501446, accepted_substeps=1, max_rel_update=0.0005511704060154095
# [DEBUG] entering step: T_old=15.58968626, dT=-2.24332369e-02
# [DEBUG] leaving step: T_new=15.56725303, rhs_norm=0.14762863013307767, channel_norm=0.5100948177808842, accepted_substeps=1, max_rel_update=0.0005519646717899307
# [DEBUG] entering step: T_old=15.56725303, dT=-2.24009559e-02
# [DEBUG] leaving step: T_new=15.54485207, rhs_norm=0.14805441806831002, channel_norm=0.5134113782737447, accepted_substeps=1, max_rel_update=0.0005527600821434304
# [DEBUG] entering step: T_old=15.54485207, dT=-2.23687214e-02
# [DEBUG] leaving step: T_new=15.52248335, rhs_norm=0.14848143405372197, channel_norm=0.516732718106099, accepted_substeps=1, max_rel_update=0.0005535566387257204
# [DEBUG] entering step: T_old=15.52248335, dT=-2.23365333e-02
# [DEBUG] leaving step: T_new=15.50014682, rhs_norm=0.14890968163123502, channel_norm=0.5200588441652257, accepted_substeps=1, max_rel_update=0.000554354343187798
# [DEBUG] entering step: T_old=15.50014682, dT=-2.23043915e-02
# [DEBUG] leaving step: T_new=15.47784242, rhs_norm=0.14933916435298525, channel_norm=0.5233897633483332, accepted_substeps=1, max_rel_update=0.0005551531971845691
# [DEBUG] entering step: T_old=15.47784242, dT=-2.22722959e-02
# [DEBUG] leaving step: T_new=15.45557013, rhs_norm=0.14976988578135486, channel_norm=0.5267254825625668, accepted_substeps=1, max_rel_update=0.000555953202372269
# [DEBUG] entering step: T_old=15.45557013, dT=-2.22402465e-02
# [DEBUG] leaving step: T_new=15.43332988, rhs_norm=0.15020184948899964, channel_norm=0.5300660087250268, accepted_substeps=1, max_rel_update=0.0005567543604100024
# [DEBUG] entering step: T_old=15.43332988, dT=-2.22082433e-02
# [DEBUG] leaving step: T_new=15.41112164, rhs_norm=0.15063505905888022, channel_norm=0.5334113487627787, accepted_substeps=1, max_rel_update=0.0005575566729586486
# [DEBUG] entering step: T_old=15.41112164, dT=-2.21762861e-02
# [DEBUG] leaving step: T_new=15.38894535, rhs_norm=0.15106951808429045, channel_norm=0.5367615096128725, accepted_substeps=1, max_rel_update=0.0005583601416822856
# [DEBUG] entering step: T_old=15.38894535, dT=-2.21443749e-02
# [DEBUG] leaving step: T_new=15.36680098, rhs_norm=0.15150523016888834, channel_norm=0.5401164982223547, accepted_substeps=1, max_rel_update=0.0005591647682470469
# [DEBUG] entering step: T_old=15.36680098, dT=-2.21125096e-02
# [DEBUG] leaving step: T_new=15.34468847, rhs_norm=0.15194219892672553, channel_norm=0.543476321548284, accepted_substeps=1, max_rel_update=0.0005599705543215266
# [DEBUG] entering step: T_old=15.34468847, dT=-2.20806901e-02
# [DEBUG] leaving step: T_new=15.32260778, rhs_norm=0.15238042798227758, channel_norm=0.54684098655774, accepted_substeps=1, max_rel_update=0.0005607775015760211
# [DEBUG] entering step: T_old=15.32260778, dT=-2.20489165e-02
# [DEBUG] leaving step: T_new=15.30055886, rhs_norm=0.1528199209704731, channel_norm=0.5502105002278471, accepted_substeps=1, max_rel_update=0.0005615856116845139
# [DEBUG] entering step: T_old=15.30055886, dT=-2.20171885e-02
# [DEBUG] leaving step: T_new=15.27854167, rhs_norm=0.15326068153672456, channel_norm=0.5535848695457831, accepted_substeps=1, max_rel_update=0.0005623948863226612
# [DEBUG] entering step: T_old=15.27854167, dT=-2.19855062e-02
# [DEBUG] leaving step: T_new=15.25655617, rhs_norm=0.15370271333695834, channel_norm=0.556964101508792, accepted_substeps=1, max_rel_update=0.0005632053271681514
# [DEBUG] entering step: T_old=15.25655617, dT=-2.19538695e-02
# [DEBUG] leaving step: T_new=15.23460230, rhs_norm=0.15414602003764588, channel_norm=0.5603482031242043, accepted_substeps=1, max_rel_update=0.0005640169359020337
# [DEBUG] entering step: T_old=15.23460230, dT=-2.19222784e-02
# [DEBUG] leaving step: T_new=15.21268002, rhs_norm=0.1545906053158329, channel_norm=0.5637371814094468, accepted_substeps=1, max_rel_update=0.0005648297142070858
# [DEBUG] entering step: T_old=15.21268002, dT=-2.18907327e-02
# [DEBUG] leaving step: T_new=15.19078929, rhs_norm=0.15503647285917058, channel_norm=0.5671310433920598, accepted_substeps=1, max_rel_update=0.0005656436637688239
# [DEBUG] entering step: T_old=15.19078929, dT=-2.18592324e-02
# [DEBUG] leaving step: T_new=15.16893005, rhs_norm=0.1554836263659454, channel_norm=0.5705297961097109, accepted_substeps=1, max_rel_update=0.000566458786275189
# [DEBUG] entering step: T_old=15.16893005, dT=-2.18277774e-02
# [DEBUG] leaving step: T_new=15.14710228, rhs_norm=0.15593206954511152, channel_norm=0.5739334466102064, accepted_substeps=1, max_rel_update=0.0005672750834159137
# [DEBUG] entering step: T_old=15.14710228, dT=-2.17963677e-02
# [DEBUG] leaving step: T_new=15.12530591, rhs_norm=0.1563818061163186, channel_norm=0.577342001951512, accepted_substeps=1, max_rel_update=0.0005680925568842689
# [DEBUG] entering step: T_old=15.12530591, dT=-2.17650031e-02
# [DEBUG] leaving step: T_new=15.10354091, rhs_norm=0.15683283980994692, channel_norm=0.5807554692017648, accepted_substeps=1, max_rel_update=0.0005689112083754767
# [DEBUG] entering step: T_old=15.10354091, dT=-2.17336837e-02
# [DEBUG] leaving step: T_new=15.08180722, rhs_norm=0.15728517436713313, channel_norm=0.5841738554392832, accepted_substeps=1, max_rel_update=0.0005697310395864126
# [DEBUG] entering step: T_old=15.08180722, dT=-2.17024094e-02
# [DEBUG] leaving step: T_new=15.06010481, rhs_norm=0.1577388135398061, channel_norm=0.5875971677525904, accepted_substeps=1, max_rel_update=0.0005705520522178598
# [DEBUG] entering step: T_old=15.06010481, dT=-2.16711801e-02
# [DEBUG] leaving step: T_new=15.03843363, rhs_norm=0.15819376109071484, channel_norm=0.5910254132404223, accepted_substeps=1, max_rel_update=0.0005713742479719976
# [DEBUG] entering step: T_old=15.03843363, dT=-2.16399957e-02
# [DEBUG] leaving step: T_new=15.01679364, rhs_norm=0.158650020793462, channel_norm=0.5944585990117452, accepted_substeps=1, max_rel_update=0.0005721976285538094
# [DEBUG] entering step: T_old=15.01679364, dT=-2.16088562e-02
# [DEBUG] leaving step: T_new=14.99518478, rhs_norm=0.15910759643253186, channel_norm=0.5978967321857707, accepted_substeps=1, max_rel_update=0.0005730221956708952
# [DEBUG] entering step: T_old=14.99518478, dT=-2.15777615e-02
# [DEBUG] leaving step: T_new=14.97360702, rhs_norm=0.1595664918033263, channel_norm=0.6013398198919657, accepted_substeps=1, max_rel_update=0.0005738479510325056
# [DEBUG] entering step: T_old=14.97360702, dT=-2.15467116e-02
# [DEBUG] leaving step: T_new=14.95206031, rhs_norm=0.16002671071219166, channel_norm=0.6047878692700751, accepted_substeps=1, max_rel_update=0.0005746748963515575
# [DEBUG] entering step: T_old=14.95206031, dT=-2.15157063e-02
# [DEBUG] leaving step: T_new=14.93054460, rhs_norm=0.16048825697645475, channel_norm=0.6082408874701323, accepted_substeps=1, max_rel_update=0.000575503033342869
# [DEBUG] entering step: T_old=14.93054460, dT=-2.14847456e-02
# [DEBUG] leaving step: T_new=14.90905986, rhs_norm=0.16095113442444964, channel_norm=0.6116988816524709, accepted_substeps=1, max_rel_update=0.0005763323637230935
# [DEBUG] entering step: T_old=14.90905986, dT=-2.14538295e-02
# [DEBUG] leaving step: T_new=14.88760603, rhs_norm=0.16141534689555448, channel_norm=0.6151618589877462, accepted_substeps=1, max_rel_update=0.0005771628892125511
# [DEBUG] entering step: T_old=14.88760603, dT=-2.14229579e-02
# [DEBUG] leaving step: T_new=14.86618307, rhs_norm=0.16188089824021887, channel_norm=0.6186298266569455, accepted_substeps=1, max_rel_update=0.0005779946115332253
# [DEBUG] entering step: T_old=14.86618307, dT=-2.13921307e-02
# [DEBUG] leaving step: T_new=14.84479094, rhs_norm=0.16234779231999935, channel_norm=0.622102791851405, accepted_substeps=1, max_rel_update=0.0005788275324099232
# [DEBUG] entering step: T_old=14.84479094, dT=-2.13613479e-02
# [DEBUG] leaving step: T_new=14.82342959, rhs_norm=0.1628160330075887, channel_norm=0.6255807617728247, accepted_substeps=1, max_rel_update=0.0005796616535699415
# [DEBUG] entering step: T_old=14.82342959, dT=-2.13306093e-02
# [DEBUG] leaving step: T_new=14.80209898, rhs_norm=0.16328562418685097, channel_norm=0.6290637436332789, accepted_substeps=1, max_rel_update=0.0005804969767423583
# [DEBUG] entering step: T_old=14.80209898, dT=-2.12999150e-02
# [DEBUG] leaving step: T_new=14.78079907, rhs_norm=0.1637565697528495, channel_norm=0.6325517446552387, accepted_substeps=1, max_rel_update=0.0005813335036599553
# [DEBUG] entering step: T_old=14.78079907, dT=-2.12692649e-02
# [DEBUG] leaving step: T_new=14.75952980, rhs_norm=0.16422887361188354, channel_norm=0.6360447720715832, accepted_substeps=1, max_rel_update=0.000582171236057409
# [DEBUG] entering step: T_old=14.75952980, dT=-2.12386589e-02
# [DEBUG] leaving step: T_new=14.73829114, rhs_norm=0.16470253968151857, channel_norm=0.6395428331256102, accepted_substeps=1, max_rel_update=0.0005830101756711853
# [DEBUG] entering step: T_old=14.73829114, dT=-2.12080969e-02
# [DEBUG] leaving step: T_new=14.71708304, rhs_norm=0.1651775718906185, channel_norm=0.6430459350710603, accepted_substeps=1, max_rel_update=0.0005838503242416867
# [DEBUG] entering step: T_old=14.71708304, dT=-2.11775789e-02
# [DEBUG] leaving step: T_new=14.69590547, rhs_norm=0.1656539741793786, channel_norm=0.6465540851721253, accepted_substeps=1, max_rel_update=0.0005846916835108295
# [DEBUG] entering step: T_old=14.69590547, dT=-2.11471048e-02
# ...
# [DEBUG] entering step: T_old=2.20575146, dT=-3.17403084e-03
# [DEBUG] leaving step: T_new=2.20257743, rhs_norm=7.374493393515152, channel_norm=14.474910338034219, accepted_substeps=1, max_rel_update=0.001619684034318006
# [DEBUG] entering step: T_old=2.20257743, dT=-3.16946347e-03
# [DEBUG] leaving step: T_new=2.19940796, rhs_norm=7.395762779491166, channel_norm=14.49835093801393, accepted_substeps=1, max_rel_update=0.0016193951763637674
# [DEBUG] entering step: T_old=2.19940796, dT=-3.16490268e-03
# [DEBUG] leaving step: T_new=2.19624306, rhs_norm=7.417093510261378, channel_norm=14.521825317140882, accepted_substeps=1, max_rel_update=0.0016191068368612111
# [DEBUG] entering step: T_old=2.19624306, dT=-3.16034845e-03
# [DEBUG] leaving step: T_new=2.19308271, rhs_norm=7.438485762755438, channel_norm=14.545333524092609, accepted_substeps=1, max_rel_update=0.0016188190147128942
# [DEBUG] entering step: T_old=2.19308271, dT=-3.15580077e-03
# [DEBUG] leaving step: T_new=2.18992691, rhs_norm=7.459939714413217, channel_norm=14.568875607616803, accepted_substeps=1, max_rel_update=0.0016185317088261147
# [DEBUG] entering step: T_old=2.18992691, dT=-3.15125964e-03
# [DEBUG] leaving step: T_new=2.18677565, rhs_norm=7.481455543186347, channel_norm=14.592451616531402, accepted_substeps=1, max_rel_update=0.0016182449181097473
# [DEBUG] entering step: T_old=2.18677565, dT=-3.14672504e-03
# [DEBUG] leaving step: T_new=2.18362893, rhs_norm=7.503033427539756, channel_norm=14.616061599724691, accepted_substeps=1, max_rel_update=0.0016179586414760737
# [DEBUG] entering step: T_old=2.18362893, dT=-3.14219697e-03
# [DEBUG] leaving step: T_new=2.18048673, rhs_norm=7.524673546453078, channel_norm=14.639705606155406, accepted_substeps=1, max_rel_update=0.0016176728778400879
# [DEBUG] entering step: T_old=2.18048673, dT=-3.13767542e-03
# [DEBUG] leaving step: T_new=2.17734905, rhs_norm=7.546376079422143, channel_norm=14.663383684852837, accepted_substeps=1, max_rel_update=0.0016173876261197256
# [DEBUG] entering step: T_old=2.17734905, dT=-3.13316036e-03
# [DEBUG] leaving step: T_new=2.17421589, rhs_norm=7.568141206460491, channel_norm=14.687095884916927, accepted_substeps=1, max_rel_update=0.0016171028852354128
# [DEBUG] entering step: T_old=2.17421589, dT=-3.12865181e-03
# [DEBUG] leaving step: T_new=2.17108724, rhs_norm=7.589969108100851, channel_norm=14.71084225551837, accepted_substeps=1, max_rel_update=0.0016168186541105213
# [DEBUG] entering step: T_old=2.17108724, dT=-3.12414975e-03
# [DEBUG] leaving step: T_new=2.16796309, rhs_norm=7.611859965396625, channel_norm=14.73462284589873, accepted_substeps=1, max_rel_update=0.0016165349316718265
# [DEBUG] entering step: T_old=2.16796309, dT=-3.11965416e-03
# [DEBUG] leaving step: T_new=2.16484344, rhs_norm=7.6338139599234305, channel_norm=14.758437705370515, accepted_substeps=1, max_rel_update=0.0016162517168474512
# [DEBUG] entering step: T_old=2.16484344, dT=-3.11516504e-03
# [DEBUG] leaving step: T_new=2.16172827, rhs_norm=7.655831273780611, channel_norm=14.782286883317306, accepted_substeps=1, max_rel_update=0.0016159690085700827
# [DEBUG] entering step: T_old=2.16172827, dT=-3.11068238e-03
# [DEBUG] leaving step: T_new=2.15861759, rhs_norm=7.67791208959261, channel_norm=14.806170429193841, accepted_substeps=1, max_rel_update=0.0016156868057734966
# [DEBUG] entering step: T_old=2.15861759, dT=-3.10620618e-03
# [DEBUG] leaving step: T_new=2.15551138, rhs_norm=7.700056590510714, channel_norm=14.830088392526138, accepted_substeps=1, max_rel_update=0.0016154051073960618
# [DEBUG] entering step: T_old=2.15551138, dT=-3.10173641e-03
# [DEBUG] leaving step: T_new=2.15240965, rhs_norm=7.722264960214408, channel_norm=14.85404082291156, accepted_substeps=1, max_rel_update=0.0016151239123763203
# [DEBUG] entering step: T_old=2.15240965, dT=-3.09727307e-03
# [DEBUG] leaving step: T_new=2.14931237, rhs_norm=7.744537382912919, channel_norm=14.878027770018978, accepted_substeps=1, max_rel_update=0.0016148432196590034
# [DEBUG] entering step: T_old=2.14931237, dT=-3.09281616e-03
# [DEBUG] leaving step: T_new=2.14621956, rhs_norm=7.766874043346787, channel_norm=14.902049283588797, accepted_substeps=1, max_rel_update=0.0016145630281874043
# [DEBUG] entering step: T_old=2.14621956, dT=-3.08836566e-03
# [DEBUG] leaving step: T_new=2.14313119, rhs_norm=7.789275126789363, channel_norm=14.926105413433138, accepted_substeps=1, max_rel_update=0.0016142833369121772
# [DEBUG] entering step: T_old=2.14313119, dT=-3.08392157e-03
# [DEBUG] leaving step: T_new=2.14004727, rhs_norm=7.811740819048385, channel_norm=14.95019620943588, accepted_substeps=1, max_rel_update=0.0016140041447825343
# [DEBUG] entering step: T_old=2.14004727, dT=-3.07948387e-03
# [DEBUG] leaving step: T_new=2.13696779, rhs_norm=7.834271306467495, channel_norm=14.974321721552798, accepted_substeps=1, max_rel_update=0.0016137254507529706
# [DEBUG] entering step: T_old=2.13696779, dT=-3.07505256e-03
# [DEBUG] leaving step: T_new=2.13389273, rhs_norm=7.85686677592774, channel_norm=14.998481999811649, accepted_substeps=1, max_rel_update=0.001613447253779542
# [DEBUG] entering step: T_old=2.13389273, dT=-3.07062762e-03
# [DEBUG] leaving step: T_new=2.13082211, rhs_norm=7.87952741484921, channel_norm=15.02267709431229, accepted_substeps=1, max_rel_update=0.0016131695528217452
# [DEBUG] entering step: T_old=2.13082211, dT=-3.06620905e-03
# [DEBUG] leaving step: T_new=2.12775590, rhs_norm=7.902253411192518, channel_norm=15.046907055226768, accepted_substeps=1, max_rel_update=0.001612892346840871
# [DEBUG] entering step: T_old=2.12775590, dT=-3.06179684e-03
# [DEBUG] leaving step: T_new=2.12469410, rhs_norm=7.925044953460436, channel_norm=15.071171932799441, accepted_substeps=1, max_rel_update=0.0016126156348021245
# [DEBUG] entering step: T_old=2.12469410, dT=-3.05739097e-03
# [DEBUG] leaving step: T_new=2.12163671, rhs_norm=7.947902230699396, channel_norm=15.095471777347056, accepted_substeps=1, max_rel_update=0.0016123394156715729
# [DEBUG] entering step: T_old=2.12163671, dT=-3.05299145e-03
# [DEBUG] leaving step: T_new=2.11858372, rhs_norm=7.970825432501008, channel_norm=15.119806639258881, accepted_substeps=1, max_rel_update=0.0016120636884196476
# [DEBUG] entering step: T_old=2.11858372, dT=-3.04859826e-03
# [DEBUG] leaving step: T_new=2.11553512, rhs_norm=7.993814749003779, channel_norm=15.144176568996796, accepted_substeps=1, max_rel_update=0.0016117884520188345
# [DEBUG] entering step: T_old=2.11553512, dT=-3.04421139e-03
# [DEBUG] leaving step: T_new=2.11249091, rhs_norm=8.016870370894598, channel_norm=15.168581617095397, accepted_substeps=1, max_rel_update=0.0016115137054438895
# [DEBUG] entering step: T_old=2.11249091, dT=-3.03983083e-03
# [DEBUG] leaving step: T_new=2.10945108, rhs_norm=8.039992489410285, channel_norm=15.193021834162098, accepted_substeps=1, max_rel_update=0.0016112394476723033
# [DEBUG] entering step: T_old=2.10945108, dT=-3.03545658e-03
# [DEBUG] leaving step: T_new=2.10641562, rhs_norm=8.063181296339286, channel_norm=15.217497270877255, accepted_substeps=1, max_rel_update=0.0016109656776852669
# [DEBUG] entering step: T_old=2.10641562, dT=-3.03108862e-03
# [DEBUG] leaving step: T_new=2.10338453, rhs_norm=8.086436984023143, channel_norm=15.24200797799424, accepted_substeps=1, max_rel_update=0.001610692394464351
# [DEBUG] entering step: T_old=2.10338453, dT=-3.02672695e-03
# [DEBUG] leaving step: T_new=2.10035781, rhs_norm=8.109759745358183, channel_norm=15.266554006339582, accepted_substeps=1, max_rel_update=0.001610419596996714
# [DEBUG] entering step: T_old=2.10035781, dT=-3.02237155e-03
# [DEBUG] leaving step: T_new=2.09733543, rhs_norm=8.133149773797065, channel_norm=15.291135406813032, accepted_substeps=1, max_rel_update=0.0016101472842687205
# [DEBUG] entering step: T_old=2.09733543, dT=-3.01802242e-03
# [DEBUG] leaving step: T_new=2.09431741, rhs_norm=8.156607263350404, channel_norm=15.315752230387712, accepted_substeps=1, max_rel_update=0.0016098754552727984
# [DEBUG] entering step: T_old=2.09431741, dT=-3.01367955e-03
# [DEBUG] leaving step: T_new=2.09130373, rhs_norm=8.180132408588356, channel_norm=15.340404528110183, accepted_substeps=1, max_rel_update=0.001609604109000813
# [DEBUG] entering step: T_old=2.09130373, dT=-3.00934292e-03
# [DEBUG] leaving step: T_new=2.08829439, rhs_norm=8.20372540464231, channel_norm=15.365092351100575, accepted_substeps=1, max_rel_update=0.0016093332444495313
# [DEBUG] entering step: T_old=2.08829439, dT=-3.00501254e-03
# [DEBUG] leaving step: T_new=2.08528938, rhs_norm=8.22738644720637, channel_norm=15.389815750552678, accepted_substeps=1, max_rel_update=0.0016090628606168025
# [DEBUG] entering step: T_old=2.08528938, dT=-3.00068839e-03
# [DEBUG] leaving step: T_new=2.08228869, rhs_norm=8.251115732539136, channel_norm=15.414574777734066, accepted_substeps=1, max_rel_update=0.0016087929565042035
# [DEBUG] entering step: T_old=2.08228869, dT=-2.99637046e-03
# [DEBUG] leaving step: T_new=2.07929232, rhs_norm=8.274913457465198, channel_norm=15.439369483986177, accepted_substeps=1, max_rel_update=0.0016085235311146364
# [DEBUG] entering step: T_old=2.07929232, dT=-2.99205875e-03
# [DEBUG] leaving step: T_new=2.07630026, rhs_norm=8.298779819376879, channel_norm=15.464199920724456, accepted_substeps=1, max_rel_update=0.0016082545834552099
# [DEBUG] entering step: T_old=2.07630026, dT=-2.98775324e-03
# [DEBUG] leaving step: T_new=2.07331251, rhs_norm=8.322715016235728, channel_norm=15.489066139438414, accepted_substeps=1, max_rel_update=0.0016079861125329199
# [DEBUG] entering step: T_old=2.07331251, dT=-2.98345392e-03
# [DEBUG] leaving step: T_new=2.07032905, rhs_norm=8.346719246574345, channel_norm=15.513968191691786, accepted_substeps=1, max_rel_update=0.0016077181173606559
# [DEBUG] entering step: T_old=2.07032905, dT=-2.97916079e-03
# [DEBUG] leaving step: T_new=2.06734989, rhs_norm=8.370792709497882, channel_norm=15.538906129122593, accepted_substeps=1, max_rel_update=0.0016074505969504835
# [DEBUG] entering step: T_old=2.06734989, dT=-2.97487384e-03
# [DEBUG] leaving step: T_new=2.06437502, rhs_norm=8.39493560468579, channel_norm=15.563880003443288, accepted_substeps=1, max_rel_update=0.0016071835503201246
# [DEBUG] entering step: T_old=2.06437502, dT=-2.97059306e-03
# [DEBUG] leaving step: T_new=2.06140442, rhs_norm=8.41914813239334, channel_norm=15.588889866440823, accepted_substeps=1, max_rel_update=0.0016069169764867054
# [DEBUG] entering step: T_old=2.06140442, dT=-2.96631844e-03
# [DEBUG] leaving step: T_new=2.05843811, rhs_norm=8.443430493453466, channel_norm=15.6139357699768, accepted_substeps=1, max_rel_update=0.0016066508744727887
# [DEBUG] entering step: T_old=2.05843811, dT=-2.96204996e-03
# [DEBUG] leaving step: T_new=2.05547606, rhs_norm=8.467782889278336, channel_norm=15.639017765987534, accepted_substeps=1, max_rel_update=0.0016063852433005944
# [DEBUG] entering step: T_old=2.05547606, dT=-2.95778764e-03
# [DEBUG] leaving step: T_new=2.05251827, rhs_norm=8.492205521860988, channel_norm=15.664135906484207, accepted_substeps=1, max_rel_update=0.0016061200819977683
# [DEBUG] entering step: T_old=2.05251827, dT=-2.95353144e-03
# [DEBUG] leaving step: T_new=2.04956474, rhs_norm=8.516698593777067, channel_norm=15.68929024355293, accepted_substeps=1, max_rel_update=0.0016058553895916137
# [DEBUG] entering step: T_old=2.04956474, dT=-2.94928137e-03
# [DEBUG] leaving step: T_new=2.04661546, rhs_norm=8.54126230818647, channel_norm=15.71448082935489, accepted_substeps=1, max_rel_update=0.0016055911651141539
# [DEBUG] entering step: T_old=2.04661546, dT=-2.94503741e-03
# [DEBUG] leaving step: T_new=2.04367042, rhs_norm=8.565896868835045, channel_norm=15.739707716126423, accepted_substeps=1, max_rel_update=0.0016053274075977866
# [DEBUG] entering step: T_old=2.04367042, dT=-2.94079957e-03
# [DEBUG] leaving step: T_new=2.04072962, rhs_norm=8.590602480056287, channel_norm=15.764970956179159, accepted_substeps=1, max_rel_update=0.0016050641160796437
# [DEBUG] entering step: T_old=2.04072962, dT=-2.93656782e-03
# [DEBUG] leaving step: T_new=2.03779305, rhs_norm=8.615379346773041, channel_norm=15.790270601900097, accepted_substeps=1, max_rel_update=0.0016048012895972354
# [DEBUG] entering step: T_old=2.03779305, dT=-2.93234216e-03
# [DEBUG] leaving step: T_new=2.03486071, rhs_norm=8.640227674499153, channel_norm=15.815606705751746, accepted_substeps=1, max_rel_update=0.001604538927192322
# [DEBUG] entering step: T_old=2.03486071, dT=-2.92812258e-03
# [DEBUG] leaving step: T_new=2.03193259, rhs_norm=8.665147669341254, channel_norm=15.840979320272192, accepted_substeps=1, max_rel_update=0.0016042770279068041
# [DEBUG] entering step: T_old=2.03193259, dT=-2.92390907e-03
# [DEBUG] leaving step: T_new=2.02900868, rhs_norm=8.690139538000352, channel_norm=15.866388498075256, accepted_substeps=1, max_rel_update=0.001604015590787809
# [DEBUG] entering step: T_old=2.02900868, dT=-2.91970162e-03
# [DEBUG] leaving step: T_new=2.02608898, rhs_norm=8.71520348777372, channel_norm=15.891834291850554, accepted_substeps=1, max_rel_update=0.0016037546148818813
# [DEBUG] entering step: T_old=2.02608898, dT=-2.91550023e-03
# [DEBUG] leaving step: T_new=2.02317348, rhs_norm=8.740339726556412, channel_norm=15.917316754363656, accepted_substeps=1, max_rel_update=0.001603494099241287
# [DEBUG] entering step: T_old=2.02317348, dT=-2.91130489e-03
# [DEBUG] leaving step: T_new=2.02026217, rhs_norm=8.765548462843158, channel_norm=15.942835938456147, accepted_substeps=1, max_rel_update=0.0016032340429172152
# [DEBUG] entering step: T_old=2.02026217, dT=-2.90711558e-03
# [DEBUG] leaving step: T_new=2.01735506, rhs_norm=8.790829905730009, channel_norm=15.968391897045775, accepted_substeps=1, max_rel_update=0.0016029744449658678
# [DEBUG] entering step: T_old=2.01735506, dT=-2.90293230e-03
# [DEBUG] leaving step: T_new=2.01445212, rhs_norm=8.81618426491606, channel_norm=15.993984683126538, accepted_substeps=1, max_rel_update=0.001602715304444553
# [DEBUG] entering step: T_old=2.01445212, dT=-2.89875504e-03
# [DEBUG] leaving step: T_new=2.01155337, rhs_norm=8.84161175070523, channel_norm=16.019614349768805, accepted_substeps=1, max_rel_update=0.0016024566204134046
# [DEBUG] entering step: T_old=2.01155337, dT=-2.89458379e-03
# [DEBUG] leaving step: T_new=2.00865878, rhs_norm=8.867112574008022, channel_norm=16.045280950119416, accepted_substeps=1, max_rel_update=0.0016021983919346546
# [DEBUG] entering step: T_old=2.00865878, dT=-2.89041855e-03
# [DEBUG] leaving step: T_new=2.00576837, rhs_norm=8.892686946343204, channel_norm=16.07098453740181, accepted_substeps=1, max_rel_update=0.0016019406180733595
# [DEBUG] entering step: T_old=2.00576837, dT=-2.88625929e-03
# [DEBUG] leaving step: T_new=2.00288211, rhs_norm=8.918335079839672, channel_norm=16.096725164916105, accepted_substeps=1, max_rel_update=0.0016016832978956984
# [DEBUG] entering step: T_old=2.00288211, dT=-2.88210603e-03
# [DEBUG] leaving step: T_new=2.00000000, rhs_norm=8.944057187238005, channel_norm=16.122502886039257, accepted_substeps=1, max_rel_update=0.001601426430472637
# history length = 1600
# instability record = None
# ===== Final record =====
# {'accepted_substeps': 1,
#  'channel_norm': 16.122502886039257,
#  'dT': -0.0028821060267740783,
#  'diagnosis_payload': {'basis_labels': ['ud', 'du'],
#                        'dominant_spin_structure': 'singlet',
#                        'geometry': 'pp',
#                        'hermitian_residual': 2.6788727698574573e-37,
#                        'leading_eigenvalue': (24.000000000000007+7.767932764930215e-38j),
#                        'leading_eigenvalue_abs': 24.000000000000007,
#                        'mother_kernel': 'pp_mother_sz0',
#                        'singlet_weight': 1.0,
#                        'sort_by': 'abs',
#                        'triplet_weight': 6.382652206320823e-32},
#  'instability': False,
#  'instability_reason': None,
#  'leading_Q': [0.0, 0.0],
#  'leading_channel_name': 'pp_mother_sz0',
#  'leading_eigenvalue_abs': 24.000000000000007,
#  'leading_order_label': None,
#  'max_rel_update': 0.001601426430472637,
#  'rhs_norm': 8.944057187238005,
#  'step_index': 1599,
#  'temperature': 2.0,
#  'terminated_early': False,
#  'termination_reason': None}

# %%
import numpy as np
import matplotlib.pyplot as plt

Qs_to_check = FLOW_KWARGS["diagnosis_Qs"]
# 如果你想继续测试 Q -> Q+G 不变性，再手动加 reciprocal vector
# Qs_to_check = FLOW_KWARGS["diagnosis_Qs"] + 5*np.array([np.pi, np.pi/np.sqrt(3)]) + np.array([0,2*np.pi/np.sqrt(3)])

solver = fm_result["solver"]

mother_channels = [
    "pp_mother_sz0",
    "ph_mother_longitudinal",
]

print("===== Final-state mother-channel diagnosis across all Q =====")
Q_summary = []

for i, Q in enumerate(Qs_to_check):
    Q = np.asarray(Q, dtype=float)
    mothers = solver.build_mother_kernel_dict(Q)

    print(f"\n===== Q[{i}] = {Q} =====")
    row = {
        "Q_index": i,
        "Q_vec": Q,
    }

    vals_dict = {}
    for name in mother_channels:
        k = mothers[name]
        vals, vecs = k.eig(sort_by="abs")
        eigmax = abs(vals[0])
        vals_dict[name] = eigmax
        row[name] = float(eigmax)
        print(f"{name:24s} |eig|max = {eigmax:.8g}")

    lead_name = max(vals_dict, key=vals_dict.get)
    row["leading_geometry"] = lead_name
    row["leading_value"] = vals_dict[lead_name]
    Q_summary.append(row)

    print(f"--> leading mother channel at this Q: {lead_name}  (|eig|max = {vals_dict[lead_name]:.8g})")

print(Q_summary)
labels = [f"Q{i}" for i in range(len(Q_summary))]
x = np.arange(len(labels))
width = 0.35

pp_vals = [row["pp_mother_sz0"] for row in Q_summary]
ph_vals = [row["ph_mother_longitudinal"] for row in Q_summary]

plt.figure(figsize=(8, 5))
plt.bar(x - width/2, pp_vals, width, label="pp_mother_sz0")
plt.bar(x + width/2, ph_vals, width, label="ph_mother_longitudinal")

plt.xticks(x, labels)
plt.ylabel("|leading eigenvalue|")
plt.title("Final mother-channel diagnosis across Q")
plt.legend()
plt.show()

# ----------------------------------------
Q = np.array([0.0, 0.0])
mothers = solver.build_mother_kernel_dict(Q)

for name in ["pp_mother_sz0", "ph_mother_longitudinal"]:
    k = mothers[name]
    vals, vecs = k.eig(sort_by="abs")
    print(f"\n==== {name} ====")
    print("Q =", k.Q)
    print("|eig|max =", abs(vals[0]))
    print("vec.real =", np.real(vecs[:, 0]))
    print("vec.abs  =", np.abs(vecs[:, 0]))
    print(f"\n==== {name} ====")
    print("Q =", k.Q)
    print("second |eig|max =", abs(vals[1]))
    print("vec.real =", np.real(vecs[:, 1]))
    print("vec.abs  =", np.abs(vecs[:, 1]))
# Out:
# ===== Final-state mother-channel diagnosis across all Q =====
#
# ===== Q[0] = [0. 0.] =====
# pp_mother_sz0            |eig|max = 24
# ph_mother_longitudinal   |eig|max = 12
# --> leading mother channel at this Q: pp_mother_sz0  (|eig|max = 24)
#
# ===== Q[1] = [0.         1.81379936] =====
# pp_mother_sz0            |eig|max = 9.5861545e-30
# ph_mother_longitudinal   |eig|max = 1.9171074e-29
# --> leading mother channel at this Q: ph_mother_longitudinal  (|eig|max = 1.9171074e-29)
#
# ===== Q[2] = [1.57079633 0.90689968] =====
# pp_mother_sz0            |eig|max = 7.5704358e-29
# ph_mother_longitudinal   |eig|max = 1.5139896e-28
# --> leading mother channel at this Q: ph_mother_longitudinal  (|eig|max = 1.5139896e-28)
#
# ===== Q[3] = [-1.57079633  0.90689968] =====
# pp_mother_sz0            |eig|max = 7.5704358e-29
# ph_mother_longitudinal   |eig|max = 1.5139896e-28
# --> leading mother channel at this Q: ph_mother_longitudinal  (|eig|max = 1.5139896e-28)
# [{'Q_index': 0, 'Q_vec': array([0., 0.]), 'pp_mother_sz0': 24.000000000000007, 'ph_mother_longitudinal': 12.0, 'leading_geometry': 'pp_mother_sz0', 'leading_value': np.float64(24.000000000000007)}, {'Q_index': 1, 'Q_vec': array([0.        , 1.81379936]), 'pp_mother_sz0': 9.586154462250143e-30, 'ph_mother_longitudinal': 1.91710735960925e-29, 'leading_geometry': 'ph_mother_longitudinal', 'leading_value': np.float64(1.91710735960925e-29)}, {'Q_index': 2, 'Q_vec': array([1.57079633, 0.90689968]), 'pp_mother_sz0': 7.570435845219364e-29, 'ph_mother_longitudinal': 1.513989611942161e-28, 'leading_geometry': 'ph_mother_longitudinal', 'leading_value': np.float64(1.513989611942161e-28)}, {'Q_index': 3, 'Q_vec': array([-1.57079633,  0.90689968]), 'pp_mother_sz0': 7.570435845219357e-29, 'ph_mother_longitudinal': 1.5139896119421617e-28, 'leading_geometry': 'ph_mother_longitudinal', 'leading_value': np.float64(1.5139896119421617e-28)}]
# ==== pp_mother_sz0 ====
# Q = [0. 0.]
# |eig|max = 24.000000000000007
# vec.real = [ 0.01193177 -0.04478485  0.49784732  0.01193177 -0.04478485  0.49784732
#  -0.01193177  0.04478485 -0.49784732 -0.01193177  0.04478485 -0.49784732]
# vec.abs  = [0.01193177 0.04478485 0.49784732 0.01193177 0.04478485 0.49784732
#  0.01193177 0.04478485 0.49784732 0.01193177 0.04478485 0.49784732]
#
# ==== pp_mother_sz0 ====
# Q = [0. 0.]
# second |eig|max = 24.000000000000004
# vec.real = [ 5.00000000e-01  2.28153182e-16  4.12246113e-31  5.00000000e-01
#  -7.60510606e-17  3.89500914e-31 -5.00000000e-01  7.60510606e-17
#  -3.89500914e-31 -5.00000000e-01  7.60510606e-17 -3.89500914e-31]
# vec.abs  = [5.00000000e-01 2.28153182e-16 4.12246113e-31 5.00000000e-01
#  7.60510606e-17 3.89500914e-31 5.00000000e-01 7.60510606e-17
#  3.89500914e-31 5.00000000e-01 7.60510606e-17 3.89500914e-31]
#
# ==== ph_mother_longitudinal ====
# Q = [0. 0.]
# |eig|max = 12.0
# vec.real = [ 5.00000000e-01 -9.18967570e-17 -8.96333494e-31  5.00000000e-01
#  -2.50565734e-17 -8.95298731e-31  5.00000000e-01 -4.17836103e-17
#  -8.95433090e-31  5.00000000e-01 -4.17836103e-17 -8.95433090e-31]
# vec.abs  = [5.00000000e-01 9.18967570e-17 8.96333494e-31 5.00000000e-01
#  2.50565734e-17 8.95298731e-31 5.00000000e-01 4.17836103e-17
#  8.95433090e-31 5.00000000e-01 4.17836103e-17 8.95433090e-31]
#
# ==== ph_mother_longitudinal ====
# Q = [0. 0.]
# second |eig|max = 11.999999999999995
# vec.real = [ 4.99491075e-01  2.25536274e-02  2.59679229e-16  4.99491075e-01
#   2.25536274e-02  2.59962012e-16 -4.99491075e-01 -2.25536274e-02
#  -2.63749994e-16 -4.99491075e-01 -2.25536274e-02 -2.63749994e-16]
# vec.abs  = [4.99491075e-01 2.25536274e-02 2.59679229e-16 4.99491075e-01
#  2.25536274e-02 2.59962012e-16 4.99491075e-01 2.25536274e-02
#  2.63749994e-16 4.99491075e-01 2.25536274e-02 2.63749994e-16]

# %% [markdown]
# ## 5. PI benchmark: `U=0, V=6`
#
# Expectation from the PRL benchmark at van Hove filling:
# - dominant nearest-neighbor repulsion should favor **Pomeranchuk instability (PI)** with d-wave character.
#
# If this still does **not** look PI-like, then the likely next suspects are:
# - `form_factor.py`
# - `kagome_order_diagnosis.py`

# %%
pi_result = run_case("PI benchmark", U=.0, V=6.0, flow_kwargs=FLOW_KWARGS)
# Out:
# ===== Running case: PI benchmark (U=0.0, V=6.0) =====
# [DEBUG] entering step: T_old=20.00000000, dT=-2.87795874e-02
# [DEBUG] leaving step: T_new=19.97122041, rhs_norm=0.35879413927570075, channel_norm=0.010325947274337357, accepted_substeps=1, max_rel_update=0.0008604956061947798
# [DEBUG] entering step: T_old=19.97122041, dT=-2.87381741e-02
# [DEBUG] leaving step: T_new=19.94248224, rhs_norm=0.3594420279680566, channel_norm=0.020655654861653015, accepted_substeps=1, max_rel_update=0.0008608089656096382
# [DEBUG] entering step: T_old=19.94248224, dT=-2.86968205e-02
# [DEBUG] leaving step: T_new=19.91378542, rhs_norm=0.36009064499975274, channel_norm=0.03098911145939262, accepted_substeps=1, max_rel_update=0.0008611213831449671
# [DEBUG] entering step: T_old=19.91378542, dT=-2.86555264e-02
# [DEBUG] leaving step: T_new=19.88512989, rhs_norm=0.3607399889203, channel_norm=0.04132630571811617, accepted_substeps=1, max_rel_update=0.0008614328548936294
# [DEBUG] entering step: T_old=19.88512989, dT=-2.86142916e-02
# [DEBUG] leaving step: T_new=19.85651560, rhs_norm=0.3613900582621812, channel_norm=0.0516672262413158, accepted_substeps=1, max_rel_update=0.0008617433769333025
# [DEBUG] entering step: T_old=19.85651560, dT=-2.85731163e-02
# [DEBUG] leaving step: T_new=19.82794248, rhs_norm=0.36204085154076726, channel_norm=0.06201186158525529, accepted_substeps=1, max_rel_update=0.0008620529453282913
# [DEBUG] entering step: T_old=19.82794248, dT=-2.85320001e-02
# [DEBUG] leaving step: T_new=19.79941048, rhs_norm=0.3626923672542089, channel_norm=0.07236020025879097, accepted_substeps=1, max_rel_update=0.0008623615561279733
# [DEBUG] entering step: T_old=19.79941048, dT=-2.84909432e-02
# [DEBUG] leaving step: T_new=19.77091954, rhs_norm=0.3633446038833473, channel_norm=0.08271223072322718, accepted_substeps=1, max_rel_update=0.0008626692053696839
# [DEBUG] entering step: T_old=19.77091954, dT=-2.84499453e-02
# [DEBUG] leaving step: T_new=19.74246960, rhs_norm=0.36399755989161464, channel_norm=0.09306794139212765, accepted_substeps=1, max_rel_update=0.0008629758890750385
# [DEBUG] entering step: T_old=19.74246960, dT=-2.84090064e-02
# [DEBUG] leaving step: T_new=19.71406059, rhs_norm=0.364651233724939, channel_norm=0.10342732063116655, accepted_substeps=1, max_rel_update=0.0008632816032532413
# [DEBUG] entering step: T_old=19.71406059, dT=-2.83681264e-02
# [DEBUG] leaving step: T_new=19.68569246, rhs_norm=0.3653056238116423, channel_norm=0.1137903567579365, accepted_substeps=1, max_rel_update=0.0008635863438974951
# [DEBUG] entering step: T_old=19.68569246, dT=-2.83273053e-02
# [DEBUG] leaving step: T_new=19.65736516, rhs_norm=0.3659607285623478, channel_norm=0.12415703804180424, accepted_substeps=1, max_rel_update=0.0008638901069889785
# [DEBUG] entering step: T_old=19.65736516, dT=-2.82865429e-02
# [DEBUG] leaving step: T_new=19.62907861, rhs_norm=0.36661654636988156, channel_norm=0.13452735270373115, accepted_substeps=1, max_rel_update=0.0008641928884939084
# [DEBUG] entering step: T_old=19.62907861, dT=-2.82458391e-02
# [DEBUG] leaving step: T_new=19.60083277, rhs_norm=0.3672730756091684, channel_norm=0.1449012889161048, accepted_substeps=1, max_rel_update=0.0008644946843644712
# [DEBUG] entering step: T_old=19.60083277, dT=-2.82051940e-02
# [DEBUG] leaving step: T_new=19.57262758, rhs_norm=0.3679303146371427, channel_norm=0.15527883480256283, accepted_substeps=1, max_rel_update=0.0008647954905381695
# [DEBUG] entering step: T_old=19.57262758, dT=-2.81646073e-02
# [DEBUG] leaving step: T_new=19.54446297, rhs_norm=0.3685882617926397, channel_norm=0.1656599784378344, accepted_substeps=1, max_rel_update=0.0008650953029392967
# [DEBUG] entering step: T_old=19.54446297, dT=-2.81240790e-02
# [DEBUG] leaving step: T_new=19.51633889, rhs_norm=0.3692469153963044, channel_norm=0.17604470784756726, accepted_substeps=1, max_rel_update=0.0008653941174777388
# [DEBUG] entering step: T_old=19.51633889, dT=-2.80836090e-02
# [DEBUG] leaving step: T_new=19.48825529, rhs_norm=0.3699062737504854, channel_norm=0.1864330110081571, accepted_substeps=1, max_rel_update=0.0008656919300491527
# [DEBUG] entering step: T_old=19.48825529, dT=-2.80431973e-02
# [DEBUG] leaving step: T_new=19.46021209, rhs_norm=0.37056633513914117, channel_norm=0.19682487584655947, accepted_substeps=1, max_rel_update=0.0008659887365335305
# [DEBUG] entering step: T_old=19.46021209, dT=-2.80028437e-02
# [DEBUG] leaving step: T_new=19.43220924, rhs_norm=0.3712270978277352, channel_norm=0.20722029024015143, accepted_substeps=1, max_rel_update=0.0008662845327993292
# [DEBUG] entering step: T_old=19.43220924, dT=-2.79625482e-02
# [DEBUG] leaving step: T_new=19.40424670, rhs_norm=0.3718885600631405, channel_norm=0.21761924201653512, accepted_substeps=1, max_rel_update=0.000866579314698641
# [DEBUG] entering step: T_old=19.40424670, dT=-2.79223106e-02
# [DEBUG] leaving step: T_new=19.37632439, rhs_norm=0.3725507200735325, channel_norm=0.22802171895337384, accepted_substeps=1, max_rel_update=0.0008668730780698928
# [DEBUG] entering step: T_old=19.37632439, dT=-2.78821310e-02
# [DEBUG] leaving step: T_new=19.34844225, rhs_norm=0.3732135760682966, channel_norm=0.23842770877821481, accepted_substeps=1, max_rel_update=0.0008671658187367473
# [DEBUG] entering step: T_old=19.34844225, dT=-2.78420092e-02
# [DEBUG] leaving step: T_new=19.32060025, rhs_norm=0.37387712623791786, channel_norm=0.24883719916832608, accepted_substeps=1, max_rel_update=0.0008674575325092731
# [DEBUG] entering step: T_old=19.32060025, dT=-2.78019451e-02
# [DEBUG] leaving step: T_new=19.29279830, rhs_norm=0.3745413687538873, channel_norm=0.2592501777505162, accepted_substeps=1, max_rel_update=0.0008677482151825071
# [DEBUG] entering step: T_old=19.29279830, dT=-2.77619387e-02
# [DEBUG] leaving step: T_new=19.26503636, rhs_norm=0.3752063017685966, channel_norm=0.26966663210096786, accepted_substeps=1, max_rel_update=0.0008680378625376424
# [DEBUG] entering step: T_old=19.26503636, dT=-2.77219898e-02
# [DEBUG] leaving step: T_new=19.23731437, rhs_norm=0.3758719234152371, channel_norm=0.2800865497450493, accepted_substeps=1, max_rel_update=0.0008683264703401236
# [DEBUG] entering step: T_old=19.23731437, dT=-2.76820985e-02
# [DEBUG] leaving step: T_new=19.20963227, rhs_norm=0.37653823180769563, channel_norm=0.29050991815716076, accepted_substeps=1, max_rel_update=0.00086861403434262
# [DEBUG] entering step: T_old=19.20963227, dT=-2.76422645e-02
# [DEBUG] leaving step: T_new=19.18199001, rhs_norm=0.37720522504045434, channel_norm=0.3009367247605462, accepted_substeps=1, max_rel_update=0.0008689005502821237
# [DEBUG] entering step: T_old=19.18199001, dT=-2.76024879e-02
# [DEBUG] leaving step: T_new=19.15438752, rhs_norm=0.3778729011884896, channel_norm=0.31136695692712946, accepted_substeps=1, max_rel_update=0.0008691860138819379
# [DEBUG] entering step: T_old=19.15438752, dT=-2.75627684e-02
# [DEBUG] leaving step: T_new=19.12682475, rhs_norm=0.37854125830716623, channel_norm=0.32180060197732113, accepted_substeps=1, max_rel_update=0.0008694704208493045
# [DEBUG] entering step: T_old=19.12682475, dT=-2.75231062e-02
# [DEBUG] leaving step: T_new=19.09930165, rhs_norm=0.3792102944321333, channel_norm=0.3322376471798687, accepted_substeps=1, max_rel_update=0.0008697537668789639
# [DEBUG] entering step: T_old=19.09930165, dT=-2.74835010e-02
# [DEBUG] leaving step: T_new=19.07181815, rhs_norm=0.37988000757922535, channel_norm=0.34267807975166215, accepted_substeps=1, max_rel_update=0.0008700360476494541
# [DEBUG] entering step: T_old=19.07181815, dT=-2.74439528e-02
# [DEBUG] leaving step: T_new=19.04437419, rhs_norm=0.3805503957443539, channel_norm=0.3531218868575714, accepted_substeps=1, max_rel_update=0.0008703172588257717
# [DEBUG] entering step: T_old=19.04437419, dT=-2.74044615e-02
# [DEBUG] leaving step: T_new=19.01696973, rhs_norm=0.3812214569034048, channel_norm=0.3635690556102513, accepted_substeps=1, max_rel_update=0.0008705973960566597
# [DEBUG] entering step: T_old=19.01696973, dT=-2.73650271e-02
# [DEBUG] leaving step: T_new=18.98960470, rhs_norm=0.38189318901213865, channel_norm=0.3740195730699911, accepted_substeps=1, max_rel_update=0.0008708764549783173
# [DEBUG] entering step: T_old=18.98960470, dT=-2.73256494e-02
# [DEBUG] leaving step: T_new=18.96227905, rhs_norm=0.3825655900060808, channel_norm=0.384473426244523, accepted_substeps=1, max_rel_update=0.0008711544312109918
# [DEBUG] entering step: T_old=18.96227905, dT=-2.72863283e-02
# [DEBUG] leaving step: T_new=18.93499273, rhs_norm=0.3832386578004173, channel_norm=0.3949306020888468, accepted_substeps=1, max_rel_update=0.000871431320360315
# [DEBUG] entering step: T_old=18.93499273, dT=-2.72470639e-02
# [DEBUG] leaving step: T_new=18.90774566, rhs_norm=0.3839123902898953, channel_norm=0.40539108750505026, accepted_substeps=1, max_rel_update=0.0008717071180169587
# [DEBUG] entering step: T_old=18.90774566, dT=-2.72078559e-02
# [DEBUG] leaving step: T_new=18.88053781, rhs_norm=0.38458678534870977, channel_norm=0.4158548693421418, accepted_substeps=1, max_rel_update=0.0008719818197576249
# [DEBUG] entering step: T_old=18.88053781, dT=-2.71687044e-02
# [DEBUG] leaving step: T_new=18.85336910, rhs_norm=0.3852618408304065, channel_norm=0.4263219343958674, accepted_substeps=1, max_rel_update=0.0008722554211438019
# [DEBUG] entering step: T_old=18.85336910, dT=-2.71296092e-02
# [DEBUG] leaving step: T_new=18.82623949, rhs_norm=0.3859375545677726, channel_norm=0.4367922694085365, accepted_substeps=1, max_rel_update=0.0008725279177224228
# [DEBUG] entering step: T_old=18.82623949, dT=-2.70905702e-02
# [DEBUG] leaving step: T_new=18.79914892, rhs_norm=0.38661392437273134, channel_norm=0.44726586106883026, accepted_substeps=1, max_rel_update=0.0008727993050244814
# [DEBUG] entering step: T_old=18.79914892, dT=-2.70515874e-02
# [DEBUG] leaving step: T_new=18.77209734, rhs_norm=0.38729094803623476, channel_norm=0.45774269601164475, accepted_substeps=1, max_rel_update=0.0008730695785678738
# [DEBUG] entering step: T_old=18.77209734, dT=-2.70126608e-02
# [DEBUG] leaving step: T_new=18.74508467, rhs_norm=0.38796862332816007, channel_norm=0.46822276081790054, accepted_substeps=1, max_rel_update=0.0008733387338546481
# [DEBUG] entering step: T_old=18.74508467, dT=-2.69737901e-02
# [DEBUG] leaving step: T_new=18.71811088, rhs_norm=0.38864694799720556, channel_norm=0.478706042014369, accepted_substeps=1, max_rel_update=0.0008736067663723709
# [DEBUG] entering step: T_old=18.71811088, dT=-2.69349754e-02
# [DEBUG] leaving step: T_new=18.69117591, rhs_norm=0.38932591977077596, channel_norm=0.4891925260734816, accepted_substeps=1, max_rel_update=0.0008738736715927165
# [DEBUG] entering step: T_old=18.69117591, dT=-2.68962165e-02
# [DEBUG] leaving step: T_new=18.66427969, rhs_norm=0.39000553635488644, channel_norm=0.49968219941317255, accepted_substeps=1, max_rel_update=0.0008741394449742426
# [DEBUG] entering step: T_old=18.66427969, dT=-2.68575134e-02
# [DEBUG] leaving step: T_new=18.63742218, rhs_norm=0.39068579543404724, channel_norm=0.5101750483966808, accepted_substeps=1, max_rel_update=0.0008744040819590221
# [DEBUG] entering step: T_old=18.63742218, dT=-2.68188660e-02
# [DEBUG] leaving step: T_new=18.61060331, rhs_norm=0.3913666946711607, channel_norm=0.5206710593323858, accepted_substeps=1, max_rel_update=0.0008746675779754092
# [DEBUG] entering step: T_old=18.61060331, dT=-2.67802742e-02
# [DEBUG] leaving step: T_new=18.58382304, rhs_norm=0.3920482317074152, channel_norm=0.5311702184736089, accepted_substeps=1, max_rel_update=0.0008749299284352567
# [DEBUG] entering step: T_old=18.58382304, dT=-2.67417379e-02
# [DEBUG] leaving step: T_new=18.55708130, rhs_norm=0.39273040416217425, channel_norm=0.5416725120184546, accepted_substeps=1, max_rel_update=0.0008751911287371425
# [DEBUG] entering step: T_old=18.55708130, dT=-2.67032571e-02
# [DEBUG] leaving step: T_new=18.53037804, rhs_norm=0.39341320963287296, channel_norm=0.5521779261096218, accepted_substeps=1, max_rel_update=0.0008754511742639376
# [DEBUG] entering step: T_old=18.53037804, dT=-2.66648317e-02
# [DEBUG] leaving step: T_new=18.50371321, rhs_norm=0.39409664569490577, channel_norm=0.5626864468342264, accepted_substeps=1, max_rel_update=0.000875710060383716
# [DEBUG] entering step: T_old=18.50371321, dT=-2.66264615e-02
# [DEBUG] leaving step: T_new=18.47708675, rhs_norm=0.3947807099015237, channel_norm=0.5731980602236068, accepted_substeps=1, max_rel_update=0.0008759677824483576
# [DEBUG] entering step: T_old=18.47708675, dT=-2.65881466e-02
# [DEBUG] leaving step: T_new=18.45049860, rhs_norm=0.3954653997837244, channel_norm=0.5837127522531698, accepted_substeps=1, max_rel_update=0.000876224335796922
# [DEBUG] entering step: T_old=18.45049860, dT=-2.65498868e-02
# [DEBUG] leaving step: T_new=18.42394872, rhs_norm=0.3961507128501427, channel_norm=0.5942305088421899, accepted_substeps=1, max_rel_update=0.0008764797157516709
# [DEBUG] entering step: T_old=18.42394872, dT=-2.65116821e-02
# [DEBUG] leaving step: T_new=18.39743704, rhs_norm=0.3968366465869443, channel_norm=0.6047513158536445, accepted_substeps=1, max_rel_update=0.000876733917621224
# [DEBUG] entering step: T_old=18.39743704, dT=-2.64735323e-02
# [DEBUG] leaving step: T_new=18.37096350, rhs_norm=0.39752319845771616, channel_norm=0.6152751590940089, accepted_substeps=1, max_rel_update=0.0008769869366970326
# [DEBUG] entering step: T_old=18.37096350, dT=-2.64354374e-02
# [DEBUG] leaving step: T_new=18.34452807, rhs_norm=0.3982103659033613, channel_norm=0.6258020243131073, accepted_substeps=1, max_rel_update=0.0008772387682581974
# [DEBUG] entering step: T_old=18.34452807, dT=-2.63973974e-02
# [DEBUG] leaving step: T_new=18.31813067, rhs_norm=0.3988981463419834, channel_norm=0.6363318972039126, accepted_substeps=1, max_rel_update=0.0008774894075671054
# [DEBUG] entering step: T_old=18.31813067, dT=-2.63594121e-02
# [DEBUG] leaving step: T_new=18.29177126, rhs_norm=0.399586537168786, channel_norm=0.6468647634023599, accepted_substeps=1, max_rel_update=0.0008777388498706105
# [DEBUG] entering step: T_old=18.29177126, dT=-2.63214814e-02
# [DEBUG] leaving step: T_new=18.26544977, rhs_norm=0.40027553575595964, channel_norm=0.6574006084871872, accepted_substeps=1, max_rel_update=0.0008779870904022727
# [DEBUG] entering step: T_old=18.26544977, dT=-2.62836054e-02
# [DEBUG] leaving step: T_new=18.23916617, rhs_norm=0.40096513945257184, channel_norm=0.6679394179797385, accepted_substeps=1, max_rel_update=0.0008782341243792814
# [DEBUG] entering step: T_old=18.23916617, dT=-2.62457838e-02
# [DEBUG] leaving step: T_new=18.21292039, rhs_norm=0.4016553455844621, channel_norm=0.6784811773437865, accepted_substeps=1, max_rel_update=0.000878479947003998
# [DEBUG] entering step: T_old=18.21292039, dT=-2.62080167e-02
# [DEBUG] leaving step: T_new=18.18671237, rhs_norm=0.40234615145412944, channel_norm=0.6890258719853554, accepted_substeps=1, max_rel_update=0.0008787245534640713
# [DEBUG] entering step: T_old=18.18671237, dT=-2.61703039e-02
# [DEBUG] leaving step: T_new=18.16054207, rhs_norm=0.4030375543406245, channel_norm=0.699573487252526, accepted_substeps=1, max_rel_update=0.0008789679389308902
# [DEBUG] entering step: T_old=18.16054207, dT=-2.61326453e-02
# [DEBUG] leaving step: T_new=18.13440942, rhs_norm=0.4037295514994398, channel_norm=0.7101240084352753, accepted_substeps=1, max_rel_update=0.0008792100985624453
# [DEBUG] entering step: T_old=18.13440942, dT=-2.60950410e-02
# [DEBUG] leaving step: T_new=18.10831438, rhs_norm=0.4044221401624023, channel_norm=0.7206774207652838, accepted_substeps=1, max_rel_update=0.0008794510275007132
# [DEBUG] entering step: T_old=18.10831438, dT=-2.60574908e-02
# [DEBUG] leaving step: T_new=18.08225689, rhs_norm=0.4051153175375618, channel_norm=0.7312337094157465, accepted_substeps=1, max_rel_update=0.0008796907208718873
# [DEBUG] entering step: T_old=18.08225689, dT=-2.60199946e-02
# [DEBUG] leaving step: T_new=18.05623689, rhs_norm=0.40580908080908157, channel_norm=0.741792859501209, accepted_substeps=1, max_rel_update=0.0008799291737885384
# [DEBUG] entering step: T_old=18.05623689, dT=-2.59825524e-02
# [DEBUG] leaving step: T_new=18.03025434, rhs_norm=0.4065034271371309, channel_norm=0.7523548560773743, accepted_substeps=1, max_rel_update=0.0008801663813471071
# [DEBUG] entering step: T_old=18.03025434, dT=-2.59451640e-02
# [DEBUG] leaving step: T_new=18.00430918, rhs_norm=0.40719835365777546, channel_norm=0.7629196841409279, accepted_substeps=1, max_rel_update=0.0008804023386294694
# [DEBUG] entering step: T_old=18.00430918, dT=-2.59078294e-02
# [DEBUG] leaving step: T_new=17.97840135, rhs_norm=0.407893857482865, channel_norm=0.7734873286293443, accepted_substeps=1, max_rel_update=0.0008806370407013683
# [DEBUG] entering step: T_old=17.97840135, dT=-2.58705486e-02
# [DEBUG] leaving step: T_new=17.95253080, rhs_norm=0.4085899356999247, channel_norm=0.7840577744207238, accepted_substeps=1, max_rel_update=0.0008808704826149552
# [DEBUG] entering step: T_old=17.95253080, dT=-2.58333214e-02
# [DEBUG] leaving step: T_new=17.92669748, rhs_norm=0.40928658537204776, channel_norm=0.7946310063335975, accepted_substeps=1, max_rel_update=0.0008811026594061493
# [DEBUG] entering step: T_old=17.92669748, dT=-2.57961478e-02
# [DEBUG] leaving step: T_new=17.90090133, rhs_norm=0.40998380353778446, channel_norm=0.8052070091267549, accepted_substeps=1, max_rel_update=0.0008813335660964526
# [DEBUG] entering step: T_old=17.90090133, dT=-2.57590277e-02
# [DEBUG] leaving step: T_new=17.87514230, rhs_norm=0.4106815872110318, channel_norm=0.8157857674990486, accepted_substeps=1, max_rel_update=0.00088156319769114
# [DEBUG] entering step: T_old=17.87514230, dT=-2.57219610e-02
# [DEBUG] leaving step: T_new=17.84942034, rhs_norm=0.4113799333809247, channel_norm=0.8263672660892334, accepted_substeps=1, max_rel_update=0.0008817915491820616
# [DEBUG] entering step: T_old=17.84942034, dT=-2.56849476e-02
# [DEBUG] leaving step: T_new=17.82373539, rhs_norm=0.41207883901172715, channel_norm=0.8369514894757688, accepted_substeps=1, max_rel_update=0.0008820186155446195
# [DEBUG] entering step: T_old=17.82373539, dT=-2.56479875e-02
# [DEBUG] leaving step: T_new=17.79808741, rhs_norm=0.41277830104272045, channel_norm=0.8475384221766513, accepted_substeps=1, max_rel_update=0.0008822443917402065
# [DEBUG] entering step: T_old=17.79808741, dT=-2.56110806e-02
# [DEBUG] leaving step: T_new=17.77247633, rhs_norm=0.41347831638809596, channel_norm=0.8581280486492109, accepted_substeps=1, max_rel_update=0.0008824688727132943
# [DEBUG] entering step: T_old=17.77247633, dT=-2.55742267e-02
# [DEBUG] leaving step: T_new=17.74690210, rhs_norm=0.4141788819368405, channel_norm=0.868720353289958, accepted_substeps=1, max_rel_update=0.0008826920533955891
# [DEBUG] entering step: T_old=17.74690210, dT=-2.55374260e-02
# [DEBUG] leaving step: T_new=17.72136467, rhs_norm=0.4148799945526376, channel_norm=0.8793153204343869, accepted_substeps=1, max_rel_update=0.0008829139287024034
# [DEBUG] entering step: T_old=17.72136467, dT=-2.55006781e-02
# [DEBUG] leaving step: T_new=17.69586399, rhs_norm=0.41558165107374595, channel_norm=0.8899129343568021, accepted_substeps=1, max_rel_update=0.0008831344935346014
# [DEBUG] entering step: T_old=17.69586399, dT=-2.54639832e-02
# [DEBUG] leaving step: T_new=17.67040001, rhs_norm=0.4162838483128968, channel_norm=0.9005131792701205, accepted_substeps=1, max_rel_update=0.000883353742776539
# [DEBUG] entering step: T_old=17.67040001, dT=-2.54273410e-02
# [DEBUG] leaving step: T_new=17.64497267, rhs_norm=0.4169865830571817, channel_norm=0.9111160393257163, accepted_substeps=1, max_rel_update=0.0008835716712996423
# [DEBUG] entering step: T_old=17.64497267, dT=-2.53907516e-02
# [DEBUG] leaving step: T_new=17.61958192, rhs_norm=0.4176898520679482, channel_norm=0.9217214986132256, accepted_substeps=1, max_rel_update=0.0008837882739591136
# [DEBUG] entering step: T_old=17.61958192, dT=-2.53542149e-02
# [DEBUG] leaving step: T_new=17.59422770, rhs_norm=0.41839365208068097, channel_norm=0.9323295411603735, accepted_substeps=1, max_rel_update=0.0008840035455956534
# [DEBUG] entering step: T_old=17.59422770, dT=-2.53177307e-02
# [DEBUG] leaving step: T_new=17.56890997, rhs_norm=0.41909797980490515, channel_norm=0.9429401509327757, accepted_substeps=1, max_rel_update=0.0008842174810335248
# [DEBUG] entering step: T_old=17.56890997, dT=-2.52812990e-02
# [DEBUG] leaving step: T_new=17.54362867, rhs_norm=0.4198028319240663, channel_norm=0.9535533118337869, accepted_substeps=1, max_rel_update=0.0008844300750842667
# [DEBUG] entering step: T_old=17.54362867, dT=-2.52449197e-02
# [DEBUG] leaving step: T_new=17.51838375, rhs_norm=0.42050820509542786, channel_norm=0.9641690077043045, accepted_substeps=1, max_rel_update=0.000884641322543136
# [DEBUG] entering step: T_old=17.51838375, dT=-2.52085928e-02
# [DEBUG] leaving step: T_new=17.49317516, rhs_norm=0.42121409594995995, channel_norm=0.9747872223225919, accepted_substeps=1, max_rel_update=0.0008848512181906114
# [DEBUG] entering step: T_old=17.49317516, dT=-2.51723181e-02
# [DEBUG] leaving step: T_new=17.46800284, rhs_norm=0.4219205010922309, channel_norm=0.9854079394040903, accepted_substeps=1, max_rel_update=0.0008850597567915419
# [DEBUG] entering step: T_old=17.46800284, dT=-2.51360957e-02
# [DEBUG] leaving step: T_new=17.44286675, rhs_norm=0.4226274171003007, channel_norm=0.9960311426012594, accepted_substeps=1, max_rel_update=0.0008852669330974224
# [DEBUG] entering step: T_old=17.44286675, dT=-2.50999254e-02
# [DEBUG] leaving step: T_new=17.41776682, rhs_norm=0.42333484052560916, channel_norm=1.0066568155033864, accepted_substeps=1, max_rel_update=0.000885472741843917
# [DEBUG] entering step: T_old=17.41776682, dT=-2.50638071e-02
# [DEBUG] leaving step: T_new=17.39270302, rhs_norm=0.42404276789287015, channel_norm=1.017284941636409, accepted_substeps=1, max_rel_update=0.0008856771777518871
# [DEBUG] entering step: T_old=17.39270302, dT=-2.50277408e-02
# [DEBUG] leaving step: T_new=17.36767527, rhs_norm=0.4247511956999631, channel_norm=1.0279155044627273, accepted_substeps=1, max_rel_update=0.0008858802355265369
# [DEBUG] entering step: T_old=17.36767527, dT=-2.49917264e-02
# [DEBUG] leaving step: T_new=17.34268355, rhs_norm=0.4254601204178237, channel_norm=1.0385484873810498, accepted_substeps=1, max_rel_update=0.0008860819098602033
# [DEBUG] entering step: T_old=17.34268355, dT=-2.49557638e-02
# [DEBUG] leaving step: T_new=17.31772778, rhs_norm=0.42616953849033956, channel_norm=1.0491838737261932, accepted_substeps=1, max_rel_update=0.000886282195428623
# [DEBUG] entering step: T_old=17.31772778, dT=-2.49198530e-02
# [DEBUG] leaving step: T_new=17.29280793, rhs_norm=0.42687944633423824, channel_norm=1.0598216467689192, accepted_substeps=1, max_rel_update=0.0008864810868938451
# [DEBUG] entering step: T_old=17.29280793, dT=-2.48839938e-02
# [DEBUG] leaving step: T_new=17.26792394, rhs_norm=0.42758984033898295, channel_norm=1.0704617897157416, accepted_substeps=1, max_rel_update=0.0008866785789018715
# [DEBUG] entering step: T_old=17.26792394, dT=-2.48481863e-02
# [DEBUG] leaving step: T_new=17.24307575, rhs_norm=0.42830071686666465, channel_norm=1.0811042857087687, accepted_substeps=1, max_rel_update=0.0008868746660855944
# [DEBUG] entering step: T_old=17.24307575, dT=-2.48124302e-02
# [DEBUG] leaving step: T_new=17.21826332, rhs_norm=0.42901207225189475, channel_norm=1.0917491178255148, accepted_substeps=1, max_rel_update=0.0008870693430621733
# [DEBUG] entering step: T_old=17.21826332, dT=-2.47767257e-02
# [DEBUG] leaving step: T_new=17.19348660, rhs_norm=0.42972390280170003, channel_norm=1.10239626907873, accepted_substeps=1, max_rel_update=0.0008872626044345919
# [DEBUG] entering step: T_old=17.19348660, dT=-2.47410725e-02
# [DEBUG] leaving step: T_new=17.16874552, rhs_norm=0.43043620479541467, channel_norm=1.1130457224162102, accepted_substeps=1, max_rel_update=0.0008874544447900367
# [DEBUG] entering step: T_old=17.16874552, dT=-2.47054706e-02
# [DEBUG] leaving step: T_new=17.14404005, rhs_norm=0.4311489744845736, channel_norm=1.1236974607206445, accepted_substeps=1, max_rel_update=0.0008876448587028597
# [DEBUG] entering step: T_old=17.14404005, dT=-2.46699199e-02
# [DEBUG] leaving step: T_new=17.11937013, rhs_norm=0.43186220809280856, channel_norm=1.1343514668094248, accepted_substeps=1, max_rel_update=0.0008878338407316931
# [DEBUG] entering step: T_old=17.11937013, dT=-2.46344204e-02
# [DEBUG] leaving step: T_new=17.09473571, rhs_norm=0.43257590181574035, channel_norm=1.1450077234344769, accepted_substeps=1, max_rel_update=0.0008880213854210117
# [DEBUG] entering step: T_old=17.09473571, dT=-2.45989720e-02
# [DEBUG] leaving step: T_new=17.07013674, rhs_norm=0.4332900518208781, channel_norm=1.1556662132820756, accepted_substeps=1, max_rel_update=0.0008882074872999025
# [DEBUG] entering step: T_old=17.07013674, dT=-2.45635746e-02
# [DEBUG] leaving step: T_new=17.04557317, rhs_norm=0.43400465424750445, channel_norm=1.16632691897269, accepted_substeps=1, max_rel_update=0.0008883921408845197
# [DEBUG] entering step: T_old=17.04557317, dT=-2.45282281e-02
# [DEBUG] leaving step: T_new=17.02104494, rhs_norm=0.4347197052065863, channel_norm=1.1769898230607956, accepted_substeps=1, max_rel_update=0.0008885753406754686
# [DEBUG] entering step: T_old=17.02104494, dT=-2.44929325e-02
# [DEBUG] leaving step: T_new=16.99655201, rhs_norm=0.4354352007806547, channel_norm=1.1876549080347094, accepted_substeps=1, max_rel_update=0.0008887570811594838
# [DEBUG] entering step: T_old=16.99655201, dT=-2.44576877e-02
# [DEBUG] leaving step: T_new=16.97209432, rhs_norm=0.4361511370237099, channel_norm=1.1983221563164017, accepted_substeps=1, max_rel_update=0.0008889373568076891
# [DEBUG] entering step: T_old=16.97209432, dT=-2.44224936e-02
# [DEBUG] leaving step: T_new=16.94767182, rhs_norm=0.436867509961115, channel_norm=1.2089915502613495, accepted_substeps=1, max_rel_update=0.0008891161620789902
# [DEBUG] entering step: T_old=16.94767182, dT=-2.43873501e-02
# [DEBUG] leaving step: T_new=16.92328447, rhs_norm=0.4375843155894954, channel_norm=1.2196630721583477, accepted_substeps=1, max_rel_update=0.0008892934914165179
# [DEBUG] entering step: T_old=16.92328447, dT=-2.43522572e-02
# [DEBUG] leaving step: T_new=16.89893222, rhs_norm=0.43830154987663295, channel_norm=1.2303367042293445, accepted_substeps=1, max_rel_update=0.0008894693392497343
# [DEBUG] entering step: T_old=16.89893222, dT=-2.43172148e-02
# [DEBUG] leaving step: T_new=16.87461500, rhs_norm=0.4390192087613626, channel_norm=1.2410124286292596, accepted_substeps=1, max_rel_update=0.0008896436999929255
# [DEBUG] entering step: T_old=16.87461500, dT=-2.42822228e-02
# [DEBUG] leaving step: T_new=16.85033278, rhs_norm=0.43973728815347535, channel_norm=1.251690227445834, accepted_substeps=1, max_rel_update=0.0008898165680478594
# [DEBUG] entering step: T_old=16.85033278, dT=-2.42472812e-02
# [DEBUG] leaving step: T_new=16.82608550, rhs_norm=0.44045578393360973, channel_norm=1.2623700826994455, accepted_substeps=1, max_rel_update=0.0008899879378009681
# [DEBUG] entering step: T_old=16.82608550, dT=-2.42123899e-02
# [DEBUG] leaving step: T_new=16.80187311, rhs_norm=0.44117469195315756, channel_norm=1.2730519763429515, accepted_substeps=1, max_rel_update=0.0008901578036254964
# [DEBUG] entering step: T_old=16.80187311, dT=-2.41775487e-02
# [DEBUG] leaving step: T_new=16.77769556, rhs_norm=0.4418940080341591, channel_norm=1.283735890261502, accepted_substeps=1, max_rel_update=0.0008903261598791993
# [DEBUG] entering step: T_old=16.77769556, dT=-2.41427577e-02
# [DEBUG] leaving step: T_new=16.75355280, rhs_norm=0.44261372796920206, channel_norm=1.2944218062723956, accepted_substeps=1, max_rel_update=0.0008904930009077939
# [DEBUG] entering step: T_old=16.75355280, dT=-2.41080168e-02
# [DEBUG] leaving step: T_new=16.72944478, rhs_norm=0.44333384752132476, channel_norm=1.3051097061249013, accepted_substeps=1, max_rel_update=0.0008906583210421502
# [DEBUG] entering step: T_old=16.72944478, dT=-2.40733259e-02
# [DEBUG] leaving step: T_new=16.70537146, rhs_norm=0.4440543624239154, channel_norm=1.3157995715000799, accepted_substeps=1, max_rel_update=0.0008908221145982084
# [DEBUG] entering step: T_old=16.70537146, dT=-2.40386849e-02
# [DEBUG] leaving step: T_new=16.68133277, rhs_norm=0.44477526838061365, channel_norm=1.3264913840106485, accepted_substeps=1, max_rel_update=0.0008909843758807188
# [DEBUG] entering step: T_old=16.68133277, dT=-2.40040937e-02
# [DEBUG] leaving step: T_new=16.65732868, rhs_norm=0.44549656106521074, channel_norm=1.3371851252007867, accepted_substeps=1, max_rel_update=0.0008911450991781785
# [DEBUG] entering step: T_old=16.65732868, dT=-2.39695523e-02
# [DEBUG] leaving step: T_new=16.63335913, rhs_norm=0.4462182361215533, channel_norm=1.3478807765459904, accepted_substeps=1, max_rel_update=0.0008913042787669716
# [DEBUG] entering step: T_old=16.63335913, dT=-2.39350606e-02
# [DEBUG] leaving step: T_new=16.60942407, rhs_norm=0.44694028916344586, channel_norm=1.3585783194529006, accepted_substeps=1, max_rel_update=0.0008914619089091984
# [DEBUG] entering step: T_old=16.60942407, dT=-2.39006185e-02
# [DEBUG] leaving step: T_new=16.58552345, rhs_norm=0.4476627157745553, channel_norm=1.3692777352591383, accepted_substeps=1, max_rel_update=0.0008916179838531353
# [DEBUG] entering step: T_old=16.58552345, dT=-2.38662260e-02
# [DEBUG] leaving step: T_new=16.56165722, rhs_norm=0.44838551150831296, channel_norm=1.3799790052331506, accepted_substeps=1, max_rel_update=0.0008917724978343592
# [DEBUG] entering step: T_old=16.56165722, dT=-2.38318830e-02
# [DEBUG] leaving step: T_new=16.53782534, rhs_norm=0.4491086718878198, channel_norm=1.3906821105740477, accepted_substeps=1, max_rel_update=0.0008919254450747608
# [DEBUG] entering step: T_old=16.53782534, dT=-2.37975895e-02
# [DEBUG] leaving step: T_new=16.51402775, rhs_norm=0.4498321924057508, channel_norm=1.4013870324114295, accepted_substeps=1, max_rel_update=0.0008920768197818125
# [DEBUG] entering step: T_old=16.51402775, dT=-2.37633452e-02
# [DEBUG] leaving step: T_new=16.49026440, rhs_norm=0.45055606852426366, channel_norm=1.4120937518052483, accepted_substeps=1, max_rel_update=0.0008922266161515741
# [DEBUG] entering step: T_old=16.49026440, dT=-2.37291502e-02
# [DEBUG] leaving step: T_new=16.46653525, rhs_norm=0.4512802956749026, channel_norm=1.4228022497456352, accepted_substeps=1, max_rel_update=0.0008923748283655684
# [DEBUG] entering step: T_old=16.46653525, dT=-2.36950045e-02
# [DEBUG] leaving step: T_new=16.44284025, rhs_norm=0.4520048692585061, channel_norm=1.4335125071527415, accepted_substeps=1, max_rel_update=0.0008925214505921874
# [DEBUG] entering step: T_old=16.44284025, dT=-2.36609079e-02
# [DEBUG] leaving step: T_new=16.41917934, rhs_norm=0.45272978464511393, channel_norm=1.444224504876594, accepted_substeps=1, max_rel_update=0.0008926664769877054
# [DEBUG] entering step: T_old=16.41917934, dT=-2.36268603e-02
# [DEBUG] leaving step: T_new=16.39555248, rhs_norm=0.4534550371738778, channel_norm=1.4549382236969182, accepted_substeps=1, max_rel_update=0.0008928099016936854
# [DEBUG] entering step: T_old=16.39555248, dT=-2.35928617e-02
# [DEBUG] leaving step: T_new=16.37195962, rhs_norm=0.4541806221529693, channel_norm=1.4656536443230015, accepted_substeps=1, max_rel_update=0.0008929517188402699
# [DEBUG] entering step: T_old=16.37195962, dT=-2.35589121e-02
# [DEBUG] leaving step: T_new=16.34840071, rhs_norm=0.4549065348594892, channel_norm=1.4763707473935406, accepted_substeps=1, max_rel_update=0.0008930919225449284
# [DEBUG] entering step: T_old=16.34840071, dT=-2.35250113e-02
# [DEBUG] leaving step: T_new=16.32487570, rhs_norm=0.4556327705393791, channel_norm=1.4870895134764603, accepted_substeps=1, max_rel_update=0.0008932305069099802
# [DEBUG] entering step: T_old=16.32487570, dT=-2.34911593e-02
# [DEBUG] leaving step: T_new=16.30138454, rhs_norm=0.4563593244073313, channel_norm=1.4978099230687987, accepted_substeps=1, max_rel_update=0.0008933674660281974
# [DEBUG] entering step: T_old=16.30138454, dT=-2.34573560e-02
# [DEBUG] leaving step: T_new=16.27792718, rhs_norm=0.45708619164670605, channel_norm=1.508531956596529, accepted_substeps=1, max_rel_update=0.0008935027939775151
# [DEBUG] entering step: T_old=16.27792718, dT=-2.34236014e-02
# [DEBUG] leaving step: T_new=16.25450358, rhs_norm=0.457813367409437, channel_norm=1.5192555944144244, accepted_substeps=1, max_rel_update=0.0008936364848246102
# [DEBUG] entering step: T_old=16.25450358, dT=-2.33898953e-02
# [DEBUG] leaving step: T_new=16.23111368, rhs_norm=0.45854084681595075, channel_norm=1.5299808168058886, accepted_substeps=1, max_rel_update=0.0008937685326220273
# [DEBUG] entering step: T_old=16.23111368, dT=-2.33562377e-02
# [DEBUG] leaving step: T_new=16.20775745, rhs_norm=0.4592686249550805, channel_norm=1.540707603982835, accepted_substeps=1, max_rel_update=0.0008938989314121992
# [DEBUG] entering step: T_old=16.20775745, dT=-2.33226286e-02
# [DEBUG] leaving step: T_new=16.18443482, rhs_norm=0.4599966968839796, channel_norm=1.5514359360855166, accepted_substeps=1, max_rel_update=0.0008940276752234681
# [DEBUG] entering step: T_old=16.18443482, dT=-2.32890678e-02
# [DEBUG] leaving step: T_new=16.16114575, rhs_norm=0.4607250576280403, channel_norm=1.562165793182393, accepted_substeps=1, max_rel_update=0.0008941547580730369
# [DEBUG] entering step: T_old=16.16114575, dT=-2.32555553e-02
# [DEBUG] leaving step: T_new=16.13789020, rhs_norm=0.4614537021808113, channel_norm=1.5728971552699733, accepted_substeps=1, max_rel_update=0.0008942801739650256
# [DEBUG] entering step: T_old=16.13789020, dT=-2.32220910e-02
# [DEBUG] leaving step: T_new=16.11466810, rhs_norm=0.4621826255039122, channel_norm=1.5836300022726846, accepted_substeps=1, max_rel_update=0.0008944039168926084
# [DEBUG] entering step: T_old=16.11466810, dT=-2.31886749e-02
# [DEBUG] leaving step: T_new=16.09147943, rhs_norm=0.46291182252695817, channel_norm=1.5943643140427208, accepted_substeps=1, max_rel_update=0.0008945259808363516
# [DEBUG] entering step: T_old=16.09147943, dT=-2.31553069e-02
# [DEBUG] leaving step: T_new=16.06832412, rhs_norm=0.4636412881474772, channel_norm=1.6051000703599123, accepted_substeps=1, max_rel_update=0.0008946463597659533
# [DEBUG] entering step: T_old=16.06832412, dT=-2.31219869e-02
# [DEBUG] leaving step: T_new=16.04520214, rhs_norm=0.46437101723082974, channel_norm=1.615837250931557, accepted_substeps=1, max_rel_update=0.0008947650476370529
# [DEBUG] entering step: T_old=16.04520214, dT=-2.30887148e-02
# [DEBUG] leaving step: T_new=16.02211342, rhs_norm=0.46510100461013526, channel_norm=1.6265758353923174, accepted_substeps=1, max_rel_update=0.0008948820383966981
# [DEBUG] entering step: T_old=16.02211342, dT=-2.30554906e-02
# [DEBUG] leaving step: T_new=15.99905793, rhs_norm=0.4658312450861912, channel_norm=1.637315803304062, accepted_substeps=1, max_rel_update=0.0008949973259787117
# [DEBUG] entering step: T_old=15.99905793, dT=-2.30223143e-02
# [DEBUG] leaving step: T_new=15.97603562, rhs_norm=0.4665617334274005, channel_norm=1.6480571341557333, accepted_substeps=1, max_rel_update=0.0008951109043059353
# [DEBUG] entering step: T_old=15.97603562, dT=-2.29891856e-02
# [DEBUG] leaving step: T_new=15.95304643, rhs_norm=0.4672924643696944, channel_norm=1.6587998073632015, accepted_substeps=1, max_rel_update=0.0008952227672890268
# [DEBUG] entering step: T_old=15.95304643, dT=-2.29561047e-02
# [DEBUG] leaving step: T_new=15.93009033, rhs_norm=0.46802343261645996, channel_norm=1.6695438022691496, accepted_substeps=1, max_rel_update=0.0008953329088289948
# [DEBUG] entering step: T_old=15.93009033, dT=-2.29230713e-02
# [DEBUG] leaving step: T_new=15.90716725, rhs_norm=0.46875463283846747, channel_norm=1.6802890981429284, accepted_substeps=1, max_rel_update=0.0008954413228148985
# [DEBUG] entering step: T_old=15.90716725, dT=-2.28900855e-02
# [DEBUG] leaving step: T_new=15.88427717, rhs_norm=0.46948605967379897, channel_norm=1.69103567418043, accepted_substeps=1, max_rel_update=0.0008955480031251407
# [DEBUG] entering step: T_old=15.88427717, dT=-2.28571471e-02
# [DEBUG] leaving step: T_new=15.86142002, rhs_norm=0.4702177077277796, channel_norm=1.7017835095039444, accepted_substeps=1, max_rel_update=0.0008956529436262012
# [DEBUG] entering step: T_old=15.86142002, dT=-2.28242562e-02
# [DEBUG] leaving step: T_new=15.83859577, rhs_norm=0.4709495715729045, channel_norm=1.7125325831620517, accepted_substeps=1, max_rel_update=0.0008957561381756025
# [DEBUG] entering step: T_old=15.83859577, dT=-2.27914125e-02
# [DEBUG] leaving step: T_new=15.81580435, rhs_norm=0.4716816457487766, channel_norm=1.7232828741294812, accepted_substeps=1, max_rel_update=0.0008958575806191257
# [DEBUG] entering step: T_old=15.81580435, dT=-2.27586161e-02
# [DEBUG] leaving step: T_new=15.79304574, rhs_norm=0.4724139247620346, channel_norm=1.7340343613069915, accepted_substeps=1, max_rel_update=0.0008959572647925276
# [DEBUG] entering step: T_old=15.79304574, dT=-2.27258670e-02
# [DEBUG] leaving step: T_new=15.77031987, rhs_norm=0.4731464030862899, channel_norm=1.7447870235212315, accepted_substeps=1, max_rel_update=0.0008960551845199955
# [DEBUG] entering step: T_old=15.77031987, dT=-2.26931649e-02
# [DEBUG] leaving step: T_new=15.74762671, rhs_norm=0.4738790751620658, channel_norm=1.7555408395246423, accepted_substeps=1, max_rel_update=0.0008961513336175728
# [DEBUG] entering step: T_old=15.74762671, dT=-2.26605099e-02
# [DEBUG] leaving step: T_new=15.72496620, rhs_norm=0.47461193539672897, channel_norm=1.7662957879953165, accepted_substeps=1, max_rel_update=0.000896245705889504
# [DEBUG] entering step: T_old=15.72496620, dT=-2.26279019e-02
# [DEBUG] leaving step: T_new=15.70233829, rhs_norm=0.47534497816443, channel_norm=1.7770518475368906, accepted_substeps=1, max_rel_update=0.000896338295131175
# [DEBUG] entering step: T_old=15.70233829, dT=-2.25953408e-02
# [DEBUG] leaving step: T_new=15.67974295, rhs_norm=0.47607819780604865, channel_norm=1.7878089966784072, accepted_substeps=1, max_rel_update=0.0008964290951263802
# [DEBUG] entering step: T_old=15.67974295, dT=-2.25628266e-02
# [DEBUG] leaving step: T_new=15.65718013, rhs_norm=0.4768115886291192, channel_norm=1.7985672138742237, accepted_substeps=1, max_rel_update=0.000896518099651372
# [DEBUG] entering step: T_old=15.65718013, dT=-2.25303592e-02
# [DEBUG] leaving step: T_new=15.63464977, rhs_norm=0.47754514490779865, channel_norm=1.8093264775038846, accepted_substeps=1, max_rel_update=0.0008966053024717448
# [DEBUG] entering step: T_old=15.63464977, dT=-2.24979384e-02
# [DEBUG] leaving step: T_new=15.61215183, rhs_norm=0.4782788608827849, channel_norm=1.8200867658720077, accepted_substeps=1, max_rel_update=0.0008966906973435846
# [DEBUG] entering step: T_old=15.61215183, dT=-2.24655644e-02
# [DEBUG] leaving step: T_new=15.58968626, rhs_norm=0.47901273076128115, channel_norm=1.8308480572081671, accepted_substeps=1, max_rel_update=0.0008967742780132959
# [DEBUG] entering step: T_old=15.58968626, dT=-2.24332369e-02
# [DEBUG] leaving step: T_new=15.56725303, rhs_norm=0.47974674871692785, channel_norm=1.8416103296668003, accepted_substeps=1, max_rel_update=0.000896856038219424
# [DEBUG] entering step: T_old=15.56725303, dT=-2.24009559e-02
# [DEBUG] leaving step: T_new=15.54485207, rhs_norm=0.4804809088897658, channel_norm=1.8523735613270829, accepted_substeps=1, max_rel_update=0.000896935971690212
# [DEBUG] entering step: T_old=15.54485207, dT=-2.23687214e-02
# [DEBUG] leaving step: T_new=15.52248335, rhs_norm=0.4812152053861736, channel_norm=1.8631377301928373, accepted_substeps=1, max_rel_update=0.0008970140721462143
# [DEBUG] entering step: T_old=15.52248335, dT=-2.23365333e-02
# [DEBUG] leaving step: T_new=15.50014682, rhs_norm=0.4819496322788275, channel_norm=1.8739028141924055, accepted_substeps=1, max_rel_update=0.0008970903332973379
# [DEBUG] entering step: T_old=15.50014682, dT=-2.23043915e-02
# [DEBUG] leaving step: T_new=15.47784242, rhs_norm=0.4826841836066501, channel_norm=1.8846687911785744, accepted_substeps=1, max_rel_update=0.0008971647488474074
# [DEBUG] entering step: T_old=15.47784242, dT=-2.22722959e-02
# [DEBUG] leaving step: T_new=15.45557013, rhs_norm=0.48341885337476803, channel_norm=1.895435638928456, accepted_substeps=1, max_rel_update=0.0008972373124901283
# [DEBUG] entering step: T_old=15.45557013, dT=-2.22402465e-02
# [DEBUG] leaving step: T_new=15.43332988, rhs_norm=0.48415363555446445, channel_norm=1.9062033351433967, accepted_substeps=1, max_rel_update=0.0008973080179117391
# [DEBUG] entering step: T_old=15.43332988, dT=-2.22082433e-02
# [DEBUG] leaving step: T_new=15.41112164, rhs_norm=0.4848885240831411, channel_norm=1.9169718574488694, accepted_substeps=1, max_rel_update=0.0008973768587893944
# [DEBUG] entering step: T_old=15.41112164, dT=-2.21762861e-02
# [DEBUG] leaving step: T_new=15.38894535, rhs_norm=0.4856235128642745, channel_norm=1.927741183394393, accepted_substeps=1, max_rel_update=0.000897443828793621
# [DEBUG] entering step: T_old=15.38894535, dT=-2.21443749e-02
# [DEBUG] leaving step: T_new=15.36680098, rhs_norm=0.48635859576737994, channel_norm=1.9385112904534325, accepted_substeps=1, max_rel_update=0.0008975089215866298
# [DEBUG] entering step: T_old=15.36680098, dT=-2.21125096e-02
# [DEBUG] leaving step: T_new=15.34468847, rhs_norm=0.4870937666279736, channel_norm=1.94928215602331, accepted_substeps=1, max_rel_update=0.0008975721308231327
# [DEBUG] entering step: T_old=15.34468847, dT=-2.20806901e-02
# [DEBUG] leaving step: T_new=15.32260778, rhs_norm=0.4878290192475386, channel_norm=1.9600537574251016, accepted_substeps=1, max_rel_update=0.0008976334501492931
# [DEBUG] entering step: T_old=15.32260778, dT=-2.20489165e-02
# [DEBUG] leaving step: T_new=15.30055886, rhs_norm=0.4885643473934896, channel_norm=1.9708260719035744, accepted_substeps=1, max_rel_update=0.0008976928732060737
# [DEBUG] entering step: T_old=15.30055886, dT=-2.20171885e-02
# [DEBUG] leaving step: T_new=15.27854167, rhs_norm=0.48929974479914207, channel_norm=1.9815990766270886, accepted_substeps=1, max_rel_update=0.0008977503936261751
# [DEBUG] entering step: T_old=15.27854167, dT=-2.19855062e-02
# [DEBUG] leaving step: T_new=15.25655617, rhs_norm=0.49003520516368204, channel_norm=1.992372748687506, accepted_substeps=1, max_rel_update=0.0008978060050347886
# [DEBUG] entering step: T_old=15.25655617, dT=-2.19538695e-02
# [DEBUG] leaving step: T_new=15.23460230, rhs_norm=0.4907707221521427, channel_norm=2.0031470651001286, accepted_substeps=1, max_rel_update=0.0008978597010518936
# [DEBUG] entering step: T_old=15.23460230, dT=-2.19222784e-02
# [DEBUG] leaving step: T_new=15.21268002, rhs_norm=0.49150628939537344, channel_norm=2.0139220028036067, accepted_substeps=1, max_rel_update=0.0008979114752898277
# [DEBUG] entering step: T_old=15.21268002, dT=-2.18907327e-02
# [DEBUG] leaving step: T_new=15.19078929, rhs_norm=0.4922419004900185, channel_norm=2.0246975386598676, accepted_substeps=1, max_rel_update=0.0008979613213550776
# [DEBUG] entering step: T_old=15.19078929, dT=-2.18592324e-02
# [DEBUG] leaving step: T_new=15.16893005, rhs_norm=0.4929775489984931, channel_norm=2.035473649454043, accepted_substeps=1, max_rel_update=0.0008980092328479631
# [DEBUG] entering step: T_old=15.16893005, dT=-2.18277774e-02
# [DEBUG] leaving step: T_new=15.14710228, rhs_norm=0.49371322844896814, channel_norm=2.046250311894385, accepted_substeps=1, max_rel_update=0.0008980552033618178
# [DEBUG] entering step: T_old=15.14710228, dT=-2.17963677e-02
# [DEBUG] leaving step: T_new=15.12530591, rhs_norm=0.4944489323353449, channel_norm=2.0570275026122165, accepted_substeps=1, max_rel_update=0.0008980992264859496
# [DEBUG] entering step: T_old=15.12530591, dT=-2.17650031e-02
# [DEBUG] leaving step: T_new=15.10354091, rhs_norm=0.4951846541172514, channel_norm=2.067805198161856, accepted_substeps=1, max_rel_update=0.0008981412958033118
# [DEBUG] entering step: T_old=15.10354091, dT=-2.17336837e-02
# [DEBUG] leaving step: T_new=15.08180722, rhs_norm=0.49592038722001186, channel_norm=2.078583375020539, accepted_substeps=1, max_rel_update=0.0008981814048902324
# [DEBUG] entering step: T_old=15.08180722, dT=-2.17024094e-02
# [DEBUG] leaving step: T_new=15.06010481, rhs_norm=0.49665612503465345, channel_norm=2.089362009588381, accepted_substeps=1, max_rel_update=0.0008982195473201727
# [DEBUG] entering step: T_old=15.06010481, dT=-2.16711801e-02
# [DEBUG] leaving step: T_new=15.03843363, rhs_norm=0.4973918609178837, channel_norm=2.1001410781883005, accepted_substeps=1, max_rel_update=0.0008982557166599571
# [DEBUG] entering step: T_old=15.03843363, dT=-2.16399957e-02
# [DEBUG] leaving step: T_new=15.01679364, rhs_norm=0.498127588192092, channel_norm=2.110920557065967, accepted_substeps=1, max_rel_update=0.0008982899064722015
# [DEBUG] entering step: T_old=15.01679364, dT=-2.16088562e-02
# [DEBUG] leaving step: T_new=14.99518478, rhs_norm=0.49886330014533553, channel_norm=2.1217004223897495, accepted_substeps=1, max_rel_update=0.0008983221103152206
# [DEBUG] entering step: T_old=14.99518478, dT=-2.15777615e-02
# [DEBUG] leaving step: T_new=14.97360702, rhs_norm=0.4995989900313489, channel_norm=2.1324806502506504, accepted_substeps=1, max_rel_update=0.0008983523217417204
# [DEBUG] entering step: T_old=14.97360702, dT=-2.15467116e-02
# [DEBUG] leaving step: T_new=14.95206031, rhs_norm=0.5003346510695323, channel_norm=2.1432612166622764, accepted_substeps=1, max_rel_update=0.0008983805343021735
# [DEBUG] entering step: T_old=14.95206031, dT=-2.15157063e-02
# [DEBUG] leaving step: T_new=14.93054460, rhs_norm=0.5010702764449655, channel_norm=2.1540420975607835, accepted_substeps=1, max_rel_update=0.0008984067415422613
# [DEBUG] entering step: T_old=14.93054460, dT=-2.14847456e-02
# [DEBUG] leaving step: T_new=14.90905986, rhs_norm=0.5018058593083972, channel_norm=2.1648232688048195, accepted_substeps=1, max_rel_update=0.0008984309370029951
# [DEBUG] entering step: T_old=14.90905986, dT=-2.14538295e-02
# [DEBUG] leaving step: T_new=14.88760603, rhs_norm=0.5025413927762695, channel_norm=2.175604706175505, accepted_substeps=1, max_rel_update=0.0008984531142237981
# [DEBUG] entering step: T_old=14.88760603, dT=-2.14229579e-02
# [DEBUG] leaving step: T_new=14.86618307, rhs_norm=0.5032768699307129, channel_norm=2.1863863853763803, accepted_substeps=1, max_rel_update=0.0008984732667395985
# [DEBUG] entering step: T_old=14.86618307, dT=-2.13921307e-02
# [DEBUG] leaving step: T_new=14.84479094, rhs_norm=0.5040122838195678, channel_norm=2.197168282033375, accepted_substeps=1, max_rel_update=0.0008984913880828663
# [DEBUG] entering step: T_old=14.84479094, dT=-2.13613479e-02
# [DEBUG] leaving step: T_new=14.82342959, rhs_norm=0.5047476274563929, channel_norm=2.207950371694775, accepted_substeps=1, max_rel_update=0.000898507471783324
# [DEBUG] entering step: T_old=14.82342959, dT=-2.13306093e-02
# [DEBUG] leaving step: T_new=14.80209898, rhs_norm=0.5054828938204892, channel_norm=2.21873262983118, accepted_substeps=1, max_rel_update=0.0008985215113670794
# [DEBUG] entering step: T_old=14.80209898, dT=-2.12999150e-02
# [DEBUG] leaving step: T_new=14.78079907, rhs_norm=0.506218075856909, channel_norm=2.229515031835498, accepted_substeps=1, max_rel_update=0.000898533500359845
# [DEBUG] entering step: T_old=14.78079907, dT=-2.12692649e-02
# [DEBUG] leaving step: T_new=14.75952980, rhs_norm=0.5069531664764901, channel_norm=2.2402975530229106, accepted_substeps=1, max_rel_update=0.0008985434322843701
# [DEBUG] entering step: T_old=14.75952980, dT=-2.12386589e-02
# [DEBUG] leaving step: T_new=14.73829114, rhs_norm=0.5076881585558735, channel_norm=2.251080168630837, accepted_substeps=1, max_rel_update=0.0008985513006605247
# [DEBUG] entering step: T_old=14.73829114, dT=-2.12080969e-02
# [DEBUG] leaving step: T_new=14.71708304, rhs_norm=0.508423044937534, channel_norm=2.2618628538189434, accepted_substeps=1, max_rel_update=0.0008985570990088653
# [DEBUG] entering step: T_old=14.71708304, dT=-2.11775789e-02
# [DEBUG] leaving step: T_new=14.69590547, rhs_norm=0.5091578184298073, channel_norm=2.272645583669109, accepted_substeps=1, max_rel_update=0.0008985608208471357
# [DEBUG] entering step: T_old=14.69590547, dT=-2.11471048e-02
# [DEBUG] leaving step: T_new=14.67475836, rhs_norm=0.5098924718069313, channel_norm=2.283428333185421, accepted_substeps=1, max_rel_update=0.0008985624596926472
# [DEBUG] entering step: T_old=14.67475836, dT=-2.11166745e-02
# ...
# [DEBUG] leaving step: T_new=5.21843544, rhs_norm=183.7290650429433, channel_norm=111.05349109982151, accepted_substeps=1, max_rel_update=0.012598040627147917
# [DEBUG] entering step: T_old=5.21843544, dT=-7.50922092e-03
# [DEBUG] leaving step: T_new=5.21092622, rhs_norm=188.00899375915733, channel_norm=112.46529216978449, accepted_substeps=1, max_rel_update=0.012712802235942015
# [DEBUG] entering step: T_old=5.21092622, dT=-7.49841531e-03
# [DEBUG] leaving step: T_new=5.20342780, rhs_norm=192.4333356306943, channel_norm=113.90823723996566, accepted_substeps=1, max_rel_update=0.01283013667899259
# [DEBUG] entering step: T_old=5.20342780, dT=-7.48762525e-03
# [DEBUG] leaving step: T_new=5.19594017, rhs_norm=197.00857830753625, channel_norm=115.38336364453444, accepted_substeps=1, max_rel_update=0.012950129334906585
# [DEBUG] entering step: T_old=5.19594017, dT=-7.47685071e-03
# [DEBUG] leaving step: T_new=5.18846332, rhs_norm=201.7415753941707, channel_norm=116.89175528525816, accepted_substeps=1, max_rel_update=0.0130728693728385
# [DEBUG] entering step: T_old=5.18846332, dT=-7.46609167e-03
# [DEBUG] leaving step: T_new=5.18099723, rhs_norm=206.63957137405203, channel_norm=118.43454526853506, accepted_substeps=1, max_rel_update=0.013198449963489201
# [DEBUG] entering step: T_old=5.18099723, dT=-7.45534812e-03
# [DEBUG] leaving step: T_new=5.17354188, rhs_norm=211.71022852773254, channel_norm=120.01291872314387, accepted_substeps=1, max_rel_update=0.013326968504248892
# [DEBUG] entering step: T_old=5.17354188, dT=-7.44462003e-03
# [DEBUG] leaving step: T_new=5.16609726, rhs_norm=216.96165602813124, channel_norm=121.62811581327024, accepted_substeps=1, max_rel_update=0.01345852685953297
# [DEBUG] entering step: T_old=5.16609726, dT=-7.43390737e-03
# [DEBUG] leaving step: T_new=5.15866336, rhs_norm=222.40244141549053, channel_norm=123.28143496272584, accepted_substeps=1, max_rel_update=0.013593231617546843
# [DEBUG] entering step: T_old=5.15866336, dT=-7.42321014e-03
# [DEBUG] leaving step: T_new=5.15124015, rhs_norm=228.04168467590986, channel_norm=124.97423630776507, accepted_substeps=1, max_rel_update=0.013731194364756151
# [DEBUG] entering step: T_old=5.15124015, dT=-7.41252829e-03
# [DEBUG] leaving step: T_new=5.14382762, rhs_norm=233.88903517118172, channel_norm=126.70794539755966, accepted_substeps=1, max_rel_update=0.013872531979512227
# [DEBUG] entering step: T_old=5.14382762, dT=-7.40186181e-03
# [DEBUG] leaving step: T_new=5.13642576, rhs_norm=239.95473169432518, channel_norm=128.48405716321474, accepted_substeps=1, max_rel_update=0.014017366946345321
# [DEBUG] entering step: T_old=5.13642576, dT=-7.39121069e-03
# [DEBUG] leaving step: T_new=5.12903455, rhs_norm=246.24964595508592, channel_norm=130.30414017824674, accepted_substeps=1, max_rel_update=0.01416582769269126
# [DEBUG] entering step: T_old=5.12903455, dT=-7.38057489e-03
# [DEBUG] leaving step: T_new=5.12165397, rhs_norm=252.7853298332026, channel_norm=132.1698412356792, accepted_substeps=1, max_rel_update=0.014318048949790212
# [DEBUG] entering step: T_old=5.12165397, dT=-7.36995439e-03
# [DEBUG] leaving step: T_new=5.11428402, rhs_norm=259.5740667748163, channel_norm=134.0828902694301, accepted_substeps=1, max_rel_update=0.01447417213991834
# [DEBUG] entering step: T_old=5.11428402, dT=-7.35934918e-03
# [DEBUG] leaving step: T_new=5.10692467, rhs_norm=266.62892774976865, channel_norm=136.04510565042753, accepted_substeps=1, max_rel_update=0.014634345792028363
# [DEBUG] entering step: T_old=5.10692467, dT=-7.34875923e-03
# [DEBUG] leaving step: T_new=5.09957591, rhs_norm=273.9638322350826, channel_norm=138.05839989100798, accepted_substeps=1, max_rel_update=0.014798725988376707
# [DEBUG] entering step: T_old=5.09957591, dT=-7.33818452e-03
# [DEBUG] leaving step: T_new=5.09223772, rhs_norm=281.5936147436645, channel_norm=140.12478579458084, accepted_substeps=1, max_rel_update=0.01496747684461207
# [DEBUG] entering step: T_old=5.09223772, dT=-7.32762502e-03
# [DEBUG] leaving step: T_new=5.08491010, rhs_norm=289.53409747775163, channel_norm=142.24638309142696, accepted_substeps=1, max_rel_update=0.015140771026450115
# [DEBUG] entering step: T_old=5.08491010, dT=-7.31708072e-03
# [DEBUG] leaving step: T_new=5.07759302, rhs_norm=299.2350612882622, channel_norm=144.42542560577866, accepted_substeps=1, max_rel_update=0.015392497508730497
# [DEBUG] entering step: T_old=5.07759302, dT=-7.30655159e-03
# [DEBUG] leaving step: T_new=5.07028647, rhs_norm=315.67267647559925, channel_norm=146.66426900418574, accepted_substeps=1, max_rel_update=0.01597003219317219
# [DEBUG] entering step: T_old=5.07028647, dT=-7.29603761e-03
# [DEBUG] leaving step: T_new=5.06299043, rhs_norm=333.354329483235, channel_norm=148.9653991805415, accepted_substeps=1, max_rel_update=0.016583219233352785
# [DEBUG] entering step: T_old=5.06299043, dT=-7.28553877e-03
# [DEBUG] leaving step: T_new=5.05570489, rhs_norm=352.40192391038335, channel_norm=151.3314413392458, accepted_substeps=1, max_rel_update=0.017235129043521216
# [DEBUG] entering step: T_old=5.05570489, dT=-7.27505503e-03
# [DEBUG] leaving step: T_new=5.04842983, rhs_norm=372.95220324137654, channel_norm=153.76516984476473, accepted_substeps=1, max_rel_update=0.017929174378339945
# [DEBUG] entering step: T_old=5.04842983, dT=-7.26458637e-03
# [DEBUG] leaving step: T_new=5.04116525, rhs_norm=395.158931142341, channel_norm=156.26951891354145, accepted_substeps=1, max_rel_update=0.018669157578842147
# [DEBUG] entering step: T_old=5.04116525, dT=-7.25413278e-03
# [DEBUG] leaving step: T_new=5.03391112, rhs_norm=419.1954501759626, channel_norm=158.8475942328309, accepted_substeps=1, max_rel_update=0.019459325647044546
# [DEBUG] entering step: T_old=5.03391112, dT=-7.24369423e-03
# [DEBUG] leaving step: T_new=5.02666742, rhs_norm=445.2576952548858, channel_norm=161.50268560079786, accepted_substeps=1, max_rel_update=0.02030443467316643
# [DEBUG] entering step: T_old=5.02666742, dT=-7.23327071e-03
# [DEBUG] leaving step: T_new=5.01943415, rhs_norm=473.56775580933663, channel_norm=164.23828069320612, accepted_substeps=1, max_rel_update=0.021209825481812862
# [DEBUG] entering step: T_old=5.01943415, dT=-7.22286218e-03
# [DEBUG] leaving step: T_new=5.01221129, rhs_norm=504.3781029344858, channel_norm=167.05808007450955, accepted_substeps=1, max_rel_update=0.022181512794520523
# [DEBUG] entering step: T_old=5.01221129, dT=-7.21246863e-03
# [DEBUG] leaving step: T_new=5.00499882, rhs_norm=537.9766260780436, channel_norm=169.96601358524896, accepted_substeps=1, max_rel_update=0.0232262907498213
# [DEBUG] entering step: T_old=5.00499882, dT=-7.20209004e-03
# [DEBUG] leaving step: T_new=4.99779673, rhs_norm=574.692659949182, channel_norm=172.96625825367695, accepted_substeps=1, max_rel_update=0.0243518583135131
# [DEBUG] entering step: T_old=4.99779673, dT=-7.19172638e-03
# [DEBUG] leaving step: T_new=4.99060500, rhs_norm=614.9042287157354, channel_norm=176.06325789773686, accepted_substeps=1, max_rel_update=0.02556696899543754
# [DEBUG] entering step: T_old=4.99060500, dT=-7.18137763e-03
# [DEBUG] leaving step: T_new=4.98342363, rhs_norm=659.0467944972619, channel_norm=179.26174460419784, accepted_substeps=1, max_rel_update=0.026881610425120637
# [DEBUG] entering step: T_old=4.98342363, dT=-7.17104378e-03
# [DEBUG] leaving step: T_new=4.97625258, rhs_norm=707.6238751262978, channel_norm=182.56676229536004, accepted_substeps=1, max_rel_update=0.02830722080999294
# [DEBUG] entering step: T_old=4.97625258, dT=-7.16072479e-03
# [DEBUG] leaving step: T_new=4.96909186, rhs_norm=761.2199982617332, channel_norm=185.98369262062394, accepted_substeps=1, max_rel_update=0.029856951216707943
# [DEBUG] entering step: T_old=4.96909186, dT=-7.15042066e-03
# [DEBUG] leaving step: T_new=4.96194144, rhs_norm=820.516593649111, channel_norm=189.5182834409946, accepted_substeps=1, max_rel_update=0.031545985133708265
# [DEBUG] entering step: T_old=4.96194144, dT=-7.14013135e-03
# [DEBUG] leaving step: T_new=4.95480131, rhs_norm=886.3116044100652, channel_norm=193.17668020972627, accepted_substeps=1, max_rel_update=0.03339193010266913
# [DEBUG] entering step: T_old=4.95480131, dT=-7.12985685e-03
# [DEBUG] leaving step: T_new=4.94767145, rhs_norm=959.543838261039, channel_norm=196.96546059266007, accepted_substeps=1, max_rel_update=0.035415300648489335
# [DEBUG] entering step: T_old=4.94767145, dT=-7.11959713e-03
# [DEBUG] leaving step: T_new=4.94055185, rhs_norm=1041.3234040150503, channel_norm=200.89167271796225, accepted_substeps=1, max_rel_update=0.03764011771063852
# [DEBUG] entering step: T_old=4.94055185, dT=-7.10935218e-03
# [DEBUG] leaving step: T_new=4.93344250, rhs_norm=1132.9700213168046, channel_norm=204.9628774981083, accepted_substeps=1, max_rel_update=0.04009465788896893
# [DEBUG] entering step: T_old=4.93344250, dT=-7.09912197e-03
# [DEBUG] leaving step: T_new=4.92634338, rhs_norm=1236.061601187444, channel_norm=209.18719552789668, accepted_substeps=1, max_rel_update=0.042812396929649145
# [DEBUG] entering step: T_old=4.92634338, dT=-7.08890648e-03
# [DEBUG] leaving step: T_new=4.91925447, rhs_norm=1352.4963433147689, channel_norm=213.57335913252518, accepted_substeps=1, max_rel_update=0.045833207266306936
# [DEBUG] entering step: T_old=4.91925447, dT=-7.07870569e-03
# [DEBUG] leaving step: T_new=4.91217576, rhs_norm=1484.572789625454, channel_norm=218.13077022052258, accepted_substeps=1, max_rel_update=0.04920489097120072
# [DEBUG] entering step: T_old=4.91217576, dT=-7.06851958e-03
# [DEBUG] leaving step: T_new=4.90510725, rhs_norm=1635.0939727826585, channel_norm=222.86956468946318, accepted_substeps=1, max_rel_update=0.05298515997894423
# [DEBUG] entering step: T_old=4.90510725, dT=-7.05834812e-03
# [DEBUG] leaving step: T_new=4.89804890, rhs_norm=1807.5042474727595, channel_norm=227.8006842396218, accepted_substeps=1, max_rel_update=0.05724421919213547
# [DEBUG] entering step: T_old=4.89804890, dT=-7.04819131e-03
# [DEBUG] leaving step: T_new=4.89100071, rhs_norm=2006.0709706437729, channel_norm=232.93595657435333, accepted_substeps=1, max_rel_update=0.06206817166037032
# [DEBUG] entering step: T_old=4.89100071, dT=-7.03804910e-03
# [DEBUG] leaving step: T_new=4.88396266, rhs_norm=2236.1285009620565, channel_norm=238.2881851082459, accepted_substeps=1, max_rel_update=0.06756355877167683
# [DEBUG] entering step: T_old=4.88396266, dT=-7.02792150e-03
# [DEBUG] leaving step: T_new=4.87693474, rhs_norm=2504.409973745248, channel_norm=254.60549783119018, accepted_substeps=1, max_rel_update=0.07386348879202873
# [DEBUG] entering step: T_old=4.87693474, dT=-7.01780846e-03
# [DEBUG] leaving step: T_new=4.86991693, rhs_norm=2819.5045364440416, channel_norm=274.39224062642785, accepted_substeps=1, max_rel_update=0.0777153005877225
# [DEBUG] entering step: T_old=4.86991693, dT=-7.00770998e-03
# [DEBUG] leaving step: T_new=4.86290922, rhs_norm=3192.4968021436766, channel_norm=296.7643323300913, accepted_substeps=1, max_rel_update=0.08153325200664845
# [DEBUG] entering step: T_old=4.86290922, dT=-6.99762603e-03
# [DEBUG] leaving step: T_new=4.85591159, rhs_norm=3637.8756247042547, channel_norm=322.22082549759716, accepted_substeps=1, max_rel_update=0.08578016423884308
# [DEBUG] entering step: T_old=4.85591159, dT=-6.98755659e-03
# [DEBUG] leaving step: T_new=4.84892403, rhs_norm=4174.84864938576, channel_norm=351.3928166945315, accepted_substeps=1, max_rel_update=0.09053415821862172
# [DEBUG] entering step: T_old=4.84892403, dT=-6.97750164e-03
# [DEBUG] leaving step: T_new=4.84194653, rhs_norm=4829.281296574607, channel_norm=385.08913486792073, accepted_substeps=1, max_rel_update=0.09589358852113844
# [DEBUG] entering step: T_old=4.84194653, dT=-6.96746116e-03
# [DEBUG] leaving step: T_new=4.83497907, rhs_norm=5636.619435685278, channel_norm=424.36206186229424, accepted_substeps=1, max_rel_update=0.10198399133707957
# [DEBUG] entering step: T_old=4.83497907, dT=-6.95743513e-03
# [DEBUG] leaving step: T_new=4.82802164, rhs_norm=6646.40264136731, channel_norm=470.6039770714727, accepted_substeps=1, max_rel_update=0.10896807081728234
# [DEBUG] entering step: T_old=4.82802164, dT=-6.94742352e-03
# [DEBUG] leaving step: T_new=4.82107421, rhs_norm=7929.425573579699, channel_norm=525.6930548172448, accepted_substeps=1, max_rel_update=0.11706037439077051
# [DEBUG] entering step: T_old=4.82107421, dT=-6.93742632e-03
# [DEBUG] leaving step: T_new=4.81413679, rhs_norm=9589.455755603263, channel_norm=592.2191975982928, accepted_substeps=1, max_rel_update=0.1265494040132896
# [DEBUG] entering step: T_old=4.81413679, dT=-6.92744351e-03
# [DEBUG] leaving step: T_new=4.80720934, rhs_norm=11783.089969522542, channel_norm=673.8458877299915, accepted_substeps=1, max_rel_update=0.13783188802850457
# [DEBUG] entering step: T_old=4.80720934, dT=-6.91747506e-03
# [DEBUG] leaving step: T_new=4.80029187, rhs_norm=14754.784378018474, channel_norm=775.911740699153, accepted_substeps=1, max_rel_update=0.15146764984052122
# [DEBUG] entering step: T_old=4.80029187, dT=-6.90752096e-03
# [DEBUG] leaving step: T_new=4.79338435, rhs_norm=18901.612820182825, channel_norm=906.4750273826198, accepted_substeps=1, max_rel_update=0.1682707965803169
# [DEBUG] entering step: T_old=4.79338435, dT=-6.89758118e-03
# [DEBUG] leaving step: T_new=4.78648677, rhs_norm=24899.747651733105, channel_norm=1078.223058102887, accepted_substeps=1, max_rel_update=0.18946802231957477
# [DEBUG] entering step: T_old=4.78648677, dT=-6.88765570e-03
# [DEBUG] leaving step: T_new=4.77959911, rhs_norm=33968.21977446535, channel_norm=1312.184460658967, accepted_substeps=1, max_rel_update=0.21698794214967962
# [DEBUG] entering step: T_old=4.77959911, dT=-6.87774451e-03
# [DEBUG] leaving step: T_new=4.77272137, rhs_norm=48464.403316825985, channel_norm=1645.5102442970838, accepted_substeps=1, max_rel_update=0.254023571861782
# [DEBUG] entering step: T_old=4.77272137, dT=-6.86784757e-03
# [DEBUG] leaving step: T_new=4.76585352, rhs_norm=73367.0572559497, channel_norm=2149.3840104353994, accepted_substeps=1, max_rel_update=0.3062112605403782
# [DEBUG] entering step: T_old=4.76585352, dT=-6.85796488e-03
# [DEBUG] leaving step: T_new=4.75899555, rhs_norm=120459.00476740899, channel_norm=2975.487634896454, accepted_substeps=1, max_rel_update=0.38434436119849574
# [DEBUG] entering step: T_old=4.75899555, dT=-6.84809641e-03
# [DEBUG] leaving step: T_new=4.75214746, rhs_norm=222208.61146534534, channel_norm=4497.193629878355, accepted_substeps=1, max_rel_update=0.5114139871177302
# [DEBUG] entering step: T_old=4.75214746, dT=-6.83824214e-03
# [DEBUG] leaving step: T_new=4.74530921, rhs_norm=489298.2711723027, channel_norm=7843.133688286713, accepted_substeps=1, max_rel_update=0.7440062256111626
# [DEBUG] entering step: T_old=4.74530921, dT=-6.82840205e-03
# [DEBUG] leaving step: T_new=4.73848081, rhs_norm=1439408.8606368217, channel_norm=17671.996108237887, accepted_substeps=2, max_rel_update=0.6265902642097022
# history length = 1001
# instability record = 1000
# ===== Final record =====
# {'accepted_substeps': 2,
#  'channel_norm': 17671.996108237887,
#  'dT': -0.00682840205360602,
#  'diagnosis_payload': {'basis_labels': ['ud', 'du'],
#                        'dominant_spin_structure': 'triplet',
#                        'geometry': 'pp',
#                        'hermitian_residual': 283.49129879292775,
#                        'leading_eigenvalue': (559.670263202972-2.687314956583494e-36j),
#                        'leading_eigenvalue_abs': 559.670263202972,
#                        'mother_kernel': 'pp_mother_sz0',
#                        'singlet_weight': 0.38967721492511626,
#                        'sort_by': 'abs',
#                        'triplet_weight': 0.6103227850748834},
#  'instability': True,
#  'instability_reason': 'channel norm=1.767e+04 exceeded '
#                        'channel_divergence_threshold',
#  'leading_Q': [0.0, 1.8137993642342174],
#  'leading_channel_name': 'pp_mother_sz0',
#  'leading_eigenvalue_abs': 559.670263202972,
#  'leading_order_label': None,
#  'max_rel_update': 0.6265902642097022,
#  'rhs_norm': 1439408.8606368217,
#  'step_index': 1000,
#  'temperature': 4.738480812414304,
#  'terminated_early': False,
#  'termination_reason': None}

# %%
import numpy as np
import matplotlib.pyplot as plt

Qs_to_check = FLOW_KWARGS["diagnosis_Qs"]
# 如果你想继续测试 Q -> Q+G 不变性，再手动加 reciprocal vector
# Qs_to_check = FLOW_KWARGS["diagnosis_Qs"] + 5*np.array([np.pi, np.pi/np.sqrt(3)]) + np.array([0,2*np.pi/np.sqrt(3)])

solver = pi_result["solver"]

mother_channels = [
    "pp_mother_sz0",
    "ph_mother_longitudinal",
]

print("===== Final-state mother-channel diagnosis across all Q =====")
Q_summary = []

for i, Q in enumerate(Qs_to_check):
    Q = np.asarray(Q, dtype=float)
    mothers = solver.build_mother_kernel_dict(Q)

    print(f"\n===== Q[{i}] = {Q} =====")
    row = {
        "Q_index": i,
        "Q_vec": Q,
    }

    vals_dict = {}
    for name in mother_channels:
        k = mothers[name]
        vals, vecs = k.eig(sort_by="abs")
        eigmax = abs(vals[0])
        vals_dict[name] = eigmax
        row[name] = float(eigmax)
        print(f"{name:24s} |eig|max = {eigmax:.8g}")

    lead_name = max(vals_dict, key=vals_dict.get)
    row["leading_geometry"] = lead_name
    row["leading_value"] = vals_dict[lead_name]
    Q_summary.append(row)

    print(f"--> leading mother channel at this Q: {lead_name}  (|eig|max = {vals_dict[lead_name]:.8g})")

print(Q_summary)
labels = [f"Q{i}" for i in range(len(Q_summary))]
x = np.arange(len(labels))
width = 0.35

pp_vals = [row["pp_mother_sz0"] for row in Q_summary]
ph_vals = [row["ph_mother_longitudinal"] for row in Q_summary]

plt.figure(figsize=(8, 5))
plt.bar(x - width/2, pp_vals, width, label="pp_mother_sz0")
plt.bar(x + width/2, ph_vals, width, label="ph_mother_longitudinal")

plt.xticks(x, labels)
plt.ylabel("|leading eigenvalue|")
plt.title("Final mother-channel diagnosis across Q")
plt.legend()
plt.show()

# ----------------------------------------
Q = np.array([0.0, 0.0])
mothers = solver.build_mother_kernel_dict(Q)

for name in ["pp_mother_sz0", "ph_mother_longitudinal"]:
    k = mothers[name]
    vals, vecs = k.eig(sort_by="abs")
    print(f"\n==== {name} ====")
    print("Q =", k.Q)
    print("|eig|max =", abs(vals[0]))
    print("vec.real =", np.real(vecs[:, 0]))
    print("vec.abs  =", np.abs(vecs[:, 0]))
    print(f"\n==== {name} ====")
    print("Q =", k.Q)
    print("second |eig|max =", abs(vals[1]))
    print("vec.real =", np.real(vecs[:, 1]))
    print("vec.abs  =", np.abs(vecs[:, 1]))
# Out:
# ===== Final-state mother-channel diagnosis across all Q =====
#
# ===== Q[0] = [0. 0.] =====
# pp_mother_sz0            |eig|max = 0.00029044602
# ph_mother_longitudinal   |eig|max = 0.00025089042
# --> leading mother channel at this Q: pp_mother_sz0  (|eig|max = 0.00029044602)
#
# ===== Q[1] = [0.         1.81379936] =====
# pp_mother_sz0            |eig|max = 559.67026
# ph_mother_longitudinal   |eig|max = 9.5172251
# --> leading mother channel at this Q: pp_mother_sz0  (|eig|max = 559.67026)
#
# ===== Q[2] = [1.57079633 0.90689968] =====
# pp_mother_sz0            |eig|max = 559.67026
# ph_mother_longitudinal   |eig|max = 9.5172251
# --> leading mother channel at this Q: pp_mother_sz0  (|eig|max = 559.67026)
#
# ===== Q[3] = [-1.57079633  0.90689968] =====
# pp_mother_sz0            |eig|max = 559.67026
# ph_mother_longitudinal   |eig|max = 9.5172251
# --> leading mother channel at this Q: pp_mother_sz0  (|eig|max = 559.67026)
# [{'Q_index': 0, 'Q_vec': array([0., 0.]), 'pp_mother_sz0': 0.00029044602236239116, 'ph_mother_longitudinal': 0.00025089041699584414, 'leading_geometry': 'pp_mother_sz0', 'leading_value': np.float64(0.00029044602236239116)}, {'Q_index': 1, 'Q_vec': array([0.        , 1.81379936]), 'pp_mother_sz0': 559.670263202972, 'ph_mother_longitudinal': 9.517225094930382, 'leading_geometry': 'pp_mother_sz0', 'leading_value': np.float64(559.670263202972)}, {'Q_index': 2, 'Q_vec': array([1.57079633, 0.90689968]), 'pp_mother_sz0': 559.6702632029718, 'ph_mother_longitudinal': 9.517225094930406, 'leading_geometry': 'pp_mother_sz0', 'leading_value': np.float64(559.6702632029718)}, {'Q_index': 3, 'Q_vec': array([-1.57079633,  0.90689968]), 'pp_mother_sz0': 559.6702632029715, 'ph_mother_longitudinal': 9.517225094929714, 'leading_geometry': 'pp_mother_sz0', 'leading_value': np.float64(559.6702632029715)}]
# ==== pp_mother_sz0 ====
# Q = [0. 0.]
# |eig|max = 0.00029044602236239116
# vec.real = [ 0.39038887 -0.09897508  0.06193756  0.39038886 -0.09897508  0.06193756
#  -0.39038887  0.09897508 -0.06193756 -0.39038887  0.09897508 -0.06193756]
# vec.abs  = [0.39038887 0.13412079 0.28214916 0.39038886 0.13412079 0.28214916
#  0.39038887 0.13412079 0.28214916 0.39038887 0.13412079 0.28214916]
#
# ==== pp_mother_sz0 ====
# Q = [0. 0.]
# second |eig|max = 0.0002904460223622666
# vec.real = [ 0.39038887 -0.09897508  0.06193757  0.39038886 -0.09897508  0.06193757
#  -0.39038887  0.09897508 -0.06193757 -0.39038887  0.09897508 -0.06193757]
# vec.abs  = [0.39038887 0.13412079 0.28214916 0.39038886 0.13412079 0.28214916
#  0.39038887 0.13412079 0.28214916 0.39038887 0.13412079 0.28214916]
#
# ==== ph_mother_longitudinal ====
# Q = [0. 0.]
# |eig|max = 0.00025089041699584414
# vec.real = [0.01866635 0.02109212 0.02191127 0.01866635 0.02109212 0.02191127
#  0.50703724 0.10415265 0.47288293 0.50703724 0.10415265 0.47288293]
# vec.abs  = [0.01929092 0.02530136 0.08452118 0.01929092 0.02530136 0.08452119
#  0.50703724 0.10482463 0.47304218 0.50703724 0.10482463 0.47304218]
#
# ==== ph_mother_longitudinal ====
# Q = [0. 0.]
# second |eig|max = 0.0002508903982466923
# vec.real = [0.01866635 0.02109212 0.02191124 0.01866635 0.02109212 0.02191124
#  0.50703725 0.10415255 0.47288294 0.50703725 0.10415256 0.47288294]
# vec.abs  = [0.01929092 0.02530136 0.08452118 0.01929093 0.02530136 0.08452117
#  0.50703725 0.10482456 0.47304219 0.50703725 0.10482457 0.47304219]
