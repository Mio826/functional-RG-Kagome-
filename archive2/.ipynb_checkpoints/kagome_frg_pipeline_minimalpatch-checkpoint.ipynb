# %% [markdown]
# # Kagome fRG sanity-check pipeline
#
# This notebook builds a **standard spinful kagome model** using the corrected `channels.py` and `frg_flow.py`, then runs two benchmark interaction points inspired by the PRL phase diagram:
#
# - **FM benchmark:** `U=6, V=0`
# - **PI benchmark:** `U=0, V=10`
#
# Target setup:
# - no flux
# - van Hove filling proxy: `mu = 0`
# - `Npatch = 12`
#
# The purpose is simple:
#
# 1. verify the corrected longitudinal channel construction in a full end-to-end pipeline
# 2. check whether the final leading instability looks **FM-like** for large `U`
# 3. check whether it looks **PI-like** for large `V`
#
# If the second case still does **not** show PI-like structure, the next place to inspect is likely:
# - `form_factor.py`
# - `kagome_order_diagnosis.py`
#
# ---

# %%
import sys
from pathlib import Path
from pprint import pprint
import numpy as np
import numpy as np
import matplotlib.pyplot as plt

# Make sure the uploaded modules are importable
sys.path.insert(0, "/mnt/data")

from noninteracting import KagomeNagaosa
from patching import FSPatcher, plot_patchset
from interaction import BareExtendedHubbard
from frg_flow import BareVertexFromInteraction, FRGFlowSolver
import sys
sys.path.insert(0, "/mnt/data")

# %% [markdown]
# ## 1. Global parameters
#
# You can tune the flow resolution here.
#
# Notes:
# - `mu=0` matches the PRL convention for kagome VHF.
# - `band_index=1` is the dispersive band crossing `mu=0` inside each 3x3 spin block.
# - `Npatch=12` is intentionally small, just for a fast pipeline sanity check.
# - For a more reliable final physics check, increase `Npatch`, `nfreq`, and `n_steps`.

# %%
# ---------- noninteracting / patching ----------
MODEL_PARAMS = dict(t=1.0, phi=0.0)   # standard kagome = phi=0
MU = 0.0
NPATCH = 24
GRID_SIZE = 320
CONTOUR_MIN_POINTS = 40

# Each spin block is 3x3 inside the full 6x6 spinful Hamiltonian
UP_SLICE = slice(0, 3)
DN_SLICE = slice(3, 6)
LOCAL_BAND_INDEX = 1   # dispersive band crossing mu=0

# ---------- flow ----------
FLOW_KWARGS = dict(
    T_start=10,
    T_stop=0.01,
    n_steps=800,
    nfreq=60,
    diagnose_every=10,
    temperature_grid="log",
    include_explicit_T_prefactor=True,
    max_relative_update=1,
    min_substep_fraction=0.01,
    channel_divergence_threshold=1e4,
    eigenvalue_threshold=1e4,
    diagnosis_sort_by="abs",
    track_crossed_channel=True,
    diagnosis_Qs = [np.array([0.0, 0.0]), np.array([0.0,  np.pi/np.sqrt(3)]), np.array([ np.pi/2,  np.pi/(2*np.sqrt(3))]), np.array([-np.pi/2,  np.pi/(2*np.sqrt(3))])]
)

# %% [markdown]
# ## 2. Build the standard spinful kagome model and the two spin patchsets

# %%
# ============================================================
# Manual exact-M patchsets on standard centered 1BZ hexagon
# ============================================================

import numpy as np
import matplotlib.pyplot as plt
from patching import PatchPoint, PatchSet, plot_patchset

model = KagomeNagaosa(MODEL_PARAMS, spin=True, B=None)

# ------------------------------------------------------------
# basic helpers
# ------------------------------------------------------------
def _sector_eig(model, k_cart, orbital_slice, band_index):
    kx, ky = float(k_cart[0]), float(k_cart[1])
    H = np.asarray(model.Hk(kx, ky), dtype=complex)
    Hs = H[orbital_slice, orbital_slice]
    evals, evecs = np.linalg.eigh(Hs)
    u = np.asarray(evecs[:, band_index], dtype=complex)
    u = u / np.linalg.norm(u)
    return float(evals[band_index]), u

def _orbital_weight(u):
    w = np.abs(np.asarray(u, dtype=complex))**2
    return w / np.sum(w)

def _cart_to_red(model, k):
    B = np.column_stack([
        np.asarray(model.b1, dtype=float),
        np.asarray(model.b2, dtype=float),
    ])
    return np.linalg.solve(B, np.asarray(k, dtype=float))

def _finite_diff_velocity(model, k_cart, orbital_slice, band_index, h=1e-6):
    kx, ky = float(k_cart[0]), float(k_cart[1])

    def band_energy(x, y):
        H = np.asarray(model.Hk(x, y), dtype=complex)
        Hs = H[orbital_slice, orbital_slice]
        evals, _ = np.linalg.eigh(Hs)
        return float(evals[band_index])

    vx = (band_energy(kx + h, ky) - band_energy(kx - h, ky)) / (2*h)
    vy = (band_energy(kx, ky + h) - band_energy(kx, ky - h)) / (2*h)
    return np.array([vx, vy], dtype=float)


# ------------------------------------------------------------
# reciprocal helpers (only for identifying duplicate M anchors)
# ------------------------------------------------------------
def _wrap_unit_interval(x, tol=1e-12):
    x = np.asarray(x, dtype=float)
    x = x - np.floor(x)
    x[np.isclose(x, 1.0, atol=tol)] = 0.0
    x[np.isclose(x, 0.0, atol=tol)] = 0.0
    return x

def _canonicalize_k_mod_G(model, k):
    B = np.column_stack([
        np.asarray(model.b1, dtype=float),
        np.asarray(model.b2, dtype=float),
    ])
    uv = np.linalg.solve(B, np.asarray(k, dtype=float))
    uv = _wrap_unit_interval(uv)
    k_can = B @ uv
    k_can[np.isclose(k_can, 0.0, atol=1e-12)] = 0.0
    return k_can


# ------------------------------------------------------------
# 1BZ geometry
# ------------------------------------------------------------
def hex_bz_vertices(model):
    """
    Standard centered 1BZ hexagon vertices for triangular/kagome reciprocal lattice.

    For reciprocal vectors b1, b2, the Wigner-Seitz 1BZ vertices are:
        ±(2b1-b2)/3, ±(b1+b2)/3, ±(-b1+2b2)/3
    """
    b1 = np.asarray(model.b1, dtype=float)
    b2 = np.asarray(model.b2, dtype=float)

    verts = np.array([
        (2*b1 - b2) / 3.0,
        (b1 + b2) / 3.0,
        (-b1 + 2*b2) / 3.0,
        -(2*b1 - b2) / 3.0,
        -(b1 + b2) / 3.0,
        -(-b1 + 2*b2) / 3.0,
    ], dtype=float)

    ang = np.arctan2(verts[:, 1], verts[:, 0])
    order = np.argsort(ang)
    return verts[order]


def exact_M6_points_1bz(model):
    """
    6 geometric M points on the boundary of the standard centered 1BZ hexagon.
    Each M point is the midpoint of one hexagon edge.
    """
    V = hex_bz_vertices(model)
    M = []

    n = len(V)
    for i in range(n):
        v0 = V[i]
        v1 = V[(i + 1) % n]
        M.append(0.5 * (v0 + v1))

    M = np.asarray(M, dtype=float)

    # keep consistent cyclic order
    ang = np.arctan2(M[:, 1], M[:, 0])
    order = np.argsort(ang)
    return M[order]


def exact_M_hex_loop_points(model, points_per_edge=1):
    """
    Build a manual hex loop from the 6 exact M points on the centered 1BZ.

    points_per_edge = 1  ->  6 patches  (6 exact M points)
    points_per_edge = 2  -> 12 patches
    points_per_edge = 4  -> 24 patches

    Total patch number = 6 * points_per_edge
    """
    if points_per_edge < 1:
        raise ValueError("points_per_edge must be >= 1")

    M6 = exact_M6_points_1bz(model)
    pts = []

    n = len(M6)
    for i in range(n):
        k0 = M6[i]
        k1 = M6[(i + 1) % n]

        # put points_per_edge points on each M-to-M segment:
        # t = 0, 1/p, 2/p, ..., (p-1)/p
        # exclude t=1 to avoid duplicating the next M point
        for m in range(points_per_edge):
            t = m / points_per_edge
            k = (1.0 - t) * k0 + t * k1
            pts.append(k)

    return np.asarray(pts, dtype=float)


def _hex_bz_vertices_for_plot(model):
    return hex_bz_vertices(model)


# ------------------------------------------------------------
# only remove duplicated M anchors from patch reps
# ------------------------------------------------------------
def _patch_keep_indices_remove_duplicate_M_anchors(model, points_per_edge, tol=1e-10):
    """
    Return indices to KEEP among the standard exact-M loop points.

    Important:
    - This function assumes the loop K_full is built exactly by exact_M_hex_loop_points.
    - Only the 6 M-anchor points are checked for modulo-G duplication:
          0, p, 2p, 3p, 4p, 5p
      where p = points_per_edge.
    - All non-anchor points are always kept.
    """
    p = int(points_per_edge)
    n_full = 6 * p
    keep = np.ones(n_full, dtype=bool)

    anchor_ids = [i * p for i in range(6)]
    M6 = exact_M6_points_1bz(model)

    seen_classes = []
    for local_anchor_idx, global_idx in enumerate(anchor_ids):
        k = M6[local_anchor_idx]
        k_can = _canonicalize_k_mod_G(model, k)

        duplicated = False
        for q_can in seen_classes:
            if np.linalg.norm(k_can - q_can) < tol:
                duplicated = True
                break

        if duplicated:
            keep[global_idx] = False
        else:
            seen_classes.append(k_can)

    return np.flatnonzero(keep)


# ------------------------------------------------------------
# patchset builder
# ------------------------------------------------------------
def build_exactM_patchset(
    model,
    orbital_slice,
    band_index,
    points_per_edge=1,
    remove_duplicate_M_modG=False,
):
    # 1) build the FULL standard loop exactly as in the original code
    K_full = exact_M_hex_loop_points(model, points_per_edge=points_per_edge)

    # 2) only patch reps may be reduced; contour stays the original full loop
    if remove_duplicate_M_modG:
        keep_idx = _patch_keep_indices_remove_duplicate_M_anchors(
            model,
            points_per_edge=points_per_edge,
        )
        K_patch = K_full[keep_idx]
    else:
        keep_idx = np.arange(len(K_full))
        K_patch = K_full

    bz_vertices = _hex_bz_vertices_for_plot(model)

    patches = []
    for pid, k in enumerate(K_patch):
        e, u = _sector_eig(model, k, orbital_slice, band_index)
        vF = _finite_diff_velocity(model, k, orbital_slice, band_index)

        patches.append(
            PatchPoint(
                patch_id=pid,
                k_cart=np.asarray(k, dtype=float),
                k_red=_cart_to_red(model, k),
                energy=e,
                vF=vF,
                vF_norm=float(np.linalg.norm(vF)),
                eigvec=u,
                orbital_weight=_orbital_weight(u),
            )
        )

    npatch = len(K_patch)
    suffix = "_dropDupM" if remove_duplicate_M_modG else ""
    return PatchSet(
        mu=0.0,
        mu_used_for_contour=0.0,
        band_index=int(band_index),
        filling=np.nan,
        patches=patches,
        fs_contour_k=np.asarray(K_full, dtype=float),   # <- keep original contour
        bz_vertices=np.asarray(bz_vertices, dtype=float),
        b1=np.asarray(model.b1, dtype=float),
        b2=np.asarray(model.b2, dtype=float),
        gauge_method=f"manual_exact_M_hex_{npatch}{suffix}",
        gauge_loop_phase=0.0,
    )


# ------------------------------------------------------------
# choose patch density here
# ------------------------------------------------------------
POINTS_PER_EDGE = 1   # 1->6, 2->12, 4->24
REMOVE_DUPLICATE_M_MODG = False

patchsets = {
    "up": build_exactM_patchset(
        model,
        UP_SLICE,
        LOCAL_BAND_INDEX,
        points_per_edge=POINTS_PER_EDGE,
        remove_duplicate_M_modG=REMOVE_DUPLICATE_M_MODG,
    ),
    "dn": build_exactM_patchset(
        model,
        DN_SLICE,
        LOCAL_BAND_INDEX,
        points_per_edge=POINTS_PER_EDGE,
        remove_duplicate_M_modG=REMOVE_DUPLICATE_M_MODG,
    ),
}

NPATCH = patchsets["up"].Npatch


# ------------------------------------------------------------
# print info
# ------------------------------------------------------------
print("Patch counts:", {k: v.Npatch for k, v in patchsets.items()})
print("mu used for contour (up/dn):", patchsets["up"].mu_used_for_contour, patchsets["dn"].mu_used_for_contour)
print("gauge method (up/dn):", patchsets["up"].gauge_method, patchsets["dn"].gauge_method)

print("\n===== exact M6 anchors in centered 1BZ =====")
M6 = exact_M6_points_1bz(model)
for i, k in enumerate(M6):
    print(
        f"M{i}: k={np.round(k, 6)} | "
        f"k_can={np.round(_canonicalize_k_mod_G(model, k), 6)}"
    )

if REMOVE_DUPLICATE_M_MODG:
    keep_idx = _patch_keep_indices_remove_duplicate_M_anchors(model, POINTS_PER_EDGE)
    print("\n===== kept indices in full loop =====")
    print(keep_idx.tolist())

for spin in ["up", "dn"]:
    print(f"\n===== {spin} exact-M{NPATCH} patches =====")
    for p in patchsets[spin].patches:
        print(
            f"id={p.patch_id:2d} | "
            f"k={np.round(p.k_cart, 6)} | "
            f"k_can={np.round(_canonicalize_k_mod_G(model, p.k_cart), 6)} | "
            f"E={p.energy:.10e} | "
            f"|vF|={p.vF_norm:.6e} | "
            f"w={np.round(p.orbital_weight, 6)}"
        )


# ------------------------------------------------------------
# neighbor distance sanity check (patch reps only)
# ------------------------------------------------------------
for spin in ["up", "dn"]:
    ks = np.array([p.k_cart for p in patchsets[spin].patches], dtype=float)
    d = np.linalg.norm(np.roll(ks, -1, axis=0) - ks, axis=1)
    print(f"\n===== {spin} neighbor distances (patch reps only) =====")
    print(np.round(d, 8))


# ------------------------------------------------------------
# plot
# ------------------------------------------------------------
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

for ax, spin in zip(axes, ["up", "dn"]):
    plot_patchset(
        patchsets[spin],
        ax=ax,
        show_contour=True,   # contour is now still the original full loop
        show_velocity=False,
        show_bz=True
    )
    ks = np.array([p.k_cart for p in patchsets[spin].patches], dtype=float)

    for i, k in enumerate(ks):
        ax.text(k[0], k[1], str(i), fontsize=8, ha="left", va="bottom")

    ax.set_title(f"{spin} exact-M{NPATCH} patchset")

plt.tight_layout()
plt.show()
# Out:
# Patch counts: {'up': 6, 'dn': 6}
# mu used for contour (up/dn): 0.0 0.0
# gauge method (up/dn): manual_exact_M_hex_6 manual_exact_M_hex_6
#
# ===== exact M6 anchors in centered 1BZ =====
# M0: k=[-1.570796 -0.9069  ] | k_can=[1.570796 0.9069  ]
# M1: k=[ 0.       -1.813799] | k_can=[0.       1.813799]
# M2: k=[ 1.570796 -0.9069  ] | k_can=[1.570796 2.720699]
# M3: k=[1.570796 0.9069  ] | k_can=[1.570796 0.9069  ]
# M4: k=[0.       1.813799] | k_can=[0.       1.813799]
# M5: k=[-1.570796  0.9069  ] | k_can=[1.570796 2.720699]
#
# ===== up exact-M6 patches =====
# id= 0 | k=[-1.570796 -0.9069  ] | k_can=[1.570796 0.9069  ] | E=1.0947644253e-47 | |vF|=7.747470e-16 | w=[0. 1. 0.]
# id= 1 | k=[ 0.       -1.813799] | k_can=[0.       1.813799] | E=1.0344233826e-31 | |vF|=3.449543e-16 | w=[1. 0. 0.]
# id= 2 | k=[ 1.570796 -0.9069  ] | k_can=[1.570796 2.720699] | E=1.4997597827e-32 | |vF|=2.255553e-16 | w=[0. 0. 1.]
# id= 3 | k=[1.570796 0.9069  ] | k_can=[1.570796 0.9069  ] | E=1.0947644253e-47 | |vF|=7.747470e-16 | w=[0. 1. 0.]
# id= 4 | k=[0.       1.813799] | k_can=[0.       1.813799] | E=1.0344233826e-31 | |vF|=3.449543e-16 | w=[1. 0. 0.]
# id= 5 | k=[-1.570796  0.9069  ] | k_can=[1.570796 2.720699] | E=1.4997597827e-32 | |vF|=2.255553e-16 | w=[0. 0. 1.]
#
# ===== dn exact-M6 patches =====
# id= 0 | k=[-1.570796 -0.9069  ] | k_can=[1.570796 0.9069  ] | E=1.0947644253e-47 | |vF|=7.747470e-16 | w=[0. 1. 0.]
# id= 1 | k=[ 0.       -1.813799] | k_can=[0.       1.813799] | E=1.0344233826e-31 | |vF|=3.449543e-16 | w=[1. 0. 0.]
# id= 2 | k=[ 1.570796 -0.9069  ] | k_can=[1.570796 2.720699] | E=1.4997597827e-32 | |vF|=2.255553e-16 | w=[0. 0. 1.]
# id= 3 | k=[1.570796 0.9069  ] | k_can=[1.570796 0.9069  ] | E=1.0947644253e-47 | |vF|=7.747470e-16 | w=[0. 1. 0.]
# id= 4 | k=[0.       1.813799] | k_can=[0.       1.813799] | E=1.0344233826e-31 | |vF|=3.449543e-16 | w=[1. 0. 0.]
# id= 5 | k=[-1.570796  0.9069  ] | k_can=[1.570796 2.720699] | E=1.4997597827e-32 | |vF|=2.255553e-16 | w=[0. 0. 1.]
#
# ===== up neighbor distances (patch reps only) =====
# [1.81379936 1.81379936 1.81379936 1.81379936 1.81379936 1.81379936]
#
# ===== dn neighbor distances (patch reps only) =====
# [1.81379936 1.81379936 1.81379936 1.81379936 1.81379936 1.81379936]

# %% [markdown]
# ## 3. Helpers for running a benchmark interaction point  Debug FRG Solver

# %%
from frg_flow import FRGFlowSolver

_old_step = FRGFlowSolver.step
_old_run = FRGFlowSolver.run

def _debug_step(self, T_old, dT):
    print(f"[DEBUG] entering step: T_old={T_old:.8f}, dT={dT:.8e}")
    try:
        rec = _old_step(self, T_old, dT)
        print(
            f"[DEBUG] leaving step: "
            f"T_new={getattr(rec, 'temperature', float(T_old + dT)):.8f}, "
            f"rhs_norm={getattr(rec, 'rhs_norm', None)}, "
            f"channel_norm={getattr(rec, 'channel_norm', None)}, "
            f"accepted_substeps={getattr(rec, 'accepted_substeps', None)}, "
            f"max_rel_update={getattr(rec, 'max_rel_update', None)}"
        )
        return rec
    except Exception as e:
        print(f"[DEBUG] exception in step:")
        print(f"        T_old = {T_old:.8f}")
        print(f"        dT    = {dT:.8e}")
        print(f"        T_new = {T_old + dT:.8f}")
        raise

def _debug_run(self):
    # print("[DEBUG] temperature path:")
    # for i, T in enumerate(self.temperature_path):
    #     print(f"  i={i:03d}, T={float(T):.8f}")
    return _old_run(self)

FRGFlowSolver.step = _debug_step
FRGFlowSolver.run = _debug_run

def build_solver(model, patchsets, U, V, flow_kwargs=None):
    flow_kwargs = {} if flow_kwargs is None else dict(flow_kwargs)
    interaction = BareExtendedHubbard.from_kagome_model(model, U=U, V=V)
    bare_gamma = BareVertexFromInteraction(interaction, patchsets)
    solver = FRGFlowSolver(
        patchsets=patchsets,
        bare_gamma=bare_gamma,
        **flow_kwargs,
    )
    return interaction, bare_gamma, solver


def summarize_history(history):
    rows = []
    for rec in history:
        rows.append({
            "step": rec.step_index,
            "T": rec.temperature,
            "channel_norm": rec.channel_norm,
            "rhs_norm": rec.rhs_norm,
            "leading_channel": rec.leading_channel_name,
            "leading_order": rec.leading_order_label,
            "leading_abs_eval": rec.leading_eigenvalue_abs,
            "instability": rec.instability,
            "reason": rec.instability_reason,
        })
    return rows


def pretty_print_final_record(history):
    rec = history[-1]
    print("===== Final record =====")
    pprint(rec.summary_dict())
    return rec


def plot_history(history, title):
    steps = [h.step_index for h in history]
    Ts = [h.temperature for h in history]
    evals = [np.nan if h.leading_eigenvalue_abs is None else h.leading_eigenvalue_abs for h in history]
    norms = [h.channel_norm for h in history]

    fig, axes = plt.subplots(1, 2, figsize=(11, 4))
    axes[0].plot(steps, evals, marker="o")
    axes[0].set_xlabel("step")
    axes[0].set_ylabel("leading |eigenvalue|")
    axes[0].set_title(f"{title}: leading eigenvalue")

    axes[1].plot(steps, norms, marker="o")
    axes[1].set_xlabel("step")
    axes[1].set_ylabel("channel norm")
    axes[1].set_title(f"{title}: channel norm")

    plt.tight_layout()
    plt.show()


def run_case(case_name, U, V, flow_kwargs=None):
    print(f"\n===== Running case: {case_name} (U={U}, V={V}) =====")
    interaction, bare_gamma, solver = build_solver(
        model=model,
        patchsets=patchsets,
        U=U,
        V=V,
        flow_kwargs=flow_kwargs if flow_kwargs is not None else FLOW_KWARGS,
    )
    history = solver.run()
    print(f"history length = {len(history)}")
    print(f"instability record = {None if solver.instability_record is None else solver.instability_record.step_index}")
    final_rec = pretty_print_final_record(history)
    plot_history(history, case_name)
    return {
        "case_name": case_name,
        "U": U,
        "V": V,
        "interaction": interaction,
        "solver": solver,
        "history": history,
        "final_record": final_rec,
    }

# %% [markdown]
# ## 4. FM benchmark: `U=6, V=0`
#
# Expectation from the PRL benchmark at van Hove filling:
# - dominant onsite interaction should favor **ferromagnetism (FM)**.

# %%
fm_result = run_case("FM benchmark", U=6.0, V=.0, flow_kwargs=FLOW_KWARGS)
# Out:
# ===== Running case: FM benchmark (U=6.0, V=0.0) =====
# [DEBUG] entering step: T_old=10.00000000, dT=-8.60823610e-02
# [DEBUG] leaving step: T_new=9.91391764, rhs_norm=0.35879413927570075, channel_norm=0.030885846621420274, accepted_substeps=1, max_rel_update=0.0051476411035700454
# [DEBUG] entering step: T_old=9.91391764, dT=-8.53413437e-02
# [DEBUG] leaving step: T_new=9.82857630, rhs_norm=0.365051995829396, channel_norm=0.06203987447002296, accepted_substeps=1, max_rel_update=0.005192337974767114
# [DEBUG] entering step: T_old=9.82857630, dT=-8.46067053e-02
# [DEBUG] leaving step: T_new=9.74396959, rhs_norm=0.3714189978912252, channel_norm=0.09346441215837795, accepted_substeps=1, max_rel_update=0.005237422948059164
# [DEBUG] entering step: T_old=9.74396959, dT=-8.38783908e-02
# [DEBUG] leaving step: T_new=9.66009120, rhs_norm=0.37789704910692506, channel_norm=0.12516180851835162, accepted_substeps=1, max_rel_update=0.005282899393328946
# [DEBUG] entering step: T_old=9.66009120, dT=-8.31563458e-02
# [DEBUG] leaving step: T_new=9.57693485, rhs_norm=0.3844880863243946, channel_norm=0.15713443277667344, accepted_substeps=1, max_rel_update=0.005328770709720303
# [DEBUG] entering step: T_old=9.57693485, dT=-8.24405163e-02
# [DEBUG] leaving step: T_new=9.49449434, rhs_norm=0.3911940801727894, channel_norm=0.18938467473202514, accepted_substeps=1, max_rel_update=0.005375040325891947
# [DEBUG] entering step: T_old=9.49449434, dT=-8.17308489e-02
# [DEBUG] leaving step: T_new=9.41276349, rhs_norm=0.39801703565171176, channel_norm=0.22191494493366606, accepted_substeps=1, max_rel_update=0.005421711700273489
# [DEBUG] entering step: T_old=9.41276349, dT=-8.10272905e-02
# [DEBUG] leaving step: T_new=9.33173620, rhs_norm=0.4049589927306758, channel_norm=0.25472767486160897, accepted_substeps=1, max_rel_update=0.0054687883213238205
# [DEBUG] entering step: T_old=9.33173620, dT=-8.03297884e-02
# [DEBUG] leaving step: T_new=9.25140641, rhs_norm=0.4120220269590317, channel_norm=0.2878253171083609, accepted_substeps=1, max_rel_update=0.005516273707791994
# [DEBUG] entering step: T_old=9.25140641, dT=-7.96382906e-02
# [DEBUG] leaving step: T_new=9.17176812, rhs_norm=0.41920825008652557, channel_norm=0.3212103455622465, accepted_substeps=1, max_rel_update=0.005564171408980925
# [DEBUG] entering step: T_old=9.17176812, dT=-7.89527454e-02
# [DEBUG] leaving step: T_new=9.09281537, rhs_norm=0.4265198106946872, channel_norm=0.3548852555923132, accepted_substeps=1, max_rel_update=0.005612485005011117
# [DEBUG] entering step: T_old=9.09281537, dT=-7.82731015e-02
# [DEBUG] leaving step: T_new=9.01454227, rhs_norm=0.4339588948392183, channel_norm=0.38885256423485226, accepted_substeps=1, max_rel_update=0.0056612181070898404
# [DEBUG] entering step: T_old=9.01454227, dT=-7.75993082e-02
# [DEBUG] leaving step: T_new=8.93694296, rhs_norm=0.4415277267036029, channel_norm=0.4231148103815336, accepted_substeps=1, max_rel_update=0.005710374357780225
# [DEBUG] entering step: T_old=8.93694296, dT=-7.69313150e-02
# [DEBUG] leaving step: T_new=8.86001165, rhs_norm=0.44922856926409843, channel_norm=0.457674554969179, accepted_substeps=1, max_rel_update=0.005759957431274238
# [DEBUG] entering step: T_old=8.86001165, dT=-7.62690721e-02
# [DEBUG] leaving step: T_new=8.78374258, rhs_norm=0.45706372496633874, channel_norm=0.4925343811711716, accepted_substeps=1, max_rel_update=0.005809971033665429
# [DEBUG] entering step: T_old=8.78374258, dT=-7.56125299e-02
# [DEBUG] leaving step: T_new=8.70813005, rhs_norm=0.465035536413737, channel_norm=0.5276968945905431, accepted_substeps=1, max_rel_update=0.005860418903228593
# [DEBUG] entering step: T_old=8.70813005, dT=-7.49616394e-02
# [DEBUG] leaving step: T_new=8.63316841, rhs_norm=0.47314638706788353, channel_norm=0.563164723454729, accepted_substeps=1, max_rel_update=0.0059113048106976375
# [DEBUG] entering step: T_old=8.63316841, dT=-7.43163519e-02
# [DEBUG] leaving step: T_new=8.55885206, rhs_norm=0.4813987019611743, channel_norm=0.5989405188120113, accepted_substeps=1, max_rel_update=0.005962632559547049
# [DEBUG] entering step: T_old=8.55885206, dT=-7.36766192e-02
# [DEBUG] leaving step: T_new=8.48517544, rhs_norm=0.48979494842185933, channel_norm=0.6350269547296765, accepted_substeps=1, max_rel_update=0.00601440598627755
# [DEBUG] entering step: T_old=8.48517544, dT=-7.30423935e-02
# [DEBUG] leaving step: T_new=8.41213304, rhs_norm=0.4983376368117434, channel_norm=0.671426728493886, accepted_substeps=1, max_rel_update=0.006066628960701575
# [DEBUG] entering step: T_old=8.41213304, dT=-7.24136273e-02
# [DEBUG] leaving step: T_new=8.33971942, rhs_norm=0.5070293212767435, channel_norm=0.7081425608112885, accepted_substeps=1, max_rel_update=0.006119305386233746
# [DEBUG] entering step: T_old=8.33971942, dT=-7.17902737e-02
# [DEBUG] leaving step: T_new=8.26792914, rhs_norm=0.5158726005105478, channel_norm=0.7451771960123755, accepted_substeps=1, max_rel_update=0.006172439200181187
# [DEBUG] entering step: T_old=8.26792914, dT=-7.11722861e-02
# [DEBUG] leaving step: T_new=8.19675686, rhs_norm=0.5248701185315893, channel_norm=0.7825334022566072, accepted_substeps=1, max_rel_update=0.006226034374038603
# [DEBUG] entering step: T_old=8.19675686, dT=-7.05596183e-02
# [DEBUG] leaving step: T_new=8.12619724, rhs_norm=0.5340245654735671, channel_norm=0.8202139717393259, accepted_substeps=1, max_rel_update=0.0062800949137864414
# [DEBUG] entering step: T_old=8.12619724, dT=-6.99522244e-02
# [DEBUG] leaving step: T_new=8.05624501, rhs_norm=0.543338678389764, channel_norm=0.8582217209004491, accepted_substeps=1, max_rel_update=0.006334624860187207
# [DEBUG] entering step: T_old=8.05624501, dT=-6.93500591e-02
# [DEBUG] leaving step: T_new=7.98689495, rhs_norm=0.5528152420713822, channel_norm=0.8965594906349909, accepted_substeps=1, max_rel_update=0.006389628289090291
# [DEBUG] entering step: T_old=7.98689495, dT=-6.87530775e-02
# [DEBUG] leaving step: T_new=7.91814188, rhs_norm=0.5624570898801651, channel_norm=0.9352301465054009, accepted_substeps=1, max_rel_update=0.006445109311735017
# [DEBUG] entering step: T_old=7.91814188, dT=-6.81612347e-02
# [DEBUG] leaving step: T_new=7.84998064, rhs_norm=0.5722671045955235, channel_norm=0.9742365789557597, accepted_substeps=1, max_rel_update=0.006501072075059784
# [DEBUG] entering step: T_old=7.84998064, dT=-6.75744867e-02
# [DEBUG] leaving step: T_new=7.78240615, rhs_norm=0.5822482192764573, channel_norm=1.0135817035278136, accepted_substeps=1, max_rel_update=0.006557520762008991
# [DEBUG] entering step: T_old=7.78240615, dT=-6.69927896e-02
# [DEBUG] leaving step: T_new=7.71541336, rhs_norm=0.5924034181384912, channel_norm=1.0532684610789067, accepted_substeps=1, max_rel_update=0.006614459591848854
# [DEBUG] entering step: T_old=7.71541336, dT=-6.64160999e-02
# [DEBUG] leaving step: T_new=7.64899726, rhs_norm=0.602735737445916, channel_norm=1.09329981800179, accepted_substeps=1, max_rel_update=0.0066718928204805746
# [DEBUG] entering step: T_old=7.64899726, dT=-6.58443744e-02
# [DEBUG] leaving step: T_new=7.58315289, rhs_norm=0.6132482664195983, channel_norm=1.1336787664463501, accepted_substeps=1, max_rel_update=0.006729824740760014
# [DEBUG] entering step: T_old=7.58315289, dT=-6.52775705e-02
# [DEBUG] leaving step: T_new=7.51787532, rhs_norm=0.6239441481605973, channel_norm=1.1744083245432533, accepted_substeps=1, max_rel_update=0.006788259682817187
# [DEBUG] entering step: T_old=7.51787532, dT=-6.47156457e-02
# [DEBUG] leaving step: T_new=7.45315967, rhs_norm=0.6348265805899256, channel_norm=1.2154915366295356, accepted_substeps=1, max_rel_update=0.006847202014380366
# [DEBUG] entering step: T_old=7.45315967, dT=-6.41585582e-02
# [DEBUG] leaving step: T_new=7.38900112, rhs_norm=0.6458988174046768, channel_norm=1.256931473476159, accepted_substeps=1, max_rel_update=0.006906656141103915
# [DEBUG] entering step: T_old=7.38900112, dT=-6.36062662e-02
# [DEBUG] leaving step: T_new=7.32539485, rhs_norm=0.6571641690508311, channel_norm=1.2987312325175289, accepted_substeps=1, max_rel_update=0.006966626506894978
# [DEBUG] entering step: T_old=7.32539485, dT=-6.30587284e-02
# [DEBUG] leaving step: T_new=7.26233612, rhs_norm=0.6686260037130431, channel_norm=1.3408939380830158, accepted_substeps=1, max_rel_update=0.0070271175942478335
# [DEBUG] entering step: T_old=7.26233612, dT=-6.25159040e-02
# [DEBUG] leaving step: T_new=7.19982022, rhs_norm=0.6802877483216747, channel_norm=1.3834227416304863, accepted_substeps=1, max_rel_update=0.007088133924578406
# [DEBUG] entering step: T_old=7.19982022, dT=-6.19777523e-02
# [DEBUG] leaving step: T_new=7.13784247, rhs_norm=0.6921528895774036, channel_norm=1.426320821981854, accepted_substeps=1, max_rel_update=0.007149680058561283
# [DEBUG] entering step: T_old=7.13784247, dT=-6.14442332e-02
# [DEBUG] leaving step: T_new=7.07639823, rhs_norm=0.7042249749936957, channel_norm=1.4695913855606817, accepted_substeps=1, max_rel_update=0.00721176059647128
# [DEBUG] entering step: T_old=7.07639823, dT=-6.09153067e-02
# [DEBUG] leaving step: T_new=7.01548293, rhs_norm=0.7165076139574679, channel_norm=1.5132376666318534, accepted_substeps=1, max_rel_update=0.007274380178528627
# [DEBUG] entering step: T_old=7.01548293, dT=-6.03909334e-02
# [DEBUG] leaving step: T_new=6.95509199, rhs_norm=0.7290044788082382, channel_norm=1.5572629275433103, accepted_substeps=1, max_rel_update=0.007337543485242828
# [DEBUG] entering step: T_old=6.95509199, dT=-5.98710740e-02
# [DEBUG] leaving step: T_new=6.89522092, rhs_norm=0.7417193059361094, channel_norm=1.6016704589699005, accepted_substeps=1, max_rel_update=0.007401255237765039
# [DEBUG] entering step: T_old=6.89522092, dT=-5.93556896e-02
# [DEBUG] leaving step: T_new=6.83586523, rhs_norm=0.754655896898895, channel_norm=1.6464635801593401, accepted_substeps=1, max_rel_update=0.007465520198239938
# [DEBUG] entering step: T_old=6.83586523, dT=-5.88447418e-02
# [DEBUG] leaving step: T_new=6.77702049, rhs_norm=0.7678181195587391, channel_norm=1.6916456391803105, accepted_substeps=1, max_rel_update=0.007530343170161721
# [DEBUG] entering step: T_old=6.77702049, dT=-5.83381924e-02
# [DEBUG] leaving step: T_new=6.71868229, rhs_norm=0.7812099092385446, channel_norm=1.7372200131727136, accepted_substeps=1, max_rel_update=0.007595728998733837
# [DEBUG] entering step: T_old=6.71868229, dT=-5.78360035e-02
# [DEBUG] leaving step: T_new=6.66084629, rhs_norm=0.7948352698985861, channel_norm=1.7831901086000899, accepted_substeps=1, max_rel_update=0.007661682571229373
# [DEBUG] entering step: T_old=6.66084629, dT=-5.73381375e-02
# [DEBUG] leaving step: T_new=6.60350815, rhs_norm=0.808698275333638, channel_norm=1.829559361504239, accepted_substeps=1, max_rel_update=0.0077282088173581875
# [DEBUG] entering step: T_old=6.60350815, dT=-5.68445573e-02
# [DEBUG] leaving step: T_new=6.54666360, rhs_norm=0.8228030703909793, channel_norm=1.876331237762052, accepted_substeps=1, max_rel_update=0.007795312709635517
# [DEBUG] entering step: T_old=6.54666360, dT=-5.63552259e-02
# [DEBUG] leaving step: T_new=6.49030837, rhs_norm=0.8371538722096535, channel_norm=1.9235092333445583, accepted_substeps=1, max_rel_update=0.007862999263751029
# [DEBUG] entering step: T_old=6.49030837, dT=-5.58701068e-02
# [DEBUG] leaving step: T_new=6.43443826, rhs_norm=0.851754971481326, channel_norm=1.97109687457824, accepted_substeps=1, max_rel_update=0.00793127353894697
# [DEBUG] entering step: T_old=6.43443826, dT=-5.53891637e-02
# [DEBUG] leaving step: T_new=6.37904910, rhs_norm=0.8666107337331505, channel_norm=2.0190977184086085, accepted_substeps=1, max_rel_update=0.00800014063839473
# [DEBUG] entering step: T_old=6.37904910, dT=-5.49123607e-02
# [DEBUG] leaving step: T_new=6.32413674, rhs_norm=0.8817256006329903, channel_norm=2.0675153526660637, accepted_substeps=1, max_rel_update=0.008069605709575841
# [DEBUG] entering step: T_old=6.32413674, dT=-5.44396622e-02
# [DEBUG] leaving step: T_new=6.26969708, rhs_norm=0.8971040913174283, channel_norm=2.1163533963340684, accepted_substeps=1, max_rel_update=0.008139673944667481
# [DEBUG] entering step: T_old=6.26969708, dT=-5.39710327e-02
# [DEBUG] leaving step: T_new=6.21572604, rhs_norm=0.9127508037429173, channel_norm=2.165615499819655, accepted_substeps=1, max_rel_update=0.00821035058093107
# [DEBUG] entering step: T_old=6.21572604, dT=-5.35064373e-02
# [DEBUG] leaving step: T_new=6.16221961, rhs_norm=0.9286704160605124, channel_norm=2.215305345226269, accepted_substeps=1, max_rel_update=0.008281640901102378
# [DEBUG] entering step: T_old=6.16221961, dT=-5.30458413e-02
# [DEBUG] leaving step: T_new=6.10917377, rhs_norm=0.9448676880145631, channel_norm=2.2654266466289923, accepted_substeps=1, max_rel_update=0.008353550233787185
# [DEBUG] entering step: T_old=6.10917377, dT=-5.25892101e-02
# [DEBUG] leaving step: T_new=6.05658456, rhs_norm=0.9613474623658181, channel_norm=2.3159831503521486, accepted_substeps=1, max_rel_update=0.008426083953859418
# [DEBUG] entering step: T_old=6.05658456, dT=-5.21365098e-02
# [DEBUG] leaving step: T_new=6.00444805, rhs_norm=0.9781146663393558, channel_norm=2.366978635249327, accepted_substeps=1, max_rel_update=0.008499247482863024
# [DEBUG] entering step: T_old=6.00444805, dT=-5.16877064e-02
# [DEBUG] leaving step: T_new=5.95276034, rhs_norm=0.995174313097728, channel_norm=2.418416912985834, accepted_substeps=1, max_rel_update=0.008573046289417895
# [DEBUG] entering step: T_old=5.95276034, dT=-5.12427664e-02
# [DEBUG] leaving step: T_new=5.90151757, rhs_norm=1.0125315032398507, channel_norm=2.470301828323592, accepted_substeps=1, max_rel_update=0.008647485889626303
# [DEBUG] entering step: T_old=5.90151757, dT=-5.08016566e-02
# [DEBUG] leaving step: T_new=5.85071592, rhs_norm=1.0301914263260095, channel_norm=2.522637259408516, accepted_substeps=1, max_rel_update=0.008722571847487317
# [DEBUG] entering step: T_old=5.85071592, dT=-5.03643440e-02
# [DEBUG] leaving step: T_new=5.80035157, rhs_norm=1.048159362429453, channel_norm=2.5754271180603974, accepted_substeps=1, max_rel_update=0.008798309775313526
# [DEBUG] entering step: T_old=5.80035157, dT=-4.99307958e-02
# [DEBUG] leaving step: T_new=5.75042078, rhs_norm=1.066440683715073, channel_norm=2.628675350065279, accepted_substeps=1, max_rel_update=0.008874705334146913
# [DEBUG] entering step: T_old=5.75042078, dT=-4.95009797e-02
# [DEBUG] leaving step: T_new=5.70091980, rhs_norm=1.0850408560456088, channel_norm=2.6823859354703887, accepted_substeps=1, max_rel_update=0.008951764234184987
# [DEBUG] entering step: T_old=5.70091980, dT=-4.90748636e-02
# [DEBUG] leaving step: T_new=5.65184493, rhs_norm=1.1039654406158574, channel_norm=2.7365628888816373, accepted_substeps=1, max_rel_update=0.0090294922352081
# [DEBUG] entering step: T_old=5.65184493, dT=-4.86524156e-02
# [DEBUG] leaving step: T_new=5.60319252, rhs_norm=1.1232200956154017, channel_norm=2.791210259763676, accepted_substeps=1, max_rel_update=0.009107895147006438
# [DEBUG] entering step: T_old=5.60319252, dT=-4.82336041e-02
# [DEBUG] leaving step: T_new=5.55495891, rhs_norm=1.1428105779203201, channel_norm=2.8463321327425843, accepted_substeps=1, max_rel_update=0.009186978829818096
# [DEBUG] entering step: T_old=5.55495891, dT=-4.78183978e-02
# [DEBUG] leaving step: T_new=5.50714052, rhs_norm=1.162742744814431, channel_norm=2.9019326279111777, accepted_substeps=1, max_rel_update=0.009266749194765564
# [DEBUG] entering step: T_old=5.50714052, dT=-4.74067658e-02
# [DEBUG] leaving step: T_new=5.45973375, rhs_norm=1.1830225557405172, channel_norm=2.9580159011369496, accepted_substeps=1, max_rel_update=0.009347212204295328
# [DEBUG] entering step: T_old=5.45973375, dT=-4.69986772e-02
# [DEBUG] leaving step: T_new=5.41273507, rhs_norm=1.2036560740821374, channel_norm=3.0145861443727258, accepted_substeps=1, max_rel_update=0.009428373872629353
# [DEBUG] entering step: T_old=5.41273507, dT=-4.65941014e-02
# [DEBUG] leaving step: T_new=5.36614097, rhs_norm=1.2246494689764789, channel_norm=3.0716475859699703, accepted_substeps=1, max_rel_update=0.009510240266207432
# [DEBUG] entering step: T_old=5.36614097, dT=-4.61930084e-02
# [DEBUG] leaving step: T_new=5.31994796, rhs_norm=1.2460090171588607, channel_norm=3.129204490994846, accepted_substeps=1, max_rel_update=0.009592817504145963
# [DEBUG] entering step: T_old=5.31994796, dT=-4.57953681e-02
# [DEBUG] leaving step: T_new=5.27415259, rhs_norm=1.2677411048393663, channel_norm=3.1872611615470112, accepted_substeps=1, max_rel_update=0.009676111758694135
# [DEBUG] entering step: T_old=5.27415259, dT=-4.54011508e-02
# [DEBUG] leaving step: T_new=5.22875144, rhs_norm=1.2898522296122612, channel_norm=3.2458219370811663, accepted_substeps=1, max_rel_update=0.00976012925569251
# [DEBUG] entering step: T_old=5.22875144, dT=-4.50103269e-02
# [DEBUG] leaving step: T_new=5.18374112, rhs_norm=1.3123490023986648, channel_norm=3.304891194731418, accepted_substeps=1, max_rel_update=0.009844876275041946
# [DEBUG] entering step: T_old=5.18374112, dT=-4.46228674e-02
# [DEBUG] leaving step: T_new=5.13911825, rhs_norm=1.3352381494231271, channel_norm=3.364473349638452, accepted_substeps=1, max_rel_update=0.009930359151172309
# [DEBUG] entering step: T_old=5.13911825, dT=-4.42387432e-02
# [DEBUG] leaving step: T_new=5.09487951, rhs_norm=1.3585265142246796, channel_norm=3.4245728552795316, accepted_substeps=1, max_rel_update=0.010016584273513268
# [DEBUG] entering step: T_old=5.09487951, dT=-4.38579257e-02
# [DEBUG] leaving step: T_new=5.05102158, rhs_norm=1.3822210597029643, channel_norm=3.4851942038013783, accepted_substeps=1, max_rel_update=0.01010355808697446
# [DEBUG] entering step: T_old=5.05102158, dT=-4.34803863e-02
# [DEBUG] leaving step: T_new=5.00754119, rhs_norm=1.4063288702000352, channel_norm=3.546341926355947, accepted_substeps=1, max_rel_update=0.010191287092428078
# [DEBUG] entering step: T_old=5.00754119, dT=-4.31060969e-02
# [DEBUG] leaving step: T_new=4.96443510, rhs_norm=1.4308571536184846, channel_norm=3.6080205934390945, accepted_substeps=1, max_rel_update=0.010279777847191232
# [DEBUG] entering step: T_old=4.96443510, dT=-4.27350294e-02
# [DEBUG] leaving step: T_new=4.92170007, rhs_norm=1.4558132435765043, channel_norm=3.670234815232205, accepted_substeps=1, max_rel_update=0.010369036965518426
# [DEBUG] entering step: T_old=4.92170007, dT=-4.23671562e-02
# [DEBUG] leaving step: T_new=4.87933291, rhs_norm=1.4812046016005311, channel_norm=3.732989241946793, accepted_substeps=1, max_rel_update=0.01045907111909799
# [DEBUG] entering step: T_old=4.87933291, dT=-4.20024497e-02
# [DEBUG] leaving step: T_new=4.83733046, rhs_norm=1.5070388193561588, channel_norm=3.7962885641720545, accepted_substeps=1, max_rel_update=0.01054988703754354
# [DEBUG] entering step: T_old=4.83733046, dT=-4.16408827e-02
# [DEBUG] leaving step: T_new=4.79568958, rhs_norm=1.5333236209179122, channel_norm=3.8601375132255007, accepted_substeps=1, max_rel_update=0.01064149150890769
# [DEBUG] entering step: T_old=4.79568958, dT=-4.12824282e-02
# [DEBUG] leaving step: T_new=4.75440715, rhs_norm=1.5600668650786678, channel_norm=3.924540861506572, accepted_substeps=1, max_rel_update=0.01073389138017862
# [DEBUG] entering step: T_old=4.75440715, dT=-4.09270593e-02
# [DEBUG] leaving step: T_new=4.71348009, rhs_norm=1.5872765476993034, channel_norm=3.9895034228533697, accepted_substeps=1, max_rel_update=0.010827093557799587
# [DEBUG] entering step: T_old=4.71348009, dT=-4.05747495e-02
# [DEBUG] leaving step: T_new=4.67290534, rhs_norm=1.614960804099364, channel_norm=4.055030052902462, accepted_substeps=1, max_rel_update=0.010921105008182068
# [DEBUG] entering step: T_old=4.67290534, dT=-4.02254725e-02
# [DEBUG] leaving step: T_new=4.63267987, rhs_norm=1.643127911489404, channel_norm=4.121125649451814, accepted_substeps=1, max_rel_update=0.011015932758225287
# [DEBUG] entering step: T_old=4.63267987, dT=-3.98792021e-02
# [DEBUG] leaving step: T_new=4.59280067, rhs_norm=1.6717862914457524, channel_norm=4.1877951528268795, accepted_substeps=1, max_rel_update=0.011111583895844242
# [DEBUG] entering step: T_old=4.59280067, dT=-3.95359125e-02
# [DEBUG] leaving step: T_new=4.55326476, rhs_norm=1.7009445124284654, channel_norm=4.255043546249869, accepted_substeps=1, max_rel_update=0.011208065570498244
# [DEBUG] entering step: T_old=4.55326476, dT=-3.91955780e-02
# [DEBUG] leaving step: T_new=4.51406918, rhs_norm=1.7306112923431538, channel_norm=4.322875856212217, accepted_substeps=1, max_rel_update=0.011305384993724655
# [DEBUG] entering step: T_old=4.51406918, dT=-3.88581732e-02
# [DEBUG] leaving step: T_new=4.47521100, rhs_norm=1.760795501147546, channel_norm=4.391297152850283, accepted_substeps=1, max_rel_update=0.011403549439677647
# [DEBUG] entering step: T_old=4.47521100, dT=-3.85236729e-02
# [DEBUG] leaving step: T_new=4.43668733, rhs_norm=1.7915061635034513, channel_norm=4.460312550324335, accepted_substeps=1, max_rel_update=0.011502566245675272
# [DEBUG] entering step: T_old=4.43668733, dT=-3.81920520e-02
# [DEBUG] leaving step: T_new=4.39849528, rhs_norm=1.8227524614750334, channel_norm=4.529927207200792, accepted_substeps=1, max_rel_update=0.011602442812742983
# [DEBUG] entering step: T_old=4.39849528, dT=-3.78632858e-02
# [DEBUG] leaving step: T_new=4.36063199, rhs_norm=1.8545437372741151, channel_norm=4.60014632683781, accepted_substeps=1, max_rel_update=0.011703186606169603
# [DEBUG] entering step: T_old=4.36063199, dT=-3.75373497e-02
# [DEBUG] leaving step: T_new=4.32309464, rhs_norm=1.8868894960533527, channel_norm=4.670975157774211, accepted_substeps=1, max_rel_update=0.011804805156066911
# [DEBUG] entering step: T_old=4.32309464, dT=-3.72142194e-02
# [DEBUG] leaving step: T_new=4.28588042, rhs_norm=1.9197994087481782, channel_norm=4.7424189941217705, accepted_substeps=1, max_rel_update=0.011907306057926633
# [DEBUG] entering step: T_old=4.28588042, dT=-3.68938706e-02
# [DEBUG] leaving step: T_new=4.24898655, rhs_norm=1.953283314968239, channel_norm=4.814483175960948, accepted_substeps=1, max_rel_update=0.012010696973196304
# [DEBUG] entering step: T_old=4.24898655, dT=-3.65762794e-02
# [DEBUG] leaving step: T_new=4.21241027, rhs_norm=1.9873512259393453, channel_norm=4.887173089740017, accepted_substeps=1, max_rel_update=0.012114985629844808
# [DEBUG] entering step: T_old=4.21241027, dT=-3.62614222e-02
# [DEBUG] leaving step: T_new=4.17614885, rhs_norm=2.02201332749665, channel_norm=4.960494168677679, accepted_substeps=1, max_rel_update=0.012220179822943685
# [DEBUG] entering step: T_old=4.17614885, dT=-3.59492753e-02
# [DEBUG] leaving step: T_new=4.14019958, rhs_norm=2.0572799831300976, channel_norm=5.034451893169175, accepted_substeps=1, max_rel_update=0.012326287415249342
# [DEBUG] entering step: T_old=4.14019958, dT=-3.56398155e-02
# [DEBUG] leaving step: T_new=4.10455976, rhs_norm=2.0931617370829536, channel_norm=5.109051791195912, accepted_substeps=1, max_rel_update=0.012433316337789635
# [DEBUG] entering step: T_old=4.10455976, dT=-3.53330195e-02
# [DEBUG] leaving step: T_new=4.06922674, rhs_norm=2.129669317504397, channel_norm=5.184299438738659, accepted_substeps=1, max_rel_update=0.01254127459045775
# [DEBUG] entering step: T_old=4.06922674, dT=-3.50288645e-02
# [DEBUG] leaving step: T_new=4.03419788, rhs_norm=2.1668136396570747, channel_norm=5.260200460194319, accepted_substeps=1, max_rel_update=0.01265017024260999
# [DEBUG] entering step: T_old=4.03419788, dT=-3.47273278e-02
# [DEBUG] leaving step: T_new=3.99947055, rhs_norm=2.2046058091806318, channel_norm=5.336760528796331, accepted_substeps=1, max_rel_update=0.012760011433668629
# [DEBUG] entering step: T_old=3.99947055, dT=-3.44283868e-02
# [DEBUG] leaving step: T_new=3.96504216, rhs_norm=2.2430571254121254, channel_norm=5.4139853670387055, accepted_substeps=1, max_rel_update=0.012870806373729095
# [DEBUG] entering step: T_old=3.96504216, dT=-3.41320191e-02
# [DEBUG] leaving step: T_new=3.93091014, rhs_norm=2.2821790847643886, channel_norm=5.491880747103773, accepted_substeps=1, max_rel_update=0.012982563344177925
# [DEBUG] entering step: T_old=3.93091014, dT=-3.38382026e-02
# [DEBUG] leaving step: T_new=3.89707194, rhs_norm=2.321983384163289, channel_norm=5.570452491293606, accepted_substeps=1, max_rel_update=0.013095290698305569
# [DEBUG] entering step: T_old=3.89707194, dT=-3.35469154e-02
# [DEBUG] leaving step: T_new=3.86352503, rhs_norm=2.3624819245449475, channel_norm=5.64970647246522, accepted_substeps=1, max_rel_update=0.013208996861935612
# [DEBUG] entering step: T_old=3.86352503, dT=-3.32581356e-02
# [DEBUG] leaving step: T_new=3.83026689, rhs_norm=2.403686814413954, channel_norm=5.729648614469542, accepted_substeps=1, max_rel_update=0.013323690334053721
# [DEBUG] entering step: T_old=3.83026689, dT=-3.29718417e-02
# [DEBUG] leaving step: T_new=3.79729505, rhs_norm=2.445610373463663, channel_norm=5.810284892594171, accepted_substeps=1, max_rel_update=0.013439379687438281
# [DEBUG] entering step: T_old=3.79729505, dT=-3.26880123e-02
# [DEBUG] leaving step: T_new=3.76460704, rhs_norm=2.4882651362595714, channel_norm=5.891621334010037, accepted_substeps=1, max_rel_update=0.013556073569310918
# [DEBUG] entering step: T_old=3.76460704, dT=-3.24066262e-02
# [DEBUG] leaving step: T_new=3.73220041, rhs_norm=2.5316638559870053, channel_norm=5.973664018221867, accepted_substeps=1, max_rel_update=0.013673780701971642
# [DEBUG] entering step: T_old=3.73220041, dT=-3.21276623e-02
# [DEBUG] leaving step: T_new=3.70007275, rhs_norm=2.5758195082641717, channel_norm=6.056419077522615, accepted_substeps=1, max_rel_update=0.013792509883458043
# [DEBUG] entering step: T_old=3.70007275, dT=-3.18510998e-02
# [DEBUG] leaving step: T_new=3.66822165, rhs_norm=2.6207452950216377, channel_norm=6.139892697451829, accepted_substeps=1, max_rel_update=0.013782669075694027
# [DEBUG] entering step: T_old=3.66822165, dT=-3.15769180e-02
# [DEBUG] leaving step: T_new=3.63664473, rhs_norm=2.6664546484495575, channel_norm=6.224091117257972, accepted_substeps=1, max_rel_update=0.013713337342375115
# [DEBUG] entering step: T_old=3.63664473, dT=-3.13050964e-02
# [DEBUG] leaving step: T_new=3.60533963, rhs_norm=2.712961235013697, channel_norm=6.309020630364785, accepted_substeps=1, max_rel_update=0.013645287561957957
# [DEBUG] entering step: T_old=3.60533963, dT=-3.10356148e-02
# [DEBUG] leaving step: T_new=3.57430402, rhs_norm=2.7602789595415484, channel_norm=6.394687584841695, accepted_substeps=1, max_rel_update=0.013578486978565663
# [DEBUG] entering step: T_old=3.57430402, dT=-3.07684529e-02
# [DEBUG] leaving step: T_new=3.54353557, rhs_norm=2.8084219693796264, channel_norm=6.481098383878293, accepted_substeps=1, max_rel_update=0.013512903936297187
# [DEBUG] entering step: T_old=3.54353557, dT=-3.05035908e-02
# [DEBUG] leaving step: T_new=3.51303197, rhs_norm=2.857404658623395, channel_norm=6.568259486262942, accepted_substeps=1, max_rel_update=0.013448507833403995
# [DEBUG] entering step: T_old=3.51303197, dT=-3.02410087e-02
# [DEBUG] leaving step: T_new=3.48279097, rhs_norm=2.9072416724208385, channel_norm=6.656177406865552, accepted_substeps=1, max_rel_update=0.013385269078739135
# [DEBUG] entering step: T_old=3.48279097, dT=-2.99806869e-02
# [DEBUG] leaving step: T_new=3.45281028, rhs_norm=2.957947911351227, channel_norm=6.74485871712452, accepted_substeps=1, max_rel_update=0.01332315905034266
# [DEBUG] entering step: T_old=3.45281028, dT=-2.97226061e-02
# [DEBUG] leaving step: T_new=3.42308767, rhs_norm=3.0095385358801225, channel_norm=6.834310045537915, accepted_substeps=1, max_rel_update=0.013262150056054986
# [DEBUG] entering step: T_old=3.42308767, dT=-2.94667469e-02
# [DEBUG] leaving step: T_new=3.39362093, rhs_norm=3.0620289708921744, channel_norm=6.924538078158947, accepted_substeps=1, max_rel_update=0.01320221529603287
# [DEBUG] entering step: T_old=3.39362093, dT=-2.92130902e-02
# [DEBUG] leaving step: T_new=3.36440784, rhs_norm=3.1154349103029633, channel_norm=7.015549559095677, accepted_substeps=1, max_rel_update=0.013143328827058393
# [DEBUG] entering step: T_old=3.36440784, dT=-2.89616170e-02
# [DEBUG] leaving step: T_new=3.33544622, rhs_norm=3.1697723217512404, channel_norm=7.107351291015151, accepted_substeps=1, max_rel_update=0.013085465528563251
# [DEBUG] entering step: T_old=3.33544622, dT=-2.87123086e-02
# [DEBUG] leaving step: T_new=3.30673391, rhs_norm=3.225057451373027, channel_norm=7.199950135651836, accepted_substeps=1, max_rel_update=0.013028601070239043
# [DEBUG] entering step: T_old=3.30673391, dT=-2.84651462e-02
# [DEBUG] leaving step: T_new=3.27826876, rhs_norm=3.281306828659016, channel_norm=7.293353014320506, accepted_substeps=1, max_rel_update=0.0129727118811795
# [DEBUG] entering step: T_old=3.27826876, dT=-2.82201115e-02
# [DEBUG] leaving step: T_new=3.25004865, rhs_norm=3.3385372713966324, channel_norm=7.387566908433595, accepted_substeps=1, max_rel_update=0.0129177751204555
# [DEBUG] entering step: T_old=3.25004865, dT=-2.79771861e-02
# [DEBUG] leaving step: T_new=3.22207147, rhs_norm=3.3967658906983313, channel_norm=7.482598860023, accepted_substeps=1, max_rel_update=0.012863768649041528
# [DEBUG] entering step: T_old=3.22207147, dT=-2.77363519e-02
# [DEBUG] leaving step: T_new=3.19433511, rhs_norm=3.456010096117598, channel_norm=7.578455972266446, accepted_substeps=1, max_rel_update=0.012810671003035928
# [DEBUG] entering step: T_old=3.19433511, dT=-2.74975908e-02
# [DEBUG] leaving step: T_new=3.16683752, rhs_norm=3.5162876008541204, channel_norm=7.675145410018429, accepted_substeps=1, max_rel_update=0.012758461368096666
# [DEBUG] entering step: T_old=3.16683752, dT=-2.72608851e-02
# [DEBUG] leaving step: T_new=3.13957664, rhs_norm=3.577616427049851, channel_norm=7.772674400345734, accepted_substeps=1, max_rel_update=0.012707119555024978
# [DEBUG] entering step: T_old=3.13957664, dT=-2.70262170e-02
# [DEBUG] leaving step: T_new=3.11255042, rhs_norm=3.640014911177313, channel_norm=7.871050233067632, accepted_substeps=1, max_rel_update=0.012656625976449292
# [DEBUG] entering step: T_old=3.11255042, dT=-2.67935689e-02
# [DEBUG] leaving step: T_new=3.08575685, rhs_norm=3.7035017095220217, channel_norm=7.970280261300758, accepted_substeps=1, max_rel_update=0.012606961624541958
# [DEBUG] entering step: T_old=3.08575685, dT=-2.65629235e-02
# [DEBUG] leaving step: T_new=3.05919393, rhs_norm=3.768095803760412, channel_norm=8.070371902008725, accepted_substeps=1, max_rel_update=0.012558108049720176
# [DEBUG] entering step: T_old=3.05919393, dT=-2.63342636e-02
# [DEBUG] leaving step: T_new=3.03285967, rhs_norm=3.8338165066351024, channel_norm=8.171332636556498, accepted_substeps=1, max_rel_update=0.01251004734027735
# [DEBUG] entering step: T_old=3.03285967, dT=-2.61075721e-02
# [DEBUG] leaving step: T_new=3.00675209, rhs_norm=3.9006834677291313, channel_norm=8.27317001126959, accepted_substeps=1, max_rel_update=0.012462762102903252
# [DEBUG] entering step: T_old=3.00675209, dT=-2.58828319e-02
# [DEBUG] leaving step: T_new=2.98086926, rhs_norm=3.968716679340938, channel_norm=8.375891637998132, accepted_substeps=1, max_rel_update=0.012416235444045664
# [DEBUG] entering step: T_old=2.98086926, dT=-2.56600264e-02
# [DEBUG] leaving step: T_new=2.95520924, rhs_norm=4.037936482461783, channel_norm=8.479505194685789, accepted_substeps=1, max_rel_update=0.012370450952063862
# [DEBUG] entering step: T_old=2.95520924, dT=-2.54391388e-02
# [DEBUG] leaving step: T_new=2.92977010, rhs_norm=4.108363572857377, channel_norm=8.584018425943675, accepted_substeps=1, max_rel_update=0.01232539268015149
# [DEBUG] entering step: T_old=2.92977010, dT=-2.52201527e-02
# [DEBUG] leaving step: T_new=2.90454994, rhs_norm=4.180019007255693, channel_norm=8.689439143629217, accepted_substeps=1, max_rel_update=0.012281045129973816
# [DEBUG] entering step: T_old=2.90454994, dT=-2.50030517e-02
# [DEBUG] leaving step: T_new=2.87954689, rhs_norm=4.252924209642598, channel_norm=8.795775227430058, accepted_substeps=1, max_rel_update=0.012237393235995207
# [DEBUG] entering step: T_old=2.87954689, dT=-2.47878195e-02
# [DEBUG] leaving step: T_new=2.85475907, rhs_norm=4.327100977667319, channel_norm=8.903034625453012, accepted_substeps=1, max_rel_update=0.012194422350455232
# [DEBUG] entering step: T_old=2.85475907, dT=-2.45744401e-02
# [DEBUG] leaving step: T_new=2.83018463, rhs_norm=4.402571489159684, channel_norm=9.011225354818157, accepted_substeps=1, max_rel_update=0.012152118228972846
# [DEBUG] entering step: T_old=2.83018463, dT=-2.43628975e-02
# [DEBUG] leaving step: T_new=2.80582173, rhs_norm=4.479358308760939, channel_norm=9.120355502258084, accepted_substeps=1, max_rel_update=0.012110467016738968
# [DEBUG] entering step: T_old=2.80582173, dT=-2.41531759e-02
# [DEBUG] leaving step: T_new=2.78166856, rhs_norm=4.5574843946703085, channel_norm=9.230433224722319, accepted_substeps=1, max_rel_update=0.012069455235268147
# [DEBUG] entering step: T_old=2.78166856, dT=-2.39452597e-02
# [DEBUG] leaving step: T_new=2.75772330, rhs_norm=4.636973105509149, channel_norm=9.341466749987038, accepted_substeps=1, max_rel_update=0.01202906976969755
# [DEBUG] entering step: T_old=2.75772330, dT=-2.37391333e-02
# [DEBUG] leaving step: T_new=2.73398417, rhs_norm=4.717848207304838, channel_norm=9.453464377270032, accepted_substeps=1, max_rel_update=0.011989297856586612
# [DEBUG] entering step: T_old=2.73398417, dT=-2.35347812e-02
# [DEBUG] leaving step: T_new=2.71044938, rhs_norm=4.80013388059656, channel_norm=9.56643447785106, accepted_substeps=1, max_rel_update=0.011950127072214203
# [DEBUG] entering step: T_old=2.71044938, dT=-2.33321882e-02
# [DEBUG] leaving step: T_new=2.68711720, rhs_norm=4.8838547276648745, channel_norm=9.680385495697532, accepted_substeps=1, max_rel_update=0.011911545321331695
# [DEBUG] entering step: T_old=2.68711720, dT=-2.31313393e-02
# [DEBUG] leaving step: T_new=2.66398586, rhs_norm=4.969035779887499, channel_norm=9.795325948095675, accepted_substeps=1, max_rel_update=0.011873540826367742
# [DEBUG] entering step: T_old=2.66398586, dT=-2.29322192e-02
# [DEBUG] leaving step: T_new=2.64105364, rhs_norm=5.05570250522335, channel_norm=9.911264426287152, accepted_substeps=1, max_rel_update=0.011836102117052789
# [DEBUG] entering step: T_old=2.64105364, dT=-2.27348133e-02
# [DEBUG] leaving step: T_new=2.61831882, rhs_norm=5.143880815827073, channel_norm=10.02820959611122, accepted_substeps=1, max_rel_update=0.011799218020447493
# [DEBUG] entering step: T_old=2.61831882, dT=-2.25391066e-02
# [DEBUG] leaving step: T_new=2.59577972, rhs_norm=5.23359707579647, channel_norm=10.146170198652445, accepted_substeps=1, max_rel_update=0.011762877651357603
# [DEBUG] entering step: T_old=2.59577972, dT=-2.23450847e-02
# [DEBUG] leaving step: T_new=2.57343463, rhs_norm=5.32487810905495, channel_norm=10.265155050894073, accepted_substeps=1, max_rel_update=0.011727070403119195
# [DEBUG] entering step: T_old=2.57343463, dT=-2.21527329e-02
# [DEBUG] leaving step: T_new=2.55128190, rhs_norm=5.417751207371575, channel_norm=10.38517304637706, accepted_substeps=1, max_rel_update=0.011691785938735872
# [DEBUG] entering step: T_old=2.55128190, dT=-2.19620370e-02
# [DEBUG] leaving step: T_new=2.52931986, rhs_norm=5.512244138520859, channel_norm=10.506233155864795, accepted_substeps=1, max_rel_update=0.011657014182345904
# [DEBUG] entering step: T_old=2.52931986, dT=-2.17729826e-02
# [DEBUG] leaving step: T_new=2.50754688, rhs_norm=5.60838515458497, channel_norm=10.628344428013643, accepted_substeps=1, max_rel_update=0.01162274531102354
# [DEBUG] entering step: T_old=2.50754688, dT=-2.15855556e-02
# [DEBUG] leaving step: T_new=2.48596133, rhs_norm=5.7062030004007305, channel_norm=10.751515990049286, accepted_substeps=1, max_rel_update=0.01158896974687749
# [DEBUG] entering step: T_old=2.48596133, dT=-2.13997420e-02
# [DEBUG] leaving step: T_new=2.46456158, rhs_norm=5.8057269221539185, channel_norm=10.875757048448937, accepted_substeps=1, max_rel_update=0.011555678149447761
# [DEBUG] entering step: T_old=2.46456158, dT=-2.12155280e-02
# [DEBUG] leaving step: T_new=2.44334606, rhs_norm=5.906986676123459, channel_norm=11.001076889629466, accepted_substeps=1, max_rel_update=0.011522861408383744
# [DEBUG] entering step: T_old=2.44334606, dT=-2.10328997e-02
# [DEBUG] leaving step: T_new=2.42231316, rhs_norm=6.010012537578128, channel_norm=11.127484880641541, accepted_substeps=1, max_rel_update=0.011490510636393943
# [DEBUG] entering step: T_old=2.42231316, dT=-2.08518436e-02
# [DEBUG] leaving step: T_new=2.40146131, rhs_norm=6.114835309828544, channel_norm=11.254990469869748, accepted_substeps=1, max_rel_update=0.011458617162448583
# [DEBUG] entering step: T_old=2.40146131, dT=-2.06723460e-02
# [DEBUG] leaving step: T_new=2.38078897, rhs_norm=6.221486333436757, channel_norm=11.383603187738823, accepted_substeps=1, max_rel_update=0.011427172525234838
# [DEBUG] entering step: T_old=2.38078897, dT=-2.04943935e-02
# [DEBUG] leaving step: T_new=2.36029457, rhs_norm=6.329997495586788, channel_norm=11.51333264742599, accepted_substeps=1, max_rel_update=0.011396168466843493
# [DEBUG] entering step: T_old=2.36029457, dT=-2.03179729e-02
# [DEBUG] leaving step: T_new=2.33997660, rhs_norm=6.440401239618413, channel_norm=11.644188545579532, accepted_substeps=1, max_rel_update=0.01136559692668972
# [DEBUG] entering step: T_old=2.33997660, dT=-2.01430710e-02
# [DEBUG] leaving step: T_new=2.31983353, rhs_norm=6.5527305747272075, channel_norm=11.776180663043528, accepted_substeps=1, max_rel_update=0.011335450035640616
# [DEBUG] entering step: T_old=2.31983353, dT=-1.99696747e-02
# [DEBUG] leaving step: T_new=2.29986385, rhs_norm=6.667019085834004, channel_norm=11.909318865588952, accepted_substeps=1, max_rel_update=0.011305720110361753
# [DEBUG] entering step: T_old=2.29986385, dT=-1.97977711e-02
# [DEBUG] leaving step: T_new=2.28006608, rhs_norm=6.783300943626109, channel_norm=12.04361310465107, accepted_substeps=1, max_rel_update=0.011276399647854806
# [DEBUG] entering step: T_old=2.28006608, dT=-1.96273472e-02
# [DEBUG] leaving step: T_new=2.26043874, rhs_norm=6.901610914774064, channel_norm=12.179073418073298, accepted_substeps=1, max_rel_update=0.0112474813201957
# [DEBUG] entering step: T_old=2.26043874, dT=-1.94583903e-02
# [DEBUG] leaving step: T_new=2.24098035, rhs_norm=7.021984372326238, channel_norm=12.315709930857436, accepted_substeps=1, max_rel_update=0.011218957969444082
# [DEBUG] entering step: T_old=2.24098035, dT=-1.92908879e-02
# [DEBUG] leaving step: T_new=2.22168946, rhs_norm=7.144457306285041, channel_norm=12.453532855920495, accepted_substeps=1, max_rel_update=0.011190822602742378
# [DEBUG] entering step: T_old=2.22168946, dT=-1.91248274e-02
# [DEBUG] leaving step: T_new=2.20256463, rhs_norm=7.2690663343672295, channel_norm=12.592552494858047, accepted_substeps=1, max_rel_update=0.011163068387574963
# [DEBUG] entering step: T_old=2.20256463, dT=-1.89601964e-02
# [DEBUG] leaving step: T_new=2.18360443, rhs_norm=7.3958487129523425, channel_norm=12.732779238714237, accepted_substeps=1, max_rel_update=0.011135688647194268
# [DEBUG] entering step: T_old=2.18360443, dT=-1.87969825e-02
# [DEBUG] leaving step: T_new=2.16480745, rhs_norm=7.52484234822164, channel_norm=12.874223568758435, accepted_substeps=1, max_rel_update=0.011108676856199226
# [DEBUG] entering step: T_old=2.16480745, dT=-1.86351737e-02
# [DEBUG] leaving step: T_new=2.14617228, rhs_norm=7.656085807491652, channel_norm=13.016896057268685, accepted_substeps=1, max_rel_update=0.011082026636267993
# [DEBUG] entering step: T_old=2.14617228, dT=-1.84747577e-02
# [DEBUG] leaving step: T_new=2.12769752, rhs_norm=7.78961833074519, channel_norm=13.16080736832193, accepted_substeps=1, max_rel_update=0.011055731752031952
# [DEBUG] entering step: T_old=2.12769752, dT=-1.83157226e-02
# [DEBUG] leaving step: T_new=2.10938180, rhs_norm=7.925479842363646, channel_norm=13.305968258591081, accepted_substeps=1, max_rel_update=0.01102978610708595
# [DEBUG] entering step: T_old=2.10938180, dT=-1.81580565e-02
# [DEBUG] leaving step: T_new=2.09122374, rhs_norm=8.063710963063784, channel_norm=13.452389578149043, accepted_substeps=1, max_rel_update=0.01100418374013668
# [DEBUG] entering step: T_old=2.09122374, dT=-1.80017477e-02
# [DEBUG] leaving step: T_new=2.07322199, rhs_norm=8.204353022042746, channel_norm=13.600082271279705, accepted_substeps=1, max_rel_update=0.010978918821274792
# [DEBUG] entering step: T_old=2.07322199, dT=-1.78467844e-02
# [DEBUG] leaving step: T_new=2.05537521, rhs_norm=8.347448069334956, channel_norm=13.749057377295959, accepted_substeps=1, max_rel_update=0.010953985648370395
# [DEBUG] entering step: T_old=2.05537521, dT=-1.76931551e-02
# [DEBUG] leaving step: T_new=2.03768205, rhs_norm=8.493038888384488, channel_norm=13.899326031364854, accepted_substeps=1, max_rel_update=0.01092937864358881
# [DEBUG] entering step: T_old=2.03768205, dT=-1.75408482e-02
# [DEBUG] leaving step: T_new=2.02014121, rhs_norm=8.641169008836757, channel_norm=14.050899465339869, accepted_substeps=1, max_rel_update=0.010905092350015948
# [DEBUG] entering step: T_old=2.02014121, dT=-1.73898525e-02
# [DEBUG] leaving step: T_new=2.00275135, rhs_norm=8.791882719553161, channel_norm=14.203789008600486, accepted_substeps=1, max_rel_update=0.010881121428400899
# [DEBUG] entering step: T_old=2.00275135, dT=-1.72401565e-02
# [DEBUG] leaving step: T_new=1.98551120, rhs_norm=8.945225081853026, channel_norm=14.358006088898943, accepted_substeps=1, max_rel_update=0.010857460653990141
# [DEBUG] entering step: T_old=1.98551120, dT=-1.70917492e-02
# [DEBUG] leaving step: T_new=1.96841945, rhs_norm=9.101241942986151, channel_norm=14.513562233214452, accepted_substeps=1, max_rel_update=0.010834104913479553
# [DEBUG] entering step: T_old=1.96841945, dT=-1.69446193e-02
# [DEBUG] leaving step: T_new=1.95147483, rhs_norm=9.259979949840607, channel_norm=14.67046906861478, accepted_substeps=1, max_rel_update=0.010811049202052225
# [DEBUG] entering step: T_old=1.95147483, dT=-1.67987561e-02
# [DEBUG] leaving step: T_new=1.93467607, rhs_norm=9.421486562889474, channel_norm=14.828738323125286, accepted_substeps=1, max_rel_update=0.010788288620511724
# [DEBUG] entering step: T_old=1.93467607, dT=-1.66541484e-02
# [DEBUG] leaving step: T_new=1.91802192, rhs_norm=9.58581007038088, channel_norm=14.988381826605567, accepted_substeps=1, max_rel_update=0.010765818372512377
# [DEBUG] entering step: T_old=1.91802192, dT=-1.65107856e-02
# [DEBUG] leaving step: T_new=1.90151114, rhs_norm=9.75299960277546, channel_norm=15.149411511633655, accepted_substeps=1, max_rel_update=0.010743633761867977
# [DEBUG] entering step: T_old=1.90151114, dT=-1.63686568e-02
# [DEBUG] leaving step: T_new=1.88514248, rhs_norm=9.923105147435725, channel_norm=15.311839414397951, accepted_substeps=1, max_rel_update=0.01072173018995249
# [DEBUG] entering step: T_old=1.88514248, dT=-1.62277516e-02
# [DEBUG] leaving step: T_new=1.86891473, rhs_norm=10.096177563571782, channel_norm=15.475677675596843, accepted_substeps=1, max_rel_update=0.010700103153173855
# [DEBUG] entering step: T_old=1.86891473, dT=-1.60880592e-02
# [DEBUG] leaving step: T_new=1.85282667, rhs_norm=10.27226859744712, channel_norm=15.640938541346173, accepted_substeps=1, max_rel_update=0.010678748240532646
# [DEBUG] entering step: T_old=1.85282667, dT=-1.59495694e-02
# [DEBUG] leaving step: T_new=1.83687710, rhs_norm=10.451430897850422, channel_norm=15.807634364094593, accepted_substeps=1, max_rel_update=0.010657661131252815
# [DEBUG] entering step: T_old=1.83687710, dT=-1.58122718e-02
# [DEBUG] leaving step: T_new=1.82106483, rhs_norm=10.633718031836619, channel_norm=15.975777603546817, accepted_substeps=1, max_rel_update=0.010636837592482833
# [DEBUG] entering step: T_old=1.82106483, dT=-1.56761560e-02
# [DEBUG] leaving step: T_new=1.80538867, rhs_norm=10.819184500742768, channel_norm=16.14538082759495, accepted_substeps=1, max_rel_update=0.010616273477071782
# [DEBUG] entering step: T_old=1.80538867, dT=-1.55412120e-02
# [DEBUG] leaving step: T_new=1.78984746, rhs_norm=11.007885756483166, channel_norm=16.31645671325786, accepted_substeps=1, max_rel_update=0.01059596472140924
# [DEBUG] entering step: T_old=1.78984746, dT=-1.54074295e-02
# [DEBUG] leaving step: T_new=1.77444003, rhs_norm=11.199878218128736, channel_norm=16.489018047628754, accepted_substeps=1, max_rel_update=0.010575907343331418
# [DEBUG] entering step: T_old=1.77444003, dT=-1.52747987e-02
# [DEBUG] leaving step: T_new=1.75916523, rhs_norm=11.395219288775552, channel_norm=16.663077728830906, accepted_substeps=1, max_rel_update=0.010556097440088893
# [DEBUG] entering step: T_old=1.75916523, dT=-1.51433097e-02
# [DEBUG] leaving step: T_new=1.74402192, rhs_norm=11.59396737270748, channel_norm=16.83864876698176, accepted_substeps=1, max_rel_update=0.01053653118637719
# [DEBUG] entering step: T_old=1.74402192, dT=-1.50129525e-02
# [DEBUG] leaving step: T_new=1.72900897, rhs_norm=11.796181892858502, channel_norm=17.015744285165372, accepted_substeps=1, max_rel_update=0.0105172048324254
# [DEBUG] entering step: T_old=1.72900897, dT=-1.48837174e-02
# [DEBUG] leaving step: T_new=1.71412525, rhs_norm=12.001923308579034, channel_norm=17.194377520413287, accepted_substeps=1, max_rel_update=0.010498114702138059
# [DEBUG] entering step: T_old=1.71412525, dT=-1.47555949e-02
# [DEBUG] leaving step: T_new=1.69936966, rhs_norm=12.211253133712658, channel_norm=17.37456182469395, accepted_substeps=1, max_rel_update=0.010479257191296667
# [DEBUG] entering step: T_old=1.69936966, dT=-1.46285752e-02
# [DEBUG] leaving step: T_new=1.68474108, rhs_norm=12.424233954987768, channel_norm=17.556310665910676, accepted_substeps=1, max_rel_update=0.010460628765809464
# [DEBUG] entering step: T_old=1.68474108, dT=-1.45026490e-02
# [DEBUG] leaving step: T_new=1.67023843, rhs_norm=12.64092945073034, channel_norm=17.73963762890837, accepted_substeps=1, max_rel_update=0.01044222596001687
# [DEBUG] entering step: T_old=1.67023843, dT=-1.43778068e-02
# [DEBUG] leaving step: T_new=1.65586063, rhs_norm=12.861404409902606, channel_norm=17.924556416488862, accepted_substeps=1, max_rel_update=0.0104240453750392
# [DEBUG] entering step: T_old=1.65586063, dT=-1.42540392e-02
# [DEBUG] leaving step: T_new=1.64160659, rhs_norm=13.085724751474284, channel_norm=18.111080850435158, accepted_substeps=1, max_rel_update=0.01040608367717881
# [DEBUG] entering step: T_old=1.64160659, dT=-1.41313371e-02
# [DEBUG] leaving step: T_new=1.62747525, rhs_norm=13.31395754413132, channel_norm=18.299224872544556, accepted_substeps=1, max_rel_update=0.010388337596365938
# [DEBUG] entering step: T_old=1.62747525, dT=-1.40096912e-02
# [DEBUG] leaving step: T_new=1.61346556, rhs_norm=13.546171026328553, channel_norm=18.489002545670715, accepted_substeps=1, max_rel_update=0.010370803924645679
# [DEBUG] entering step: T_old=1.61346556, dT=-1.38890925e-02
# [DEBUG] leaving step: T_new=1.59957647, rhs_norm=13.782434626692046, channel_norm=18.680428054774787, accepted_substeps=1, max_rel_update=0.01035347951471257
# [DEBUG] entering step: T_old=1.59957647, dT=-1.37695319e-02
# [DEBUG] leaving step: T_new=1.58580694, rhs_norm=14.022818984777263, channel_norm=18.87351570798566, accepted_substeps=1, max_rel_update=0.010336361278483667
# [DEBUG] entering step: T_old=1.58580694, dT=-1.36510005e-02
# [DEBUG] leaving step: T_new=1.57215593, rhs_norm=14.267395972189393, channel_norm=19.068279937669473, accepted_substeps=1, max_rel_update=0.010319446185715444
# [DEBUG] entering step: T_old=1.57215593, dT=-1.35334895e-02
# [DEBUG] leaving step: T_new=1.55862245, rhs_norm=14.516238714071918, channel_norm=19.264735301508303, accepted_substeps=1, max_rel_update=0.010302731262652064
# [DEBUG] entering step: T_old=1.55862245, dT=-1.34169900e-02
# [DEBUG] leaving step: T_new=1.54520546, rhs_norm=14.769421610969937, channel_norm=19.4628964835883, accepted_substeps=1, max_rel_update=0.01028621359071991
# [DEBUG] entering step: T_old=1.54520546, dT=-1.33014934e-02
# [DEBUG] leaving step: T_new=1.53190396, rhs_norm=15.027020361075177, channel_norm=19.66277829549729, accepted_substeps=1, max_rel_update=0.010269890305255318
# [DEBUG] entering step: T_old=1.53190396, dT=-1.31869910e-02
# [DEBUG] leaving step: T_new=1.51871697, rhs_norm=15.28911198285841, channel_norm=19.86439567743182, accepted_substeps=1, max_rel_update=0.010253758594262198
# [DEBUG] entering step: T_old=1.51871697, dT=-1.30734743e-02
# [DEBUG] leaving step: T_new=1.50564350, rhs_norm=15.555774838096932, channel_norm=20.067763699313872, accepted_substeps=1, max_rel_update=0.010237815697212596
# [DEBUG] entering step: T_old=1.50564350, dT=-1.29609347e-02
# ...
# [DEBUG] entering step: T_old=0.24083919, dT=-2.07320061e-03
# [DEBUG] leaving step: T_new=0.23876599, rhs_norm=618.5730896200863, channel_norm=145.41958667315635, accepted_substeps=1, max_rel_update=0.008897262195108314
# [DEBUG] entering step: T_old=0.23876599, dT=-2.05535401e-03
# [DEBUG] leaving step: T_new=0.23671064, rhs_norm=629.3618435017218, channel_norm=146.7131480646163, accepted_substeps=1, max_rel_update=0.008895372494541188
# [DEBUG] entering step: T_old=0.23671064, dT=-2.03766104e-03
# [DEBUG] leaving step: T_new=0.23467297, rhs_norm=640.3387678878163, channel_norm=148.01794142538722, accepted_substeps=1, max_rel_update=0.008893499853171054
# [DEBUG] entering step: T_old=0.23467297, dT=-2.02012037e-03
# [DEBUG] leaving step: T_new=0.23265285, rhs_norm=651.5071447272524, channel_norm=149.3340642824482, accepted_substeps=1, max_rel_update=0.008891644110078444
# [DEBUG] entering step: T_old=0.23265285, dT=-2.00273070e-03
# [DEBUG] leaving step: T_new=0.23065012, rhs_norm=662.8703132105555, channel_norm=150.6616150096032, accepted_substeps=1, max_rel_update=0.008889805105981013
# [DEBUG] entering step: T_old=0.23065012, dT=-1.98549072e-03
# [DEBUG] leaving step: T_new=0.22866463, rhs_norm=674.4316707682592, channel_norm=152.0006928348338, accepted_substeps=1, max_rel_update=0.008887982683215365
# [DEBUG] entering step: T_old=0.22866463, dT=-1.96839915e-03
# [DEBUG] leaving step: T_new=0.22669623, rhs_norm=686.1946740866994, channel_norm=153.35139784771673, accepted_substeps=1, max_rel_update=0.00888617668572475
# [DEBUG] entering step: T_old=0.22669623, dT=-1.95145470e-03
# [DEBUG] leaving step: T_new=0.22474478, rhs_norm=698.1628401415118, channel_norm=154.71383100690414, accepted_substeps=1, max_rel_update=0.00888438695903101
# [DEBUG] entering step: T_old=0.22474478, dT=-1.93465612e-03
# [DEBUG] leaving step: T_new=0.22281012, rhs_norm=710.3397472491524, channel_norm=156.08809414767066, accepted_substeps=1, max_rel_update=0.008882613350225835
# [DEBUG] entering step: T_old=0.22281012, dT=-1.91800215e-03
# [DEBUG] leaving step: T_new=0.22089212, rhs_norm=722.7290361367777, channel_norm=157.47428998952464, accepted_substeps=1, max_rel_update=0.008880855707947423
# [DEBUG] entering step: T_old=0.22089212, dT=-1.90149153e-03
# [DEBUG] leaving step: T_new=0.21899063, rhs_norm=735.3344110307648, channel_norm=158.87252214388573, accepted_substeps=1, max_rel_update=0.00887911388236201
# [DEBUG] entering step: T_old=0.21899063, dT=-1.88512304e-03
# [DEBUG] leaving step: T_new=0.21710551, rhs_norm=748.1596407642157, channel_norm=160.28289512182985, accepted_substeps=1, max_rel_update=0.00887738772515237
# [DEBUG] entering step: T_old=0.21710551, dT=-1.86889546e-03
# [DEBUG] leaving step: T_new=0.21523661, rhs_norm=761.2085599038044, channel_norm=161.70551434190068, accepted_substeps=1, max_rel_update=0.008875677089495415
# [DEBUG] entering step: T_old=0.21523661, dT=-1.85280756e-03
# [DEBUG] leaving step: T_new=0.21338380, rhs_norm=774.4850698962473, channel_norm=163.14048613798883, accepted_substeps=1, max_rel_update=0.008873981830045305
# [DEBUG] entering step: T_old=0.21338380, dT=-1.83685816e-03
# [DEBUG] leaving step: T_new=0.21154695, rhs_norm=787.9931402347794, channel_norm=164.5879177672804, accepted_substeps=1, max_rel_update=0.008872301802921435
# [DEBUG] entering step: T_old=0.21154695, dT=-1.82104605e-03
# [DEBUG] leaving step: T_new=0.20972590, rhs_norm=801.7368096459899, channel_norm=166.04791741827353, accepted_substeps=1, max_rel_update=0.008870636865687107
# [DEBUG] entering step: T_old=0.20972590, dT=-1.80537006e-03
# [DEBUG] leaving step: T_new=0.20792053, rhs_norm=815.7201872973396, channel_norm=167.52059421886491, accepted_substeps=1, max_rel_update=0.008868986877334426
# [DEBUG] entering step: T_old=0.20792053, dT=-1.78982900e-03
# [DEBUG] leaving step: T_new=0.20613070, rhs_norm=829.9474540257338, channel_norm=169.0060582445069, accepted_substeps=1, max_rel_update=0.00886735169827083
# [DEBUG] entering step: T_old=0.20613070, dT=-1.77442173e-03
# [DEBUG] leaving step: T_new=0.20435628, rhs_norm=844.4228635875588, channel_norm=170.50442052643498, accepted_substeps=1, max_rel_update=0.008865731190300596
# [DEBUG] entering step: T_old=0.20435628, dT=-1.75914709e-03
# [DEBUG] leaving step: T_new=0.20259713, rhs_norm=859.1507439304763, channel_norm=172.01579305996648, accepted_substeps=1, max_rel_update=0.008864125216608015
# [DEBUG] entering step: T_old=0.20259713, dT=-1.74400394e-03
# [DEBUG] leaving step: T_new=0.20085313, rhs_norm=874.1354984874237, channel_norm=173.5402888128724, accepted_substeps=1, max_rel_update=0.008862533641748042
# [DEBUG] entering step: T_old=0.20085313, dT=-1.72899114e-03
# [DEBUG] leaving step: T_new=0.19912414, rhs_norm=889.381607493192, channel_norm=175.0780217338203, accepted_substeps=1, max_rel_update=0.008860956331621771
# [DEBUG] entering step: T_old=0.19912414, dT=-1.71410758e-03
# [DEBUG] leaving step: T_new=0.19741003, rhs_norm=904.8936293239344, channel_norm=176.62910676089223, accepted_substeps=1, max_rel_update=0.008859393153471496
# [DEBUG] entering step: T_old=0.19741003, dT=-1.69935214e-03
# [DEBUG] leaving step: T_new=0.19571068, rhs_norm=920.6762018600799, channel_norm=178.19365983017548, accepted_substeps=1, max_rel_update=0.008857843975858594
# [DEBUG] entering step: T_old=0.19571068, dT=-1.68472371e-03
# [DEBUG] leaving step: T_new=0.19402595, rhs_norm=936.7340438729764, channel_norm=179.77179788442783, accepted_substeps=1, max_rel_update=0.008856308668649462
# [DEBUG] entering step: T_old=0.19402595, dT=-1.67022121e-03
# [DEBUG] leaving step: T_new=0.19235573, rhs_norm=953.0719564357436, channel_norm=181.36363888181924, accepted_substeps=1, max_rel_update=0.008854787103006962
# [DEBUG] entering step: T_old=0.19235573, dT=-1.65584355e-03
# [DEBUG] leaving step: T_new=0.19069989, rhs_norm=969.6948243587409, channel_norm=182.96930180474817, accepted_substeps=1, max_rel_update=0.008853279151369502
# [DEBUG] entering step: T_old=0.19069989, dT=-1.64158966e-03
# [DEBUG] leaving step: T_new=0.18905830, rhs_norm=986.607617650038, channel_norm=184.5889066687347, accepted_substeps=1, max_rel_update=0.0088517846874382
# [DEBUG] entering step: T_old=0.18905830, dT=-1.62745847e-03
# [DEBUG] leaving step: T_new=0.18743084, rhs_norm=1003.8153930013868, channel_norm=186.22257453139176, accepted_substeps=1, max_rel_update=0.008850303586167693
# [DEBUG] entering step: T_old=0.18743084, dT=-1.61344892e-03
# [DEBUG] leaving step: T_new=0.18581739, rhs_norm=1021.3232953001143, channel_norm=187.87042750147333, accepted_substeps=1, max_rel_update=0.008848835723747315
# [DEBUG] entering step: T_old=0.18581739, dT=-1.59955997e-03
# [DEBUG] leaving step: T_new=0.18421783, rhs_norm=1039.1365591673548, channel_norm=189.532588748001, accepted_substeps=1, max_rel_update=0.00884738097758692
# [DEBUG] entering step: T_old=0.18421783, dT=-1.58579058e-03
# [DEBUG] leaving step: T_new=0.18263204, rhs_norm=1057.2605105231332, channel_norm=191.20918250947096, accepted_substeps=1, max_rel_update=0.0088459392263098
# [DEBUG] entering step: T_old=0.18263204, dT=-1.57213972e-03
# [DEBUG] leaving step: T_new=0.18105990, rhs_norm=1075.7005681787596, channel_norm=192.90033410314012, accepted_substeps=1, max_rel_update=0.008844510349733766
# [DEBUG] entering step: T_old=0.18105990, dT=-1.55860637e-03
# [DEBUG] leaving step: T_new=0.17950129, rhs_norm=1094.4622454569803, channel_norm=194.60616993439228, accepted_substeps=1, max_rel_update=0.008843094228857503
# [DEBUG] entering step: T_old=0.17950129, dT=-1.54518952e-03
# [DEBUG] leaving step: T_new=0.17795610, rhs_norm=1113.5511518403623, channel_norm=196.32681750618738, accepted_substeps=1, max_rel_update=0.008841690745854504
# [DEBUG] entering step: T_old=0.17795610, dT=-1.53188817e-03
# [DEBUG] leaving step: T_new=0.17642422, rhs_norm=1132.9729946485522, channel_norm=198.06240542859098, accepted_substeps=1, max_rel_update=0.008840299784052189
# [DEBUG] entering step: T_old=0.17642422, dT=-1.51870131e-03
# [DEBUG] leaving step: T_new=0.17490552, rhs_norm=1152.7335807447066, channel_norm=199.81306342838792, accepted_substeps=1, max_rel_update=0.008838921227926486
# [DEBUG] entering step: T_old=0.17490552, dT=-1.50562797e-03
# [DEBUG] leaving step: T_new=0.17339989, rhs_norm=1172.8388182719652, channel_norm=201.57892235877938, accepted_substeps=1, max_rel_update=0.00883755496308851
# [DEBUG] entering step: T_old=0.17339989, dT=-1.49266717e-03
# [DEBUG] leaving step: T_new=0.17190722, rhs_norm=1193.2947184204793, channel_norm=203.36011420916444, accepted_substeps=1, max_rel_update=0.008836200876274177
# [DEBUG] entering step: T_old=0.17190722, dT=-1.47981794e-03
# [DEBUG] leaving step: T_new=0.17042740, rhs_norm=1214.1073972263246, channel_norm=205.15677211501014, accepted_substeps=1, max_rel_update=0.008834858855349407
# [DEBUG] entering step: T_old=0.17042740, dT=-1.46707932e-03
# [DEBUG] leaving step: T_new=0.16896032, rhs_norm=1235.2830774044337, channel_norm=206.9690303678124, accepted_substeps=1, max_rel_update=0.008833528789321698
# [DEBUG] entering step: T_old=0.16896032, dT=-1.45445035e-03
# [DEBUG] leaving step: T_new=0.16750587, rhs_norm=1256.8280902206488, channel_norm=208.79702442515983, accepted_substeps=1, max_rel_update=0.008832210568406553
# [DEBUG] entering step: T_old=0.16750587, dT=-1.44193010e-03
# [DEBUG] leaving step: T_new=0.16606394, rhs_norm=1278.7488774156868, channel_norm=210.6408909209289, accepted_substeps=1, max_rel_update=0.008830904084219755
# [DEBUG] entering step: T_old=0.16606394, dT=-1.42951762e-03
# [DEBUG] leaving step: T_new=0.16463442, rhs_norm=1301.051993215012, channel_norm=212.50076767568328, accepted_substeps=1, max_rel_update=0.008829609230301502
# [DEBUG] entering step: T_old=0.16463442, dT=-1.41721200e-03
# [DEBUG] leaving step: T_new=0.16321721, rhs_norm=1323.7441065164148, channel_norm=214.3767937074768, accepted_substeps=1, max_rel_update=0.008828325903540674
# [DEBUG] entering step: T_old=0.16321721, dT=-1.40501230e-03
# [DEBUG] leaving step: T_new=0.16181220, rhs_norm=1346.8320035084894, channel_norm=216.26910924360257, accepted_substeps=1, max_rel_update=0.008827054008037323
# [DEBUG] entering step: T_old=0.16181220, dT=-1.39291763e-03
# [DEBUG] leaving step: T_new=0.16041928, rhs_norm=1370.3225914208329, channel_norm=218.1778557347709, accepted_substeps=1, max_rel_update=0.008825793465576862
# [DEBUG] entering step: T_old=0.16041928, dT=-1.38092706e-03
# [DEBUG] leaving step: T_new=0.15903836, rhs_norm=1394.2229053648634, channel_norm=220.10317587581355, accepted_substeps=1, max_rel_update=0.008824544244229692
# [DEBUG] entering step: T_old=0.15903836, dT=-1.36903972e-03
# [DEBUG] leaving step: T_new=0.15766932, rhs_norm=1418.5401237743818, channel_norm=222.04521364430485, accepted_substeps=1, max_rel_update=0.00882330643691866
# [DEBUG] entering step: T_old=0.15766932, dT=-1.35725470e-03
# [DEBUG] leaving step: T_new=0.15631206, rhs_norm=1443.2816080448647, channel_norm=224.00411438895895, accepted_substeps=1, max_rel_update=0.008822080478582562
# [DEBUG] entering step: T_old=0.15631206, dT=-1.34557113e-03
# [DEBUG] leaving step: T_new=0.15496649, rhs_norm=1468.455010824517, channel_norm=225.98002505753627, accepted_substeps=1, max_rel_update=0.00882086775043051
# [DEBUG] entering step: T_old=0.15496649, dT=-1.33398814e-03
# [DEBUG] leaving step: T_new=0.15363250, rhs_norm=1494.068580437291, channel_norm=227.97309481855626, accepted_substeps=1, max_rel_update=0.008819672271974296
# [DEBUG] entering step: T_old=0.15363250, dT=-1.32250485e-03
# [DEBUG] leaving step: T_new=0.15231000, rhs_norm=1520.1320292357243, channel_norm=229.98347680198992, accepted_substeps=1, max_rel_update=0.008818505468962174
# [DEBUG] entering step: T_old=0.15231000, dT=-1.31112042e-03
# [DEBUG] leaving step: T_new=0.15099888, rhs_norm=1546.6590329865162, channel_norm=232.01133303888923, accepted_substeps=1, max_rel_update=0.008817399689305712
# [DEBUG] entering step: T_old=0.15099888, dT=-1.29983398e-03
# [DEBUG] leaving step: T_new=0.14969904, rhs_norm=1573.6744723138577, channel_norm=234.05684859663592, accepted_substeps=1, max_rel_update=0.008816446726780431
# [DEBUG] entering step: T_old=0.14969904, dT=-1.28864471e-03
# [DEBUG] leaving step: T_new=0.14841040, rhs_norm=1601.2355180819513, channel_norm=236.12027226922166, accepted_substeps=1, max_rel_update=0.008815908122140715
# [DEBUG] entering step: T_old=0.14841040, dT=-1.27755175e-03
# [DEBUG] leaving step: T_new=0.14713285, rhs_norm=1629.493224143118, channel_norm=238.20203418542118, accepted_substeps=1, max_rel_update=0.008816531914828216
# [DEBUG] entering step: T_old=0.14713285, dT=-1.26655428e-03
# [DEBUG] leaving step: T_new=0.14586629, rhs_norm=1658.8725386095903, channel_norm=240.30308630003876, accepted_substeps=1, max_rel_update=0.008820462519568853
# [DEBUG] entering step: T_old=0.14586629, dT=-1.25565148e-03
# [DEBUG] leaving step: T_new=0.14461064, rhs_norm=1690.5963491978223, channel_norm=242.4258861117829, accepted_substeps=1, max_rel_update=0.00883384331191501
# [DEBUG] entering step: T_old=0.14461064, dT=-1.24484254e-03
# [DEBUG] leaving step: T_new=0.14336580, rhs_norm=1728.1940230185553, channel_norm=244.57721554525006, accepted_substeps=1, max_rel_update=0.008874173744280723
# [DEBUG] entering step: T_old=0.14336580, dT=-1.23412664e-03
# [DEBUG] leaving step: T_new=0.14213167, rhs_norm=1781.7450604229473, channel_norm=246.77611458885104, accepted_substeps=1, max_rel_update=0.008990612795631256
# [DEBUG] entering step: T_old=0.14213167, dT=-1.22350299e-03
# [DEBUG] leaving step: T_new=0.14090817, rhs_norm=1879.340827926494, channel_norm=249.07549370327297, accepted_substeps=1, max_rel_update=0.009317672896555954
# [DEBUG] entering step: T_old=0.14090817, dT=-1.21297078e-03
# [DEBUG] leaving step: T_new=0.13969520, rhs_norm=2096.192040304458, channel_norm=251.6181134043307, accepted_substeps=1, max_rel_update=0.01020822909252881
# [DEBUG] entering step: T_old=0.13969520, dT=-1.20252924e-03
# [DEBUG] leaving step: T_new=0.13849267, rhs_norm=2624.0637949871198, channel_norm=254.7736268569916, accepted_substeps=1, max_rel_update=0.012540883523716115
# [DEBUG] entering step: T_old=0.13849267, dT=-1.19217759e-03
# [DEBUG] leaving step: T_new=0.13730049, rhs_norm=3944.2236045246036, channel_norm=259.4758418433397, accepted_substeps=1, max_rel_update=0.01845644325261165
# [DEBUG] entering step: T_old=0.13730049, dT=-1.18191504e-03
# [DEBUG] leaving step: T_new=0.13611858, rhs_norm=7417.846902265886, channel_norm=268.2431066808086, accepted_substeps=1, max_rel_update=0.03378836648215671
# [DEBUG] entering step: T_old=0.13611858, dT=-1.17174084e-03
# [DEBUG] leaving step: T_new=0.13494684, rhs_norm=18321.098857389887, channel_norm=289.7106864248069, accepted_substeps=1, max_rel_update=0.08003031283686743
# [DEBUG] entering step: T_old=0.13494684, dT=-1.16165422e-03
# [DEBUG] leaving step: T_new=0.13378518, rhs_norm=68993.65893456695, channel_norm=369.8574612773306, accepted_substeps=1, max_rel_update=0.2766441785133301
# [DEBUG] entering step: T_old=0.13378518, dT=-1.15165442e-03
# [DEBUG] leaving step: T_new=0.13263353, rhs_norm=580065.3942508281, channel_norm=1037.8923383721358, accepted_substeps=2, max_rel_update=0.9030977430977011
# [DEBUG] entering step: T_old=0.13263353, dT=-1.14174071e-03
# [DEBUG] leaving step: T_new=0.13149179, rhs_norm=26763470.561875656, channel_norm=31594.836223046757, accepted_substeps=30, max_rel_update=0.9813780856628842
# history length = 502
# instability record = 501
# ===== Final record =====
# {'accepted_substeps': 30,
#  'channel_norm': 31594.836223046757,
#  'dT': -0.0011417407101231014,
#  'diagnosis_payload': {},
#  'instability': True,
#  'instability_reason': 'channel norm=3.159e+04 exceeded '
#                        'channel_divergence_threshold',
#  'leading_Q': None,
#  'leading_channel_name': None,
#  'leading_eigenvalue_abs': None,
#  'leading_order_label': None,
#  'max_rel_update': 0.9813780856628842,
#  'rhs_norm': 26763470.561875656,
#  'step_index': 501,
#  'temperature': 0.13149178570276499,
#  'terminated_early': False,
#  'termination_reason': None}

# %%
import numpy as np
import matplotlib.pyplot as plt

Qs_to_check = FLOW_KWARGS["diagnosis_Qs"]
# 如果你想继续测试 Q -> Q+G 不变性，再手动加 reciprocal vector
# Qs_to_check = FLOW_KWARGS["diagnosis_Qs"] + 5*np.array([np.pi, np.pi/np.sqrt(3)]) + np.array([0,2*np.pi/np.sqrt(3)])

solver = fm_result["solver"]

mother_channels = [
    "pp_mother_sz0",
    "ph_mother_longitudinal",
]

print("===== Final-state mother-channel diagnosis across all Q =====")
Q_summary = []

for i, Q in enumerate(Qs_to_check):
    Q = np.asarray(Q, dtype=float)
    mothers = solver.build_mother_kernel_dict(Q)

    print(f"\n===== Q[{i}] = {Q} =====")
    row = {
        "Q_index": i,
        "Q_vec": Q,
    }

    vals_dict = {}
    for name in mother_channels:
        k = mothers[name]
        vals, vecs = k.eig(sort_by="abs")
        eigmax = abs(vals[0])
        vals_dict[name] = eigmax
        row[name] = float(eigmax)
        print(f"{name:24s} |eig|max = {eigmax:.8g}")

    lead_name = max(vals_dict, key=vals_dict.get)
    row["leading_geometry"] = lead_name
    row["leading_value"] = vals_dict[lead_name]
    Q_summary.append(row)

    print(f"--> leading mother channel at this Q: {lead_name}  (|eig|max = {vals_dict[lead_name]:.8g})")

print(Q_summary)
labels = [f"Q{i}" for i in range(len(Q_summary))]
x = np.arange(len(labels))
width = 0.35

pp_vals = [row["pp_mother_sz0"] for row in Q_summary]
ph_vals = [row["ph_mother_longitudinal"] for row in Q_summary]

plt.figure(figsize=(8, 5))
plt.bar(x - width/2, pp_vals, width, label="pp_mother_sz0")
plt.bar(x + width/2, ph_vals, width, label="ph_mother_longitudinal")

plt.xticks(x, labels)
plt.ylabel("|leading eigenvalue|")
plt.title("Final mother-channel diagnosis across Q")
plt.legend()
plt.show()

# ----------------------------------------
Q = np.array([0.0, 0.0])
mothers = solver.build_mother_kernel_dict(Q)

for name in ["pp_mother_sz0", "ph_mother_longitudinal"]:
    k = mothers[name]
    vals, vecs = k.eig(sort_by="abs")
    print(f"\n==== {name} ====")
    print("Q =", k.Q)
    print("|eig|max =", abs(vals[0]))
    print("vec.real =", np.real(vecs[:, 0]))
    print("vec.abs  =", np.abs(vecs[:, 0]))
    print(f"\n==== {name} ====")
    print("Q =", k.Q)
    print("second |eig|max =", abs(vals[1]))
    print("vec.real =", np.real(vecs[:, 1]))
    print("vec.abs  =", np.abs(vecs[:, 1]))
# Out:
# ===== Final-state mother-channel diagnosis across all Q =====
#
# ===== Q[0] = [0. 0.] =====
# pp_mother_sz0            |eig|max = 190730.06
# ph_mother_longitudinal   |eig|max = 68175.487
# --> leading mother channel at this Q: pp_mother_sz0  (|eig|max = 190730.06)
#
# ===== Q[1] = [0.         1.81379936] =====
# pp_mother_sz0            |eig|max = 26618.059
# ph_mother_longitudinal   |eig|max = 53236.117
# --> leading mother channel at this Q: ph_mother_longitudinal  (|eig|max = 53236.117)
#
# ===== Q[2] = [1.57079633 0.90689968] =====
# pp_mother_sz0            |eig|max = 27485.089
# ph_mother_longitudinal   |eig|max = 54970.178
# --> leading mother channel at this Q: ph_mother_longitudinal  (|eig|max = 54970.178)
#
# ===== Q[3] = [-1.57079633  0.90689968] =====
# pp_mother_sz0            |eig|max = 27485.089
# ph_mother_longitudinal   |eig|max = 54970.178
# --> leading mother channel at this Q: ph_mother_longitudinal  (|eig|max = 54970.178)
# [{'Q_index': 0, 'Q_vec': array([0., 0.]), 'pp_mother_sz0': 190730.06291041238, 'ph_mother_longitudinal': 68175.48652380955, 'leading_geometry': 'pp_mother_sz0', 'leading_value': np.float64(190730.06291041238)}, {'Q_index': 1, 'Q_vec': array([0.        , 1.81379936]), 'pp_mother_sz0': 26618.058534652297, 'ph_mother_longitudinal': 53236.11706929994, 'leading_geometry': 'ph_mother_longitudinal', 'leading_value': np.float64(53236.11706929994)}, {'Q_index': 2, 'Q_vec': array([1.57079633, 0.90689968]), 'pp_mother_sz0': 27485.089169762447, 'ph_mother_longitudinal': 54970.178339520615, 'leading_geometry': 'ph_mother_longitudinal', 'leading_value': np.float64(54970.178339520615)}, {'Q_index': 3, 'Q_vec': array([-1.57079633,  0.90689968]), 'pp_mother_sz0': 27485.08916976331, 'ph_mother_longitudinal': 54970.178339521124, 'leading_geometry': 'ph_mother_longitudinal', 'leading_value': np.float64(54970.178339521124)}]
# ==== pp_mother_sz0 ====
# Q = [0. 0.]
# |eig|max = 190730.06291041238
# vec.real = [-0.28567873 -0.29457652 -0.28567873 -0.28567873 -0.29457652 -0.28567873
#   0.28567873  0.29457652  0.28567873  0.28567873  0.29457652  0.28567873]
# vec.abs  = [0.28567873 0.29457652 0.28567873 0.28567873 0.29457652 0.28567873
#  0.28567873 0.29457652 0.28567873 0.28567873 0.29457652 0.28567873]
#
# ==== pp_mother_sz0 ====
# Q = [0. 0.]
# second |eig|max = 27575.540853467104
# vec.real = [-3.53553391e-01  1.25866158e-12  3.53553391e-01 -3.53553391e-01
#   1.25915424e-12  3.53553391e-01  3.53553391e-01 -1.25904322e-12
#  -3.53553391e-01  3.53553391e-01 -1.25904322e-12 -3.53553391e-01]
# vec.abs  = [3.53553391e-01 1.25866158e-12 3.53553391e-01 3.53553391e-01
#  1.25915424e-12 3.53553391e-01 3.53553391e-01 1.25904322e-12
#  3.53553391e-01 3.53553391e-01 1.25904322e-12 3.53553391e-01]
#
# ==== ph_mother_longitudinal ====
# Q = [0. 0.]
# |eig|max = 68175.48652380955
# vec.real = [-0.28365008 -0.29847154 -0.28365008 -0.28365008 -0.29847154 -0.28365008
#   0.28365008  0.29847154  0.28365008  0.28365008  0.29847154  0.28365008]
# vec.abs  = [0.28365008 0.29847154 0.28365008 0.28365008 0.29847154 0.28365008
#  0.28365008 0.29847154 0.28365008 0.28365008 0.29847154 0.28365008]
#
# ==== ph_mother_longitudinal ====
# Q = [0. 0.]
# second |eig|max = 55400.38101047329
# vec.real = [-0.2001316   0.41218283 -0.2001316  -0.2001316   0.41218283 -0.2001316
#  -0.2001316   0.41218283 -0.2001316  -0.2001316   0.41218283 -0.2001316 ]
# vec.abs  = [0.2001316  0.41218283 0.2001316  0.2001316  0.41218283 0.2001316
#  0.2001316  0.41218283 0.2001316  0.2001316  0.41218283 0.2001316 ]

# %% [markdown]
# ## 5. PI benchmark: `U=0, V=6`
#
# Expectation from the PRL benchmark at van Hove filling:
# - dominant nearest-neighbor repulsion should favor **Pomeranchuk instability (PI)** with d-wave character.
#
# If this still does **not** look PI-like, then the likely next suspects are:
# - `form_factor.py`
# - `kagome_order_diagnosis.py`

# %%
pi_result = run_case("PI benchmark", U=.0, V=6.0, flow_kwargs=FLOW_KWARGS)
# Out:
# ===== Running case: PI benchmark (U=0.0, V=6.0) =====
# [DEBUG] entering step: T_old=10.00000000, dT=-8.60823610e-02
# [DEBUG] leaving step: T_new=9.91391764, rhs_norm=1.435176557102803, channel_norm=0.1235433864856811, accepted_substeps=1, max_rel_update=0.010295282207140091
# [DEBUG] entering step: T_old=9.91391764, dT=-8.53413437e-02
# [DEBUG] leaving step: T_new=9.82857630, rhs_norm=1.4414744560752046, channel_norm=0.2465607534927734, accepted_substeps=1, max_rel_update=0.010251447250591024
# [DEBUG] entering step: T_old=9.82857630, dT=-8.46067053e-02
# [DEBUG] leaving step: T_new=9.74396959, rhs_norm=1.4477052938057815, channel_norm=0.3690463286117773, accepted_substeps=1, max_rel_update=0.01020713125991699
# [DEBUG] entering step: T_old=9.74396959, dT=-8.38783908e-02
# [DEBUG] leaving step: T_new=9.66009120, rhs_norm=1.4538622026051997, channel_norm=0.4909939505836073, accepted_substeps=1, max_rel_update=0.010162301830985833
# [DEBUG] entering step: T_old=9.66009120, dT=-8.31563458e-02
# [DEBUG] leaving step: T_new=9.57693485, rhs_norm=1.4599380722649085, channel_norm=0.612397065752076, accepted_substeps=1, max_rel_update=0.010116926264039058
# [DEBUG] entering step: T_old=9.57693485, dT=-8.24405163e-02
# [DEBUG] leaving step: T_new=9.49449434, rhs_norm=1.4659255508153042, channel_norm=0.7332487250651307, accepted_substeps=1, max_rel_update=0.010070971609421225
# [DEBUG] entering step: T_old=9.49449434, dT=-8.17308489e-02
# [DEBUG] leaving step: T_new=9.41276349, rhs_norm=1.471817046304273, channel_norm=0.8535415816893774, accepted_substeps=1, max_rel_update=0.010024404718687228
# [DEBUG] entering step: T_old=9.41276349, dT=-8.10272905e-02
# [DEBUG] leaving step: T_new=9.33173620, rhs_norm=1.4776047297049015, channel_norm=0.9732678893066606, accepted_substeps=1, max_rel_update=0.009977192301440266
# [DEBUG] entering step: T_old=9.33173620, dT=-8.03297884e-02
# [DEBUG] leaving step: T_new=9.25140641, rhs_norm=1.4832805390681636, channel_norm=1.092419501165822, accepted_substeps=1, max_rel_update=0.00992930098826345
# [DEBUG] entering step: T_old=9.25140641, dT=-7.96382906e-02
# [DEBUG] leaving step: T_new=9.17176812, rhs_norm=1.4888361850435157, channel_norm=1.2109878699672303, accepted_substeps=1, max_rel_update=0.009880697400117362
# [DEBUG] entering step: T_old=9.17176812, dT=-7.89527454e-02
# [DEBUG] leaving step: T_new=9.09281537, rhs_norm=1.4942631578976382, channel_norm=1.3289640486621654, accepted_substeps=1, max_rel_update=0.009831348224577928
# [DEBUG] entering step: T_old=9.09281537, dT=-7.82731015e-02
# [DEBUG] leaving step: T_new=9.01454227, rhs_norm=1.4995527361687793, channel_norm=1.446338692253883, accepted_substeps=1, max_rel_update=0.00978122029930979
# [DEBUG] entering step: T_old=9.01454227, dT=-7.75993082e-02
# [DEBUG] leaving step: T_new=8.93694296, rhs_norm=1.5046959971015859, channel_norm=1.5631020606917365, accepted_substeps=1, max_rel_update=0.009730280703154456
# [DEBUG] entering step: T_old=8.93694296, dT=-7.69313150e-02
# [DEBUG] leaving step: T_new=8.86001165, rhs_norm=1.5096838290143033, channel_norm=1.679244022954515, accepted_substeps=1, max_rel_update=0.009678496855231542
# [DEBUG] entering step: T_old=8.86001165, dT=-7.62690721e-02
# [DEBUG] leaving step: T_new=8.78374258, rhs_norm=1.5145069457575118, channel_norm=1.7947540624237501, accepted_substeps=1, max_rel_update=0.009625836622436266
# [DEBUG] entering step: T_old=8.78374258, dT=-7.56125299e-02
# [DEBUG] leaving step: T_new=8.70813005, rhs_norm=1.5191559034302715, channel_norm=1.9096212836525372, accepted_substeps=1, max_rel_update=0.009572268435732263
# [DEBUG] entering step: T_old=8.70813005, dT=-7.49616394e-02
# [DEBUG] leaving step: T_new=8.63316841, rhs_norm=1.5236211195260507, channel_norm=2.0238344206397927, accepted_substeps=1, max_rel_update=0.009517761415604623
# [DEBUG] entering step: T_old=8.63316841, dT=-7.43163519e-02
# [DEBUG] leaving step: T_new=8.55885206, rhs_norm=1.527892894687112, channel_norm=2.1373818467244194, accepted_substeps=1, max_rel_update=0.009462285507052243
# [DEBUG] entering step: T_old=8.55885206, dT=-7.36766192e-02
# [DEBUG] leaving step: T_new=8.48517544, rhs_norm=1.5319614372514356, channel_norm=2.250251586218125, accepted_substeps=1, max_rel_update=0.009405811624475487
# [DEBUG] entering step: T_old=8.48517544, dT=-7.30423935e-02
# [DEBUG] leaving step: T_new=8.41213304, rhs_norm=1.5358168907814278, channel_norm=2.362431327899595, accepted_substeps=1, max_rel_update=0.009348311806789158
# [DEBUG] entering step: T_old=8.41213304, dT=-7.24136273e-02
# [DEBUG] leaving step: T_new=8.33971942, rhs_norm=1.5506055137648362, channel_norm=2.4739084404965928, accepted_substeps=1, max_rel_update=0.009357080817744152
# [DEBUG] entering step: T_old=8.33971942, dT=-7.17902737e-02
# [DEBUG] leaving step: T_new=8.26792914, rhs_norm=1.6135035069250465, channel_norm=2.5846699902859, accepted_substeps=1, max_rel_update=0.009652821535702343
# [DEBUG] entering step: T_old=8.26792914, dT=-7.11722861e-02
# [DEBUG] leaving step: T_new=8.19675686, rhs_norm=1.6792163465497552, channel_norm=2.6947027609441374, accepted_substeps=1, max_rel_update=0.009959472187438949
# [DEBUG] entering step: T_old=8.19675686, dT=-7.05596183e-02
# [DEBUG] leaving step: T_new=8.12619724, rhs_norm=1.7478890331784274, channel_norm=2.8039932757850696, accepted_substeps=1, max_rel_update=0.010277531912219
# [DEBUG] entering step: T_old=8.12619724, dT=-6.99522244e-02
# [DEBUG] leaving step: T_new=8.05624501, rhs_norm=1.819675095057732, channel_norm=2.9125278225209583, accepted_substeps=1, max_rel_update=0.010607526716832925
# [DEBUG] entering step: T_old=8.05624501, dT=-6.93500591e-02
# [DEBUG] leaving step: T_new=7.98689495, rhs_norm=1.8947371576386887, channel_norm=3.020292480687211, accepted_substeps=1, max_rel_update=0.010950011162387073
# [DEBUG] entering step: T_old=7.98689495, dT=-6.87530775e-02
# [DEBUG] leaving step: T_new=7.91814188, rhs_norm=1.9732475566100005, channel_norm=3.1272731518701873, accepted_substeps=1, max_rel_update=0.011305570176184542
# [DEBUG] entering step: T_old=7.91814188, dT=-6.81612347e-02
# [DEBUG] leaving step: T_new=7.84998064, rhs_norm=2.055388998330982, channel_norm=3.233455592878291, accepted_substeps=1, max_rel_update=0.011674820999783857
# [DEBUG] entering step: T_old=7.84998064, dT=-6.75744867e-02
# [DEBUG] leaving step: T_new=7.78240615, rhs_norm=2.141355271927106, channel_norm=3.338825451995654, accepted_substeps=1, max_rel_update=0.012058415285450734
# [DEBUG] entering step: T_old=7.78240615, dT=-6.69927896e-02
# [DEBUG] leaving step: T_new=7.71541336, rhs_norm=2.231352017757608, channel_norm=3.443368308456415, accepted_substeps=1, max_rel_update=0.012457041354543404
# [DEBUG] entering step: T_old=7.71541336, dT=-6.64160999e-02
# [DEBUG] leaving step: T_new=7.64899726, rhs_norm=2.3255975574650463, channel_norm=3.5470697152750326, accepted_substeps=1, max_rel_update=0.012871426632779077
# [DEBUG] entering step: T_old=7.64899726, dT=-6.58443744e-02
# [DEBUG] leaving step: T_new=7.58315289, rhs_norm=2.4243237913774465, channel_norm=3.649915245564956, accepted_substeps=1, max_rel_update=0.013302340278987253
# [DEBUG] entering step: T_old=7.58315289, dT=-6.52775705e-02
# [DEBUG] leaving step: T_new=7.51787532, rhs_norm=2.5277771696632265, channel_norm=3.7518905424736686, accepted_substeps=1, max_rel_update=0.013750596025747167
# [DEBUG] entering step: T_old=7.51787532, dT=-6.47156457e-02
# [DEBUG] leaving step: T_new=7.45315967, rhs_norm=2.6362197443473345, channel_norm=3.8529813728570903, accepted_substeps=1, max_rel_update=0.014217055252373297
# [DEBUG] entering step: T_old=7.45315967, dT=-6.41585582e-02
# [DEBUG] leaving step: T_new=7.38900112, rhs_norm=2.7499303100933434, channel_norm=3.953173684810298, accepted_substeps=1, max_rel_update=0.01470263031300331
# [DEBUG] entering step: T_old=7.38900112, dT=-6.36062662e-02
# [DEBUG] leaving step: T_new=7.32539485, rhs_norm=2.869205642554631, channel_norm=4.052453669164611, accepted_substeps=1, max_rel_update=0.015208288145125287
# [DEBUG] entering step: T_old=7.32539485, dT=-6.30587284e-02
# [DEBUG] leaving step: T_new=7.26233612, rhs_norm=2.994361844111197, channel_norm=4.156944806206449, accepted_substeps=1, max_rel_update=0.015735054186831136
# [DEBUG] entering step: T_old=7.26233612, dT=-6.25159040e-02
# [DEBUG] leaving step: T_new=7.19982022, rhs_norm=3.1257358079539324, channel_norm=4.352353005818635, accepted_substeps=1, max_rel_update=0.016284016634348857
# [DEBUG] entering step: T_old=7.19982022, dT=-6.19777523e-02
# [DEBUG] leaving step: T_new=7.13784247, rhs_norm=3.263686812774414, channel_norm=4.554628978720485, accepted_substeps=1, max_rel_update=0.016856331075154152
# [DEBUG] entering step: T_old=7.13784247, dT=-6.14442332e-02
# [DEBUG] leaving step: T_new=7.07639823, rhs_norm=3.4085982617868957, channel_norm=4.764067685154678, accepted_substeps=1, max_rel_update=0.01745322553618273
# [DEBUG] entering step: T_old=7.07639823, dT=-6.09153067e-02
# [DEBUG] leaving step: T_new=7.01548293, rhs_norm=3.56087958147592, channel_norm=4.980979757051963, accepted_substeps=1, max_rel_update=0.01807600599144043
# [DEBUG] entering step: T_old=7.01548293, dT=-6.03909334e-02
# [DEBUG] leaving step: T_new=6.95509199, rhs_norm=3.720968297356741, channel_norm=5.205692505596655, accepted_substeps=1, max_rel_update=0.018726062378724387
# [DEBUG] entering step: T_old=6.95509199, dT=-5.98710740e-02
# [DEBUG] leaving step: T_new=6.89522092, rhs_norm=3.889332306191148, channel_norm=5.438551007773102, accepted_substeps=1, max_rel_update=0.019404875181370563
# [DEBUG] entering step: T_old=6.89522092, dT=-5.93556896e-02
# [DEBUG] leaving step: T_new=6.83586523, rhs_norm=4.06647236655769, channel_norm=5.679919279428082, accepted_substeps=1, max_rel_update=0.0201140226379151
# [DEBUG] entering step: T_old=6.83586523, dT=-5.88447418e-02
# [DEBUG] leaving step: T_new=6.77702049, rhs_norm=4.252924832479099, channel_norm=5.930181543235105, accepted_substeps=1, max_rel_update=0.020855188650585194
# [DEBUG] entering step: T_old=6.77702049, dT=-5.83381924e-02
# [DEBUG] leaving step: T_new=6.71868229, rhs_norm=4.449264658015068, channel_norm=6.189743600906909, accepted_substeps=1, max_rel_update=0.02163017147265033
# [DEBUG] entering step: T_old=6.71868229, dT=-5.78360035e-02
# [DEBUG] leaving step: T_new=6.66084629, rhs_norm=4.656108704399138, channel_norm=6.459034320087973, accepted_substeps=1, max_rel_update=0.02244089326508868
# [DEBUG] entering step: T_old=6.66084629, dT=-5.73381375e-02
# [DEBUG] leaving step: T_new=6.60350815, rhs_norm=4.8741193855079405, channel_norm=6.7385072475879, accepted_substeps=1, max_rel_update=0.023289410624993897
# [DEBUG] entering step: T_old=6.60350815, dT=-5.68445573e-02
# [DEBUG] leaving step: T_new=6.54666360, rhs_norm=5.104008692287814, channel_norm=7.028642362009691, accepted_substeps=1, max_rel_update=0.024177926201815955
# [DEBUG] entering step: T_old=6.54666360, dT=-5.63552259e-02
# [DEBUG] leaving step: T_new=6.49030837, rhs_norm=5.346542642330448, channel_norm=7.329947980409049, accepted_substeps=1, max_rel_update=0.025108801533279834
# [DEBUG] entering step: T_old=6.49030837, dT=-5.58701068e-02
# [DEBUG] leaving step: T_new=6.43443826, rhs_norm=5.602546207207349, channel_norm=7.642962835420732, accepted_substeps=1, max_rel_update=0.02608457125097365
# [DEBUG] entering step: T_old=6.43443826, dT=-5.53891637e-02
# [DEBUG] leaving step: T_new=6.37904910, rhs_norm=5.872908777587947, channel_norm=7.96825834133793, accepted_substeps=1, max_rel_update=0.027107958826433104
# [DEBUG] entering step: T_old=6.37904910, dT=-5.49123607e-02
# [DEBUG] leaving step: T_new=6.32413674, rhs_norm=6.158590234747456, channel_norm=8.306441069970818, accepted_substeps=1, max_rel_update=0.028181894052740648
# [DEBUG] entering step: T_old=6.32413674, dT=-5.44396622e-02
# [DEBUG] leaving step: T_new=6.26969708, rhs_norm=6.460627707024494, channel_norm=8.658155459785968, accepted_substeps=1, max_rel_update=0.02930953248459589
# [DEBUG] entering step: T_old=6.26969708, dT=-5.39710327e-02
# [DEBUG] leaving step: T_new=6.21572604, rhs_norm=6.780143101355311, channel_norm=9.024086784892885, accepted_substeps=1, max_rel_update=0.030494277092243168
# [DEBUG] entering step: T_old=6.21572604, dT=-5.35064373e-02
# [DEBUG] leaving step: T_new=6.16221961, rhs_norm=7.118351513485584, channel_norm=9.404964413961226, accepted_substeps=1, max_rel_update=0.03173980242236172
# [DEBUG] entering step: T_old=6.16221961, dT=-5.30458413e-02
# [DEBUG] leaving step: T_new=6.10917377, rhs_norm=7.476570636187812, channel_norm=9.801565393197318, accepted_substeps=1, max_rel_update=0.03305008160300772
# [DEBUG] entering step: T_old=6.10917377, dT=-5.25892101e-02
# [DEBUG] leaving step: T_new=6.05658456, rhs_norm=7.856231303215907, channel_norm=10.214718392169791, accepted_substeps=1, max_rel_update=0.03442941658103935
# [DEBUG] entering step: T_old=6.05658456, dT=-5.21365098e-02
# [DEBUG] leaving step: T_new=6.00444805, rhs_norm=8.258889328312701, channel_norm=10.645308056657363, accepted_substeps=1, max_rel_update=0.03588247204063095
# [DEBUG] entering step: T_old=6.00444805, dT=-5.16877064e-02
# [DEBUG] leaving step: T_new=5.95276034, rhs_norm=8.686238823965692, channel_norm=11.094279818922798, accepted_substeps=1, max_rel_update=0.03741431352211956
# [DEBUG] entering step: T_old=5.95276034, dT=-5.12427664e-02
# [DEBUG] leaving step: T_new=5.90151757, rhs_norm=9.140127214527457, channel_norm=11.562645223045692, accepted_substeps=1, max_rel_update=0.03903045034357444
# [DEBUG] entering step: T_old=5.90151757, dT=-5.08016566e-02
# [DEBUG] leaving step: T_new=5.85071592, rhs_norm=9.62257219368288, channel_norm=12.051487831354128, accepted_substeps=1, max_rel_update=0.04073688402570307
# [DEBUG] entering step: T_old=5.85071592, dT=-5.03643440e-02
# [DEBUG] leaving step: T_new=5.80035157, rhs_norm=10.135780918169097, channel_norm=12.561969787796695, accepted_substeps=1, max_rel_update=0.0423584177809528
# [DEBUG] entering step: T_old=5.80035157, dT=-4.99307958e-02
# [DEBUG] leaving step: T_new=5.75042078, rhs_norm=10.682171779490861, channel_norm=13.095339125553785, accepted_substeps=1, max_rel_update=0.04245905274149211
# [DEBUG] entering step: T_old=5.75042078, dT=-4.95009797e-02
# [DEBUG] leaving step: T_new=5.70091980, rhs_norm=11.264399154795957, channel_norm=13.652937919617521, accepted_substeps=1, max_rel_update=0.04257994304062413
# [DEBUG] entering step: T_old=5.70091980, dT=-4.90748636e-02
# [DEBUG] leaving step: T_new=5.65184493, rhs_norm=11.885381609147965, channel_norm=14.236211400854856, accepted_substeps=1, max_rel_update=0.0427214629313773
# [DEBUG] entering step: T_old=5.65184493, dT=-4.86524156e-02
# [DEBUG] leaving step: T_new=5.60319252, rhs_norm=12.54833410671174, channel_norm=14.846718166677546, accepted_substeps=1, max_rel_update=0.04288407558952308
# [DEBUG] entering step: T_old=5.60319252, dT=-4.82336041e-02
# [DEBUG] leaving step: T_new=5.55495891, rhs_norm=13.256804891032699, channel_norm=15.48614164544817, accepted_substeps=1, max_rel_update=0.04306833817360168
# [DEBUG] entering step: T_old=5.55495891, dT=-4.78183978e-02
# [DEBUG] leaving step: T_new=5.50714052, rhs_norm=14.014717818618227, channel_norm=16.156302997852602, accepted_substeps=1, max_rel_update=0.04327490783357349
# [DEBUG] entering step: T_old=5.50714052, dT=-4.74067658e-02
# [DEBUG] leaving step: T_new=5.45973375, rhs_norm=14.826421080396488, channel_norm=16.859175669533602, accepted_substeps=1, max_rel_update=0.04350454876802082
# [DEBUG] entering step: T_old=5.45973375, dT=-4.69986772e-02
# [DEBUG] leaving step: T_new=5.41273507, rhs_norm=15.696743428614049, channel_norm=17.596901846376433, accepted_substeps=1, max_rel_update=0.04375814045143289
# [DEBUG] entering step: T_old=5.41273507, dT=-4.65941014e-02
# [DEBUG] leaving step: T_new=5.36614097, rhs_norm=16.631059250269562, channel_norm=18.37181110829177, accepted_substeps=1, max_rel_update=0.04403668717825494
# [DEBUG] entering step: T_old=5.36614097, dT=-4.61930084e-02
# [DEBUG] leaving step: T_new=5.31994796, rhs_norm=17.635364102354902, channel_norm=19.186441630816255, accepted_substeps=1, max_rel_update=0.04434132910047277
# [DEBUG] entering step: T_old=5.31994796, dT=-4.57953681e-02
# [DEBUG] leaving step: T_new=5.27415259, rhs_norm=18.71636266186404, channel_norm=20.043564348417465, accepted_substeps=1, max_rel_update=0.04467335497086366
# [DEBUG] entering step: T_old=5.27415259, dT=-4.54011508e-02
# [DEBUG] leaving step: T_new=5.22875144, rhs_norm=19.881571461256453, channel_norm=20.946210571666537, accepted_substeps=1, max_rel_update=0.04503421684678255
# [DEBUG] entering step: T_old=5.22875144, dT=-4.50103269e-02
# [DEBUG] leaving step: T_new=5.18374112, rhs_norm=21.139439299137567, channel_norm=21.897703645734715, accepted_substeps=1, max_rel_update=0.04542554706077678
# [DEBUG] entering step: T_old=5.18374112, dT=-4.46228674e-02
# [DEBUG] leaving step: T_new=5.13911825, rhs_norm=22.49948886398938, channel_norm=22.901695354181985, accepted_substeps=1, max_rel_update=0.04584917782659056
# [DEBUG] entering step: T_old=5.13911825, dT=-4.42387432e-02
# [DEBUG] leaving step: T_new=5.09487951, rhs_norm=23.97248392188792, channel_norm=23.962207915113805, accepted_substeps=1, max_rel_update=0.046307163925231584
# [DEBUG] entering step: T_old=5.09487951, dT=-4.38579257e-02
# [DEBUG] leaving step: T_new=5.05102158, rhs_norm=25.570627444573308, channel_norm=25.083682593392037, accepted_substeps=1, max_rel_update=0.04680180900904705
# [DEBUG] entering step: T_old=5.05102158, dT=-4.34803863e-02
# [DEBUG] leaving step: T_new=5.00754119, rhs_norm=27.307797354407064, channel_norm=26.271036171624523, accepted_substeps=1, max_rel_update=0.04733569617665626
# [DEBUG] entering step: T_old=5.00754119, dT=-4.31060969e-02
# [DEBUG] leaving step: T_new=4.96443510, rhs_norm=29.19982822057346, channel_norm=27.529726795735595, accepted_substeps=1, max_rel_update=0.04791172361410663
# [DEBUG] entering step: T_old=4.96443510, dT=-4.27350294e-02
# [DEBUG] leaving step: T_new=4.92170007, rhs_norm=31.26484936724637, channel_norm=28.86583105323189, accepted_substeps=1, max_rel_update=0.04853314627529321
# [DEBUG] entering step: T_old=4.92170007, dT=-4.23671562e-02
# [DEBUG] leaving step: T_new=4.87933291, rhs_norm=33.52369259871262, channel_norm=30.28613457383603, accepted_substeps=1, max_rel_update=0.049203624797253785
# [DEBUG] entering step: T_old=4.87933291, dT=-4.20024497e-02
# [DEBUG] leaving step: T_new=4.83733046, rhs_norm=36.00038631127475, channel_norm=31.79823898951712, accepted_substeps=1, max_rel_update=0.049927283126694755
# [DEBUG] entering step: T_old=4.83733046, dT=-4.16408827e-02
# [DEBUG] leaving step: T_new=4.79568958, rhs_norm=38.72275742428853, channel_norm=33.410688789587546, accepted_substeps=1, max_rel_update=0.0507087766904954
# [DEBUG] entering step: T_old=4.79568958, dT=-4.12824282e-02
# [DEBUG] leaving step: T_new=4.75440715, rhs_norm=41.72316870505353, channel_norm=35.13312250422578, accepted_substeps=1, max_rel_update=0.051553373397528746
# [DEBUG] entering step: T_old=4.75440715, dT=-4.09270593e-02
# [DEBUG] leaving step: T_new=4.71348009, rhs_norm=45.03942721583239, channel_norm=36.976453811409826, accepted_substeps=1, max_rel_update=0.05246705034436748
# [DEBUG] entering step: T_old=4.71348009, dT=-4.05747495e-02
# [DEBUG] leaving step: T_new=4.67290534, rhs_norm=48.71591052185315, channel_norm=38.95308967660681, accepted_substeps=1, max_rel_update=0.05345660985443258
# [DEBUG] entering step: T_old=4.67290534, dT=-4.02254725e-02
# [DEBUG] leaving step: T_new=4.63267987, rhs_norm=52.80497202345836, channel_norm=41.07719462440643, accepted_substeps=1, max_rel_update=0.054529819468345085
# [DEBUG] entering step: T_old=4.63267987, dT=-3.98792021e-02
# [DEBUG] leaving step: T_new=4.59280067, rhs_norm=57.36870682635459, channel_norm=43.36501287782396, accepted_substeps=1, max_rel_update=0.05569558180241933
# [DEBUG] entering step: T_old=4.59280067, dT=-3.95359125e-02
# [DEBUG] leaving step: T_new=4.55326476, rhs_norm=62.481187130068804, channel_norm=45.835263625544926, accepted_substeps=1, max_rel_update=0.05696414191506459
# [DEBUG] entering step: T_old=4.55326476, dT=-3.91955780e-02
# [DEBUG] leaving step: T_new=4.51406918, rhs_norm=68.23131440001298, channel_norm=48.509629433740734, accepted_substeps=1, max_rel_update=0.05834734212601608
# [DEBUG] entering step: T_old=4.51406918, dT=-3.88581732e-02
# [DEBUG] leaving step: T_new=4.47521100, rhs_norm=74.7264893396946, channel_norm=51.413364302724865, accepted_substeps=1, max_rel_update=0.059858937346663046
# [DEBUG] entering step: T_old=4.47521100, dT=-3.85236729e-02
# [DEBUG] leaving step: T_new=4.43668733, rhs_norm=82.09737702101263, channel_norm=54.576056802538496, accepted_substeps=1, max_rel_update=0.06151498822740943
# [DEBUG] entering step: T_old=4.43668733, dT=-3.81920520e-02
# [DEBUG] leaving step: T_new=4.39849528, rhs_norm=90.50415430475925, channel_norm=58.03259617416623, accepted_substeps=1, max_rel_update=0.06333435528575893
# [DEBUG] entering step: T_old=4.39849528, dT=-3.78632858e-02
# [DEBUG] leaving step: T_new=4.36063199, rhs_norm=100.14478663768888, channel_norm=61.82440685654545, accepted_substeps=1, max_rel_update=0.06533932535086523
# [DEBUG] entering step: T_old=4.36063199, dT=-3.75373497e-02
# [DEBUG] leaving step: T_new=4.32309464, rhs_norm=111.26611772945941, channel_norm=66.00104203210466, accepted_substeps=1, max_rel_update=0.06755641320183603
# [DEBUG] entering step: T_old=4.32309464, dT=-3.72142194e-02
# [DEBUG] leaving step: T_new=4.28588042, rhs_norm=124.17891045074248, channel_norm=70.62226324700548, accepted_substeps=1, max_rel_update=0.07001739779582469
# [DEBUG] entering step: T_old=4.28588042, dT=-3.68938706e-02
# [DEBUG] leaving step: T_new=4.24898655, rhs_norm=139.2785187832552, channel_norm=75.76078689432956, accepted_substeps=1, max_rel_update=0.07276067646475427
# [DEBUG] entering step: T_old=4.24898655, dT=-3.65762794e-02
# [DEBUG] leaving step: T_new=4.21241027, rhs_norm=157.0737119811834, channel_norm=81.50595887593227, accepted_substeps=1, max_rel_update=0.07583305582102808
# [DEBUG] entering step: T_old=4.21241027, dT=-3.62614222e-02
# [DEBUG] leaving step: T_new=4.17614885, rhs_norm=178.2275051461948, channel_norm=87.96874168551213, accepted_substeps=1, max_rel_update=0.0792921511348325
# [DEBUG] entering step: T_old=4.17614885, dT=-3.59492753e-02
# [DEBUG] leaving step: T_new=4.14019958, rhs_norm=203.61600819341243, channel_norm=95.28858962041244, accepted_substeps=1, max_rel_update=0.08320964691149886
# [DEBUG] entering step: T_old=4.14019958, dT=-3.56398155e-02
# [DEBUG] leaving step: T_new=4.10455976, rhs_norm=234.41488075368977, channel_norm=103.64309271033879, accepted_substeps=1, max_rel_update=0.08767579752420517
# [DEBUG] entering step: T_old=4.10455976, dT=-3.53330195e-02
# [DEBUG] leaving step: T_new=4.06922674, rhs_norm=272.2290603436367, channel_norm=113.26176741033186, accepted_substeps=1, max_rel_update=0.09280574757524161
# [DEBUG] entering step: T_old=4.06922674, dT=-3.50288645e-02
# [DEBUG] leaving step: T_new=4.03419788, rhs_norm=319.2920683230427, channel_norm=124.44620601864924, accepted_substeps=1, max_rel_update=0.09874857918999001
# [DEBUG] entering step: T_old=4.03419788, dT=-3.47273278e-02
# [DEBUG] leaving step: T_new=3.99947055, rhs_norm=378.7804092372229, channel_norm=137.60023745390063, accepted_substeps=1, max_rel_update=0.10570054207422093
# [DEBUG] entering step: T_old=3.99947055, dT=-3.44283868e-02
# [DEBUG] leaving step: T_new=3.96504216, rhs_norm=455.32452946349684, channel_norm=153.27632645637905, accepted_substeps=1, max_rel_update=0.11392486882684542
# [DEBUG] entering step: T_old=3.96504216, dT=-3.41320191e-02
# [DEBUG] leaving step: T_new=3.93091014, rhs_norm=555.8678230114214, channel_norm=172.24921759734164, accepted_substeps=1, max_rel_update=0.12378226683532949
# [DEBUG] entering step: T_old=3.93091014, dT=-3.38382026e-02
# [DEBUG] leaving step: T_new=3.89707194, rhs_norm=818.2681768937774, channel_norm=195.6370970008885, accepted_substeps=1, max_rel_update=0.1607480413440025
# [DEBUG] entering step: T_old=3.89707194, dT=-3.35469154e-02
# [DEBUG] leaving step: T_new=3.86352503, rhs_norm=1287.2604895999368, channel_norm=225.1094314807137, accepted_substeps=1, max_rel_update=0.22073328299178868
# [DEBUG] entering step: T_old=3.86352503, dT=-3.32581356e-02
# [DEBUG] leaving step: T_new=3.83026689, rhs_norm=2182.93310562839, channel_norm=263.2614436204534, accepted_substeps=1, max_rel_update=0.32251107715320865
# [DEBUG] entering step: T_old=3.83026689, dT=-3.29718417e-02
# [DEBUG] leaving step: T_new=3.79729505, rhs_norm=4107.424287674038, channel_norm=364.1359916367394, accepted_substeps=1, max_rel_update=0.5144290846292082
# [DEBUG] entering step: T_old=3.79729505, dT=-3.26880123e-02
# [DEBUG] leaving step: T_new=3.76460704, rhs_norm=8999.279769892757, channel_norm=658.3045595768835, accepted_substeps=1, max_rel_update=0.807853589583107
# [DEBUG] entering step: T_old=3.76460704, dT=-3.24066262e-02
# [DEBUG] leaving step: T_new=3.73220041, rhs_norm=25057.384456684307, channel_norm=1470.3298508858243, accepted_substeps=2, max_rel_update=0.6167550258430985
# [DEBUG] entering step: T_old=3.73220041, dT=-3.21276623e-02
# [DEBUG] leaving step: T_new=3.70007275, rhs_norm=105590.88534712617, channel_norm=4862.718157009237, accepted_substeps=3, max_rel_update=0.7690764771999093
# [DEBUG] entering step: T_old=3.70007275, dT=-3.18510998e-02
# [DEBUG] leaving step: T_new=3.66822165, rhs_norm=989747.010779564, channel_norm=36387.24896922888, accepted_substeps=7, max_rel_update=0.9261290200942874
# history length = 117
# instability record = 116
# ===== Final record =====
# {'accepted_substeps': 7,
#  'channel_norm': 36387.24896922888,
#  'dT': -0.03185109979507761,
#  'diagnosis_payload': {},
#  'instability': True,
#  'instability_reason': 'channel norm=3.639e+04 exceeded '
#                        'channel_divergence_threshold',
#  'leading_Q': None,
#  'leading_channel_name': None,
#  'leading_eigenvalue_abs': None,
#  'leading_order_label': None,
#  'max_rel_update': 0.9261290200942874,
#  'rhs_norm': 989747.010779564,
#  'step_index': 116,
#  'temperature': 3.6682216474527043,
#  'terminated_early': False,
#  'termination_reason': None}

# %%
import numpy as np
import matplotlib.pyplot as plt

Qs_to_check = FLOW_KWARGS["diagnosis_Qs"]
# 如果你想继续测试 Q -> Q+G 不变性，再手动加 reciprocal vector
# Qs_to_check = FLOW_KWARGS["diagnosis_Qs"] + 5*np.array([np.pi, np.pi/np.sqrt(3)]) + np.array([0,2*np.pi/np.sqrt(3)])

solver = pi_result["solver"]

mother_channels = [
    "pp_mother_sz0",
    "ph_mother_longitudinal",
]

print("===== Final-state mother-channel diagnosis across all Q =====")
Q_summary = []

for i, Q in enumerate(Qs_to_check):
    Q = np.asarray(Q, dtype=float)
    mothers = solver.build_mother_kernel_dict(Q)

    print(f"\n===== Q[{i}] = {Q} =====")
    row = {
        "Q_index": i,
        "Q_vec": Q,
    }

    vals_dict = {}
    for name in mother_channels:
        k = mothers[name]
        vals, vecs = k.eig(sort_by="abs")
        eigmax = abs(vals[0])
        vals_dict[name] = eigmax
        row[name] = float(eigmax)
        print(f"{name:24s} |eig|max = {eigmax:.8g}")

    lead_name = max(vals_dict, key=vals_dict.get)
    row["leading_geometry"] = lead_name
    row["leading_value"] = vals_dict[lead_name]
    Q_summary.append(row)

    print(f"--> leading mother channel at this Q: {lead_name}  (|eig|max = {vals_dict[lead_name]:.8g})")

print(Q_summary)
labels = [f"Q{i}" for i in range(len(Q_summary))]
x = np.arange(len(labels))
width = 0.35

pp_vals = [row["pp_mother_sz0"] for row in Q_summary]
ph_vals = [row["ph_mother_longitudinal"] for row in Q_summary]

plt.figure(figsize=(8, 5))
plt.bar(x - width/2, pp_vals, width, label="pp_mother_sz0")
plt.bar(x + width/2, ph_vals, width, label="ph_mother_longitudinal")

plt.xticks(x, labels)
plt.ylabel("|leading eigenvalue|")
plt.title("Final mother-channel diagnosis across Q")
plt.legend()
plt.show()

# ----------------------------------------
Q = np.array([0.0, 0.0])
mothers = solver.build_mother_kernel_dict(Q)

for name in ["pp_mother_sz0", "ph_mother_longitudinal"]:
    k = mothers[name]
    vals, vecs = k.eig(sort_by="abs")
    print(f"\n==== {name} ====")
    print("Q =", k.Q)
    print("|eig|max =", abs(vals[0]))
    print("vec.real =", np.real(vecs[:, 0]))
    print("vec.abs  =", np.abs(vecs[:, 0]))
    print(f"\n==== {name} ====")
    print("Q =", k.Q)
    print("second |eig|max =", abs(vals[1]))
    print("vec.real =", np.real(vecs[:, 1]))
    print("vec.abs  =", np.abs(vecs[:, 1]))
# Out:
# ===== Final-state mother-channel diagnosis across all Q =====
#
# ===== Q[0] = [0. 0.] =====
# pp_mother_sz0            |eig|max = 0.00069036078
# ph_mother_longitudinal   |eig|max = 0.00076852378
# --> leading mother channel at this Q: ph_mother_longitudinal  (|eig|max = 0.00076852378)
#
# ===== Q[1] = [0.         1.81379936] =====
# pp_mother_sz0            |eig|max = 1214.0263
# ph_mother_longitudinal   |eig|max = 5.8903018
# --> leading mother channel at this Q: pp_mother_sz0  (|eig|max = 1214.0263)
#
# ===== Q[2] = [1.57079633 0.90689968] =====
# pp_mother_sz0            |eig|max = 1214.0263
# ph_mother_longitudinal   |eig|max = 5.8903018
# --> leading mother channel at this Q: pp_mother_sz0  (|eig|max = 1214.0263)
#
# ===== Q[3] = [-1.57079633  0.90689968] =====
# pp_mother_sz0            |eig|max = 1214.0263
# ph_mother_longitudinal   |eig|max = 5.8903018
# --> leading mother channel at this Q: pp_mother_sz0  (|eig|max = 1214.0263)
# [{'Q_index': 0, 'Q_vec': array([0., 0.]), 'pp_mother_sz0': 0.0006903607848780684, 'ph_mother_longitudinal': 0.0007685237822487518, 'leading_geometry': 'ph_mother_longitudinal', 'leading_value': np.float64(0.0007685237822487518)}, {'Q_index': 1, 'Q_vec': array([0.        , 1.81379936]), 'pp_mother_sz0': 1214.0263380680346, 'ph_mother_longitudinal': 5.890301798908152, 'leading_geometry': 'pp_mother_sz0', 'leading_value': np.float64(1214.0263380680346)}, {'Q_index': 2, 'Q_vec': array([1.57079633, 0.90689968]), 'pp_mother_sz0': 1214.0263380680346, 'ph_mother_longitudinal': 5.890301798912175, 'leading_geometry': 'pp_mother_sz0', 'leading_value': np.float64(1214.0263380680346)}, {'Q_index': 3, 'Q_vec': array([-1.57079633,  0.90689968]), 'pp_mother_sz0': 1214.026338068035, 'ph_mother_longitudinal': 5.890301798906288, 'leading_geometry': 'pp_mother_sz0', 'leading_value': np.float64(1214.026338068035)}]
# ==== pp_mother_sz0 ====
# Q = [0. 0.]
# |eig|max = 0.0006903607848780684
# vec.real = [ 3.27326835e-01  3.77964473e-01  1.35741975e-17  3.27326835e-01
#   3.77964473e-01 -6.25861236e-66 -3.27326835e-01 -3.77964473e-01
#   4.68669489e-66 -3.27326835e-01 -3.77964473e-01  4.68669489e-66]
# vec.abs  = [3.27326835e-01 3.77964473e-01 1.35741975e-17 3.27326835e-01
#  3.77964473e-01 1.68391247e-58 3.27326835e-01 3.77964473e-01
#  1.27623981e-58 3.27326835e-01 3.77964473e-01 1.27623981e-58]
#
# ==== pp_mother_sz0 ====
# Q = [0. 0.]
# second |eig|max = 0.0006903607848780681
# vec.real = [ 3.27326835e-01  3.77964473e-01  1.35741975e-17  3.27326835e-01
#   3.77964473e-01  2.78380877e-67 -3.27326835e-01 -3.77964473e-01
#  -2.67702181e-67 -3.27326835e-01 -3.77964473e-01 -2.67702181e-67]
# vec.abs  = [3.27326835e-01 3.77964473e-01 1.35741975e-17 3.27326835e-01
#  3.77964473e-01 1.68391247e-58 3.27326835e-01 3.77964473e-01
#  1.27623981e-58 3.27326835e-01 3.77964473e-01 1.27623981e-58]
#
# ==== ph_mother_longitudinal ====
# Q = [0. 0.]
# |eig|max = 0.0007685237822487518
# vec.real = [ 4.08122880e-04  8.33816480e-04 -3.69004959e-02  4.08122766e-04
#   8.33816153e-04 -3.69004959e-02 -3.14583517e-02  7.03717581e-01
#   4.87514597e-02 -3.14583517e-02  7.03717581e-01  4.87514596e-02]
# vec.abs  = [4.08146776e-04 8.37069627e-04 3.70938037e-02 4.08146670e-04
#  8.37068012e-04 3.70938039e-02 3.20617735e-02 7.03717581e-01
#  4.87523498e-02 3.20617735e-02 7.03717581e-01 4.87523498e-02]
#
# ==== ph_mother_longitudinal ====
# Q = [0. 0.]
# second |eig|max = 0.000768523777460253
# vec.real = [ 4.08124047e-04  8.33815633e-04 -3.69004998e-02  4.08124161e-04
#   8.33815959e-04 -3.69004998e-02 -3.14583616e-02  7.03717581e-01
#   4.87514590e-02 -3.14583617e-02  7.03717581e-01  4.87514591e-02]
# vec.abs  = [4.08147944e-04 8.37067176e-04 3.70938077e-02 4.08148050e-04
#  8.37068791e-04 3.70938075e-02 3.20617646e-02 7.03717581e-01
#  4.87523492e-02 3.20617646e-02 7.03717581e-01 4.87523493e-02]

# %% [markdown]
# # Debug
