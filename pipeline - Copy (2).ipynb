# %% [markdown]
# # Import & Helpers

# %%
import sys
from importlib import reload
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
from importlib import reload

if "/mnt/data" not in sys.path:
    sys.path.insert(0, "/mnt/data")
if "/mnt/data" not in sys.path:
    sys.path.insert(0, "/mnt/data")

import noninteracting
from noninteracting import KagomeNagaosa
import interaction
import frg_kernel
import channels
import frg_flow
import patching
from patching import build_exactM_patchset, PatchPoint, PatchSet, plot_patchset, exact_M6_points_1bz

# %% [markdown]
# ## Plot Helper

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import channels
import instability
import frg_flow
import interaction
import frg_kernel

from channels import SZ0ChannelBuilder
from instability import InstabilityConfig, diagnose_kernel_collection
from frg_flow import BareSZ0VertexFromInteraction, FRGFlowSolverSZ0
from frg_kernel import FlowConfig


# ============================================================
# Basic formatting / plotting helpers
# ============================================================

CHANNELS_ORDER = ["pp_singlet", "pp_triplet", "ph_charge", "ph_spin"]


def fmt_q(q, nd=3):
    q = np.asarray(q, dtype=float)
    return f"({q[0]:.{nd}f}, {q[1]:.{nd}f})"


def hermitian_part(M):
    M = np.asarray(M, dtype=complex)
    return 0.5 * (M + M.conjugate().T)


def sign_aware_channel_score(channel_name, M):
    """
    Same logic as current solver sign-aware score:
      pp -> largest positive eigenvalue of Hermitian part
      ph -> absolute value of most negative eigenvalue of Hermitian part
    """
    H = hermitian_part(M)
    evals, _ = np.linalg.eigh(H)
    eval_pos_max = float(np.max(evals)) if evals.size else 0.0
    eval_neg_min = float(np.min(evals)) if evals.size else 0.0

    if channel_name.startswith("pp"):
        physical_score = max(eval_pos_max, 0.0)
        chosen_eval = eval_pos_max
        chosen_sign = "positive"
    elif channel_name.startswith("ph"):
        physical_score = max(-eval_neg_min, 0.0)
        chosen_eval = eval_neg_min
        chosen_sign = "negative"
    else:
        raise ValueError(f"Unknown channel name: {channel_name}")

    return {
        "eval_pos_max": eval_pos_max,
        "eval_neg_min": eval_neg_min,
        "physical_score": float(physical_score),
        "chosen_eval": float(chosen_eval),
        "chosen_sign": chosen_sign,
        "herm_resid": float(np.max(np.abs(M - M.conjugate().T))),
    }


def build_builder_from_solver(solver, *, Landau_F=None):
    if Landau_F is None:
        Landau_F = getattr(solver, "diagnosis_landau_F", False)
    return channels.SZ0ChannelBuilder.from_solver(
        solver.current_vertex_accessor(),
        solver,
        Landau_F=Landau_F,
    )


def evaluate_signaware_selected_Qs(builder, diagnosis_Qs, *, landau_F=False):
    rows = []
    kernel_store = {}

    for iq, Q in enumerate(diagnosis_Qs):
        Q = np.asarray(Q, dtype=float)
        kernel_dict = builder.build_kernel_dict(Q, Landau_F=landau_F)
        kernel_store[iq] = {"Q": Q.copy(), "kernels": kernel_dict}

        for ch_name, ker in kernel_dict.items():
            info = sign_aware_channel_score(ch_name, ker.matrix)
            rows.append({
                "channel": ch_name,
                "Q_index": int(iq),
                "Q": Q.copy(),
                "Qx": float(Q[0]),
                "Qy": float(Q[1]),
                **info,
            })

    df = pd.DataFrame(rows)
    return df, kernel_store


def evaluate_instability_selected_Qs(
    builder,
    solver,
    diagnosis_Qs,
    *,
    temperature=None,
    landau_F=False,
    ph_bubble_mode="patchrep",
    project_ph_charge_q0_uniform=True,
    project_pp_singlet_q0_local_gram_default=False,
):
    rows = []
    result_store = {}

    if temperature is None:
        temperature = float(solver.state.T)

    cfg = InstabilityConfig(
        ph_sign=-1,
        pp_sign=+1,
        use_hermitian_part=True,
        bubble_floor=0.0,
        ph_bubble_mode=ph_bubble_mode,
        project_ph_charge_q0_uniform=project_ph_charge_q0_uniform,
        report_pp_singlet_q0_local_gram_both=True,
        project_pp_singlet_q0_local_gram_default=project_pp_singlet_q0_local_gram_default,
        store_operator_matrices=False,
        store_all_evals=False,

        # IMPORTANT: keep diagnosis consistent with current flow measure
        patch_measure_mode=getattr(solver, "patch_measure_mode", "unit"),
        patch_measure_soft_vf_eps=getattr(solver, "patch_measure_soft_vf_eps", 1e-8),
        patch_measure_normalize_mean=getattr(solver, "patch_measure_normalize_mean", False),
    )

    flow_cfg = FlowConfig(
        temperature=float(temperature),
        nfreq=solver.nfreq,
        include_explicit_T_prefactor=solver.include_explicit_T_prefactor,
    )

    for iq, Q in enumerate(diagnosis_Qs):
        Q = np.asarray(Q, dtype=float)
        kernel_dict = builder.build_kernel_dict(Q, Landau_F=landau_F)

        res_dict = diagnose_kernel_collection(
            kernel_dict,
            solver.patchsets,
            solver.transfer_context(),
            flow_cfg,
            config=cfg,
        )
        result_store[iq] = {"Q": Q.copy(), "results": res_dict}

        for ch_name, res in res_dict.items():
            rows.append({
                "channel": ch_name,
                "Q_index": int(iq),
                "Q": Q.copy(),
                "Qx": float(Q[0]),
                "Qy": float(Q[1]),
                "score": float(res.score),
                "leading_eval": float(res.leading_eval),
                "score_unprojected": float(res.score_unprojected),
                "score_projected": None if res.score_projected is None else float(res.score_projected),
                "projection_name": res.projection_name,
                "bubble_source": res.bubble.source,
                "channel_type": res.channel_type,
                "spin_structure": res.spin_structure,
            })

    df = pd.DataFrame(rows)
    return df, result_store


def leading_row_from_df(df, score_col):
    if len(df) == 0:
        raise ValueError("Empty dataframe.")
    return df.sort_values(score_col, ascending=False).iloc[0]


def plot_channel_bars(df, *, value_col, title, ylabel):
    df = df.copy()
    df["Q_key"] = df["Q"].apply(lambda x: tuple(np.asarray(x, dtype=float)))
    q_keys = list(dict.fromkeys(df["Q_key"].tolist()))
    q_labels = [f"Q{i}:{fmt_q(np.array(qk))}" for i, qk in enumerate(q_keys)]

    x = np.arange(len(q_keys))
    width = 0.18

    fig, ax = plt.subplots(figsize=(11, 5))
    for j, ch in enumerate(CHANNELS_ORDER):
        vals = []
        for qk in q_keys:
            sub = df[(df["channel"] == ch) & (df["Q_key"] == qk)]
            vals.append(float(sub.iloc[0][value_col]) if len(sub) else 0.0)
        ax.bar(x + (j - 1.5) * width, vals, width=width, label=ch)

    ax.set_xticks(x)
    ax.set_xticklabels(q_labels)
    ax.set_ylabel(ylabel)
    ax.set_title(title)
    ax.grid(True, axis="y", alpha=0.3)
    ax.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Flow Helper

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ============================================================
# Helpers: dataframe shaping / printing / plotting
# ============================================================

def _is_q0_vec(q, tol=1e-10):
    q = np.asarray(q, dtype=float)
    return bool(np.allclose(q, 0.0, atol=tol, rtol=0.0))


def _scores_at_qindex(df, q_index, value_col, channels_order=CHANNELS_ORDER):
    sub = df[df["Q_index"] == int(q_index)]
    out = {}
    for ch in channels_order:
        ss = sub[sub["channel"] == ch]
        out[ch] = float(ss.iloc[0][value_col]) if len(ss) else np.nan
    return out


def _leading_row(df, value_col):
    if len(df) == 0:
        raise ValueError("Empty dataframe.")
    return df.sort_values(value_col, ascending=False).iloc[0]


def _format_channel_scores(score_map, channels_order=CHANNELS_ORDER):
    parts = []
    for ch in channels_order:
        val = score_map.get(ch, np.nan)
        if np.isfinite(val):
            parts.append(f"{ch}={val:.3e}")
        else:
            parts.append(f"{ch}=nan")
    return ", ".join(parts)


def _append_step_rows(storage, df, *, step_index, T, family):
    for _, row in df.iterrows():
        storage.append({
            "family": family,  # "kernel" or "instability"
            "step_index": int(step_index),
            "T": float(T),
            "Q_index": int(row["Q_index"]),
            "Q": np.asarray(row["Q"], dtype=float),
            "Qx": float(row["Qx"]),
            "Qy": float(row["Qy"]),
            "channel": str(row["channel"]),
            "value": float(row["physical_score"] if family == "kernel" else row["score"]),
        })


def _collapse_q_groups(history_df, *, q0_tol=1e-10):
    """
    Collapse selected Qs into two groups:
      - Q0 : exact q=0
      - QM : max over all nonzero selected Q's
    """
    rows = []
    for (family, step_index, T, channel), sub in history_df.groupby(["family", "step_index", "T", "channel"]):
        sub = sub.copy()
        q0_mask = sub["Q"].apply(lambda x: _is_q0_vec(x, tol=q0_tol)).values

        # Q=0
        sub_q0 = sub[q0_mask]
        q0_val = np.nan
        if len(sub_q0):
            q0_val = float(np.max(sub_q0["value"].values))
        rows.append({
            "family": family,
            "step_index": int(step_index),
            "T": float(T),
            "channel": channel,
            "Q_group": "Q0",
            "value": q0_val,
        })

        # Q=M group = max over all nonzero chosen Qs
        sub_qm = sub[~q0_mask]
        qm_val = np.nan
        if len(sub_qm):
            qm_val = float(np.max(sub_qm["value"].values))
        rows.append({
            "family": family,
            "step_index": int(step_index),
            "T": float(T),
            "channel": channel,
            "Q_group": "QM",
            "value": qm_val,
        })

    out = pd.DataFrame(rows).sort_values(["family", "Q_group", "step_index", "channel"]).reset_index(drop=True)
    return out


def plot_flow_group_curves(
    grouped_df,
    *,
    last_n_steps=None,
    ylog=True,
    title_prefix="RG flow",
    ylim=1e-2
):
    """
    Produce exactly 4 plots:
      1. Q=0 kernel score vs T
      2. Q=M kernel score vs T
      3. Q=0 instability score vs T
      4. Q=M instability score vs T
    """
    df = grouped_df.copy()

    if last_n_steps is not None:
        keep_steps = sorted(df["step_index"].unique())[-int(last_n_steps):]
        df = df[df["step_index"].isin(keep_steps)].copy()

    panels = [
        ("kernel", "Q0", "sign-aware kernel score"),
        ("kernel", "QM", "sign-aware kernel score"),
        ("instability", "Q0", "physical instability score"),
        ("instability", "QM", "physical instability score"),
    ]

    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    axes = axes.ravel()

    for ax, (family, q_group, ylabel) in zip(axes, panels):
        sub = df[(df["family"] == family) & (df["Q_group"] == q_group)].copy()

        for ch in CHANNELS_ORDER:
            ss = sub[sub["channel"] == ch].sort_values("step_index")
            if len(ss) == 0:
                continue

            y = ss["value"].to_numpy(dtype=float)
            x = ss["T"].to_numpy(dtype=float)

            if ylog:
                y = np.where(y > 0, y, np.nan)
                ax.set_yscale("log")

            ax.plot(x, y, marker="o", markersize=3, linewidth=1.5, label=ch)

        ax.set_title(f"{title_prefix}: {family} / {q_group}")
        ax.set_xlabel("Temperature")
        ax.set_ylabel(ylabel)
        ax.set_ylim(bottom=ylim)
        ax.grid(True, alpha=0.3)
        ax.invert_xaxis()
        ax.legend(fontsize=8)

    plt.tight_layout()
    plt.show()


def print_flow_step_summary(
    *,
    step_index,
    T,
    rhs_norm,
    signaware_df,
    instab_df,
):
    lead_kernel = _leading_row(signaware_df, "physical_score")
    lead_instab = _leading_row(instab_df, "score")

    lead_qi_kernel = int(lead_kernel["Q_index"])
    lead_qi_instab = int(lead_instab["Q_index"])

    kernel_scores_at_leadQ = _scores_at_qindex(signaware_df, lead_qi_kernel, "physical_score")
    instab_scores_at_leadQ = _scores_at_qindex(instab_df, lead_qi_instab, "score")

    print(
        f"step={step_index:4d} | "
        f"T={T:.6f} | rhs_norm={rhs_norm:.3e} | "
        f"lead_kernel={lead_kernel['channel']} @ Q{lead_qi_kernel}:{fmt_q(lead_kernel['Q'])} "
        f"score={float(lead_kernel['physical_score']):.3e}"
    )
    print("kernel scores:", _format_channel_scores(kernel_scores_at_leadQ))
    print(
        f"    lead_instability={lead_instab['channel']} @ Q{lead_qi_instab}:{fmt_q(lead_instab['Q'])} "
        f"score={float(lead_instab['score']):.3e}"
    )
    print("instability:", _format_channel_scores(instab_scores_at_leadQ))


def run_flow_with_tracking(
    solver,
    diagnosis_Qs,
    *,
    print_every=1,
    ph_bubble_mode="patchrep",
    project_ph_charge_q0_uniform=True,
    project_pp_singlet_q0_local_gram_default=False,
):
    """
    Manual RG flow with per-step diagnostics:
      - sign-aware kernel score
      - physical instability score

    Returns
    -------
    history : list[FlowStepRecord]
    signaware_history_df : pd.DataFrame
    instability_history_df : pd.DataFrame
    grouped_plot_df : pd.DataFrame
    """
    temps = solver.temperature_path
    signaware_rows = []
    instab_rows = []

    # -------------------------------
    # step 0
    # -------------------------------
    rec0 = frg_flow.FlowStepRecord(
        step_index=0,
        temperature=float(temps[0]),
        dT=0.0,
        channel_norm=solver.state.channel_norm(),
        rhs_norm=0.0,
        accepted_substeps=0,
        max_rel_update=0.0,
        diagnosis_payload=solver.diagnose_current_state(),
    )
    rec0.instability, rec0.instability_reason = solver.check_instability(rec0)
    solver.history = [rec0]
    solver.instability_record = rec0 if rec0.instability else None

    builder0 = build_builder_from_solver(solver, Landau_F=False)

    sign_df0, _ = evaluate_signaware_selected_Qs(builder0, diagnosis_Qs, landau_F=False)
    instab_df0, _ = evaluate_instability_selected_Qs(
        builder0,
        solver,
        diagnosis_Qs,
        temperature=float(temps[0]),
        landau_F=False,
        ph_bubble_mode=ph_bubble_mode,
        project_ph_charge_q0_uniform=project_ph_charge_q0_uniform,
        project_pp_singlet_q0_local_gram_default=project_pp_singlet_q0_local_gram_default,
    )

    _append_step_rows(signaware_rows, sign_df0, step_index=0, T=float(temps[0]), family="kernel")
    _append_step_rows(instab_rows, instab_df0, step_index=0, T=float(temps[0]), family="instability")

    print_flow_step_summary(
        step_index=0,
        T=float(temps[0]),
        rhs_norm=0.0,
        signaware_df=sign_df0,
        instab_df=instab_df0,
    )

    if rec0.instability:
        print("\n[flow stopped at step 0]")
        print("reason:", rec0.instability_reason)
        signaware_history_df = pd.DataFrame(signaware_rows)
        instability_history_df = pd.DataFrame(instab_rows)
        grouped_plot_df = _collapse_q_groups(pd.concat([signaware_history_df, instability_history_df], ignore_index=True))
        return solver.history, signaware_history_df, instability_history_df, grouped_plot_df

    # -------------------------------
    # main loop
    # -------------------------------
    for i in range(len(temps) - 1):
        T_old = float(temps[i])
        T_new = float(temps[i + 1])

        rec = solver.step(T_old, T_new - T_old)
        rec.instability, rec.instability_reason = solver.check_instability(rec)
        solver.history.append(rec)

        builder = build_builder_from_solver(solver, Landau_F=False)

        sign_df, _ = evaluate_signaware_selected_Qs(builder, diagnosis_Qs, landau_F=False)
        instab_df, _ = evaluate_instability_selected_Qs(
            builder,
            solver,
            diagnosis_Qs,
            temperature=rec.temperature,
            landau_F=False,
            ph_bubble_mode=ph_bubble_mode,
            project_ph_charge_q0_uniform=project_ph_charge_q0_uniform,
            project_pp_singlet_q0_local_gram_default=project_pp_singlet_q0_local_gram_default,
        )

        _append_step_rows(signaware_rows, sign_df, step_index=rec.step_index, T=rec.temperature, family="kernel")
        _append_step_rows(instab_rows, instab_df, step_index=rec.step_index, T=rec.temperature, family="instability")

        if (rec.step_index % int(print_every) == 0) or rec.instability or rec.terminated_early:
            print_flow_step_summary(
                step_index=rec.step_index,
                T=rec.temperature,
                rhs_norm=rec.rhs_norm,
                signaware_df=sign_df,
                instab_df=instab_df,
            )

        if rec.instability:
            solver.instability_record = rec
            print("\n[flow stopped]")
            if rec.instability_reason is not None:
                print("instability_reason:", rec.instability_reason)
            if rec.termination_reason is not None:
                print("termination_reason:", rec.termination_reason)
            break

    signaware_history_df = pd.DataFrame(signaware_rows)
    instability_history_df = pd.DataFrame(instab_rows)
    grouped_plot_df = _collapse_q_groups(
        pd.concat([signaware_history_df, instability_history_df], ignore_index=True)
    )

    return solver.history, signaware_history_df, instability_history_df, grouped_plot_df

def run_flow_with_tracking_and_snapshots(
    solver,
    diagnosis_Qs,
    *,
    print_every=1,
    ph_bubble_mode="patchrep",
    project_ph_charge_q0_uniform=True,
    project_pp_singlet_q0_local_gram_default=False,
):
    temps = solver.temperature_path
    signaware_rows = []
    instab_rows = []
    snapshots = {}

    # step 0
    rec0 = frg_flow.FlowStepRecord(
        step_index=0,
        temperature=float(temps[0]),
        dT=0.0,
        channel_norm=solver.state.channel_norm(),
        rhs_norm=0.0,
        accepted_substeps=0,
        max_rel_update=0.0,
        diagnosis_payload=solver.diagnose_current_state(),
    )
    rec0.instability, rec0.instability_reason = solver.check_instability(rec0)
    solver.history = [rec0]
    solver.instability_record = rec0 if rec0.instability else None

    snapshots[0] = make_snapshot_from_solver(solver, label="step_0")

    builder0 = build_builder_from_solver(solver, Landau_F=False)
    sign_df0, _ = evaluate_signaware_selected_Qs(builder0, diagnosis_Qs, landau_F=False)
    instab_df0, _ = evaluate_instability_selected_Qs(
        builder0,
        solver,
        diagnosis_Qs,
        temperature=float(temps[0]),
        landau_F=False,
        ph_bubble_mode=ph_bubble_mode,
        project_ph_charge_q0_uniform=project_ph_charge_q0_uniform,
        project_pp_singlet_q0_local_gram_default=project_pp_singlet_q0_local_gram_default,
    )

    _append_step_rows(signaware_rows, sign_df0, step_index=0, T=float(temps[0]), family="kernel")
    _append_step_rows(instab_rows, instab_df0, step_index=0, T=float(temps[0]), family="instability")

    print_flow_step_summary(
        step_index=0,
        T=float(temps[0]),
        rhs_norm=0.0,
        signaware_df=sign_df0,
        instab_df=instab_df0,
    )

    if rec0.instability:
        signaware_history_df = pd.DataFrame(signaware_rows)
        instability_history_df = pd.DataFrame(instab_rows)
        grouped_plot_df = _collapse_q_groups(pd.concat([signaware_history_df, instability_history_df], ignore_index=True))
        return solver.history, signaware_history_df, instability_history_df, grouped_plot_df, snapshots

    for i in range(len(temps) - 1):
        T_old = float(temps[i])
        T_new = float(temps[i + 1])

        rec = solver.step(T_old, T_new - T_old)
        rec.instability, rec.instability_reason = solver.check_instability(rec)
        solver.history.append(rec)

        snapshots[int(rec.step_index)] = make_snapshot_from_solver(
            solver, label=f"step_{rec.step_index}"
        )

        builder = build_builder_from_solver(solver, Landau_F=False)

        sign_df, _ = evaluate_signaware_selected_Qs(builder, diagnosis_Qs, landau_F=False)
        instab_df, _ = evaluate_instability_selected_Qs(
            builder,
            solver,
            diagnosis_Qs,
            temperature=rec.temperature,
            landau_F=False,
            ph_bubble_mode=ph_bubble_mode,
            project_ph_charge_q0_uniform=project_ph_charge_q0_uniform,
            project_pp_singlet_q0_local_gram_default=project_pp_singlet_q0_local_gram_default,
        )

        _append_step_rows(signaware_rows, sign_df, step_index=rec.step_index, T=rec.temperature, family="kernel")
        _append_step_rows(instab_rows, instab_df, step_index=rec.step_index, T=rec.temperature, family="instability")

        if (rec.step_index % int(print_every) == 0) or rec.instability or rec.terminated_early:
            print_flow_step_summary(
                step_index=rec.step_index,
                T=rec.temperature,
                rhs_norm=rec.rhs_norm,
                signaware_df=sign_df,
                instab_df=instab_df,
            )

        if rec.instability:
            solver.instability_record = rec
            print("\n[flow stopped]")
            if rec.instability_reason is not None:
                print("instability_reason:", rec.instability_reason)
            if rec.termination_reason is not None:
                print("termination_reason:", rec.termination_reason)
            break

    signaware_history_df = pd.DataFrame(signaware_rows)
    instability_history_df = pd.DataFrame(instab_rows)
    grouped_plot_df = _collapse_q_groups(
        pd.concat([signaware_history_df, instability_history_df], ignore_index=True)
    )

    return solver.history, signaware_history_df, instability_history_df, grouped_plot_df, snapshots

# %% [markdown]
# ## Diagnosis Helper

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ============================================================
# Step selection helpers
# ============================================================
def summarize_eigenvector_against_constant(eigvec):
    v = np.asarray(eigvec, dtype=complex)
    n = len(v)
    v = v / np.linalg.norm(v)

    u_const = np.ones(n, dtype=complex) / np.sqrt(float(n))
    overlap = np.vdot(u_const, v)

    return {
        "eigvec": v,
        "const_vec": u_const,
        "const_overlap_abs": float(np.abs(overlap)),
        "const_overlap_complex": overlap,
    }


def plot_kernel_eigenstate_components(
    kernel_matrix,
    channel_name,
    Q,
    *,
    title_prefix="Kernel eigenstate components",
):
    eigval, eigvec = choose_signaware_eigenpair(channel_name, kernel_matrix)
    info = summarize_eigenvector_against_constant(eigvec)

    v = info["eigvec"]
    u_const = info["const_vec"]
    overlap_abs = info["const_overlap_abs"]

    idx = np.arange(len(v))
    amp = np.abs(v)

    fig, axes = plt.subplots(1, 2, figsize=(13, 4.8))

    # left: Re / Im vs patch index
    axes[0].plot(idx, np.real(v), marker="o", linewidth=1.5, label="Re(v)")
    axes[0].plot(idx, np.imag(v), marker="s", linewidth=1.5, label="Im(v)")
    axes[0].plot(idx, np.real(u_const), linestyle=":", linewidth=1.5, color="black", label="constant vector")
    axes[0].set_xlabel("patch index")
    axes[0].set_ylabel("component")
    axes[0].set_title(
        f"{title_prefix}\n{channel_name} @ Q={fmt_q(Q)} | chosen eval={eigval:.3e}\n"
        f"|<u_const|v>| = {overlap_abs:.6f}"
    )
    axes[0].grid(True, alpha=0.3)
    axes[0].legend()

    # right: |component|
    axes[1].bar(idx, amp)
    axes[1].set_xlabel("patch index")
    axes[1].set_ylabel("|component|")
    axes[1].set_title("Absolute component weight of leading eigenstate")
    axes[1].grid(True, axis="y", alpha=0.3)

    plt.tight_layout()
    plt.show()

    print("\n=== leader eigenstate summary ===")
    print("channel            :", channel_name)
    print("Q                  :", fmt_q(Q, nd=6))
    print("selected eigenvalue:", f"{eigval:.12e}")
    print("kernel dimension   :", len(v))
    print("|<u_const|v>|      :", f"{overlap_abs:.12e}")

    return eigval, eigvec, info

def resolve_history_step(history, step_selector=-1):
    """
    step_selector:
      - negative int: Python-style indexing from the end
      - nonnegative int: exact step_index lookup if possible, else positional fallback
    """
    if len(history) == 0:
        raise ValueError("History is empty.")

    if isinstance(step_selector, (int, np.integer)):
        step_selector = int(step_selector)

        # negative -> python indexing
        if step_selector < 0:
            rec = history[step_selector]
            return rec

        # first try exact step_index
        for rec in history:
            if int(rec.step_index) == step_selector:
                return rec

        # fallback: positional
        if 0 <= step_selector < len(history):
            return history[step_selector]

    raise ValueError(f"Could not resolve step_selector={step_selector!r}")


# ============================================================
# Snapshot helpers
# ============================================================

from dataclasses import dataclass

@dataclass
class VertexSnapshot:
    label: str
    T: float
    data: np.ndarray
    p4_index: np.ndarray
    p4_residual: np.ndarray


def make_snapshot_from_solver(solver, label):
    return VertexSnapshot(
        label=label,
        T=float(solver.state.T),
        data=np.array(solver.state.vertex.data, dtype=complex, copy=True),
        p4_index=np.array(solver.state.vertex.p4_index, dtype=int, copy=True),
        p4_residual=np.array(solver.state.vertex.p4_residual, dtype=float, copy=True),
    )


def make_snapshot_from_history_record(solver, rec, label=None):
    """
    Build a snapshot from the CURRENT solver state only if the solver is already
    sitting at that record's state. This helper is mostly for the last step.

    For arbitrary historical steps, use stored snapshots if you saved them during flow.
    """
    if label is None:
        label = f"step_{rec.step_index}"
    return make_snapshot_from_solver(solver, label=label)


def make_snapshot_accessor(snapshot, solver):
    data = np.asarray(snapshot.data, dtype=complex)
    p4_index = np.asarray(snapshot.p4_index, dtype=int)
    p4_residual = np.asarray(snapshot.p4_residual, dtype=float)

    closure_tol = getattr(solver, "closure_tol", None)
    drop_inexact_closure = bool(getattr(solver, "drop_inexact_closure", False))

    def closure_is_valid(p1, p2, p3):
        if not drop_inexact_closure:
            return True
        if closure_tol is None:
            return True
        return bool(float(p4_residual[p1, p2, p3]) <= float(closure_tol))

    def accessor(p1, p2, p3, p4):
        p4_expected = int(p4_index[p1, p2, p3])
        if p4_expected < 0 or int(p4) != p4_expected:
            return 0.0 + 0.0j
        if not closure_is_valid(p1, p2, p3):
            return 0.0 + 0.0j
        return complex(data[p1, p2, p3])

    return accessor


def make_builder_from_snapshot(snapshot, solver, *, Landau_F=False):
    return channels.SZ0ChannelBuilder.from_solver(
        make_snapshot_accessor(snapshot, solver),
        solver,
        Landau_F=Landau_F,
    )


# ============================================================
# Diagnosis on one snapshot
# ============================================================

def diagnose_snapshot_signaware(snapshot, solver, diagnosis_Qs, *, landau_F=False):
    builder = make_builder_from_snapshot(snapshot, solver, Landau_F=landau_F)
    df, kernel_store = evaluate_signaware_selected_Qs(builder, diagnosis_Qs, landau_F=landau_F)
    return df, kernel_store, builder


def diagnose_snapshot_instability(
    snapshot,
    solver,
    diagnosis_Qs,
    *,
    landau_F=False,
    ph_bubble_mode="patchrep",
    project_ph_charge_q0_uniform=True,
    project_pp_singlet_q0_local_gram_default=False,
):
    builder = make_builder_from_snapshot(snapshot, solver, Landau_F=landau_F)

    cfg = instability.InstabilityConfig(
        ph_sign=-1,
        pp_sign=+1,
        use_hermitian_part=True,
        bubble_floor=0.0,
        ph_bubble_mode=ph_bubble_mode,
        project_ph_charge_q0_uniform=project_ph_charge_q0_uniform,
        report_pp_singlet_q0_local_gram_both=True,
        project_pp_singlet_q0_local_gram_default=project_pp_singlet_q0_local_gram_default,
        store_operator_matrices=False,
        store_all_evals=False,

        # keep consistent with solver flow measure
        patch_measure_mode=getattr(solver, "patch_measure_mode", "unit"),
        patch_measure_soft_vf_eps=getattr(solver, "patch_measure_soft_vf_eps", 1e-8),
        patch_measure_normalize_mean=getattr(solver, "patch_measure_normalize_mean", False),
    )

    flow_cfg = frg_kernel.FlowConfig(
        temperature=float(snapshot.T),
        nfreq=solver.nfreq,
        include_explicit_T_prefactor=solver.include_explicit_T_prefactor,
    )

    rows = []
    result_store = {}

    for iq, Q in enumerate(diagnosis_Qs):
        kernel_dict = builder.build_kernel_dict(np.asarray(Q, dtype=float), Landau_F=landau_F)

        res_dict = instability.diagnose_kernel_collection(
            kernel_dict,
            solver.patchsets,
            solver.transfer_context(),
            flow_cfg,
            config=cfg,
        )
        result_store[iq] = {"Q": np.asarray(Q, dtype=float), "results": res_dict}

        for ch_name, res in res_dict.items():
            rows.append({
                "channel": ch_name,
                "Q_index": int(iq),
                "Q": np.asarray(Q, dtype=float),
                "Qx": float(Q[0]),
                "Qy": float(Q[1]),
                "score": float(res.score),
                "leading_eval": float(res.leading_eval),
                "score_unprojected": float(res.score_unprojected),
                "score_projected": None if res.score_projected is None else float(res.score_projected),
                "projection_name": res.projection_name,
                "bubble_source": res.bubble.source,
                "channel_type": res.channel_type,
                "spin_structure": res.spin_structure,
            })

    df = pd.DataFrame(rows)
    return df, result_store, builder


# ============================================================
# Eigenvector distribution helpers
# ============================================================

def choose_signaware_eigenpair(channel_name, M):
    H = hermitian_part(M)
    evals, evecs = np.linalg.eigh(H)

    if channel_name.startswith("pp"):
        idx = int(np.argmax(evals))
    elif channel_name.startswith("ph"):
        idx = int(np.argmin(evals))
    else:
        raise ValueError(f"Unknown channel_name={channel_name}")

    val = float(np.real(evals[idx]))
    vec = np.asarray(evecs[:, idx], dtype=complex)
    nrm = np.linalg.norm(vec)
    if nrm > 0:
        vec = vec / nrm
    return val, vec


def plot_kernel_eigenstate_distribution(
    kernel_matrix,
    channel_name,
    Q,
    patchsets,
    *,
    title_prefix="Kernel eigenstate distribution",
    annotate=True,
):
    eigval, eigvec = choose_signaware_eigenpair(channel_name, kernel_matrix)

    ps = patchsets["up"]
    ks = np.asarray([p.k_cart for p in ps.patches], dtype=float)

    amp = np.abs(eigvec)
    phase = np.angle(eigvec)

    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    # amplitude
    sc0 = axes[0].scatter(ks[:, 0], ks[:, 1], c=amp, s=120, cmap="viridis")
    if annotate:
        for i, (x, y) in enumerate(ks):
            axes[0].text(x, y, str(i), fontsize=8, ha="left", va="bottom")
    axes[0].set_title(
        f"{title_prefix}\n{channel_name} @ Q={fmt_q(Q)} | chosen eval={eigval:.3e}\n|evec|"
    )
    axes[0].set_xlabel(r"$k_x$")
    axes[0].set_ylabel(r"$k_y$")
    axes[0].set_aspect("equal")
    plt.colorbar(sc0, ax=axes[0])

    # phase
    sc1 = axes[1].scatter(ks[:, 0], ks[:, 1], c=phase, s=120, cmap="twilight", vmin=-np.pi, vmax=np.pi)
    if annotate:
        for i, (x, y) in enumerate(ks):
            axes[1].text(x, y, str(i), fontsize=8, ha="left", va="bottom")
    axes[1].set_title(
        f"{title_prefix}\n{channel_name} @ Q={fmt_q(Q)} | chosen eval={eigval:.3e}\nphase(evec)"
    )
    axes[1].set_xlabel(r"$k_x$")
    axes[1].set_ylabel(r"$k_y$")
    axes[1].set_aspect("equal")
    plt.colorbar(sc1, ax=axes[1])

    plt.tight_layout()
    plt.show()

    return eigval, eigvec


# ============================================================
# High-level one-step diagnosis wrapper
# ============================================================

def diagnose_flowed_step(
    solver,
    history,
    diagnosis_Qs,
    *,
    step_selector=-1,
    ph_bubble_mode="patchrep",
    project_ph_charge_q0_uniform=True,
    project_pp_singlet_q0_local_gram_default=False,
    plot_eigenstate=True,
):
    rec = resolve_history_step(history, step_selector=step_selector)
    if "snapshots" not in globals():
        raise ValueError("No snapshots found. Re-run the flow cell that stores snapshots.")
    
    if int(rec.step_index) not in snapshots:
        raise ValueError(f"Snapshot for step {rec.step_index} not found.")
    
    snapshot = snapshots[int(rec.step_index)]
    print(f"Diagnosing step_index = {rec.step_index}")
    print(f"T = {rec.temperature:.6f}")
    print(f"rhs_norm = {rec.rhs_norm:.3e}")
    print(f"channel_norm = {rec.channel_norm:.3e}")
    print(f"instability = {rec.instability}")
    print(f"terminated_early = {rec.terminated_early}")
    print(f"instability_reason = {rec.instability_reason}")
    print(f"termination_reason = {rec.termination_reason}")

    # sign-aware
    df_sign, sign_store, sign_builder = diagnose_snapshot_signaware(
        snapshot, solver, diagnosis_Qs, landau_F=False
    )

    # instability
    df_inst, inst_store, inst_builder = diagnose_snapshot_instability(
        snapshot,
        solver,
        diagnosis_Qs,
        landau_F=False,
        ph_bubble_mode=ph_bubble_mode,
        project_ph_charge_q0_uniform=project_ph_charge_q0_uniform,
        project_pp_singlet_q0_local_gram_default=project_pp_singlet_q0_local_gram_default,
    )

    # leaders
    best_sign = leading_row_from_df(df_sign, "physical_score")
    best_inst = leading_row_from_df(df_inst, "score")

    print("\n=== sign-aware leader at selected step ===")
    print("channel :", best_sign["channel"])
    print("Q       :", fmt_q(best_sign["Q"], nd=6))
    print("score   :", f"{best_sign['physical_score']:.12e}")
    print("chosen  :", best_sign["chosen_sign"], f"{best_sign['chosen_eval']:.12e}")

    print("\n=== physical-instability leader at selected step ===")
    print("channel :", best_inst["channel"])
    print("Q       :", fmt_q(best_inst["Q"], nd=6))
    print("score   :", f"{best_inst['score']:.12e}")
    print("eval    :", f"{best_inst['leading_eval']:.12e}")
    print("bubble  :", best_inst["bubble_source"])
    print("proj    :", best_inst["projection_name"])

    # plots 1 and 2
    plot_channel_bars(
        df_sign,
        value_col="physical_score",
        title=f"Flowed step {rec.step_index}: sign-aware kernel score on selected Q's",
        ylabel="sign-aware physical score",
    )

    plot_channel_bars(
        df_inst,
        value_col="score",
        title=f"Flowed step {rec.step_index}: physical instability score on selected Q's",
        ylabel="instability score",
    )

    # plot 3: eigenstate distribution of the leading sign-aware kernel
    eig_info = None
    if plot_eigenstate:
        lead_qi = int(best_sign["Q_index"])
        lead_q = np.asarray(best_sign["Q"], dtype=float)
        lead_channel = str(best_sign["channel"])

        lead_kernel = sign_store[lead_qi]["kernels"][lead_channel]
        eigval1, eigvec1 = plot_kernel_eigenstate_distribution(
            lead_kernel.matrix,
            lead_channel,
            lead_q,
            solver.patchsets,
            title_prefix=f"Step {rec.step_index}",
            annotate=True,
        )
        
        eigval2, eigvec2, eig_summary = plot_kernel_eigenstate_components(
            lead_kernel.matrix,
            lead_channel,
            lead_q,
            title_prefix=f"Step {rec.step_index}",
        )
        
        eig_info = {
            "channel": lead_channel,
            "Q_index": lead_qi,
            "Q": lead_q,
            "eigval": eigval1,
            "eigvec": eigvec1,
            "summary": eig_summary,
        }

    return {
        "record": rec,
        "snapshot": snapshot,
        "df_signaware": df_sign,
        "df_instability": df_inst,
        "sign_store": sign_store,
        "instability_store": inst_store,
        "eigenstate_info": eig_info,
    }

# %% [markdown]
# # Patch

# %%
UP_SLICE = slice(0, 3)
DN_SLICE = slice(3, 6)
LOCAL_BAND_INDEX = 1
model = KagomeNagaosa(dict(t=1.0, phi=0.0), spin=True, B=None)
# ------------------------------------------------------------
# choose patch density / options here
# ------------------------------------------------------------
POINTS_PER_EDGE = 13           # 1->6, 2->12, 4->24
REMOVE_DUPLICATE_M_MODG = True # True: remove replicated M anchors modulo G
GAUGE_FIX = True
CLOSE_LOOP_GAUGE = True
GAUGE_ANCHOR = "max_component"  # or "first_component"

PATCHSETS = {
    "up": build_exactM_patchset(
        model,
        UP_SLICE,
        LOCAL_BAND_INDEX,
        points_per_edge=POINTS_PER_EDGE,
        # remove_duplicate_M_modG=REMOVE_DUPLICATE_M_MODG,
        gauge_fix=GAUGE_FIX,
        close_loop_gauge=CLOSE_LOOP_GAUGE,
        gauge_anchor=GAUGE_ANCHOR,
        project_to_fs_points=True,
        mu=0.0,
        keep_strict_M_anchors=False,
        edge_cluster_alpha=0.9
    ),
    "dn": build_exactM_patchset(
        model,
        DN_SLICE,
        LOCAL_BAND_INDEX,
        points_per_edge=POINTS_PER_EDGE,
        # remove_duplicate_M_modG=REMOVE_DUPLICATE_M_MODG,
        gauge_fix=GAUGE_FIX,
        close_loop_gauge=CLOSE_LOOP_GAUGE,
        gauge_anchor=GAUGE_ANCHOR,
        project_to_fs_points=True,
        mu=0.0,
        keep_strict_M_anchors=False,
        edge_cluster_alpha=0.9
    ),
}

# ------------------------------------------------------------
# basic sanity: centered 1BZ patch plots
# ------------------------------------------------------------
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

for ax, spin in zip(axes, ["up", "dn"]):
    patching.plot_patchset(
        PATCHSETS[spin],
        ax=ax,
        show_contour=True,
        show_velocity=False,
        show_bz=True,
    )

    ks = np.array([p.k_cart for p in PATCHSETS[spin].patches], dtype=float)
    for i, k in enumerate(ks):
        ax.text(k[0], k[1], str(i), fontsize=8, ha="left", va="bottom")

    ax.set_title(f"{spin} patchset in centered 1BZ")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Model

# %%
# ============================================================
# Choose interaction case
# ============================================================
CASE = "U_only"   # "U_only" or "V_only"

if CASE == "U_only":
    U_TEST, V_TEST = 5.0, 12.0
elif CASE == "V_only":
    U_TEST, V_TEST = 0.0, 10.0
else:
    raise ValueError("CASE must be 'U_only' or 'V_only'")


# ============================================================
# Basic diagnosis setup
# ============================================================
T_START = 15.0
T_STOP  = 0.05
NFREQ   = 50
NSTEPS  = 600

# Selected transfer momenta
M6 = patching.exact_M6_points_1bz(model)
diagnosis_Qs = [
    np.array([0.0, 0.0]),
    np.array(M6[0], dtype=float),
    np.array(M6[1], dtype=float),
    np.array(M6[-1], dtype=float),
]

print("CASE =", CASE, " | U =", U_TEST, " V =", V_TEST)
print("T_START, T_STOP, NFREQ, NSTEPS =", T_START, T_STOP, NFREQ, NSTEPS)
print("NPATCH =", PATCHSETS["up"].Npatch)
print("diagnosis_Qs:")
for i, q in enumerate(diagnosis_Qs):
    print(f"  Q{i} = {fmt_q(q, nd=6)}")


# ============================================================
# Build bare interaction + bare solver
# ============================================================
bare_int = interaction.BareExtendedHubbard.from_kagome_model(model, U=U_TEST, V=V_TEST)
bare_sz0 = frg_flow.BareSZ0VertexFromInteraction(bare_int, PATCHSETS)

solver = frg_flow.FRGFlowSolverSZ0(
    patchsets=PATCHSETS,
    bare_vertex=bare_sz0,

    T_start=T_START,
    T_stop=T_STOP,
    n_steps=NSTEPS,
    temperature_grid="linear",
    nfreq=NFREQ,
    include_explicit_T_prefactor=True,

    # lenient integrator setup for exploration
    max_relative_update=5.0,
    min_substep_fraction=1.0 / 512.0,
    channel_divergence_threshold=2e2,

    diagnosis_Qs=diagnosis_Qs,
    diagnosis_score_threshold=None,
    diagnosis_landau_F=False,

    # current flow measure
    patch_measure_mode="length_over_vf_soft",              # change here later if needed
    patch_measure_soft_vf_eps=1e-8,
    patch_measure_normalize_mean=False,
)

print("\nsolver built.")
print("temperature path length =", len(solver.temperature_path))
print("initial channel norm    =", solver.state.channel_norm())
print("solver.patch_measure_mode =", getattr(solver, "patch_measure_mode", None))

# ============================================================
# Bare sign-aware kernel metrics
# ============================================================
builder0 = build_builder_from_solver(solver, Landau_F=False)
df_signaware_bare, signaware_store = evaluate_signaware_selected_Qs(
    builder0,
    diagnosis_Qs,
    landau_F=False,
)

print("\n=== bare (initial) sign-aware kernel metrics ===")
# display(df_signaware_bare.sort_values(["Q_index", "channel"]).reset_index(drop=True))

plot_channel_bars(
    df_signaware_bare,
    value_col="physical_score",
    title="Bare diagnosis: sign-aware kernel score on selected Q's",
    ylabel="sign-aware physical score",
)

best_signaware_bare = leading_row_from_df(df_signaware_bare, "physical_score")
# print("\n=== bare sign-aware leader ===")
# print("channel :", best_signaware_bare["channel"])
# print("Q       :", fmt_q(best_signaware_bare["Q"], nd=6))
# print("score   :", f"{best_signaware_bare['physical_score']:.12e}")
# print("chosen  :", best_signaware_bare["chosen_sign"], f"{best_signaware_bare['chosen_eval']:.12e}")


# ============================================================
# Bare physical instability diagnosis
# ============================================================
df_instab_bare, instab_store = evaluate_instability_selected_Qs(
    builder0,
    solver,
    diagnosis_Qs,
    temperature=T_START,          # use initial T
    landau_F=False,
    ph_bubble_mode="patchrep",
    project_ph_charge_q0_uniform=True,
    project_pp_singlet_q0_local_gram_default=False,
)

print("\n=== bare (initial) physical instability metrics ===")
# display(df_instab_bare.sort_values(["Q_index", "channel"]).reset_index(drop=True))

plot_channel_bars(
    df_instab_bare,
    value_col="score",
    title="Bare diagnosis: physical instability score on selected Q's",
    ylabel="instability score",
)

best_instab_bare = leading_row_from_df(df_instab_bare, "score")
# print("\n=== bare physical-instability leader ===")
# print("channel :", best_instab_bare["channel"])
# print("Q       :", fmt_q(best_instab_bare["Q"], nd=6))
# print("score   :", f"{best_instab_bare['score']:.12e}")
# print("eval    :", f"{best_instab_bare['leading_eval']:.12e}")
# print("bubble  :", best_instab_bare["bubble_source"])
# print("proj    :", best_instab_bare["projection_name"])
# Out:
# CASE = U_only  | U = 5.0  V = 12.0
# T_START, T_STOP, NFREQ, NSTEPS = 15.0 0.05 50 600
# NPATCH = 72
# diagnosis_Qs:
#   Q0 = (0.000000, 0.000000)
#   Q1 = (-1.570796, -0.906900)
#   Q2 = (0.000000, -1.813799)
#   Q3 = (-1.570796, 0.906900)

# %% [markdown]
# # Flow

# %%
# ============================================================
# Flow run parameters
# ============================================================
PRINT_EVERY = 5               # print every N steps
LAST_N_STEPS_TO_PLOT = 60     # None -> plot all; integer -> only last N steps
PLOT_YLOG = True

# physical instability diagnosis options
PH_BUBBLE_MODE = "patchrep"
PROJECT_PH_CHARGE_Q0_UNIFORM = True
PROJECT_PP_SINGLET_Q0_LOCAL_GRAM_DEFAULT = False


print("\n================ RG FLOW START ================\n")

# history, signaware_history_df, instability_history_df, grouped_plot_df = run_flow_with_tracking(
#     solver,
#     diagnosis_Qs,
#     print_every=PRINT_EVERY,
#     ph_bubble_mode=PH_BUBBLE_MODE,
#     project_ph_charge_q0_uniform=PROJECT_PH_CHARGE_Q0_UNIFORM,
#     project_pp_singlet_q0_local_gram_default=PROJECT_PP_SINGLET_Q0_LOCAL_GRAM_DEFAULT,
# )
history, signaware_history_df, instability_history_df, grouped_plot_df, snapshots = run_flow_with_tracking_and_snapshots(
    solver,
    diagnosis_Qs,
    print_every=PRINT_EVERY,
    ph_bubble_mode=PH_BUBBLE_MODE,
    project_ph_charge_q0_uniform=PROJECT_PH_CHARGE_Q0_UNIFORM,
    project_pp_singlet_q0_local_gram_default=PROJECT_PP_SINGLET_Q0_LOCAL_GRAM_DEFAULT,
)

print("\n================ RG FLOW DONE ================\n")
print("history length =", len(history))

last_rec = history[-1]
print("final step =", last_rec.step_index)
print("final T    =", last_rec.temperature)
print("final rhs_norm =", last_rec.rhs_norm)
print("final channel_norm =", last_rec.channel_norm)
print("instability =", last_rec.instability)
print("terminated_early =", last_rec.terminated_early)
print("instability_reason =", last_rec.instability_reason)
print("termination_reason =", last_rec.termination_reason)

# display(signaware_history_df.tail(12))
# display(instability_history_df.tail(12))

plot_flow_group_curves(
    grouped_plot_df,
    last_n_steps=LAST_N_STEPS_TO_PLOT,
    ylog=PLOT_YLOG,
    title_prefix=f"{CASE} | U={U_TEST}, V={V_TEST}",
    ylim=1e-2
)
# Out:
# ================ RG FLOW START ================
#
# step=   0 | T=15.000000 | rhs_norm=0.000e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.045e+02
# kernel scores: pp_singlet=2.383e-14, pp_triplet=1.574e+02, ph_charge=3.045e+02, ph_spin=7.869e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=9.698e-02
# instability: pp_singlet=9.609e-18, pp_triplet=3.193e-02, ph_charge=9.698e-02, ph_spin=1.627e-02
# step=   5 | T=14.875209 | rhs_norm=6.615e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.077e+02
# kernel scores: pp_singlet=2.593e+00, pp_triplet=1.562e+02, ph_charge=3.077e+02, ph_spin=7.832e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=9.963e-02
# instability: pp_singlet=1.167e-03, pp_triplet=3.220e-02, ph_charge=9.963e-02, ph_spin=1.641e-02
# step=  10 | T=14.750417 | rhs_norm=6.356e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.110e+02
# kernel scores: pp_singlet=5.129e+00, pp_triplet=1.552e+02, ph_charge=3.110e+02, ph_spin=7.800e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.024e-01
# instability: pp_singlet=2.343e-03, pp_triplet=3.248e-02, ph_charge=1.024e-01, ph_spin=1.657e-02
# step=  15 | T=14.625626 | rhs_norm=6.127e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.145e+02
# kernel scores: pp_singlet=7.613e+00, pp_triplet=1.542e+02, ph_charge=3.145e+02, ph_spin=7.772e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.053e-01
# instability: pp_singlet=3.532e-03, pp_triplet=3.278e-02, ph_charge=1.053e-01, ph_spin=1.675e-02
# step=  20 | T=14.500835 | rhs_norm=5.927e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.181e+02
# kernel scores: pp_singlet=1.005e+01, pp_triplet=1.532e+02, ph_charge=3.181e+02, ph_spin=7.747e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.084e-01
# instability: pp_singlet=4.738e-03, pp_triplet=3.311e-02, ph_charge=1.084e-01, ph_spin=1.694e-02
# step=  25 | T=14.376043 | rhs_norm=5.752e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.220e+02
# kernel scores: pp_singlet=1.246e+01, pp_triplet=1.523e+02, ph_charge=3.220e+02, ph_spin=7.725e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.117e-01
# instability: pp_singlet=5.963e-03, pp_triplet=3.345e-02, ph_charge=1.117e-01, ph_spin=1.714e-02
# step=  30 | T=14.251252 | rhs_norm=5.602e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.260e+02
# kernel scores: pp_singlet=1.483e+01, pp_triplet=1.514e+02, ph_charge=3.260e+02, ph_spin=7.706e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.151e-01
# instability: pp_singlet=7.211e-03, pp_triplet=3.380e-02, ph_charge=1.151e-01, ph_spin=1.736e-02
# step=  35 | T=14.126461 | rhs_norm=5.473e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.303e+02
# kernel scores: pp_singlet=1.718e+01, pp_triplet=1.506e+02, ph_charge=3.303e+02, ph_spin=7.689e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.187e-01
# instability: pp_singlet=8.485e-03, pp_triplet=3.418e-02, ph_charge=1.187e-01, ph_spin=1.759e-02
# step=  40 | T=14.001669 | rhs_norm=5.366e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.348e+02
# kernel scores: pp_singlet=1.950e+01, pp_triplet=1.498e+02, ph_charge=3.348e+02, ph_spin=7.675e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.224e-01
# instability: pp_singlet=9.788e-03, pp_triplet=3.456e-02, ph_charge=1.224e-01, ph_spin=1.783e-02
# step=  45 | T=13.876878 | rhs_norm=5.278e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.396e+02
# kernel scores: pp_singlet=2.181e+01, pp_triplet=1.490e+02, ph_charge=3.396e+02, ph_spin=7.664e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.264e-01
# instability: pp_singlet=1.112e-02, pp_triplet=3.497e-02, ph_charge=1.264e-01, ph_spin=1.808e-02
# step=  50 | T=13.752087 | rhs_norm=5.210e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.446e+02
# kernel scores: pp_singlet=2.410e+01, pp_triplet=1.482e+02, ph_charge=3.446e+02, ph_spin=7.654e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.306e-01
# instability: pp_singlet=1.249e-02, pp_triplet=3.538e-02, ph_charge=1.306e-01, ph_spin=1.837e-02
# step=  55 | T=13.627295 | rhs_norm=5.160e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.499e+02
# kernel scores: pp_singlet=2.639e+01, pp_triplet=1.475e+02, ph_charge=3.499e+02, ph_spin=7.646e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.351e-01
# instability: pp_singlet=1.390e-02, pp_triplet=3.581e-02, ph_charge=1.351e-01, ph_spin=1.868e-02
# step=  60 | T=13.502504 | rhs_norm=5.129e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.554e+02
# kernel scores: pp_singlet=2.867e+01, pp_triplet=1.467e+02, ph_charge=3.554e+02, ph_spin=7.640e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.398e-01
# instability: pp_singlet=1.535e-02, pp_triplet=3.625e-02, ph_charge=1.398e-01, ph_spin=1.900e-02
# step=  65 | T=13.377713 | rhs_norm=5.116e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.613e+02
# kernel scores: pp_singlet=3.095e+01, pp_triplet=1.460e+02, ph_charge=3.613e+02, ph_spin=7.635e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.448e-01
# instability: pp_singlet=1.685e-02, pp_triplet=3.671e-02, ph_charge=1.448e-01, ph_spin=1.933e-02
# step=  70 | T=13.252922 | rhs_norm=5.121e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.675e+02
# kernel scores: pp_singlet=3.323e+01, pp_triplet=1.452e+02, ph_charge=3.675e+02, ph_spin=7.632e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.501e-01
# instability: pp_singlet=1.840e-02, pp_triplet=3.717e-02, ph_charge=1.501e-01, ph_spin=1.968e-02
# step=  75 | T=13.128130 | rhs_norm=5.145e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.741e+02
# kernel scores: pp_singlet=3.553e+01, pp_triplet=1.445e+02, ph_charge=3.741e+02, ph_spin=7.630e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.557e-01
# instability: pp_singlet=2.000e-02, pp_triplet=3.765e-02, ph_charge=1.557e-01, ph_spin=2.004e-02
# step=  80 | T=13.003339 | rhs_norm=5.187e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.811e+02
# kernel scores: pp_singlet=3.783e+01, pp_triplet=1.438e+02, ph_charge=3.811e+02, ph_spin=7.629e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.616e-01
# instability: pp_singlet=2.166e-02, pp_triplet=3.813e-02, ph_charge=1.616e-01, ph_spin=2.041e-02
# step=  85 | T=12.878548 | rhs_norm=5.250e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.885e+02
# kernel scores: pp_singlet=4.014e+01, pp_triplet=1.430e+02, ph_charge=3.885e+02, ph_spin=7.630e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.680e-01
# instability: pp_singlet=2.338e-02, pp_triplet=3.862e-02, ph_charge=1.680e-01, ph_spin=2.080e-02
# step=  90 | T=12.753756 | rhs_norm=5.333e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.964e+02
# kernel scores: pp_singlet=4.248e+01, pp_triplet=1.422e+02, ph_charge=3.964e+02, ph_spin=7.632e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.747e-01
# instability: pp_singlet=2.517e-02, pp_triplet=3.912e-02, ph_charge=1.747e-01, ph_spin=2.120e-02
# step=  95 | T=12.628965 | rhs_norm=5.439e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=4.048e+02
# kernel scores: pp_singlet=4.484e+01, pp_triplet=1.415e+02, ph_charge=4.048e+02, ph_spin=7.634e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.820e-01
# instability: pp_singlet=2.704e-02, pp_triplet=3.962e-02, ph_charge=1.820e-01, ph_spin=2.161e-02
# step= 100 | T=12.504174 | rhs_norm=5.568e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=4.137e+02
# kernel scores: pp_singlet=4.722e+01, pp_triplet=1.406e+02, ph_charge=4.137e+02, ph_spin=7.638e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.897e-01
# instability: pp_singlet=2.898e-02, pp_triplet=4.012e-02, ph_charge=1.897e-01, ph_spin=2.204e-02
# step= 105 | T=12.379382 | rhs_norm=5.722e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=4.233e+02
# kernel scores: pp_singlet=4.964e+01, pp_triplet=1.398e+02, ph_charge=4.233e+02, ph_spin=7.642e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.980e-01
# instability: pp_singlet=3.102e-02, pp_triplet=4.063e-02, ph_charge=1.980e-01, ph_spin=2.248e-02
# step= 110 | T=12.254591 | rhs_norm=5.905e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=4.336e+02
# kernel scores: pp_singlet=5.209e+01, pp_triplet=1.389e+02, ph_charge=4.336e+02, ph_spin=7.647e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=2.069e-01
# instability: pp_singlet=3.314e-02, pp_triplet=4.114e-02, ph_charge=2.069e-01, ph_spin=2.294e-02
# step= 115 | T=12.129800 | rhs_norm=6.118e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=4.446e+02
# kernel scores: pp_singlet=5.458e+01, pp_triplet=1.380e+02, ph_charge=4.446e+02, ph_spin=7.652e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=2.165e-01
# instability: pp_singlet=3.537e-02, pp_triplet=4.165e-02, ph_charge=2.165e-01, ph_spin=2.341e-02
# step= 120 | T=12.005008 | rhs_norm=6.366e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=4.564e+02
# kernel scores: pp_singlet=5.713e+01, pp_triplet=1.371e+02, ph_charge=4.564e+02, ph_spin=7.658e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=2.268e-01
# instability: pp_singlet=3.771e-02, pp_triplet=4.215e-02, ph_charge=2.268e-01, ph_spin=2.389e-02
# step= 125 | T=11.880217 | rhs_norm=6.653e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=4.691e+02
# kernel scores: pp_singlet=5.972e+01, pp_triplet=1.361e+02, ph_charge=4.691e+02, ph_spin=7.664e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=2.380e-01
# instability: pp_singlet=4.017e-02, pp_triplet=4.265e-02, ph_charge=2.380e-01, ph_spin=2.439e-02
# step= 130 | T=11.755426 | rhs_norm=6.985e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=4.830e+02
# kernel scores: pp_singlet=6.238e+01, pp_triplet=1.350e+02, ph_charge=4.830e+02, ph_spin=7.670e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=2.502e-01
# instability: pp_singlet=4.276e-02, pp_triplet=4.313e-02, ph_charge=2.502e-01, ph_spin=2.490e-02
# step= 135 | T=11.630634 | rhs_norm=7.366e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=4.979e+02
# kernel scores: pp_singlet=6.512e+01, pp_triplet=1.339e+02, ph_charge=4.979e+02, ph_spin=7.676e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=2.634e-01
# instability: pp_singlet=4.551e-02, pp_triplet=4.360e-02, ph_charge=2.634e-01, ph_spin=2.543e-02
# step= 140 | T=11.505843 | rhs_norm=7.807e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=5.142e+02
# kernel scores: pp_singlet=6.793e+01, pp_triplet=1.327e+02, ph_charge=5.142e+02, ph_spin=7.681e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=2.778e-01
# instability: pp_singlet=4.841e-02, pp_triplet=4.405e-02, ph_charge=2.778e-01, ph_spin=2.597e-02
# step= 145 | T=11.381052 | rhs_norm=8.315e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=5.321e+02
# kernel scores: pp_singlet=7.083e+01, pp_triplet=1.314e+02, ph_charge=5.321e+02, ph_spin=7.687e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=2.936e-01
# instability: pp_singlet=5.150e-02, pp_triplet=4.447e-02, ph_charge=2.936e-01, ph_spin=2.653e-02
# step= 150 | T=11.256260 | rhs_norm=8.904e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=5.516e+02
# kernel scores: pp_singlet=7.384e+01, pp_triplet=1.300e+02, ph_charge=5.516e+02, ph_spin=7.691e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=3.110e-01
# instability: pp_singlet=5.479e-02, pp_triplet=4.486e-02, ph_charge=3.110e-01, ph_spin=2.709e-02
# step= 155 | T=11.131469 | rhs_norm=9.588e+00 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=5.731e+02
# kernel scores: pp_singlet=7.697e+01, pp_triplet=1.284e+02, ph_charge=5.731e+02, ph_spin=7.694e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=3.302e-01
# instability: pp_singlet=5.832e-02, pp_triplet=4.521e-02, ph_charge=3.302e-01, ph_spin=2.767e-02
# step= 160 | T=11.006678 | rhs_norm=1.039e+01 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=5.969e+02
# kernel scores: pp_singlet=8.025e+01, pp_triplet=1.268e+02, ph_charge=5.969e+02, ph_spin=7.696e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=3.516e-01
# instability: pp_singlet=6.210e-02, pp_triplet=4.551e-02, ph_charge=3.516e-01, ph_spin=2.826e-02
# step= 165 | T=10.881886 | rhs_norm=1.132e+01 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=6.234e+02
# kernel scores: pp_singlet=8.369e+01, pp_triplet=1.250e+02, ph_charge=6.234e+02, ph_spin=7.696e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=3.753e-01
# instability: pp_singlet=6.618e-02, pp_triplet=4.574e-02, ph_charge=3.753e-01, ph_spin=2.886e-02
# step= 170 | T=10.757095 | rhs_norm=1.243e+01 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=6.530e+02
# kernel scores: pp_singlet=8.732e+01, pp_triplet=1.230e+02, ph_charge=6.530e+02, ph_spin=7.693e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=4.020e-01
# instability: pp_singlet=7.061e-02, pp_triplet=4.590e-02, ph_charge=4.020e-01, ph_spin=2.947e-02
# step= 175 | T=10.632304 | rhs_norm=1.376e+01 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=6.863e+02
# kernel scores: pp_singlet=9.119e+01, pp_triplet=1.207e+02, ph_charge=6.863e+02, ph_spin=7.687e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=4.321e-01
# instability: pp_singlet=7.543e-02, pp_triplet=4.597e-02, ph_charge=4.321e-01, ph_spin=3.007e-02
# step= 180 | T=10.507513 | rhs_norm=1.535e+01 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=7.242e+02
# kernel scores: pp_singlet=9.534e+01, pp_triplet=1.183e+02, ph_charge=7.242e+02, ph_spin=7.676e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=4.663e-01
# instability: pp_singlet=8.073e-02, pp_triplet=4.592e-02, ph_charge=4.663e-01, ph_spin=3.067e-02
# step= 185 | T=10.382721 | rhs_norm=1.728e+01 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=7.674e+02
# kernel scores: pp_singlet=9.982e+01, pp_triplet=1.155e+02, ph_charge=7.674e+02, ph_spin=7.659e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=5.055e-01
# instability: pp_singlet=8.660e-02, pp_triplet=4.572e-02, ph_charge=5.055e-01, ph_spin=3.126e-02
# step= 190 | T=10.257930 | rhs_norm=1.966e+01 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=8.173e+02
# kernel scores: pp_singlet=1.047e+02, pp_triplet=1.123e+02, ph_charge=8.173e+02, ph_spin=7.633e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=5.508e-01
# instability: pp_singlet=9.315e-02, pp_triplet=4.535e-02, ph_charge=5.508e-01, ph_spin=3.183e-02
# step= 195 | T=10.133139 | rhs_norm=2.264e+01 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=8.755e+02
# kernel scores: pp_singlet=1.102e+02, pp_triplet=1.087e+02, ph_charge=8.755e+02, ph_spin=7.597e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=6.037e-01
# instability: pp_singlet=1.005e-01, pp_triplet=4.475e-02, ph_charge=6.037e-01, ph_spin=3.236e-02
# step= 200 | T=10.008347 | rhs_norm=2.642e+01 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=9.443e+02
# kernel scores: pp_singlet=1.162e+02, pp_triplet=1.045e+02, ph_charge=9.443e+02, ph_spin=7.546e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=6.664e-01
# instability: pp_singlet=1.090e-01, pp_triplet=4.387e-02, ph_charge=6.664e-01, ph_spin=3.284e-02
# step= 205 | T=9.883556 | rhs_norm=3.134e+01 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=1.027e+03
# kernel scores: pp_singlet=1.232e+02, pp_triplet=9.965e+01, ph_charge=1.027e+03, ph_spin=7.475e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=7.415e-01
# instability: pp_singlet=1.188e-01, pp_triplet=4.263e-02, ph_charge=7.415e-01, ph_spin=3.322e-02
# step= 210 | T=9.758765 | rhs_norm=3.787e+01 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=1.127e+03
# kernel scores: pp_singlet=1.313e+02, pp_triplet=9.385e+01, ph_charge=1.127e+03, ph_spin=7.376e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=8.333e-01
# instability: pp_singlet=1.305e-01, pp_triplet=4.091e-02, ph_charge=8.333e-01, ph_spin=3.347e-02
# step= 215 | T=9.633973 | rhs_norm=4.683e+01 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=1.252e+03
# kernel scores: pp_singlet=1.411e+02, pp_triplet=8.685e+01, ph_charge=1.252e+03, ph_spin=7.237e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=9.476e-01
# instability: pp_singlet=1.446e-01, pp_triplet=3.856e-02, ph_charge=9.476e-01, ph_spin=3.351e-02
# step= 220 | T=9.509182 | rhs_norm=5.958e+01 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=1.412e+03
# kernel scores: pp_singlet=1.531e+02, pp_triplet=7.818e+01, ph_charge=1.412e+03, ph_spin=7.037e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.094e+00
# instability: pp_singlet=1.621e-01, pp_triplet=3.533e-02, ph_charge=1.094e+00, ph_spin=3.324e-02
# step= 225 | T=9.384391 | rhs_norm=7.858e+01 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=1.624e+03
# kernel scores: pp_singlet=1.685e+02, pp_triplet=6.714e+01, ph_charge=1.624e+03, ph_spin=6.745e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.287e+00
# instability: pp_singlet=1.847e-01, pp_triplet=3.087e-02, ph_charge=1.287e+00, ph_spin=3.247e-02
# step= 230 | T=9.259599 | rhs_norm=1.087e+02 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=1.916e+03
# kernel scores: pp_singlet=1.894e+02, pp_triplet=5.252e+01, ph_charge=1.916e+03, ph_spin=6.304e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.554e+00
# instability: pp_singlet=2.152e-01, pp_triplet=2.455e-02, ph_charge=1.554e+00, ph_spin=3.088e-02
# step= 235 | T=9.134808 | rhs_norm=1.605e+02 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=2.343e+03
# kernel scores: pp_singlet=2.194e+02, pp_triplet=3.206e+01, ph_charge=2.343e+03, ph_spin=5.601e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=1.943e+00
# instability: pp_singlet=2.589e-01, pp_triplet=1.522e-02, ph_charge=1.943e+00, ph_spin=2.785e-02
# step= 240 | T=9.010017 | rhs_norm=2.610e+02 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=3.026e+03
# kernel scores: pp_singlet=2.668e+02, pp_triplet=1.608e+00, ph_charge=3.026e+03, ph_spin=4.395e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=2.564e+00
# instability: pp_singlet=3.275e-01, pp_triplet=8.256e-04, ph_charge=2.564e+00, ph_spin=2.212e-02
# step= 245 | T=8.885225 | rhs_norm=4.959e+02 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=4.275e+03
# kernel scores: pp_singlet=3.529e+02, pp_triplet=7.218e-02, ph_charge=4.275e+03, ph_spin=2.055e+01
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=3.695e+00
# instability: pp_singlet=4.507e-01, pp_triplet=3.996e-05, ph_charge=3.695e+00, ph_spin=1.041e-02
# step= 248 | T=8.810351 | rhs_norm=8.251e+02 | lead_kernel=ph_charge @ Q0:(0.000, 0.000) score=5.665e+03
# kernel scores: pp_singlet=4.482e+02, pp_triplet=5.302e-02, ph_charge=5.665e+03, ph_spin=0.000e+00
#     lead_instability=ph_charge @ Q0:(0.000, 0.000) score=4.948e+00
# instability: pp_singlet=5.858e-01, pp_triplet=2.945e-05, ph_charge=4.948e+00, ph_spin=-3.197e-03
#
# [flow stopped]
# instability_reason: channel norm=2.197e+02 exceeded channel_divergence_threshold
#
# ================ RG FLOW DONE ================
#
# history length = 249
# final step = 248
# final T    = 8.81035058430718
# final rhs_norm = 825.1482732010948
# final channel_norm = 219.73702850357964
# instability = True
# terminated_early = False
# instability_reason = channel norm=2.197e+02 exceeded channel_divergence_threshold
# termination_reason = None

# %% [markdown]
# # Diagnosis

# %%
# ============================================================
# Diagnose one flowed step
# ============================================================
STEP_SELECTOR = -2   # -1 last step, -2 second last, -3 third last, or exact step index

diagnosis_result = diagnose_flowed_step(
    solver,
    history,
    diagnosis_Qs,
    step_selector=STEP_SELECTOR,
    ph_bubble_mode="patchrep",
    project_ph_charge_q0_uniform=True,
    project_pp_singlet_q0_local_gram_default=False,
    plot_eigenstate=True,
)

# Optional: inspect the raw tables
# display(diagnosis_result["df_signaware"].sort_values(["Q_index", "channel"]).reset_index(drop=True))
# display(diagnosis_result["df_instability"].sort_values(["Q_index", "channel"]).reset_index(drop=True))
# Out:
# Diagnosing step_index = 247
# T = 8.835309
# rhs_norm = 6.866e+02
# channel_norm = 1.991e+02
# instability = False
# terminated_early = False
# instability_reason = None
# termination_reason = None
#
# === sign-aware leader at selected step ===
# channel : ph_charge
# Q       : (0.000000, 0.000000)
# score   : 5.113780648069e+03
# chosen  : negative -5.113780648069e+03
#
# === physical-instability leader at selected step ===
# channel : ph_charge
# Q       : (0.000000, 0.000000)
# score   : 4.451590715146e+00
# eval    : 4.451590715146e+00
# bubble  : patchrep:bubble_dot_ph(eps_p,eps_p+Q)*measure_p
# proj    : nan
# === leader eigenstate summary ===
# channel            : ph_charge
# Q                  : (0.000000, 0.000000)
# selected eigenvalue: -5.113780648069e+03
# kernel dimension   : 36
# |<u_const|v>|      : 6.824076324604e-18

# %% [markdown]
# # Debug

# %%
import numpy as np
import matplotlib.pyplot as plt
from frg_kernel import canonicalize_q_for_patchsets

# ============================================================
# Robust ratio tracking: sBO-like(Q=M, ph_spin) / PI(Q=0, ph_charge)
# ============================================================

# ----------------------------
# helper: iterate snapshots robustly
# ----------------------------
def iter_snapshot_items(snapshots_obj):
    """
    Returns a list of (step_key, snapshot_obj), sorted by step if possible.
    Compatible with dict or list/tuple.
    """
    if isinstance(snapshots_obj, dict):
        items = list(snapshots_obj.items())
        try:
            items = sorted(items, key=lambda kv: kv[0])
        except Exception:
            pass
        return items

    # list / tuple
    return list(enumerate(snapshots_obj))

# ----------------------------
# helper: L1 weight on current patch loop
# ----------------------------
ps_up = solver.patchsets["up"]
kxy = np.array([p.k_cart for p in ps_up.patches], dtype=float)
theta = np.arctan2(kxy[:, 1], kxy[:, 0])

# normalized L1 proxy basis
b_l1_sin = np.sin(theta)
b_l1_cos = np.cos(theta)
b_l1_sin = b_l1_sin / np.linalg.norm(b_l1_sin)
b_l1_cos = b_l1_cos / np.linalg.norm(b_l1_cos)

def l1_weight(v):
    v = np.asarray(v, dtype=complex)
    v = v / np.linalg.norm(v)
    return float(np.abs(np.vdot(b_l1_sin, v))**2 + np.abs(np.vdot(b_l1_cos, v))**2)

# ----------------------------
# choose which M-point to track
# ----------------------------
QM_INDEX = 1   # try 1 first; later you can repeat for 2 or 3

ratio_track = []
temps = []
pi_track = []
sbo_track = []
step_keys = []

snapshot_items = iter_snapshot_items(snapshots)

for step_key, snap in snapshot_items:
    builder = make_builder_from_snapshot(snap, solver, Landau_F=False)

    # ----------------------------
    # Q0 PI candidate = ph_charge @ Q0
    # ----------------------------
    Q0 = canonicalize_q_for_patchsets(builder.patchsets, diagnosis_Qs[0])
    K0 = builder.build_kernel_dict(Q0, Landau_F=False)["ph_charge"].matrix
    H0 = 0.5 * (K0 + K0.conj().T)
    eval0 = np.linalg.eigvalsh(H0)
    PI_score = float(-np.min(eval0))   # ph channel: more negative => stronger ordering

    # ----------------------------
    # QM sBO candidate = most L1-like mode among lowest few
    # in ph_spin @ QM
    # ----------------------------
    QM = canonicalize_q_for_patchsets(builder.patchsets, diagnosis_Qs[QM_INDEX])
    KM = builder.build_kernel_dict(QM, Landau_F=False)["ph_spin"].matrix
    HM = 0.5 * (KM + KM.conj().T)
    evalM, evecM = np.linalg.eigh(HM)

    # among the lowest few eigenmodes, choose the most L1-like one
    n_pick = min(8, len(evalM))
    candidate_idxs = np.argsort(evalM)[:n_pick]

    best_idx = None
    best_l1 = -np.inf
    best_score = None

    for idx in candidate_idxs:
        v = evecM[:, idx]
        wL1 = l1_weight(v)
        if wL1 > best_l1:
            best_l1 = wL1
            best_idx = idx
            best_score = float(-evalM[idx])  # ph score from most negative side

    SBO_score = best_score

    ratio = SBO_score / PI_score if PI_score > 0 else np.nan

    # temperature
    T_here = getattr(snap, "T", None)
    if T_here is None:
        T_here = getattr(snap, "temperature", None)
    if T_here is None and isinstance(snap, dict):
        T_here = snap.get("T", snap.get("temperature", np.nan))

    temps.append(float(T_here))
    ratio_track.append(float(ratio))
    pi_track.append(float(PI_score))
    sbo_track.append(float(SBO_score))
    step_keys.append(step_key)

# ----------------------------
# plot ratio
# ----------------------------
plt.figure(figsize=(7,4))
plt.plot(temps, ratio_track, 'o-')
plt.axhline(1.0, color='r', linestyle='--')
plt.gca().invert_xaxis()
plt.xlabel("Temperature")
plt.ylabel("sBO / PI score ratio")
plt.title(f"Competition ratio during flow (QM index={QM_INDEX})")
plt.show()

# ----------------------------
# plot raw tracked scores too
# ----------------------------
plt.figure(figsize=(7,4))
plt.plot(temps, pi_track, 'o-', label='PI: ph_charge @ Q0')
plt.plot(temps, sbo_track, 'o-', label=f'sBO-like: ph_spin @ QM[{QM_INDEX}]')
plt.yscale('log')
plt.gca().invert_xaxis()
plt.xlabel("Temperature")
plt.ylabel("score")
plt.title("Tracked PI and sBO-like scores")
plt.legend()
plt.show()

# ----------------------------
# print summary
# ----------------------------
imax = int(np.nanargmax(ratio_track))
print("Best ratio point:")
print(f"  step_key   = {step_keys[imax]}")
print(f"  T          = {temps[imax]:.6f}")
print(f"  ratio      = {ratio_track[imax]:.6f}")
print(f"  PI_score   = {pi_track[imax]:.6e}")
print(f"  SBO_score  = {sbo_track[imax]:.6e}")
# Out:
# Best ratio point:
#   step_key   = 0
#   T          = 15.000000
#   ratio      = 0.472854
#   PI_score   = 3.045340e+02
#   SBO_score  = 1.440000e+02

# %%
import numpy as np
import matplotlib.pyplot as plt

# ============================================================
# Bare-level direct comparison:
#   Q0 ph_charge L2-like  vs  QM ph_spin L1-like
# ============================================================

BARE_STEP = 0
QM_INDEX = 1   # try 1 first, later you can test 2,3 too

rec = resolve_history_step(history, step_selector=BARE_STEP)
snapshot = snapshots[int(rec.step_index)]
builder = make_builder_from_snapshot(snapshot, solver, Landau_F=False)

ps = solver.patchsets["up"]
kxy = np.array([p.k_cart for p in ps.patches], dtype=float)
theta = np.arctan2(kxy[:, 1], kxy[:, 0])

def _norm(v):
    v = np.asarray(v, dtype=complex)
    n = np.linalg.norm(v)
    return v / n if n > 0 else v

# harmonic basis
basis = {
    "L0_const": _norm(np.ones_like(theta)),
    "L1_cos": _norm(np.cos(theta)),
    "L1_sin": _norm(np.sin(theta)),
    "L2_cos": _norm(np.cos(2*theta)),
    "L2_sin": _norm(np.sin(2*theta)),
    "L3_cos": _norm(np.cos(3*theta)),
    "L3_sin": _norm(np.sin(3*theta)),
}

def harmonic_weight(v, which):
    v = _norm(v)
    if which == "L1":
        return float(abs(np.vdot(basis["L1_cos"], v))**2 + abs(np.vdot(basis["L1_sin"], v))**2)
    if which == "L2":
        return float(abs(np.vdot(basis["L2_cos"], v))**2 + abs(np.vdot(basis["L2_sin"], v))**2)
    if which == "L3":
        return float(abs(np.vdot(basis["L3_cos"], v))**2 + abs(np.vdot(basis["L3_sin"], v))**2)
    raise ValueError("which must be L1/L2/L3")

def pick_best_mode(H, channel_type, target_harmonic, n_pick=10):
    evals, evecs = np.linalg.eigh(H)
    if channel_type == "ph":
        cand = np.argsort(evals)[:min(n_pick, len(evals))]   # most negative side
        scores = [-evals[i] for i in cand]
    else:
        cand = np.argsort(evals)[-min(n_pick, len(evals)):]  # most positive side
        scores = [evals[i] for i in cand]

    best = None
    best_hw = -np.inf
    for i, score in zip(cand, scores):
        v = evecs[:, i]
        hw = harmonic_weight(v, target_harmonic)
        if hw > best_hw:
            best_hw = hw
            best = {
                "idx": int(i),
                "eval": float(evals[i]),
                "score": float(score),
                "vec": np.asarray(v, dtype=complex),
                "harmonic_weight": float(hw),
            }
    return best

# build kernels
Q0 = diagnosis_Qs[0]
QM = diagnosis_Qs[QM_INDEX]

kd0 = builder.build_kernel_dict(Q0, Landau_F=False)
kdM = builder.build_kernel_dict(QM, Landau_F=False)

H_q0_charge = 0.5 * (kd0["ph_charge"].matrix + kd0["ph_charge"].matrix.T.conj())
H_qm_spin   = 0.5 * (kdM["ph_spin"].matrix   + kdM["ph_spin"].matrix.T.conj())

best_q0_pi = pick_best_mode(H_q0_charge, channel_type="ph", target_harmonic="L2", n_pick=10)
best_qm_sbo = pick_best_mode(H_qm_spin, channel_type="ph", target_harmonic="L1", n_pick=10)

ratio = best_qm_sbo["score"] / best_q0_pi["score"] if best_q0_pi["score"] > 0 else np.nan

print("=== Bare-level comparison ===")
print(f"Q0 charge L2-like score = {best_q0_pi['score']:.6e}")
print(f"Q0 charge chosen eval   = {best_q0_pi['eval']:.6e}")
print(f"Q0 charge L2 weight     = {best_q0_pi['harmonic_weight']:.6f}")
print()
print(f"QM spin L1-like score   = {best_qm_sbo['score']:.6e}")
print(f"QM spin chosen eval     = {best_qm_sbo['eval']:.6e}")
print(f"QM spin L1 weight       = {best_qm_sbo['harmonic_weight']:.6f}")
print()
print(f"sBO / PI bare ratio     = {ratio:.6f}")

# phase-fix for plotting
def phase_fix(v):
    v = np.asarray(v, dtype=complex)
    imax = int(np.argmax(np.abs(v)))
    phase = np.angle(v[imax])
    return v * np.exp(-1j * phase)

v_pi = phase_fix(best_q0_pi["vec"])
v_sbo = phase_fix(best_qm_sbo["vec"])

fig, axes = plt.subplots(1, 2, figsize=(12, 4), constrained_layout=True)

sc0 = axes[0].scatter(kxy[:,0], kxy[:,1], c=np.real(v_pi), s=90)
for i, (x, y) in enumerate(kxy):
    axes[0].text(x, y, str(i), fontsize=8, ha="center", va="center")
axes[0].set_title("Bare Q0 ph_charge best L2-like mode")
plt.colorbar(sc0, ax=axes[0])

sc1 = axes[1].scatter(kxy[:,0], kxy[:,1], c=np.real(v_sbo), s=90)
for i, (x, y) in enumerate(kxy):
    axes[1].text(x, y, str(i), fontsize=8, ha="center", va="center")
axes[1].set_title(f"Bare QM[{QM_INDEX}] ph_spin best L1-like mode")
plt.colorbar(sc1, ax=axes[1])

plt.show()
# Out:
# === Bare-level comparison ===
# Q0 charge L2-like score = 3.045340e+02
# Q0 charge chosen eval   = -3.045340e+02
# Q0 charge L2 weight     = 0.893756
#
# QM spin L1-like score   = 1.440000e+02
# QM spin chosen eval     = -1.440000e+02
# QM spin L1 weight       = 0.614590
#
# sBO / PI bare ratio     = 0.472854

# %%
import numpy as np
import matplotlib.pyplot as plt

# ============================================================
# Bare Q0 ph_exchange leading positive mode:
# inspect its Bloch / sublattice structure patch by patch
# ============================================================

BARE_STEP = 0

rec = resolve_history_step(history, step_selector=BARE_STEP)
snapshot = snapshots[int(rec.step_index)]
builder = make_builder_from_snapshot(snapshot, solver, Landau_F=False)

Q0 = diagnosis_Qs[0]
kd0 = builder.build_kernel_dict(Q0, Landau_F=False)

Vd = kd["ph_spin"].matrix
Vx = (kd["ph_spin"].matrix-kd["ph_charge"].matrix)/2
Hvx = 0.5 * (Vx + Vx.T.conj())

evals, evecs = np.linalg.eigh(Hvx)
idx = np.argmax(evals)

lam = float(evals[idx])
vx = np.asarray(evecs[:, idx], dtype=complex)

# phase-fix
imax = int(np.argmax(np.abs(vx)))
phase = np.angle(vx[imax])
vx = vx * np.exp(-1j * phase)

print("Bare Q0 ph_exchange:")
print(f"largest positive eval = {lam:.6e}")

# patch geometry and Bloch weights
ps = solver.patchsets["up"]
kxy = np.array([p.k_cart for p in ps.patches], dtype=float)
theta = np.arctan2(kxy[:,1], kxy[:,0])

eigvecs = np.array([np.asarray(p.eigvec, dtype=complex) for p in ps.patches])
orb_w = np.abs(eigvecs)**2   # shape (Npatch, 3)
wA, wB, wC = orb_w[:,0], orb_w[:,1], orb_w[:,2]

# sort by angle for line plots
order = np.argsort(theta)
theta_s = theta[order]
vx_s = vx[order]
wA_s, wB_s, wC_s = wA[order], wB[order], wC[order]

# simple correlations
corrA = np.corrcoef(np.real(vx), wA)[0,1]
corrB = np.corrcoef(np.real(vx), wB)[0,1]
corrC = np.corrcoef(np.real(vx), wC)[0,1]

print("Correlation of Re(vx) with orbital weights:")
print(f"corr(Re(vx), |u_A|^2) = {corrA:.6f}")
print(f"corr(Re(vx), |u_B|^2) = {corrB:.6f}")
print(f"corr(Re(vx), |u_C|^2) = {corrC:.6f}")

fig, axes = plt.subplots(2, 3, figsize=(15, 8), constrained_layout=True)

# mode on FS
sc0 = axes[0,0].scatter(kxy[:,0], kxy[:,1], c=np.real(vx), s=90)
for i, (x, y) in enumerate(kxy):
    axes[0,0].text(x, y, str(i), fontsize=8, ha="center", va="center")
axes[0,0].set_title("Bare Q0 Vx leading positive mode: Re(v)")
plt.colorbar(sc0, ax=axes[0,0])

# orbital weights on FS
sc1 = axes[0,1].scatter(kxy[:,0], kxy[:,1], c=wA, s=90)
for i, (x, y) in enumerate(kxy):
    axes[0,1].text(x, y, str(i), fontsize=8, ha="center", va="center")
axes[0,1].set_title(r"$|u_A|^2$")
plt.colorbar(sc1, ax=axes[0,1])

sc2 = axes[0,2].scatter(kxy[:,0], kxy[:,1], c=wB, s=90)
for i, (x, y) in enumerate(kxy):
    axes[0,2].text(x, y, str(i), fontsize=8, ha="center", va="center")
axes[0,2].set_title(r"$|u_B|^2$")
plt.colorbar(sc2, ax=axes[0,2])

# sorted line plots
axes[1,0].plot(np.real(vx_s), marker="o", label="Re(vx)")
axes[1,0].plot(np.imag(vx_s), marker="s", label="Im(vx)")
axes[1,0].set_title("Mode components (sorted by angle)")
axes[1,0].legend()

axes[1,1].plot(wA_s, marker="o", label=r"$|u_A|^2$")
axes[1,1].plot(wB_s, marker="o", label=r"$|u_B|^2$")
axes[1,1].plot(wC_s, marker="o", label=r"$|u_C|^2$")
axes[1,1].set_title("Orbital weights (sorted by angle)")
axes[1,1].legend()

# overlap against each orbital weight profile
def normalized(x):
    x = np.asarray(x, dtype=float)
    n = np.linalg.norm(x)
    return x / n if n > 0 else x

ovA = abs(np.vdot(normalized(np.real(vx)), normalized(wA)))**2
ovB = abs(np.vdot(normalized(np.real(vx)), normalized(wB)))**2
ovC = abs(np.vdot(normalized(np.real(vx)), normalized(wC)))**2

axes[1,2].bar(["A","B","C"], [ovA, ovB, ovC])
axes[1,2].set_title(r"Proxy overlaps with $|u_\alpha|^2$ profiles")

plt.show()
# Out:
# Bare Q0 ph_exchange:
# largest positive eval = 1.345615e+02
# Correlation of Re(vx) with orbital weights:
# corr(Re(vx), |u_A|^2) = -0.529156
# corr(Re(vx), |u_B|^2) = -0.470265
# corr(Re(vx), |u_C|^2) = 0.999422

# %%
Vd = kd["ph_spin"].matrix
Vx = (kd["ph_spin"].matrix-kd["ph_charge"].matrix)/2

# %%
import numpy as np
import matplotlib.pyplot as plt

# STEP_SELECTOR choose first snapshot / bare
STEP_SELECTOR = 0

rec = resolve_history_step(history, step_selector=STEP_SELECTOR)
snapshot = snapshots[int(rec.step_index)]
builder = make_builder_from_snapshot(snapshot, solver, Landau_F=False)

Q0 = diagnosis_Qs[0]

kd = builder.build_kernel_dict(Q0, Landau_F=False)

Vd = kd["ph_spin"].matrix
Vx = (kd["ph_spin"].matrix-kd["ph_charge"].matrix)/2
Hvx = 0.5*(Vx+Vx.T.conj())

evals,evecs=np.linalg.eigh(Hvx)

idx=np.argmax(evals)

print("Bare-step Hvx largest positive =",evals[idx])

v=evecs[:,idx]

theta=np.arctan2(
    np.array([p.k_cart[1] for p in solver.patchsets["up"].patches]),
    np.array([p.k_cart[0] for p in solver.patchsets["up"].patches])
)

for l in [1,2,3]:
    c=np.cos(l*theta); c/=np.linalg.norm(c)
    s=np.sin(l*theta); s/=np.linalg.norm(s)

    print(
        f"L{l} total =",
        abs(np.vdot(v,c))**2+abs(np.vdot(v,s))**2
    )
# Out:
# Bare-step Hvx largest positive = 134.56153070100015
# L1 total = 1.0191951853235971e-32
# L2 total = 0.8937564175821116
# L3 total = 1.5343283982899168e-32

# %%
import numpy as np
import matplotlib.pyplot as plt

rec = resolve_history_step(history, step_selector=STEP_SELECTOR)
snapshot = snapshots[int(rec.step_index)]
builder = make_builder_from_snapshot(snapshot, solver, Landau_F=False)

Q0 = diagnosis_Qs[0]
kd = builder.build_kernel_dict(Q0, Landau_F=False)

Vd = kd["ph_spin"].matrix
Vx = (kd["ph_spin"].matrix-kd["ph_charge"].matrix)/2

Hvx = 0.5 * (Vx + Vx.T.conj())
Hc  = 0.5 * ((Vd - 2*Vx) + (Vd - 2*Vx).T.conj())

# eig of Hvx: take largest positive
eval_x, evec_x = np.linalg.eigh(Hvx)
ix = np.argmax(eval_x)
lam_x = float(eval_x[ix])
vx = np.asarray(evec_x[:, ix], dtype=complex)

# eig of Hc: take most negative
eval_c, evec_c = np.linalg.eigh(Hc)
ic = np.argmin(eval_c)
lam_c = float(eval_c[ic])
vc = np.asarray(evec_c[:, ic], dtype=complex)

# phase-fix
def phase_fix(v):
    v = np.asarray(v, dtype=complex)
    imax = int(np.argmax(np.abs(v)))
    phase = np.angle(v[imax])
    return v * np.exp(-1j * phase)

vx = phase_fix(vx)
vc = phase_fix(vc)

overlap = float(np.abs(np.vdot(vx, vc))**2)

print("Hvx largest positive eval =", lam_x)
print("Hc  most negative eval    =", lam_c)
print("|<vx_pos | vc_neg>|^2     =", overlap)

# harmonic proxy on vx
ps = solver.patchsets["up"]
kxy = np.array([p.k_cart for p in ps.patches], dtype=float)
theta = np.arctan2(kxy[:,1], kxy[:,0])

def norm_basis(x):
    x = np.asarray(x, dtype=complex)
    nrm = np.linalg.norm(x)
    return x / nrm if nrm > 0 else x

basis = {
    "L0_const": np.ones_like(theta, dtype=float),
    "L1_cos": np.cos(theta),
    "L1_sin": np.sin(theta),
    "L2_cos": np.cos(2*theta),
    "L2_sin": np.sin(2*theta),
    "L3_cos": np.cos(3*theta),
    "L3_sin": np.sin(3*theta),
}

print("\nHvx leading positive mode harmonic weights:")
wt = {}
for name, b in basis.items():
    bb = norm_basis(b)
    wt[name] = float(np.abs(np.vdot(bb, vx))**2)
    print(f"{name:8s}: {wt[name]:.6f}")

print("\nCombined:")
print("L1 total =", wt["L1_cos"] + wt["L1_sin"])
print("L2 total =", wt["L2_cos"] + wt["L2_sin"])
print("L3 total =", wt["L3_cos"] + wt["L3_sin"])

fig, axes = plt.subplots(1, 2, figsize=(12, 4), constrained_layout=True)

sc0 = axes[0].scatter(kxy[:,0], kxy[:,1], c=np.real(vx), s=90)
for i, (x, y) in enumerate(kxy):
    axes[0].text(x, y, str(i), fontsize=8, ha="center", va="center")
axes[0].set_title("Hvx leading positive mode")
plt.colorbar(sc0, ax=axes[0])

sc1 = axes[1].scatter(kxy[:,0], kxy[:,1], c=np.real(vc), s=90)
for i, (x, y) in enumerate(kxy):
    axes[1].text(x, y, str(i), fontsize=8, ha="center", va="center")
axes[1].set_title("Hc leading negative mode")
plt.colorbar(sc1, ax=axes[1])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 15
#      11 Q0 = diagnosis_Qs[0]
#      13 kd = builder.build_kernel_dict(Q0, Landau_F=False)
# ---> 15 Vx = kd["ph_exchange"].matrix
#      16 Hvx = 0.5*(Vx+Vx.T.conj())
#      18 evals,evecs=np.linalg.eigh(Hvx)
#
# KeyError: 'ph_exchange'

# %% [markdown]
# ## Patch Information

# %%
# # ------------------------------------------------------------
# # print patch info: k, energy, vF, |vF|, l, l/|vF|
# # ------------------------------------------------------------
# for spin in ["up", "dn"]:
#     ps = patchsets[spin]
#     print(f"\n{'='*72}")
#     print(f"{spin} patchset summary")
#     print(f"{'='*72}")
#     print(f"Npatch            = {ps.Npatch}")
#     print(f"gauge_method      = {ps.gauge_method}")
#     print(f"gauge_loop_phase  = {ps.gauge_loop_phase:.12e}")
#     print()

#     for p in ps.patches:
#         print(
#             f"id={p.patch_id:2d} | "
#             f"k={np.round(p.k_cart, 8)} | "
#             f"k_red={np.round(p.k_red, 8)} | "
#             f"E={p.energy:+.12e} | "
#             f"vF={np.round(p.vF, 8)} | "
#             f"|vF|={p.vF_norm:.12e} | "
#             f"l={0.0 if p.fs_arc_length is None else p.fs_arc_length:.12e} | "
#             f"l/|vF|={0.0 if p.weight_length_over_vf is None else p.weight_length_over_vf:.12e}"
#         )

# # ------------------------------------------------------------
# # gauge smoothness / loop phase check
# # ------------------------------------------------------------
# for spin in ["up", "dn"]:
#     U = np.array([p.eigvec for p in patchsets[spin].patches], dtype=complex)

#     ovs = []
#     for i in range(len(U)):
#         j = (i + 1) % len(U)
#         ovs.append(np.vdot(U[i], U[j]))
#     ovs = np.asarray(ovs, dtype=complex)

#     print(f"\n{'='*72}")
#     print(f"{spin} gauge smoothness check")
#     print(f"{'='*72}")
#     print("neighbor overlap abs =")
#     print(np.round(np.abs(ovs), 8))
#     print("neighbor overlap arg =")
#     print(np.round(np.angle(ovs), 8))

#     # loop closure overlap
#     if len(U) > 1:
#         loop_ov = np.vdot(U[-1], U[0])
#         print(f"last-first overlap abs = {abs(loop_ov):.12e}")
#         print(f"last-first overlap arg = {np.angle(loop_ov):.12e}")

#     # whether the stored loop phase is basically fixed
#     if abs(patchsets[spin].gauge_loop_phase) < 1e-8:
#         print("Gauge loop phase looks fixed: YES")
#     else:
#         print("Gauge loop phase looks fixed: NOT fully")

# # ------------------------------------------------------------
# # compact arrays for later reuse
# # ------------------------------------------------------------
# for spin in ["up", "dn"]:
#     ps = patchsets[spin]
#     print(f"\n{'='*72}")
#     print(f"{spin} compact arrays")
#     print(f"{'='*72}")
#     print("energies =")
#     print(np.array2string(ps.patch_energy, precision=10, suppress_small=False))
#     print("vF norms =")
#     print(np.array2string(ps.patch_vF_norm, precision=10, suppress_small=False))
#     print("arc lengths l =")
#     print(np.array2string(ps.patch_arc_length, precision=10, suppress_small=False))
#     print("l / |vF| =")
#     print(np.array2string(ps.patch_weight_length_over_vf, precision=10, suppress_small=False))

# # ------------------------------------------------------------
# # extra strict sanity checks
# # ------------------------------------------------------------
# for spin in ["up", "dn"]:
#     ps = patchsets[spin]
#     max_abs_E = np.max(np.abs(ps.patch_energy)) if ps.Npatch > 0 else 0.0
#     print(f"\n{spin}: max |E-mu| = {max_abs_E:.12e}")
