# %% [markdown]
# # Kagome fRG sanity-check pipeline
#
# This notebook builds a **standard spinful kagome model** using the corrected `channels.py` and `frg_flow.py`, then runs two benchmark interaction points inspired by the PRL phase diagram:
#
# - **FM benchmark:** `U=6, V=0`
# - **PI benchmark:** `U=0, V=10`
#
# Target setup:
# - no flux
# - van Hove filling proxy: `mu = 0`
# - `Npatch = 12`
#
# The purpose is simple:
#
# 1. verify the corrected longitudinal channel construction in a full end-to-end pipeline
# 2. check whether the final leading instability looks **FM-like** for large `U`
# 3. check whether it looks **PI-like** for large `V`
#
# If the second case still does **not** show PI-like structure, the next place to inspect is likely:
# - `form_factor.py`
# - `kagome_order_diagnosis.py`
#
# ---

# %%
import sys
from pathlib import Path
from pprint import pprint
import numpy as np
import numpy as np
import matplotlib.pyplot as plt

# Make sure the uploaded modules are importable
sys.path.insert(0, "/mnt/data")

from noninteracting import KagomeNagaosa
from patching import FSPatcher, plot_patchset
from interaction import BareExtendedHubbard
from frg_flow import BareVertexFromInteraction, FRGFlowSolver
import sys
sys.path.insert(0, "/mnt/data")

# %% [markdown]
# ## 1. Global parameters
#
# You can tune the flow resolution here.
#
# Notes:
# - `mu=0` matches the PRL convention for kagome VHF.
# - `band_index=1` is the dispersive band crossing `mu=0` inside each 3x3 spin block.
# - `Npatch=12` is intentionally small, just for a fast pipeline sanity check.
# - For a more reliable final physics check, increase `Npatch`, `nfreq`, and `n_steps`.

# %%
# ---------- noninteracting / patching ----------
MODEL_PARAMS = dict(t=1.0, phi=0.0)   # standard kagome = phi=0
MU = 0.0
NPATCH = 6
GRID_SIZE = 320
CONTOUR_MIN_POINTS = 40

# Each spin block is 3x3 inside the full 6x6 spinful Hamiltonian
UP_SLICE = slice(0, 3)
DN_SLICE = slice(3, 6)
LOCAL_BAND_INDEX = 1   # dispersive band crossing mu=0

# ---------- flow ----------
FLOW_KWARGS = dict(
    T_start=4,
    T_stop=0.001,
    n_steps=500,
    nfreq=10,
    diagnose_every=10,
    temperature_grid="log",
    include_explicit_T_prefactor=True,
    max_relative_update=1,
    min_substep_fraction=0.1,
    channel_divergence_threshold=1e4,
    eigenvalue_threshold=1e4,
    diagnosis_sort_by="abs",
    track_crossed_channel=True,
    diagnosis_Qs = [np.array([0.0, 0.0]), np.array([0.0,  np.pi/np.sqrt(3)]), np.array([ np.pi/2,  np.pi/(2*np.sqrt(3))]), np.array([-np.pi/2,  np.pi/(2*np.sqrt(3))])]
)

# %% [markdown]
# ## 2. Build the standard spinful kagome model and the two spin patchsets

# %%
# ============================================================
# Manual exact-M patchsets on standard centered 1BZ hexagon
# ============================================================

import numpy as np
import matplotlib.pyplot as plt
from patching import PatchPoint, PatchSet, plot_patchset

model = KagomeNagaosa(MODEL_PARAMS, spin=True, B=None)

# ------------------------------------------------------------
# basic helpers
# ------------------------------------------------------------
def _sector_eig(model, k_cart, orbital_slice, band_index):
    kx, ky = float(k_cart[0]), float(k_cart[1])
    H = np.asarray(model.Hk(kx, ky), dtype=complex)
    Hs = H[orbital_slice, orbital_slice]
    evals, evecs = np.linalg.eigh(Hs)
    u = np.asarray(evecs[:, band_index], dtype=complex)
    u = u / np.linalg.norm(u)
    return float(evals[band_index]), u

def _orbital_weight(u):
    w = np.abs(np.asarray(u, dtype=complex))**2
    return w / np.sum(w)

def _cart_to_red(model, k):
    B = np.column_stack([
        np.asarray(model.b1, dtype=float),
        np.asarray(model.b2, dtype=float),
    ])
    return np.linalg.solve(B, np.asarray(k, dtype=float))

def _finite_diff_velocity(model, k_cart, orbital_slice, band_index, h=1e-6):
    kx, ky = float(k_cart[0]), float(k_cart[1])

    def band_energy(x, y):
        H = np.asarray(model.Hk(x, y), dtype=complex)
        Hs = H[orbital_slice, orbital_slice]
        evals, _ = np.linalg.eigh(Hs)
        return float(evals[band_index])

    vx = (band_energy(kx + h, ky) - band_energy(kx - h, ky)) / (2*h)
    vy = (band_energy(kx, ky + h) - band_energy(kx, ky - h)) / (2*h)
    return np.array([vx, vy], dtype=float)


# ------------------------------------------------------------
# 1BZ geometry
# ------------------------------------------------------------
def hex_bz_vertices(model):
    """
    Standard centered 1BZ hexagon vertices for triangular/kagome reciprocal lattice.

    For reciprocal vectors b1, b2, the Wigner-Seitz 1BZ vertices are:
        ±(2b1-b2)/3, ±(b1+b2)/3, ±(-b1+2b2)/3
    """
    b1 = np.asarray(model.b1, dtype=float)
    b2 = np.asarray(model.b2, dtype=float)

    verts = np.array([
        (2*b1 - b2) / 3.0,
        (b1 + b2) / 3.0,
        (-b1 + 2*b2) / 3.0,
        -(2*b1 - b2) / 3.0,
        -(b1 + b2) / 3.0,
        -(-b1 + 2*b2) / 3.0,
    ], dtype=float)

    ang = np.arctan2(verts[:, 1], verts[:, 0])
    order = np.argsort(ang)
    return verts[order]


def exact_M6_points_1bz(model):
    """
    6 geometric M points on the boundary of the standard centered 1BZ hexagon.
    Each M point is the midpoint of one hexagon edge.
    """
    V = hex_bz_vertices(model)
    M = []

    n = len(V)
    for i in range(n):
        v0 = V[i]
        v1 = V[(i + 1) % n]
        M.append(0.5 * (v0 + v1))

    M = np.asarray(M, dtype=float)

    # keep consistent cyclic order
    ang = np.arctan2(M[:, 1], M[:, 0])
    order = np.argsort(ang)
    return M[order]


def exact_M_hex_loop_points(model, points_per_edge=1):
    """
    Build a manual hex loop from the 6 exact M points on the centered 1BZ.

    points_per_edge = 1  ->  6 patches  (6 exact M points)
    points_per_edge = 2  -> 12 patches
    points_per_edge = 4  -> 24 patches

    Total patch number = 6 * points_per_edge
    """
    if points_per_edge < 1:
        raise ValueError("points_per_edge must be >= 1")

    M6 = exact_M6_points_1bz(model)
    pts = []

    n = len(M6)
    for i in range(n):
        k0 = M6[i]
        k1 = M6[(i + 1) % n]

        # put points_per_edge points on each M-to-M segment:
        # t = 0, 1/p, 2/p, ..., (p-1)/p
        # exclude t=1 to avoid duplicating the next M point
        for m in range(points_per_edge):
            t = m / points_per_edge
            k = (1.0 - t) * k0 + t * k1
            pts.append(k)

    return np.asarray(pts, dtype=float)


def _hex_bz_vertices_for_plot(model):
    return hex_bz_vertices(model)


# ------------------------------------------------------------
# patchset builder
# ------------------------------------------------------------
def build_exactM_patchset(model, orbital_slice, band_index, points_per_edge=1):
    K = exact_M_hex_loop_points(model, points_per_edge=points_per_edge)
    bz_vertices = _hex_bz_vertices_for_plot(model)

    patches = []
    for pid, k in enumerate(K):
        e, u = _sector_eig(model, k, orbital_slice, band_index)
        vF = _finite_diff_velocity(model, k, orbital_slice, band_index)

        patches.append(
            PatchPoint(
                patch_id=pid,
                k_cart=np.asarray(k, dtype=float),
                k_red=_cart_to_red(model, k),
                energy=e,
                vF=vF,
                vF_norm=float(np.linalg.norm(vF)),
                eigvec=u,
                orbital_weight=_orbital_weight(u),
            )
        )

    npatch = len(K)
    return PatchSet(
        mu=0.0,
        mu_used_for_contour=0.0,
        band_index=int(band_index),
        filling=np.nan,
        patches=patches,
        fs_contour_k=np.asarray(K, dtype=float),
        bz_vertices=np.asarray(bz_vertices, dtype=float),
        b1=np.asarray(model.b1, dtype=float),
        b2=np.asarray(model.b2, dtype=float),
        gauge_method=f"manual_exact_M_hex_{npatch}",
        gauge_loop_phase=0.0,
    )


# ------------------------------------------------------------
# choose patch density here
# ------------------------------------------------------------
POINTS_PER_EDGE = 1   # 1->6, 2->12, 4->24
NPATCH = 6 * POINTS_PER_EDGE

patchsets = {
    "up": build_exactM_patchset(
        model, UP_SLICE, LOCAL_BAND_INDEX, points_per_edge=POINTS_PER_EDGE
    ),
    "dn": build_exactM_patchset(
        model, DN_SLICE, LOCAL_BAND_INDEX, points_per_edge=POINTS_PER_EDGE
    ),
}


# ------------------------------------------------------------
# print info
# ------------------------------------------------------------
print("Patch counts:", {k: v.Npatch for k, v in patchsets.items()})
print("mu used for contour (up/dn):", patchsets["up"].mu_used_for_contour, patchsets["dn"].mu_used_for_contour)
print("gauge method (up/dn):", patchsets["up"].gauge_method, patchsets["dn"].gauge_method)

print("\n===== exact M6 anchors in centered 1BZ =====")
M6 = exact_M6_points_1bz(model)
for i, k in enumerate(M6):
    e_up, _ = _sector_eig(model, k, UP_SLICE, LOCAL_BAND_INDEX)
    e_dn, _ = _sector_eig(model, k, DN_SLICE, LOCAL_BAND_INDEX)
    print(
        f"M{i}: k={np.round(k, 6)} | "
        f"E_up={e_up:.10e} | E_dn={e_dn:.10e}"
    )

for spin in ["up", "dn"]:
    print(f"\n===== {spin} exact-M{NPATCH} patches =====")
    for p in patchsets[spin].patches:
        print(
            f"id={p.patch_id:2d} | "
            f"k={np.round(p.k_cart, 6)} | "
            f"E={p.energy:.10e} | "
            f"|vF|={p.vF_norm:.6e} | "
            f"w={np.round(p.orbital_weight, 6)}"
        )


# ------------------------------------------------------------
# neighbor distance sanity check
# ------------------------------------------------------------
for spin in ["up", "dn"]:
    ks = np.array([p.k_cart for p in patchsets[spin].patches], dtype=float)
    d = np.linalg.norm(np.roll(ks, -1, axis=0) - ks, axis=1)
    print(f"\n===== {spin} neighbor distances =====")
    print(np.round(d, 8))


# ------------------------------------------------------------
# plot
# ------------------------------------------------------------
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

for ax, spin in zip(axes, ["up", "dn"]):
    plot_patchset(patchsets[spin], ax=ax, show_contour=True, show_velocity=False, show_bz=True)
    ks = np.array([p.k_cart for p in patchsets[spin].patches], dtype=float)

    for i, k in enumerate(ks):
        ax.text(k[0], k[1], str(i), fontsize=8, ha="left", va="bottom")

    ax.set_title(f"{spin} exact-M{NPATCH} patchset")

plt.tight_layout()
plt.show()
# Out:
# Patch counts: {'up': 6, 'dn': 6}
# mu used for contour (up/dn): 0.0 0.0
# gauge method (up/dn): manual_exact_M_hex_6 manual_exact_M_hex_6
#
# ===== exact M6 anchors in centered 1BZ =====
# M0: k=[-1.570796 -0.9069  ] | E_up=1.0947644253e-47 | E_dn=1.0947644253e-47
# M1: k=[ 0.       -1.813799] | E_up=1.0344233826e-31 | E_dn=1.0344233826e-31
# M2: k=[ 1.570796 -0.9069  ] | E_up=1.4997597827e-32 | E_dn=1.4997597827e-32
# M3: k=[1.570796 0.9069  ] | E_up=1.0947644253e-47 | E_dn=1.0947644253e-47
# M4: k=[0.       1.813799] | E_up=1.0344233826e-31 | E_dn=1.0344233826e-31
# M5: k=[-1.570796  0.9069  ] | E_up=1.4997597827e-32 | E_dn=1.4997597827e-32
#
# ===== up exact-M6 patches =====
# id= 0 | k=[-1.570796 -0.9069  ] | E=1.0947644253e-47 | |vF|=7.747470e-16 | w=[0. 1. 0.]
# id= 1 | k=[ 0.       -1.813799] | E=1.0344233826e-31 | |vF|=3.449543e-16 | w=[1. 0. 0.]
# id= 2 | k=[ 1.570796 -0.9069  ] | E=1.4997597827e-32 | |vF|=2.255553e-16 | w=[0. 0. 1.]
# id= 3 | k=[1.570796 0.9069  ] | E=1.0947644253e-47 | |vF|=7.747470e-16 | w=[0. 1. 0.]
# id= 4 | k=[0.       1.813799] | E=1.0344233826e-31 | |vF|=3.449543e-16 | w=[1. 0. 0.]
# id= 5 | k=[-1.570796  0.9069  ] | E=1.4997597827e-32 | |vF|=2.255553e-16 | w=[0. 0. 1.]
#
# ===== dn exact-M6 patches =====
# id= 0 | k=[-1.570796 -0.9069  ] | E=1.0947644253e-47 | |vF|=7.747470e-16 | w=[0. 1. 0.]
# id= 1 | k=[ 0.       -1.813799] | E=1.0344233826e-31 | |vF|=3.449543e-16 | w=[1. 0. 0.]
# id= 2 | k=[ 1.570796 -0.9069  ] | E=1.4997597827e-32 | |vF|=2.255553e-16 | w=[0. 0. 1.]
# id= 3 | k=[1.570796 0.9069  ] | E=1.0947644253e-47 | |vF|=7.747470e-16 | w=[0. 1. 0.]
# id= 4 | k=[0.       1.813799] | E=1.0344233826e-31 | |vF|=3.449543e-16 | w=[1. 0. 0.]
# id= 5 | k=[-1.570796  0.9069  ] | E=1.4997597827e-32 | |vF|=2.255553e-16 | w=[0. 0. 1.]
#
# ===== up neighbor distances =====
# [1.81379936 1.81379936 1.81379936 1.81379936 1.81379936 1.81379936]
#
# ===== dn neighbor distances =====
# [1.81379936 1.81379936 1.81379936 1.81379936 1.81379936 1.81379936]

# %% [markdown]
# ## 3. Helpers for running a benchmark interaction point  Debug FRG Solver

# %%
from frg_flow import FRGFlowSolver

_old_step = FRGFlowSolver.step
_old_run = FRGFlowSolver.run

def _debug_step(self, T_old, dT):
    print(f"[DEBUG] entering step: T_old={T_old:.8f}, dT={dT:.8e}")
    try:
        rec = _old_step(self, T_old, dT)
        print(
            f"[DEBUG] leaving step: "
            f"T_new={getattr(rec, 'temperature', float(T_old + dT)):.8f}, "
            f"rhs_norm={getattr(rec, 'rhs_norm', None)}, "
            f"channel_norm={getattr(rec, 'channel_norm', None)}, "
            f"accepted_substeps={getattr(rec, 'accepted_substeps', None)}, "
            f"max_rel_update={getattr(rec, 'max_rel_update', None)}"
        )
        return rec
    except Exception as e:
        print(f"[DEBUG] exception in step:")
        print(f"        T_old = {T_old:.8f}")
        print(f"        dT    = {dT:.8e}")
        print(f"        T_new = {T_old + dT:.8f}")
        raise

def _debug_run(self):
    # print("[DEBUG] temperature path:")
    # for i, T in enumerate(self.temperature_path):
    #     print(f"  i={i:03d}, T={float(T):.8f}")
    return _old_run(self)

FRGFlowSolver.step = _debug_step
FRGFlowSolver.run = _debug_run

def build_solver(model, patchsets, U, V, flow_kwargs=None):
    flow_kwargs = {} if flow_kwargs is None else dict(flow_kwargs)
    interaction = BareExtendedHubbard.from_kagome_model(model, U=U, V=V)
    bare_gamma = BareVertexFromInteraction(interaction, patchsets)
    solver = FRGFlowSolver(
        patchsets=patchsets,
        bare_gamma=bare_gamma,
        **flow_kwargs,
    )
    return interaction, bare_gamma, solver


def summarize_history(history):
    rows = []
    for rec in history:
        rows.append({
            "step": rec.step_index,
            "T": rec.temperature,
            "channel_norm": rec.channel_norm,
            "rhs_norm": rec.rhs_norm,
            "leading_channel": rec.leading_channel_name,
            "leading_order": rec.leading_order_label,
            "leading_abs_eval": rec.leading_eigenvalue_abs,
            "instability": rec.instability,
            "reason": rec.instability_reason,
        })
    return rows


def pretty_print_final_record(history):
    rec = history[-1]
    print("===== Final record =====")
    pprint(rec.summary_dict())
    return rec


def plot_history(history, title):
    steps = [h.step_index for h in history]
    Ts = [h.temperature for h in history]
    evals = [np.nan if h.leading_eigenvalue_abs is None else h.leading_eigenvalue_abs for h in history]
    norms = [h.channel_norm for h in history]

    fig, axes = plt.subplots(1, 2, figsize=(11, 4))
    axes[0].plot(steps, evals, marker="o")
    axes[0].set_xlabel("step")
    axes[0].set_ylabel("leading |eigenvalue|")
    axes[0].set_title(f"{title}: leading eigenvalue")

    axes[1].plot(steps, norms, marker="o")
    axes[1].set_xlabel("step")
    axes[1].set_ylabel("channel norm")
    axes[1].set_title(f"{title}: channel norm")

    plt.tight_layout()
    plt.show()


def run_case(case_name, U, V, flow_kwargs=None):
    print(f"\n===== Running case: {case_name} (U={U}, V={V}) =====")
    interaction, bare_gamma, solver = build_solver(
        model=model,
        patchsets=patchsets,
        U=U,
        V=V,
        flow_kwargs=flow_kwargs if flow_kwargs is not None else FLOW_KWARGS,
    )
    history = solver.run()
    print(f"history length = {len(history)}")
    print(f"instability record = {None if solver.instability_record is None else solver.instability_record.step_index}")
    final_rec = pretty_print_final_record(history)
    plot_history(history, case_name)
    return {
        "case_name": case_name,
        "U": U,
        "V": V,
        "interaction": interaction,
        "solver": solver,
        "history": history,
        "final_record": final_rec,
    }

# %% [markdown]
# ## 4. FM benchmark: `U=6, V=0`
#
# Expectation from the PRL benchmark at van Hove filling:
# - dominant onsite interaction should favor **ferromagnetism (FM)**.

# %%
fm_result = run_case("FM benchmark", U=6.0, V=.0, flow_kwargs=FLOW_KWARGS)
# Out:
# ===== Running case: FM benchmark (U=6.0, V=0.0) =====
# [DEBUG] entering step: T_old=4.00000000, dT=-6.59358785e-02
# [DEBUG] leaving step: T_new=3.93406412, rhs_norm=2.206511110115681, channel_norm=0.14548824839562838, accepted_substeps=1, max_rel_update=0.024248041399271395
# [DEBUG] entering step: T_old=3.93406412, dT=-6.48489935e-02
# [DEBUG] leaving step: T_new=3.86921513, rhs_norm=2.281094265451428, channel_norm=0.29341491547698273, accepted_substeps=1, max_rel_update=0.024654444513559064
# [DEBUG] entering step: T_old=3.86921513, dT=-6.37800246e-02
# [DEBUG] leaving step: T_new=3.80543510, rhs_norm=2.358198435539529, channel_norm=0.44382086973861745, accepted_substeps=1, max_rel_update=0.02506765904360579
# [DEBUG] entering step: T_old=3.80543510, dT=-6.27286766e-02
# [DEBUG] leaving step: T_new=3.74270643, rhs_norm=2.4379088341974087, channel_norm=0.5967476646410584, accepted_substeps=1, max_rel_update=0.025487799150406835
# [DEBUG] entering step: T_old=3.74270643, dT=-6.16946590e-02
# [DEBUG] leaving step: T_new=3.68101177, rhs_norm=2.520313555588456, channel_norm=0.7522375500910216, accepted_substeps=1, max_rel_update=0.025914980908327192
# [DEBUG] entering step: T_old=3.68101177, dT=-6.06776861e-02
# [DEBUG] leaving step: T_new=3.62033408, rhs_norm=2.605503671581748, channel_norm=0.9103334841140044, accepted_substeps=1, max_rel_update=0.02634932233716381
# [DEBUG] entering step: T_old=3.62033408, dT=-5.96774770e-02
# [DEBUG] leaving step: T_new=3.56065660, rhs_norm=2.6935733324026496, channel_norm=1.0710791447225383, accepted_substeps=1, max_rel_update=0.026790943434755642
# [DEBUG] entering step: T_old=3.56065660, dT=-5.86937553e-02
# [DEBUG] leaving step: T_new=3.50196285, rhs_norm=2.784619870685563, channel_norm=1.2345189419833404, accepted_substeps=1, max_rel_update=0.027239966210133682
# [DEBUG] entering step: T_old=3.50196285, dT=-5.77262492e-02
# [DEBUG] leaving step: T_new=3.44423660, rhs_norm=2.87874390904377, channel_norm=1.4006980302867296, accepted_substeps=1, max_rel_update=0.027696514717231512
# [DEBUG] entering step: T_old=3.44423660, dT=-5.67746915e-02
# [DEBUG] leaving step: T_new=3.38746191, rhs_norm=2.976049471275358, channel_norm=1.569662320821669, accepted_substeps=1, max_rel_update=0.02816071508915655
# [DEBUG] entering step: T_old=3.38746191, dT=-5.58388192e-02
# [DEBUG] leaving step: T_new=3.33162309, rhs_norm=3.0766440973279594, channel_norm=1.7414584942598994, accepted_substeps=1, max_rel_update=0.028632695573038405
# [DEBUG] entering step: T_old=3.33162309, dT=-5.49183738e-02
# [DEBUG] leaving step: T_new=3.27670472, rhs_norm=3.1806389621495517, channel_norm=1.9161340136526441, accepted_substeps=1, max_rel_update=0.02911258656545744
# [DEBUG] entering step: T_old=3.27670472, dT=-5.40131010e-02
# [DEBUG] leaving step: T_new=3.22269161, rhs_norm=3.2881489985565224, channel_norm=2.093737137543506, accepted_substeps=1, max_rel_update=0.029600520648476954
# [DEBUG] entering step: T_old=3.22269161, dT=-5.31227507e-02
# [DEBUG] leaving step: T_new=3.16956886, rhs_norm=3.3992930242548827, channel_norm=2.2743169333010953, accepted_substeps=1, max_rel_update=0.030096632626264917
# [DEBUG] entering step: T_old=3.16956886, dT=-5.22470769e-02
# [DEBUG] leaving step: T_new=3.11732179, rhs_norm=3.5141938731549534, channel_norm=2.457923290675144, accepted_substeps=1, max_rel_update=0.030601059562341475
# [DEBUG] entering step: T_old=3.11732179, dT=-5.13858376e-02
# [DEBUG] leaving step: T_new=3.06593595, rhs_norm=3.632978531124659, channel_norm=2.644606935579806, accepted_substeps=1, max_rel_update=0.03111394081744369
# [DEBUG] entering step: T_old=3.06593595, dT=-5.05387950e-02
# [DEBUG] leaving step: T_new=3.01539715, rhs_norm=3.7557782763315153, channel_norm=2.8344194441079895, accepted_substeps=1, max_rel_update=0.03163541808803057
# [DEBUG] entering step: T_old=3.01539715, dT=-4.97057151e-02
# [DEBUG] leaving step: T_new=2.96569144, rhs_norm=3.8827288243283378, channel_norm=3.0274132567805516, accepted_substeps=1, max_rel_update=0.032165635445427054
# [DEBUG] entering step: T_old=2.96569144, dT=-4.88863676e-02
# [DEBUG] leaving step: T_new=2.91680507, rhs_norm=4.013970478043044, channel_norm=3.2236416930343315, accepted_substeps=1, max_rel_update=0.03270473937562999
# [DEBUG] entering step: T_old=2.91680507, dT=-4.80805262e-02
# [DEBUG] leaving step: T_new=2.86872455, rhs_norm=4.149648282838368, channel_norm=3.4231589659529873, accepted_substeps=1, max_rel_update=0.03325287881977599
# [DEBUG] entering step: T_old=2.86872455, dT=-4.72879683e-02
# [DEBUG] leaving step: T_new=2.82143658, rhs_norm=4.28991218681274, channel_norm=3.6260201972447366, accepted_substeps=1, max_rel_update=0.033810205215291544
# [DEBUG] entering step: T_old=2.82143658, dT=-4.65084748e-02
# [DEBUG] leaving step: T_new=2.77492810, rhs_norm=4.434917206519618, channel_norm=3.8322814324711425, accepted_substeps=1, max_rel_update=0.03437687253773435
# [DEBUG] entering step: T_old=2.77492810, dT=-4.57418305e-02
# [DEBUG] leaving step: T_new=2.72918627, rhs_norm=4.584823598288331, channel_norm=4.041999656531103, accepted_substeps=1, max_rel_update=0.03495303734332673
# [DEBUG] entering step: T_old=2.72918627, dT=-4.49878236e-02
# [DEBUG] leaving step: T_new=2.68419845, rhs_norm=4.739797035335844, channel_norm=4.255232809404379, accepted_substeps=1, max_rel_update=0.035538858812212706
# [DEBUG] entering step: T_old=2.68419845, dT=-4.42462457e-02
# [DEBUG] leaving step: T_new=2.63995220, rhs_norm=4.900008790865062, channel_norm=4.472039802158997, accepted_substeps=1, max_rel_update=0.03613449879243618
# [DEBUG] entering step: T_old=2.63995220, dT=-4.35168919e-02
# [DEBUG] leaving step: T_new=2.59643531, rhs_norm=5.065635927352248, channel_norm=4.692480533226904, accepted_substeps=1, max_rel_update=0.0367401218446513
# [DEBUG] entering step: T_old=2.59643531, dT=-4.27995608e-02
# [DEBUG] leaving step: T_new=2.55363575, rhs_norm=5.23686149223247, channel_norm=4.916615904952448, accepted_substeps=1, max_rel_update=0.037355895287590646
# [DEBUG] entering step: T_old=2.55363575, dT=-4.20940541e-02
# [DEBUG] leaving step: T_new=2.51154170, rhs_norm=5.41387472019962, channel_norm=5.14450784041819, accepted_substeps=1, max_rel_update=0.03798198924429034
# [DEBUG] entering step: T_old=2.51154170, dT=-4.14001770e-02
# [DEBUG] leaving step: T_new=2.47014152, rhs_norm=5.596871242344371, channel_norm=5.376219300552721, accepted_substeps=1, max_rel_update=0.03861857668908858
# [DEBUG] entering step: T_old=2.47014152, dT=-4.07177377e-02
# [DEBUG] leaving step: T_new=2.42942378, rhs_norm=5.786053302361312, channel_norm=5.611814301525218, accepted_substeps=1, max_rel_update=0.039265833495416146
# [DEBUG] entering step: T_old=2.42942378, dT=-4.00465478e-02
# [DEBUG] leaving step: T_new=2.38937723, rhs_norm=5.981629980064193, channel_norm=5.851357932431541, accepted_substeps=1, max_rel_update=0.039923938484387134
# [DEBUG] entering step: T_old=2.38937723, dT=-3.93864217e-02
# [DEBUG] leaving step: T_new=2.34999081, rhs_norm=6.183817422456315, channel_norm=6.094916373276742, accepted_substeps=1, max_rel_update=0.04059307347420023
# [DEBUG] entering step: T_old=2.34999081, dT=-3.87371771e-02
# [DEBUG] leaving step: T_new=2.31125363, rhs_norm=6.392839082611372, channel_norm=6.342556913258967, accepted_substeps=1, max_rel_update=0.040630670679586166
# [DEBUG] entering step: T_old=2.31125363, dT=-3.80986347e-02
# [DEBUG] leaving step: T_new=2.27315500, rhs_norm=6.608925966628849, channel_norm=6.594347969359812, accepted_substeps=1, max_rel_update=0.039698667200680784
# [DEBUG] entering step: T_old=2.27315500, dT=-3.74706180e-02
# [DEBUG] leaving step: T_new=2.23568438, rhs_norm=6.832316888936827, channel_norm=6.8503591052462465, accepted_substeps=1, max_rel_update=0.03882281266866304
# [DEBUG] entering step: T_old=2.23568438, dT=-3.68529534e-02
# [DEBUG] leaving step: T_new=2.19883143, rhs_norm=7.0632587362243715, channel_norm=7.110661050489335, accepted_substeps=1, max_rel_update=0.03799829194994166
# [DEBUG] entering step: T_old=2.19883143, dT=-3.62454705e-02
# [DEBUG] leaving step: T_new=2.16258596, rhs_norm=7.302006740295269, channel_norm=7.375325720105085, accepted_substeps=1, max_rel_update=0.03722082486234339
# [DEBUG] entering step: T_old=2.16258596, dT=-3.56480012e-02
# [DEBUG] leaving step: T_new=2.12693796, rhs_norm=7.548824760144519, channel_norm=7.64442623442279, accepted_substeps=1, max_rel_update=0.03648659388481499
# [DEBUG] entering step: T_old=2.12693796, dT=-3.50603807e-02
# [DEBUG] leaving step: T_new=2.09187758, rhs_norm=7.803985573569417, channel_norm=7.918036939286376, accepted_substeps=1, max_rel_update=0.035792183281397806
# [DEBUG] entering step: T_old=2.09187758, dT=-3.44824464e-02
# [DEBUG] leaving step: T_new=2.05739513, rhs_norm=8.067771178637566, channel_norm=8.196233426594326, accepted_substeps=1, max_rel_update=0.035134527590752
# [DEBUG] entering step: T_old=2.05739513, dT=-3.39140388e-02
# [DEBUG] leaving step: T_new=2.02348109, rhs_norm=8.340473105344856, channel_norm=8.47909255518386, accepted_substeps=1, max_rel_update=0.034510867842262746
# [DEBUG] entering step: T_old=2.02348109, dT=-3.33550008e-02
# [DEBUG] leaving step: T_new=1.99012609, rhs_norm=8.622392737807953, channel_norm=8.766692472065143, accepted_substeps=1, max_rel_update=0.03391871417955621
# [DEBUG] entering step: T_old=1.99012609, dT=-3.28051780e-02
# [DEBUG] leaving step: T_new=1.95732091, rhs_norm=8.913841647347331, channel_norm=9.059112634011369, accepted_substeps=1, max_rel_update=0.03335581382351615
# [DEBUG] entering step: T_old=1.95732091, dT=-3.22644184e-02
# [DEBUG] leaving step: T_new=1.92505649, rhs_norm=9.215141936829005, channel_norm=9.356433829510724, accepted_substeps=1, max_rel_update=0.03282012350559574
# [DEBUG] entering step: T_old=1.92505649, dT=-3.17325728e-02
# [DEBUG] leaving step: T_new=1.89332392, rhs_norm=9.52662659664539, channel_norm=9.658738201086237, accepted_substeps=1, max_rel_update=0.032309785660218984
# [DEBUG] entering step: T_old=1.89332392, dT=-3.12094940e-02
# [DEBUG] leaving step: T_new=1.86211443, rhs_norm=9.848639872729006, channel_norm=9.966109267989765, accepted_substeps=1, max_rel_update=0.03182310779154985
# [DEBUG] entering step: T_old=1.86211443, dT=-3.06950376e-02
# [DEBUG] leaving step: T_new=1.83141939, rhs_norm=10.181537647005374, channel_norm=10.278631949276264, accepted_substeps=1, max_rel_update=0.03135854453154487
# [DEBUG] entering step: T_old=1.83141939, dT=-3.01890616e-02
# [DEBUG] leaving step: T_new=1.80123033, rhs_norm=10.525687830705797, channel_norm=10.596392587264875, accepted_substeps=1, max_rel_update=0.030914681988490265
# [DEBUG] entering step: T_old=1.80123033, dT=-2.96914260e-02
# [DEBUG] leaving step: T_new=1.77153890, rhs_norm=10.881470770974774, channel_norm=10.91947897139315, accepted_substeps=1, max_rel_update=0.03049022405196402
# [DEBUG] entering step: T_old=1.77153890, dT=-2.92019934e-02
# [DEBUG] leaving step: T_new=1.74233691, rhs_norm=11.249279671221132, channel_norm=11.247980362471125, accepted_substeps=1, max_rel_update=0.03008398037475805
# [DEBUG] entering step: T_old=1.74233691, dT=-2.87206287e-02
# [DEBUG] leaving step: T_new=1.71361628, rhs_norm=11.62952102567773, channel_norm=11.58198751734188, accepted_substeps=1, max_rel_update=0.029694855796972137
# [DEBUG] entering step: T_old=1.71361628, dT=-2.82471987e-02
# [DEBUG] leaving step: T_new=1.68536908, rhs_norm=12.022615068649946, channel_norm=11.921592713955413, accepted_substeps=1, max_rel_update=0.029321841014336835
# [DEBUG] entering step: T_old=1.68536908, dT=-2.77815727e-02
# [DEBUG] leaving step: T_new=1.65758751, rhs_norm=12.428996238949134, channel_norm=12.266889776862783, accepted_substeps=1, max_rel_update=0.028964004323278572
# [DEBUG] entering step: T_old=1.65758751, dT=-2.73236221e-02
# [DEBUG] leaving step: T_new=1.63026389, rhs_norm=12.849113660024969, channel_norm=12.617974103137499, accepted_substeps=1, max_rel_update=0.028620484300504123
# [DEBUG] entering step: T_old=1.63026389, dT=-2.68732204e-02
# [DEBUG] leaving step: T_new=1.60339067, rhs_norm=13.28343163632652, channel_norm=12.9749426887314, accepted_substeps=1, max_rel_update=0.02829048329597852
# [DEBUG] entering step: T_old=1.60339067, dT=-2.64302430e-02
# [DEBUG] leaving step: T_new=1.57696042, rhs_norm=13.732430166441311, channel_norm=13.337894155272235, accepted_substeps=1, max_rel_update=0.027973261635756926
# [DEBUG] entering step: T_old=1.57696042, dT=-2.59945677e-02
# [DEBUG] leaving step: T_new=1.55096586, rhs_norm=14.196605473579147, channel_norm=13.706928777310402, accepted_substeps=1, max_rel_update=0.02766813244595247
# [DEBUG] entering step: T_old=1.55096586, dT=-2.55660740e-02
# [DEBUG] leaving step: T_new=1.52539978, rhs_norm=14.676470553986908, channel_norm=14.08214851002232, accepted_substeps=1, max_rel_update=0.027374457021548986
# [DEBUG] entering step: T_old=1.52539978, dT=-2.51446436e-02
# [DEBUG] leaving step: T_new=1.50025514, rhs_norm=15.172555743900647, channel_norm=14.463657017378154, accepted_substeps=1, max_rel_update=0.02709164067431279
# [DEBUG] entering step: T_old=1.50025514, dT=-2.47301601e-02
# [DEBUG] leaving step: T_new=1.47552498, rhs_norm=15.685409305661448, channel_norm=14.851559700781593, accepted_substeps=1, max_rel_update=0.026819129002946675
# [DEBUG] entering step: T_old=1.47552498, dT=-2.43225089e-02
# [DEBUG] leaving step: T_new=1.45120247, rhs_norm=16.215598033642777, channel_norm=15.245963728189684, accepted_substeps=1, max_rel_update=0.02655640453624109
# [DEBUG] entering step: T_old=1.45120247, dT=-2.39215774e-02
# [DEBUG] leaving step: T_new=1.42728089, rhs_norm=16.763707880659066, channel_norm=15.646978063720683, accepted_substeps=1, max_rel_update=0.02630298370640387
# [DEBUG] entering step: T_old=1.42728089, dT=-2.35272548e-02
# [DEBUG] leaving step: T_new=1.40375364, rhs_norm=17.33034460554764, channel_norm=16.05471349775817, accepted_substeps=1, max_rel_update=0.02605841411530239
# [DEBUG] entering step: T_old=1.40375364, dT=-2.31394323e-02
# [DEBUG] leaving step: T_new=1.38061420, rhs_norm=17.916134442640203, channel_norm=16.469282677559676, accepted_substeps=1, max_rel_update=0.02582227206106157
# [DEBUG] entering step: T_old=1.38061420, dT=-2.27580026e-02
# [DEBUG] leaving step: T_new=1.35785620, rhs_norm=18.52172479386284, channel_norm=16.89080013837839, accepted_substeps=1, max_rel_update=0.025594160296553464
# [DEBUG] entering step: T_old=1.35785620, dT=-2.23828604e-02
# [DEBUG] leaving step: T_new=1.33547334, rhs_norm=19.14778494423035, channel_norm=17.319382335106397, accepted_substeps=1, max_rel_update=0.025373705994792092
# [DEBUG] entering step: T_old=1.33547334, dT=-2.20139020e-02
# [DEBUG] leaving step: T_new=1.31345944, rhs_norm=19.79500680152531, channel_norm=17.75514767444829, accepted_substeps=1, max_rel_update=0.025160558899297206
# [DEBUG] entering step: T_old=1.31345944, dT=-2.16510255e-02
# [DEBUG] leaving step: T_new=1.29180841, rhs_norm=20.464105660978998, channel_norm=18.198216547634058, accepted_substeps=1, max_rel_update=0.024954389640103967
# [DEBUG] entering step: T_old=1.29180841, dT=-2.12941306e-02
# [DEBUG] leaving step: T_new=1.27051428, rhs_norm=21.155820995800013, channel_norm=18.64871136368018, accepted_substeps=1, max_rel_update=0.024754888198354395
# [DEBUG] entering step: T_old=1.27051428, dT=-2.09431188e-02
# [DEBUG] leaving step: T_new=1.24957116, rhs_norm=21.870917274423437, channel_norm=19.106756583208252, accepted_substeps=1, max_rel_update=0.024561762504413578
# [DEBUG] entering step: T_old=1.24957116, dT=-2.05978931e-02
# [DEBUG] leaving step: T_new=1.22897327, rhs_norm=22.610184805384613, channel_norm=19.57247875283039, accepted_substeps=1, max_rel_update=0.024374737156144546
# [DEBUG] entering step: T_old=1.22897327, dT=-2.02583581e-02
# [DEBUG] leaving step: T_new=1.20871491, rhs_norm=23.37444061075037, channel_norm=20.046006540110895, accepted_substeps=1, max_rel_update=0.024193552245498195
# [DEBUG] entering step: T_old=1.20871491, dT=-1.99244199e-02
# [DEBUG] leaving step: T_new=1.18879049, rhs_norm=24.164529329073815, channel_norm=20.527470769114004, accepted_substeps=1, max_rel_update=0.024017962282898025
# [DEBUG] entering step: T_old=1.18879049, dT=-1.95959864e-02
# [DEBUG] leaving step: T_new=1.16919451, rhs_norm=24.98132414887017, channel_norm=21.017004456547294, accepted_substeps=1, max_rel_update=0.023847735210021738
# [DEBUG] entering step: T_old=1.16919451, dT=-1.92729667e-02
# [DEBUG] leaving step: T_new=1.14992154, rhs_norm=25.825727773645063, channel_norm=21.514742848510984, accepted_substeps=1, max_rel_update=0.023682651492640865
# [DEBUG] entering step: T_old=1.14992154, dT=-1.89552717e-02
# [DEBUG] leaving step: T_new=1.13096627, rhs_norm=26.69867341954283, channel_norm=22.020823457863024, accepted_substeps=1, max_rel_update=0.023522503286023053
# [DEBUG] entering step: T_old=1.13096627, dT=-1.86428136e-02
# [DEBUG] leaving step: T_new=1.11232345, rhs_norm=27.601125846715842, channel_norm=22.53538610221057, accepted_substeps=1, max_rel_update=0.02336709366623665
# [DEBUG] entering step: T_old=1.11232345, dT=-1.83355060e-02
# [DEBUG] leaving step: T_new=1.09398795, rhs_norm=28.534082425556363, channel_norm=23.058572942538138, accepted_substeps=1, max_rel_update=0.023216235921347205
# [DEBUG] entering step: T_old=1.09398795, dT=-1.80332641e-02
# [DEBUG] leaving step: T_new=1.07595468, rhs_norm=29.49857423896793, channel_norm=23.59052852248316, accepted_substeps=1, max_rel_update=0.023069752897139636
# [DEBUG] entering step: T_old=1.07595468, dT=-1.77360043e-02
# [DEBUG] leaving step: T_new=1.05821868, rhs_norm=30.49566722189549, channel_norm=24.131399808269848, accepted_substeps=1, max_rel_update=0.022927476392536193
# [DEBUG] entering step: T_old=1.05821868, dT=-1.74436446e-02
# [DEBUG] leaving step: T_new=1.04077504, rhs_norm=31.52646333937281, channel_norm=24.681336229312322, accepted_substeps=1, max_rel_update=0.02278924660035724
# [DEBUG] entering step: T_old=1.04077504, dT=-1.71561041e-02
# [DEBUG] leaving step: T_new=1.02361893, rhs_norm=32.59210180439008, channel_norm=25.240489719498306, accepted_substeps=1, max_rel_update=0.022654911589507755
# [DEBUG] entering step: T_old=1.02361893, dT=-1.68733034e-02
# [DEBUG] leaving step: T_new=1.00674563, rhs_norm=33.69376033692647, channel_norm=25.809014759164704, accepted_substeps=1, max_rel_update=0.02252432682505409
# [DEBUG] entering step: T_old=1.00674563, dT=-1.65951643e-02
# [DEBUG] leaving step: T_new=0.99015046, rhs_norm=34.8326564655404, channel_norm=26.387068417776717, accepted_substeps=1, max_rel_update=0.022397354722994558
# [DEBUG] entering step: T_old=0.99015046, dT=-1.63216102e-02
# [DEBUG] leaving step: T_new=0.97382885, rhs_norm=36.01004887295498, channel_norm=26.974810397322234, accepted_substeps=1, max_rel_update=0.02227386423683046
# [DEBUG] entering step: T_old=0.97382885, dT=-1.60525652e-02
# [DEBUG] leaving step: T_new=0.95777629, rhs_norm=37.22723878712616, channel_norm=27.572403076433616, accepted_substeps=1, max_rel_update=0.022153730473327346
# [DEBUG] entering step: T_old=0.95777629, dT=-1.57879552e-02
# [DEBUG] leaving step: T_new=0.94198833, rhs_norm=38.48557141933102, channel_norm=28.18001155524887, accepted_substeps=1, max_rel_update=0.02203683433507405
# [DEBUG] entering step: T_old=0.94198833, dT=-1.55277071e-02
# [DEBUG] leaving step: T_new=0.92646063, rhs_norm=39.7864374508655, channel_norm=28.797803701024783, accepted_substeps=1, max_rel_update=0.02192306218770308
# [DEBUG] entering step: T_old=0.92646063, dT=-1.52717488e-02
# [DEBUG] leaving step: T_new=0.91118888, rhs_norm=41.13127456999446, channel_norm=29.425950194514442, accepted_substeps=1, max_rel_update=0.021812305549791213
# [DEBUG] entering step: T_old=0.91118888, dT=-1.50200098e-02
# [DEBUG] leaving step: T_new=0.89616887, rhs_norm=42.521569060852585, channel_norm=30.064624577122224, accepted_substeps=1, max_rel_update=0.02170446080367665
# [DEBUG] entering step: T_old=0.89616887, dT=-1.47724204e-02
# [DEBUG] leaving step: T_new=0.88139645, rhs_norm=43.958857446053116, channel_norm=30.714003298848926, accepted_substeps=1, max_rel_update=0.021599428925543607
# [DEBUG] entering step: T_old=0.88139645, dT=-1.45289123e-02
# [DEBUG] leaving step: T_new=0.86686753, rhs_norm=45.44472818481812, channel_norm=31.37426576704061, accepted_substeps=1, max_rel_update=0.02149711523331219
# [DEBUG] entering step: T_old=0.86686753, dT=-1.42894181e-02
# [DEBUG] leaving step: T_new=0.85257812, rhs_norm=46.98082342850877, channel_norm=32.04559439595438, accepted_substeps=1, max_rel_update=0.021397429150964157
# [DEBUG] entering step: T_old=0.85257812, dT=-1.40538718e-02
# [DEBUG] leaving step: T_new=0.83852424, rhs_norm=48.568840835493894, channel_norm=32.72817465715501, accepted_substeps=1, max_rel_update=0.021300283988079097
# [DEBUG] entering step: T_old=0.83852424, dT=-1.38222082e-02
# [DEBUG] leaving step: T_new=0.82470204, rhs_norm=50.210535447365054, channel_norm=33.42219513075611, accepted_substeps=1, max_rel_update=0.021205596733436326
# [DEBUG] entering step: T_old=0.82470204, dT=-1.35943633e-02
# [DEBUG] leaving step: T_new=0.81110767, rhs_norm=51.9077216285693, channel_norm=34.127847557520205, accepted_substeps=1, max_rel_update=0.021113287861656227
# [DEBUG] entering step: T_old=0.81110767, dT=-1.33702742e-02
# [DEBUG] leaving step: T_new=0.79773740, rhs_norm=53.662275071604185, channel_norm=34.845326891831995, accepted_substeps=1, max_rel_update=0.02102328115192525
# [DEBUG] entering step: T_old=0.79773740, dT=-1.31498791e-02
# [DEBUG] leaving step: T_new=0.78458752, rhs_norm=55.476134869992066, channel_norm=35.57483135555939, accepted_substeps=1, max_rel_update=0.02093550351793067
# [DEBUG] entering step: T_old=0.78458752, dT=-1.29331168e-02
# [DEBUG] leaving step: T_new=0.77165440, rhs_norm=57.35130566132268, channel_norm=36.31656249281739, accepted_substeps=1, max_rel_update=0.0208498848482128
# [DEBUG] entering step: T_old=0.77165440, dT=-1.27199277e-02
# [DEBUG] leaving step: T_new=0.75893448, rhs_norm=59.28985984273452, channel_norm=37.07072522564973, accepted_substeps=1, max_rel_update=0.02076635785618478
# [DEBUG] entering step: T_old=0.75893448, dT=-1.25102528e-02
# [DEBUG] leaving step: T_new=0.74642422, rhs_norm=61.293939861281714, channel_norm=37.83752791064383, accepted_substeps=1, max_rel_update=0.020684857939157267
# [DEBUG] entering step: T_old=0.74642422, dT=-1.23040342e-02
# [DEBUG] leaving step: T_new=0.73412019, rhs_norm=63.365760581719556, channel_norm=38.617182396494506, accepted_substeps=1, max_rel_update=0.020605323045730966
# [DEBUG] entering step: T_old=0.73412019, dT=-1.21012149e-02
# [DEBUG] leaving step: T_new=0.72201897, rhs_norm=65.50761173432322, channel_norm=39.409904082532634, accepted_substeps=1, max_rel_update=0.020527693550995273
# [DEBUG] entering step: T_old=0.72201897, dT=-1.19017388e-02
# [DEBUG] leaving step: T_new=0.71011723, rhs_norm=67.72186044544736, channel_norm=40.21591197823465, accepted_substeps=1, max_rel_update=0.020451912138990936
# [DEBUG] entering step: T_old=0.71011723, dT=-1.17055509e-02
# [DEBUG] leaving step: T_new=0.69841168, rhs_norm=70.01095385362137, channel_norm=41.03542876372946, accepted_substeps=1, max_rel_update=0.020377923691954212
# [DEBUG] entering step: T_old=0.69841168, dT=-1.15125970e-02
# [DEBUG] leaving step: T_new=0.68689909, rhs_norm=72.37742181407269, channel_norm=41.86868085131947, accepted_substeps=1, max_rel_update=0.020305675185889608
# [DEBUG] entering step: T_old=0.68689909, dT=-1.13228237e-02
# [DEBUG] leaving step: T_new=0.67557626, rhs_norm=74.82387969466625, channel_norm=42.71589844803275, accepted_substeps=1, max_rel_update=0.02023511559205448
# [DEBUG] entering step: T_old=0.67557626, dT=-1.11361786e-02
# [DEBUG] leaving step: T_new=0.66444008, rhs_norm=77.35303126635176, channel_norm=43.57731561922359, accepted_substeps=1, max_rel_update=0.020166195783961324
# [DEBUG] entering step: T_old=0.66444008, dT=-1.09526102e-02
# [DEBUG] leaving step: T_new=0.65348747, rhs_norm=79.9676716913105, channel_norm=44.45317035323892, accepted_substeps=1, max_rel_update=0.02009886844955081
# [DEBUG] entering step: T_old=0.65348747, dT=-1.07720677e-02
# [DEBUG] leaving step: T_new=0.64271541, rhs_norm=82.67069061210735, channel_norm=45.34370462716868, accepted_substeps=1, max_rel_update=0.020033088008195886
# [DEBUG] entering step: T_old=0.64271541, dT=-1.05945012e-02
# [DEBUG] leaving step: T_new=0.63212091, rhs_norm=85.4650753452588, channel_norm=46.24916447369811, accepted_substeps=1, max_rel_update=0.019968810532232262
# [DEBUG] entering step: T_old=0.63212091, dT=-1.04198618e-02
# [DEBUG] leaving step: T_new=0.62170104, rhs_norm=88.35391418274943, channel_norm=47.16980004908056, accepted_substeps=1, max_rel_update=0.019905993672729175
# [DEBUG] entering step: T_old=0.62170104, dT=-1.02481011e-02
# [DEBUG] leaving step: T_new=0.61145294, rhs_norm=91.34039980514343, channel_norm=48.10586570224944, accepted_substeps=1, max_rel_update=0.019844596589235004
# [DEBUG] entering step: T_old=0.61145294, dT=-1.00791717e-02
# [DEBUG] leaving step: T_new=0.60137377, rhs_norm=94.42783281006453, channel_norm=49.057620045088626, accepted_substeps=1, max_rel_update=0.01978457988325284
# [DEBUG] entering step: T_old=0.60137377, dT=-9.91302697e-03
# [DEBUG] leaving step: T_new=0.59146074, rhs_norm=97.61962535994292, channel_norm=50.025326023880474, accepted_substeps=1, max_rel_update=0.019725905535214118
# [DEBUG] entering step: T_old=0.59146074, dT=-9.74962093e-03
# [DEBUG] leaving step: T_new=0.58171112, rhs_norm=100.91930495306137, channel_norm=51.00925099195148, accepted_substeps=1, max_rel_update=0.019668536844743723
# [DEBUG] entering step: T_old=0.58171112, dT=-9.58890848e-03
# [DEBUG] leaving step: T_new=0.57212221, rhs_norm=104.33051832206867, channel_norm=52.00966678353542, accepted_substeps=1, max_rel_update=0.019612438374007727
# [DEBUG] entering step: T_old=0.57212221, dT=-9.43084520e-03
# [DEBUG] leaving step: T_new=0.56269137, rhs_norm=107.85703546426697, channel_norm=53.02684978887441, accepted_substeps=1, max_rel_update=0.019557575893968077
# [DEBUG] entering step: T_old=0.56269137, dT=-9.27538744e-03
# [DEBUG] leaving step: T_new=0.55341598, rhs_norm=111.5027538081293, channel_norm=54.06108103057866, accepted_substeps=1, max_rel_update=0.01950391633336756
# [DEBUG] entering step: T_old=0.55341598, dT=-9.12249223e-03
# [DEBUG] leaving step: T_new=0.54429349, rhs_norm=115.27170252065088, channel_norm=55.112646241266276, accepted_substeps=1, max_rel_update=0.019451427730289256
# [DEBUG] entering step: T_old=0.54429349, dT=-8.97211735e-03
# [DEBUG] leaving step: T_new=0.53532137, rhs_norm=119.1680469602957, channel_norm=56.181835942504, accepted_substeps=1, max_rel_update=0.019400079186129817
# [DEBUG] entering step: T_old=0.53532137, dT=-8.82422124e-03
# [DEBUG] leaving step: T_new=0.52649715, rhs_norm=123.19609328045722, channel_norm=57.2689455250712, accepted_substeps=1, max_rel_update=0.019349840821858186
# [DEBUG] entering step: T_old=0.52649715, dT=-8.67876304e-03
# [DEBUG] leaving step: T_new=0.51781839, rhs_norm=127.36029318852468, channel_norm=58.37427533056909, accepted_substeps=1, max_rel_update=0.01930068373642388
# [DEBUG] entering step: T_old=0.51781839, dT=-8.53570258e-03
# [DEBUG] leaving step: T_new=0.50928269, rhs_norm=131.66524886581024, channel_norm=59.498130734397684, accepted_substeps=1, max_rel_update=0.01925257996719073
# [DEBUG] entering step: T_old=0.50928269, dT=-8.39500031e-03
# [DEBUG] leaving step: T_new=0.50088769, rhs_norm=136.11571805377773, channel_norm=60.64082223012351, accepted_substeps=1, max_rel_update=0.01920550245228468
# [DEBUG] entering step: T_old=0.50088769, dT=-8.25661738e-03
# [DEBUG] leaving step: T_new=0.49263107, rhs_norm=140.71661931219506, channel_norm=61.802665515261396, accepted_substeps=1, max_rel_update=0.019159424994747733
# [DEBUG] entering step: T_old=0.49263107, dT=-8.12051555e-03
# [DEBUG] leaving step: T_new=0.48451055, rhs_norm=145.47303745501225, channel_norm=62.98398157849376, accepted_substeps=1, max_rel_update=0.019114322228394095
# [DEBUG] entering step: T_old=0.48451055, dT=-7.98665722e-03
# [DEBUG] leaving step: T_new=0.47652389, rhs_norm=150.3902291699918, channel_norm=64.18509678835204, accepted_substeps=1, max_rel_update=0.019070169585284017
# [DEBUG] entering step: T_old=0.47652389, dT=-7.85500541e-03
# [DEBUG] leaving step: T_new=0.46866889, rhs_norm=155.47362882827622, channel_norm=65.4063429833842, accepted_substeps=1, max_rel_update=0.019026943264714304
# [DEBUG] entering step: T_old=0.46866889, dT=-7.72552374e-03
# [DEBUG] leaving step: T_new=0.46094337, rhs_norm=160.7288544903413, channel_norm=66.6480575638336, accepted_substeps=1, max_rel_update=0.018984620203652665
# [DEBUG] entering step: T_old=0.46094337, dT=-7.59817644e-03
# [DEBUG] leaving step: T_new=0.45334519, rhs_norm=166.16171411494642, channel_norm=67.91058358485431, accepted_substeps=1, max_rel_update=0.01894317804853484
# [DEBUG] entering step: T_old=0.45334519, dT=-7.47292833e-03
# [DEBUG] leaving step: T_new=0.44587226, rhs_norm=171.77821197796382, channel_norm=69.19426985128877, accepted_substeps=1, max_rel_update=0.018902595128349717
# [DEBUG] entering step: T_old=0.44587226, dT=-7.34974480e-03
# [DEBUG] leaving step: T_new=0.43852252, rhs_norm=177.58455530817145, channel_norm=70.4994710140341, accepted_substeps=1, max_rel_update=0.018862850428950938
# [DEBUG] entering step: T_old=0.43852252, dT=-7.22859183e-03
# [DEBUG] leaving step: T_new=0.43129392, rhs_norm=183.58716114734355, channel_norm=71.82654766802332, accepted_substeps=1, max_rel_update=0.018823923568519422
# [DEBUG] entering step: T_old=0.43129392, dT=-7.10943595e-03
# [DEBUG] leaving step: T_new=0.42418449, rhs_norm=189.79266344222378, channel_norm=73.17586645184892, accepted_substeps=1, max_rel_update=0.018785794774127833
# [DEBUG] entering step: T_old=0.42418449, dT=-6.99224422e-03
# [DEBUG] leaving step: T_new=0.41719224, rhs_norm=196.2079203762142, channel_norm=74.5478001490559, accepted_substeps=1, max_rel_update=0.018748444859340845
# [DEBUG] entering step: T_old=0.41719224, dT=-6.87698428e-03
# [DEBUG] leaving step: T_new=0.41031526, rhs_norm=202.84002194888907, channel_norm=75.94272779113292, accepted_substeps=1, max_rel_update=0.01871185520280823
# [DEBUG] entering step: T_old=0.41031526, dT=-6.76362428e-03
# [DEBUG] leaving step: T_new=0.40355164, rhs_norm=209.69629781170462, channel_norm=77.3610347622292, accepted_substeps=1, max_rel_update=0.01867600772778496
# [DEBUG] entering step: T_old=0.40355164, dT=-6.65213290e-03
# [DEBUG] leaving step: T_new=0.39689950, rhs_norm=216.78432536856613, channel_norm=78.8031129056267, accepted_substeps=1, max_rel_update=0.0186408848825481
# [DEBUG] entering step: T_old=0.39689950, dT=-6.54247935e-03
# [DEBUG] leaving step: T_new=0.39035702, rhs_norm=224.11193815020823, channel_norm=80.26936063199678, accepted_substeps=1, max_rel_update=0.018606469621650967
# [DEBUG] entering step: T_old=0.39035702, dT=-6.43463331e-03
# [DEBUG] leaving step: T_new=0.38392239, rhs_norm=231.68723447163762, channel_norm=81.76018302947135, accepted_substeps=1, max_rel_update=0.018572745387986835
# [DEBUG] entering step: T_old=0.38392239, dT=-6.32856501e-03
# [DEBUG] leaving step: T_new=0.37759383, rhs_norm=239.51858638221174, channel_norm=83.27599197555851, accepted_substeps=1, max_rel_update=0.018539696095601636
# [DEBUG] entering step: T_old=0.37759383, dT=-6.22424514e-03
# [DEBUG] leaving step: T_new=0.37136958, rhs_norm=247.61464891824252, channel_norm=84.81720625093433, accepted_substeps=1, max_rel_update=0.018507306113245386
# [DEBUG] entering step: T_old=0.37136958, dT=-6.12164487e-03
# [DEBUG] leaving step: T_new=0.36524794, rhs_norm=255.98436966834916, channel_norm=86.38425165514177, accepted_substeps=1, max_rel_update=0.01847556024860436
# [DEBUG] entering step: T_old=0.36524794, dT=-6.02073587e-03
# [DEBUG] leaving step: T_new=0.35922720, rhs_norm=264.636998662135, channel_norm=87.97756112422817, accepted_substeps=1, max_rel_update=0.018444443733183286
# [DEBUG] entering step: T_old=0.35922720, dT=-5.92149024e-03
# [DEBUG] leaving step: T_new=0.35330571, rhs_norm=273.5820985931156, channel_norm=89.59757485035539, accepted_substeps=1, max_rel_update=0.018413942207828146
# [DEBUG] entering step: T_old=0.35330571, dT=-5.82388057e-03
# [DEBUG] leaving step: T_new=0.34748183, rhs_norm=282.8295553871944, channel_norm=91.24474040341352, accepted_substeps=1, max_rel_update=0.01838404170882085
# [DEBUG] entering step: T_old=0.34748183, dT=-5.72787990e-03
# [DEBUG] leaving step: T_new=0.34175395, rhs_norm=292.38958912836966, channel_norm=92.9195128546737, accepted_substeps=1, max_rel_update=0.018354728654557385
# [DEBUG] entering step: T_old=0.34175395, dT=-5.63346170e-03
# [DEBUG] leaving step: T_new=0.33612049, rhs_norm=302.2727653537424, channel_norm=94.62235490251321, accepted_substeps=1, max_rel_update=0.018325989832757305
# [DEBUG] entering step: T_old=0.33612049, dT=-5.54059989e-03
# [DEBUG] leaving step: T_new=0.33057989, rhs_norm=312.4900067303163, channel_norm=96.35373700024734, accepted_substeps=1, max_rel_update=0.018297812388181615
# [DEBUG] entering step: T_old=0.33057989, dT=-5.44926881e-03
# [DEBUG] leaving step: T_new=0.32513062, rhs_norm=323.0526051264849, channel_norm=98.11413748610417, accepted_substeps=1, max_rel_update=0.01827018381085013
# [DEBUG] entering step: T_old=0.32513062, dT=-5.35944323e-03
# [DEBUG] leaving step: T_new=0.31977117, rhs_norm=333.97223409155384, channel_norm=99.90404271537787, accepted_substeps=1, max_rel_update=0.018243091924720917
# [DEBUG] entering step: T_old=0.31977117, dT=-5.27109833e-03
# [DEBUG] leaving step: T_new=0.31450008, rhs_norm=345.26096175709074, channel_norm=101.72394719479625, accepted_substeps=1, max_rel_update=0.01821652487680816
# [DEBUG] entering step: T_old=0.31450008, dT=-5.18420971e-03
# [DEBUG] leaving step: T_new=0.30931587, rhs_norm=356.9312641743524, channel_norm=103.57435371914124, accepted_substeps=1, max_rel_update=0.0181904711267402
# [DEBUG] entering step: T_old=0.30931587, dT=-5.09875335e-03
# [DEBUG] leaving step: T_new=0.30421711, rhs_norm=368.9960391025442, channel_norm=105.45577351015834, accepted_substeps=1, max_rel_update=0.018164919436705992
# [DEBUG] entering step: T_old=0.30421711, dT=-5.01470566e-03
# [DEBUG] leaving step: T_new=0.29920241, rhs_norm=381.46862026313374, channel_norm=107.36872635779473, accepted_substeps=1, max_rel_update=0.018139858861801663
# [DEBUG] entering step: T_old=0.29920241, dT=-4.93204340e-03
# [DEBUG] leaving step: T_new=0.29427036, rhs_norm=394.3627920759856, channel_norm=109.31374076380465, accepted_substeps=1, max_rel_update=0.018115278740742168
# [DEBUG] entering step: T_old=0.29427036, dT=-4.85074375e-03
# [DEBUG] leaving step: T_new=0.28941962, rhs_norm=407.6928048935965, channel_norm=111.29135408776101, accepted_substeps=1, max_rel_update=0.01809116868692117
# [DEBUG] entering step: T_old=0.28941962, dT=-4.77078423e-03
# [DEBUG] leaving step: T_new=0.28464884, rhs_norm=421.47339075026673, channel_norm=113.3021126955148, accepted_substeps=1, max_rel_update=0.0180675185798185
# [DEBUG] entering step: T_old=0.28464884, dT=-4.69214277e-03
# [DEBUG] leaving step: T_new=0.27995669, rhs_norm=435.71977964361906, channel_norm=115.34657211014276, accepted_substeps=1, max_rel_update=0.018044318556726245
# [DEBUG] entering step: T_old=0.27995669, dT=-4.61479763e-03
# [DEBUG] leaving step: T_new=0.27534190, rhs_norm=450.44771636645487, channel_norm=117.42529716542418, accepted_substeps=1, max_rel_update=0.018021559004774524
# [DEBUG] entering step: T_old=0.27534190, dT=-4.53872745e-03
# [DEBUG] leaving step: T_new=0.27080317, rhs_norm=465.6734779075468, channel_norm=119.53886216189117, accepted_substeps=1, max_rel_update=0.01799923055327235
# [DEBUG] entering step: T_old=0.27080317, dT=-4.46391120e-03
# [DEBUG] leaving step: T_new=0.26633926, rhs_norm=481.4138914406083, channel_norm=121.68785102549323, accepted_substeps=1, max_rel_update=0.017977324066308097
# [DEBUG] entering step: T_old=0.26633926, dT=-4.39032823e-03
# [DEBUG] leaving step: T_new=0.26194893, rhs_norm=497.686352921312, channel_norm=123.87285746892181, accepted_substeps=1, max_rel_update=0.017955830635638596
# [DEBUG] entering step: T_old=0.26194893, dT=-4.31795819e-03
# [DEBUG] leaving step: T_new=0.25763097, rhs_norm=514.5088463129108, channel_norm=126.09448515563881, accepted_substeps=1, max_rel_update=0.01793474157383009
# [DEBUG] entering step: T_old=0.25763097, dT=-4.24678110e-03
# [DEBUG] leaving step: T_new=0.25338419, rhs_norm=531.8999634617207, channel_norm=128.35334786665325, accepted_substeps=1, max_rel_update=0.017914048407639018
# [DEBUG] entering step: T_old=0.25338419, dT=-4.17677729e-03
# [DEBUG] leaving step: T_new=0.24920741, rhs_norm=549.8789246444097, channel_norm=130.65006967009458, accepted_substeps=1, max_rel_update=0.017893742871649937
# [DEBUG] entering step: T_old=0.24920741, dT=-4.10792742e-03
# [DEBUG] leaving step: T_new=0.24509949, rhs_norm=568.4655998098292, channel_norm=132.98528509362674, accepted_substeps=1, max_rel_update=0.01787381690211757
# [DEBUG] entering step: T_old=0.24509949, dT=-4.04021247e-03
# [DEBUG] leaving step: T_new=0.24105927, rhs_norm=587.6805305388308, channel_norm=135.35963929975284, accepted_substeps=1, max_rel_update=0.017854262631045798
# [DEBUG] entering step: T_old=0.24105927, dT=-3.97361373e-03
# [DEBUG] leaving step: T_new=0.23708566, rhs_norm=607.5449527463729, channel_norm=137.7737882640577, accepted_substeps=1, max_rel_update=0.017835072380466065
# [DEBUG] entering step: T_old=0.23708566, dT=-3.90811280e-03
# [DEBUG] leaving step: T_new=0.23317755, rhs_norm=628.0808201509817, channel_norm=140.22839895643756, accepted_substeps=1, max_rel_update=0.017816238656915905
# [DEBUG] entering step: T_old=0.23317755, dT=-3.84369159e-03
# [DEBUG] leaving step: T_new=0.22933385, rhs_norm=649.3108285375106, channel_norm=142.7241495253674, accepted_substeps=1, max_rel_update=0.017797754146113818
# [DEBUG] entering step: T_old=0.22933385, dT=-3.78033229e-03
# [DEBUG] leaving step: T_new=0.22555352, rhs_norm=671.258440840018, channel_norm=145.26172948525706, accepted_substeps=1, max_rel_update=0.0177796117078185
# [DEBUG] entering step: T_old=0.22555352, dT=-3.71801741e-03
# [DEBUG] leaving step: T_new=0.22183550, rhs_norm=693.9479130724865, channel_norm=147.8418399069465, accepted_substeps=1, max_rel_update=0.01776180437085656
# [DEBUG] entering step: T_old=0.22183550, dT=-3.65672972e-03
# [DEBUG] leaving step: T_new=0.21817878, rhs_norm=717.4043211360234, channel_norm=150.465193611395, accepted_substeps=1, max_rel_update=0.017744325328335177
# [DEBUG] entering step: T_old=0.21817878, dT=-3.59645230e-03
# [DEBUG] leaving step: T_new=0.21458232, rhs_norm=741.6535885321981, channel_norm=153.13251536661554, accepted_substeps=1, max_rel_update=0.017727167932999943
# [DEBUG] entering step: T_old=0.21458232, dT=-3.53716849e-03
# [DEBUG] leaving step: T_new=0.21104515, rhs_norm=766.7225150131126, channel_norm=155.84454208791055, accepted_substeps=1, max_rel_update=0.017710325692764522
# [DEBUG] entering step: T_old=0.21104515, dT=-3.47886191e-03
# [DEBUG] leaving step: T_new=0.20756629, rhs_norm=792.6388061998983, channel_norm=158.60202304146372, accepted_substeps=1, max_rel_update=0.017693792266383547
# [DEBUG] entering step: T_old=0.20756629, dT=-3.42151646e-03
# [DEBUG] leaving step: T_new=0.20414478, rhs_norm=819.4311042023551, channel_norm=161.40572005134317, accepted_substeps=1, max_rel_update=0.017677561459266224
# [DEBUG] entering step: T_old=0.20414478, dT=-3.36511629e-03
# [DEBUG] leaving step: T_new=0.20077966, rhs_norm=847.1290192735647, channel_norm=164.25640770997538, accepted_substeps=1, max_rel_update=0.017661627219440642
# [DEBUG] entering step: T_old=0.20077966, dT=-3.30964581e-03
# [DEBUG] leaving step: T_new=0.19747001, rhs_norm=875.7631625345002, channel_norm=167.15487359214546, accepted_substeps=1, max_rel_update=0.017645983633636106
# [DEBUG] entering step: T_old=0.19747001, dT=-3.25508971e-03
# [DEBUG] leaving step: T_new=0.19421492, rhs_norm=905.3651798047476, channel_norm=170.1019184725848, accepted_substeps=1, max_rel_update=0.017630624923506942
# [DEBUG] entering step: T_old=0.19421492, dT=-3.20143291e-03
# [DEBUG] leaving step: T_new=0.19101349, rhs_norm=935.967786576763, channel_norm=173.09835654720573, accepted_substeps=1, max_rel_update=0.017615545441974922
# [DEBUG] entering step: T_old=0.19101349, dT=-3.14866059e-03
# [DEBUG] leaving step: T_new=0.18786483, rhs_norm=967.6048041723144, channel_norm=176.14501565804335, accepted_substeps=1, max_rel_update=0.017600739669684697
# [DEBUG] entering step: T_old=0.18786483, dT=-3.09675816e-03
# [DEBUG] leaving step: T_new=0.18476807, rhs_norm=1000.3111971210532, channel_norm=179.24273752196797, accepted_substeps=1, max_rel_update=0.017586202211581962
# [DEBUG] entering step: T_old=0.18476807, dT=-3.04571129e-03
# [DEBUG] leaving step: T_new=0.18172236, rhs_norm=1034.1231118025303, channel_norm=182.39237796323124, accepted_substeps=1, max_rel_update=0.017571927793600246
# [DEBUG] entering step: T_old=0.18172236, dT=-2.99550588e-03
# [DEBUG] leaving step: T_new=0.17872686, rhs_norm=1069.077916394388, channel_norm=185.59480714990843, accepted_substeps=1, max_rel_update=0.017557911259442956
# [DEBUG] entering step: T_old=0.17872686, dT=-2.94612805e-03
# [DEBUG] leaving step: T_new=0.17578073, rhs_norm=1105.214242170819, channel_norm=188.85090983430547, accepted_substeps=1, max_rel_update=0.017544147567485596
# [DEBUG] entering step: T_old=0.17578073, dT=-2.89756417e-03
# [DEBUG] leaving step: T_new=0.17288316, rhs_norm=1142.5720261970175, channel_norm=192.16158559739324, accepted_substeps=1, max_rel_update=0.017530631787755227
# [DEBUG] entering step: T_old=0.17288316, dT=-2.84980081e-03
# [DEBUG] leaving step: T_new=0.17003336, rhs_norm=1181.1925554667139, channel_norm=195.52774909734018, accepted_substeps=1, max_rel_update=0.017517359099021718
# [DEBUG] entering step: T_old=0.17003336, dT=-2.80282478e-03
# [DEBUG] leaving step: T_new=0.16723054, rhs_norm=1221.1185125316576, channel_norm=198.95033032220996, accepted_substeps=1, max_rel_update=0.017504324785971553
# [DEBUG] entering step: T_old=0.16723054, dT=-2.75662310e-03
# [DEBUG] leaving step: T_new=0.16447391, rhs_norm=1262.3940226734264, channel_norm=202.4302748468937, accepted_substeps=1, max_rel_update=0.01749152423646534
# [DEBUG] entering step: T_old=0.16447391, dT=-2.71118301e-03
# [DEBUG] leaving step: T_new=0.16176273, rhs_norm=1305.0647026697002, channel_norm=205.96854409434965, accepted_substeps=1, max_rel_update=0.017478952938892636
# [DEBUG] entering step: T_old=0.16176273, dT=-2.66649195e-03
# [DEBUG] leaving step: T_new=0.15909624, rhs_norm=1349.1777112089192, channel_norm=209.56611560122013, accepted_substeps=1, max_rel_update=0.01746660647959193
# [DEBUG] entering step: T_old=0.15909624, dT=-2.62253758e-03
# [DEBUG] leaving step: T_new=0.15647370, rhs_norm=1394.7818010090157, channel_norm=213.22398328790112, accepted_substeps=1, max_rel_update=0.017454480540363096
# [DEBUG] entering step: T_old=0.15647370, dT=-2.57930775e-03
# [DEBUG] leaving step: T_new=0.15389439, rhs_norm=1441.9273726978397, channel_norm=216.94315773313812, accepted_substeps=1, max_rel_update=0.017442570896048146
# [DEBUG] entering step: T_old=0.15389439, dT=-2.53679052e-03
# [DEBUG] leaving step: T_new=0.15135760, rhs_norm=1490.6665305148556, channel_norm=220.72466645322393, accepted_substeps=1, max_rel_update=0.01743087341218411
# [DEBUG] entering step: T_old=0.15135760, dT=-2.49497414e-03
# [DEBUG] leaving step: T_new=0.14886263, rhs_norm=1541.0531398956693, channel_norm=224.56955418587648, accepted_substeps=1, max_rel_update=0.017419384042731603
# [DEBUG] entering step: T_old=0.14886263, dT=-2.45384706e-03
# [DEBUG] leaving step: T_new=0.14640878, rhs_norm=1593.1428870036889, channel_norm=228.47888317887677, accepted_substeps=1, max_rel_update=0.017408098827878256
# [DEBUG] entering step: T_old=0.14640878, dT=-2.41339792e-03
# [DEBUG] leaving step: T_new=0.14399538, rhs_norm=1646.9933402770887, channel_norm=232.4537334835522, accepted_substeps=1, max_rel_update=0.01739701389192949
# [DEBUG] entering step: T_old=0.14399538, dT=-2.37361554e-03
# [DEBUG] leaving step: T_new=0.14162177, rhs_norm=1702.6640140746313, channel_norm=236.49520325323283, accepted_substeps=1, max_rel_update=0.017386125441459385
# [DEBUG] entering step: T_old=0.14162177, dT=-2.33448894e-03
# [DEBUG] leaving step: T_new=0.13928728, rhs_norm=1760.2164345793153, channel_norm=240.60440904700442, accepted_substeps=1, max_rel_update=0.017375429764516517
# [DEBUG] entering step: T_old=0.13928728, dT=-2.29600729e-03
# [DEBUG] leaving step: T_new=0.13699127, rhs_norm=1819.714208562516, channel_norm=244.78248614027885, accepted_substeps=1, max_rel_update=0.017364923235709262
# [DEBUG] entering step: T_old=0.13699127, dT=-2.25815998e-03
# [DEBUG] leaving step: T_new=0.13473311, rhs_norm=1881.2230982990943, channel_norm=249.0305888507924, accepted_substeps=1, max_rel_update=0.017354602355329832
# [DEBUG] entering step: T_old=0.13473311, dT=-2.22093654e-03
# [DEBUG] leaving step: T_new=0.13251218, rhs_norm=1944.811122594795, channel_norm=253.3498909318116, accepted_substeps=1, max_rel_update=0.017344463991156887
# [DEBUG] entering step: T_old=0.13251218, dT=-2.18432669e-03
# [DEBUG] leaving step: T_new=0.13032785, rhs_norm=2010.5488093359097, channel_norm=257.7415863520669, accepted_substeps=1, max_rel_update=0.017334506851780427
# [DEBUG] entering step: T_old=0.13032785, dT=-2.14832031e-03
# [DEBUG] leaving step: T_new=0.12817953, rhs_norm=2078.510404711631, channel_norm=262.2068924742633, accepted_substeps=1, max_rel_update=0.017324740587640237
# [DEBUG] entering step: T_old=0.12817953, dT=-2.11290747e-03
# [DEBUG] leaving step: T_new=0.12606662, rhs_norm=2148.78130801939, channel_norm=266.74706854223405, accepted_substeps=1, max_rel_update=0.017315243032432426
# [DEBUG] entering step: T_old=0.12606662, dT=-2.07807836e-03
# [DEBUG] leaving step: T_new=0.12398854, rhs_norm=2221.506829891588, channel_norm=271.36353381930496, accepted_substeps=1, max_rel_update=0.017306526749477698
# [DEBUG] entering step: T_old=0.12398854, dT=-2.04382338e-03
# [DEBUG] leaving step: T_new=0.12194472, rhs_norm=2297.2196214711757, channel_norm=276.0586449968083, accepted_substeps=1, max_rel_update=0.017301923775173658
# [DEBUG] entering step: T_old=0.12194472, dT=-2.01013306e-03
# [DEBUG] leaving step: T_new=0.11993459, rhs_norm=2379.0639621075366, channel_norm=280.8408801192106, accepted_substeps=1, max_rel_update=0.017323257970992285
# [DEBUG] entering step: T_old=0.11993459, dT=-1.97699809e-03
# [DEBUG] leaving step: T_new=0.11795759, rhs_norm=2487.8444108359076, channel_norm=285.75934376228435, accepted_substeps=1, max_rel_update=0.01751334649352304
# [DEBUG] entering step: T_old=0.11795759, dT=-1.94440931e-03
# [DEBUG] leaving step: T_new=0.11601318, rhs_norm=2759.871961079161, channel_norm=291.1256645017612, accepted_substeps=1, max_rel_update=0.018779161054978344
# [DEBUG] entering step: T_old=0.11601318, dT=-1.91235773e-03
# [DEBUG] leaving step: T_new=0.11410082, rhs_norm=4016.3020039920902, channel_norm=298.80627067473694, accepted_substeps=1, max_rel_update=0.026382442736955166
# [DEBUG] entering step: T_old=0.11410082, dT=-1.88083448e-03
# [DEBUG] leaving step: T_new=0.11221999, rhs_norm=10739.155697355449, channel_norm=319.0048450043747, accepted_substeps=1, max_rel_update=0.0675975583913525
# [DEBUG] entering step: T_old=0.11221999, dT=-1.84983086e-03
# [DEBUG] leaving step: T_new=0.11037016, rhs_norm=58587.42963458892, channel_norm=427.38168048562665, accepted_substeps=1, max_rel_update=0.3397341362629326
# [DEBUG] entering step: T_old=0.11037016, dT=-1.81933831e-03
# [DEBUG] leaving step: T_new=0.10855082, rhs_norm=983463.7840208325, channel_norm=2216.6350158841396, accepted_substeps=5, max_rel_update=0.83730932657919
# [DEBUG] entering step: T_old=0.10855082, dT=-1.78934839e-03
# [DEBUG] leaving step: T_new=0.10855082, rhs_norm=227836830.80353692, channel_norm=2216.6350158841396, accepted_substeps=0, max_rel_update=183.9181747463268
# [FRGFlowSolver] Adaptive step control requested too many substeps; stopping flow early and returning partial history. Current state remains at T=0.10855082, attempted T_new=0.10676147, rhs_norm=2.278e+08, rel_update=1.839e+02, proposed_n_sub=184. Reduce temperature spacing or relax max_relative_update to continue further.
# history length = 219
# instability record = 218
# ===== Final record =====
# {'accepted_substeps': 0,
#  'channel_norm': 2216.6350158841396,
#  'dT': -0.0017893483892064271,
#  'diagnosis_payload': {'basis_labels': ['ud', 'du'],
#                        'dominant_spin_structure': 'singlet',
#                        'geometry': 'pp',
#                        'hermitian_residual': 9.094947017729282e-13,
#                        'leading_eigenvalue': (10665.58444667326+4.564727485532671e-28j),
#                        'leading_eigenvalue_abs': 10665.58444667326,
#                        'mother_kernel': 'pp_mother_sz0',
#                        'singlet_weight': 0.9999999999999999,
#                        'sort_by': 'abs',
#                        'triplet_weight': 3.004450713244088e-31},
#  'instability': True,
#  'instability_reason': 'Adaptive step control requested too many substeps; '
#                        'stopping flow early and returning partial history. '
#                        'Current state remains at T=0.10855082, attempted '
#                        'T_new=0.10676147, rhs_norm=2.278e+08, '
#                        'rel_update=1.839e+02, proposed_n_sub=184. Reduce '
#                        'temperature spacing or relax max_relative_update to '
#                        'continue further.',
#  'leading_Q': [0.0, 0.0],
#  'leading_channel_name': 'pp_mother_sz0',
#  'leading_eigenvalue_abs': 10665.58444667326,
#  'leading_order_label': None,
#  'max_rel_update': 183.9181747463268,
#  'rhs_norm': 227836830.80353692,
#  'step_index': 218,
#  'temperature': 0.10855081820533162,
#  'terminated_early': True,
#  'termination_reason': 'Adaptive step control requested too many substeps; '
#                        'stopping flow early and returning partial history. '
#                        'Current state remains at T=0.10855082, attempted '
#                        'T_new=0.10676147, rhs_norm=2.278e+08, '
#                        'rel_update=1.839e+02, proposed_n_sub=184. Reduce '
#                        'temperature spacing or relax max_relative_update to '
#                        'continue further.'}

# %%
import numpy as np
import matplotlib.pyplot as plt

Qs_to_check = FLOW_KWARGS["diagnosis_Qs"]
# 如果你想继续测试 Q -> Q+G 不变性，再手动加 reciprocal vector
# Qs_to_check = FLOW_KWARGS["diagnosis_Qs"] + 5*np.array([np.pi, np.pi/np.sqrt(3)]) + np.array([0,2*np.pi/np.sqrt(3)])

solver = fm_result["solver"]

mother_channels = [
    "pp_mother_sz0",
    "ph_mother_longitudinal",
]

print("===== Final-state mother-channel diagnosis across all Q =====")
Q_summary = []

for i, Q in enumerate(Qs_to_check):
    Q = np.asarray(Q, dtype=float)
    mothers = solver.build_mother_kernel_dict(Q)

    print(f"\n===== Q[{i}] = {Q} =====")
    row = {
        "Q_index": i,
        "Q_vec": Q,
    }

    vals_dict = {}
    for name in mother_channels:
        k = mothers[name]
        vals, vecs = k.eig(sort_by="abs")
        eigmax = abs(vals[0])
        vals_dict[name] = eigmax
        row[name] = float(eigmax)
        print(f"{name:24s} |eig|max = {eigmax:.8g}")

    lead_name = max(vals_dict, key=vals_dict.get)
    row["leading_geometry"] = lead_name
    row["leading_value"] = vals_dict[lead_name]
    Q_summary.append(row)

    print(f"--> leading mother channel at this Q: {lead_name}  (|eig|max = {vals_dict[lead_name]:.8g})")

print(Q_summary)
labels = [f"Q{i}" for i in range(len(Q_summary))]
x = np.arange(len(labels))
width = 0.35

pp_vals = [row["pp_mother_sz0"] for row in Q_summary]
ph_vals = [row["ph_mother_longitudinal"] for row in Q_summary]

plt.figure(figsize=(8, 5))
plt.bar(x - width/2, pp_vals, width, label="pp_mother_sz0")
plt.bar(x + width/2, ph_vals, width, label="ph_mother_longitudinal")

plt.xticks(x, labels)
plt.ylabel("|leading eigenvalue|")
plt.title("Final mother-channel diagnosis across Q")
plt.legend()
plt.show()

# ----------------------------------------
Q = np.array([0.0, 0.0])
mothers = solver.build_mother_kernel_dict(Q)

for name in ["pp_mother_sz0", "ph_mother_longitudinal"]:
    k = mothers[name]
    vals, vecs = k.eig(sort_by="abs")
    print(f"\n==== {name} ====")
    print("Q =", k.Q)
    print("|eig|max =", abs(vals[0]))
    print("vec.real =", np.real(vecs[:, 0]))
    print("vec.abs  =", np.abs(vecs[:, 0]))
    print(f"\n==== {name} ====")
    print("Q =", k.Q)
    print("second |eig|max =", abs(vals[1]))
    print("vec.real =", np.real(vecs[:, 1]))
    print("vec.abs  =", np.abs(vecs[:, 1]))
# Out:
# ===== Final-state mother-channel diagnosis across all Q =====
#
# ===== Q[0] = [0. 0.] =====
# pp_mother_sz0            |eig|max = 10665.584
# ph_mother_longitudinal   |eig|max = 3834.3393
# --> leading mother channel at this Q: pp_mother_sz0  (|eig|max = 10665.584)
#
# ===== Q[1] = [0.         1.81379936] =====
# pp_mother_sz0            |eig|max = 1491.3504
# ph_mother_longitudinal   |eig|max = 2982.7008
# --> leading mother channel at this Q: ph_mother_longitudinal  (|eig|max = 2982.7008)
#
# ===== Q[2] = [1.57079633 0.90689968] =====
# pp_mother_sz0            |eig|max = 1509.648
# ph_mother_longitudinal   |eig|max = 3019.2959
# --> leading mother channel at this Q: ph_mother_longitudinal  (|eig|max = 3019.2959)
#
# ===== Q[3] = [-1.57079633  0.90689968] =====
# pp_mother_sz0            |eig|max = 1509.648
# ph_mother_longitudinal   |eig|max = 3019.2959
# --> leading mother channel at this Q: ph_mother_longitudinal  (|eig|max = 3019.2959)
# [{'Q_index': 0, 'Q_vec': array([0., 0.]), 'pp_mother_sz0': 10665.58444667326, 'ph_mother_longitudinal': 3834.3393012817583, 'leading_geometry': 'pp_mother_sz0', 'leading_value': np.float64(10665.58444667326)}, {'Q_index': 1, 'Q_vec': array([0.        , 1.81379936]), 'pp_mother_sz0': 1491.3504022191173, 'ph_mother_longitudinal': 2982.7008044381864, 'leading_geometry': 'ph_mother_longitudinal', 'leading_value': np.float64(2982.7008044381864)}, {'Q_index': 2, 'Q_vec': array([1.57079633, 0.90689968]), 'pp_mother_sz0': 1509.647966677968, 'ph_mother_longitudinal': 3019.2959333558874, 'leading_geometry': 'ph_mother_longitudinal', 'leading_value': np.float64(3019.2959333558874)}, {'Q_index': 3, 'Q_vec': array([-1.57079633,  0.90689968]), 'pp_mother_sz0': 1509.647966677982, 'ph_mother_longitudinal': 3019.295933355901, 'leading_geometry': 'ph_mother_longitudinal', 'leading_value': np.float64(3019.295933355901)}]
# ==== pp_mother_sz0 ====
# Q = [0. 0.]
# |eig|max = 10665.58444667326
# vec.real = [ 0.28131463  0.30285996  0.28131463  0.28131463  0.30285996  0.28131463
#  -0.28131463 -0.30285996 -0.28131463 -0.28131463 -0.30285996 -0.28131463]
# vec.abs  = [0.28131463 0.30285996 0.28131463 0.28131463 0.30285996 0.28131463
#  0.28131463 0.30285996 0.28131463 0.28131463 0.30285996 0.28131463]
#
# ==== pp_mother_sz0 ====
# Q = [0. 0.]
# second |eig|max = 1806.037631350619
# vec.real = [-0.21415433  0.39783897 -0.21415433 -0.21415433  0.39783897 -0.21415433
#   0.21415433 -0.39783897  0.21415433  0.21415433 -0.39783897  0.21415433]
# vec.abs  = [0.21415433 0.39783897 0.21415433 0.21415433 0.39783897 0.21415433
#  0.21415433 0.39783897 0.21415433 0.21415433 0.39783897 0.21415433]
#
# ==== ph_mother_longitudinal ====
# Q = [0. 0.]
# |eig|max = 3834.3393012817583
# vec.real = [ 0.27374874  0.31642259  0.27374874  0.27374874  0.31642259  0.27374874
#  -0.27374874 -0.31642259 -0.27374874 -0.27374874 -0.31642259 -0.27374874]
# vec.abs  = [0.27374874 0.31642259 0.27374874 0.27374874 0.31642259 0.27374874
#  0.27374874 0.31642259 0.27374874 0.27374874 0.31642259 0.27374874]
#
# ==== ph_mother_longitudinal ====
# Q = [0. 0.]
# second |eig|max = 3190.714848791111
# vec.real = [-0.18642084  0.42484649 -0.18642084 -0.18642084  0.42484649 -0.18642084
#  -0.18642084  0.42484649 -0.18642084 -0.18642084  0.42484649 -0.18642084]
# vec.abs  = [0.18642084 0.42484649 0.18642084 0.18642084 0.42484649 0.18642084
#  0.18642084 0.42484649 0.18642084 0.18642084 0.42484649 0.18642084]

# %% [markdown]
# ## 5. PI benchmark: `U=0, V=6`
#
# Expectation from the PRL benchmark at van Hove filling:
# - dominant nearest-neighbor repulsion should favor **Pomeranchuk instability (PI)** with d-wave character.
#
# If this still does **not** look PI-like, then the likely next suspects are:
# - `form_factor.py`
# - `kagome_order_diagnosis.py`

# %%
pi_result = run_case("PI benchmark", U=.0, V=6.0, flow_kwargs=FLOW_KWARGS)
# Out:
# ===== Running case: PI benchmark (U=0.0, V=6.0) =====
# [DEBUG] entering step: T_old=4.00000000, dT=-6.59358785e-02
# [DEBUG] leaving step: T_new=3.93406412, rhs_norm=8.826044440462724, channel_norm=0.5819529935825135, accepted_substeps=1, max_rel_update=0.04849608279854279
# [DEBUG] entering step: T_old=3.93406412, dT=-6.48489935e-02
# [DEBUG] leaving step: T_new=3.86921513, rhs_norm=8.579303635877917, channel_norm=1.1383121988796299, accepted_substeps=1, max_rel_update=0.04636326710809303
# [DEBUG] entering step: T_old=3.86921513, dT=-6.37800246e-02
# [DEBUG] leaving step: T_new=3.80543510, rhs_norm=8.339715233076788, channel_norm=1.670219441712749, accepted_substeps=1, max_rel_update=0.04432560356942659
# [DEBUG] entering step: T_old=3.80543510, dT=-6.27286766e-02
# [DEBUG] leaving step: T_new=3.74270643, rhs_norm=8.103783546175492, channel_norm=2.1785590592225827, accepted_substeps=1, max_rel_update=0.04236163479248616
# [DEBUG] entering step: T_old=3.74270643, dT=-6.16946590e-02
# [DEBUG] leaving step: T_new=3.68101177, rhs_norm=7.868482387450815, channel_norm=2.6640023971663482, accepted_substeps=1, max_rel_update=0.040453611495313783
# [DEBUG] entering step: T_old=3.68101177, dT=-6.06776861e-02
# [DEBUG] leaving step: T_new=3.62033408, rhs_norm=8.30753952362487, channel_norm=3.1270507956774267, accepted_substeps=1, max_rel_update=0.042006856318078316
# [DEBUG] entering step: T_old=3.62033408, dT=-5.96774770e-02
# [DEBUG] leaving step: T_new=3.56065660, rhs_norm=9.436653556448181, channel_norm=3.568078606893086, accepted_substeps=1, max_rel_update=0.04692963963573954
# [DEBUG] entering step: T_old=3.56065660, dT=-5.86937553e-02
# [DEBUG] leaving step: T_new=3.50196285, rhs_norm=10.731743788088172, channel_norm=3.9873773898443834, accepted_substeps=1, max_rel_update=0.05249052864284897
# [DEBUG] entering step: T_old=3.50196285, dT=-5.77262492e-02
# [DEBUG] leaving step: T_new=3.44423660, rhs_norm=12.222420649387695, channel_norm=4.385202012732731, accepted_substeps=1, max_rel_update=0.05879620836234892
# [DEBUG] entering step: T_old=3.44423660, dT=-5.67746915e-02
# [DEBUG] leaving step: T_new=3.38746191, rhs_norm=13.944387918157386, channel_norm=5.029560462059787, accepted_substeps=1, max_rel_update=0.06597402681744165
# [DEBUG] entering step: T_old=3.38746191, dT=-5.58388192e-02
# [DEBUG] leaving step: T_new=3.33162309, rhs_norm=15.940971142128845, channel_norm=5.9196854672514645, accepted_substeps=1, max_rel_update=0.07417708376597311
# [DEBUG] entering step: T_old=3.33162309, dT=-5.49183738e-02
# [DEBUG] leaving step: T_new=3.27670472, rhs_norm=18.26512939911616, channel_norm=6.922776670790677, accepted_substeps=1, max_rel_update=0.0835909336282677
# [DEBUG] entering step: T_old=3.27670472, dT=-5.40131010e-02
# [DEBUG] leaving step: T_new=3.22269161, rhs_norm=20.98214088302395, channel_norm=8.05608716504721, accepted_substeps=1, max_rel_update=0.09444254118804445
# [DEBUG] entering step: T_old=3.22269161, dT=-5.31227507e-02
# [DEBUG] leaving step: T_new=3.16956886, rhs_norm=24.17324045545081, channel_norm=9.34023619047618, accepted_substeps=1, max_rel_update=0.10701241878574759
# [DEBUG] entering step: T_old=3.16956886, dT=-5.22470769e-02
# [DEBUG] leaving step: T_new=3.11732179, rhs_norm=27.940620332684745, channel_norm=10.800051928373954, accepted_substeps=1, max_rel_update=0.12165131149148108
# [DEBUG] entering step: T_old=3.11732179, dT=-5.13858376e-02
# [DEBUG] leaving step: T_new=3.06593595, rhs_norm=32.41441016417234, channel_norm=12.465693545862164, accepted_substeps=1, max_rel_update=0.13880346812401753
# [DEBUG] entering step: T_old=3.06593595, dT=-5.05387950e-02
# [DEBUG] leaving step: T_new=3.01539715, rhs_norm=37.762574779904874, channel_norm=14.374168572896526, accepted_substeps=1, max_rel_update=0.15309818262521438
# [DEBUG] entering step: T_old=3.01539715, dT=-4.97057151e-02
# [DEBUG] leaving step: T_new=2.96569144, rhs_norm=44.205184274384166, channel_norm=16.571418867470577, accepted_substeps=1, max_rel_update=0.15286103564397563
# [DEBUG] entering step: T_old=2.96569144, dT=-4.88863676e-02
# [DEBUG] leaving step: T_new=2.91680507, rhs_norm=52.03535903131313, channel_norm=19.11523855634799, accepted_substeps=1, max_rel_update=0.1535064504265769
# [DEBUG] entering step: T_old=2.91680507, dT=-4.80805262e-02
# [DEBUG] leaving step: T_new=2.86872455, rhs_norm=61.65062167010749, channel_norm=22.07943288583612, accepted_substeps=1, max_rel_update=0.15506970110523408
# [DEBUG] entering step: T_old=2.86872455, dT=-4.72879683e-02
# [DEBUG] leaving step: T_new=2.82143658, rhs_norm=73.6008678749969, channel_norm=25.559868389192257, accepted_substeps=1, max_rel_update=0.15763246825007105
# [DEBUG] entering step: T_old=2.82143658, dT=-4.65084748e-02
# [DEBUG] leaving step: T_new=2.77492810, rhs_norm=88.66360923877497, channel_norm=29.68347762688823, accepted_substeps=1, max_rel_update=0.16133139556538567
# [DEBUG] entering step: T_old=2.77492810, dT=-4.57418305e-02
# [DEBUG] leaving step: T_new=2.72918627, rhs_norm=107.9653778696463, channel_norm=34.622011644911936, accepted_substeps=1, max_rel_update=0.16637316153112144
# [DEBUG] entering step: T_old=2.72918627, dT=-4.49878236e-02
# [DEBUG] leaving step: T_new=2.68419845, rhs_norm=133.18406754001865, channel_norm=40.61367298026557, accepted_substeps=1, max_rel_update=0.17305930680183826
# [DEBUG] entering step: T_old=2.68419845, dT=-4.42462457e-02
# [DEBUG] leaving step: T_new=2.63995220, rhs_norm=166.8990069842247, channel_norm=47.99832744566979, accepted_substeps=1, max_rel_update=0.18182680667647233
# [DEBUG] entering step: T_old=2.63995220, dT=-4.35168919e-02
# [DEBUG] leaving step: T_new=2.59643531, rhs_norm=213.22345572123984, channel_norm=57.27714951936426, accepted_substeps=1, max_rel_update=0.1933155292587506
# [DEBUG] entering step: T_old=2.59643531, dT=-4.27995608e-02
# [DEBUG] leaving step: T_new=2.55363575, rhs_norm=279.0068390297596, channel_norm=69.21851968404383, accepted_substeps=1, max_rel_update=0.2084840161370536
# [DEBUG] entering step: T_old=2.55363575, dT=-4.20940541e-02
# [DEBUG] leaving step: T_new=2.51154170, rhs_norm=376.2614286434034, channel_norm=85.05688862426355, accepted_substeps=1, max_rel_update=0.22881692663344783
# [DEBUG] entering step: T_old=2.51154170, dT=-4.14001770e-02
# [DEBUG] leaving step: T_new=2.47014152, rhs_norm=527.4272654611274, channel_norm=106.89247077418813, accepted_substeps=1, max_rel_update=0.25671738648215386
# [DEBUG] entering step: T_old=2.47014152, dT=-4.07177377e-02
# [DEBUG] leaving step: T_new=2.42942378, rhs_norm=777.8502223504357, channel_norm=138.5647721365554, accepted_substeps=1, max_rel_update=0.29630058256652575
# [DEBUG] entering step: T_old=2.42942378, dT=-4.00465478e-02
# [DEBUG] leaving step: T_new=2.38937723, rhs_norm=1228.814542224852, channel_norm=187.77455243658542, accepted_substeps=1, max_rel_update=0.35513918538785494
# [DEBUG] entering step: T_old=2.38937723, dT=-3.93864217e-02
# [DEBUG] leaving step: T_new=2.34999081, rhs_norm=2138.3786984713306, channel_norm=271.99763765332034, accepted_substeps=1, max_rel_update=0.44853301005831686
# [DEBUG] entering step: T_old=2.34999081, dT=-3.87371771e-02
# [DEBUG] leaving step: T_new=2.31125363, rhs_norm=6866.4168120448885, channel_norm=438.32700676222987, accepted_substeps=1, max_rel_update=0.9778967445177807
# [DEBUG] entering step: T_old=2.31125363, dT=-3.80986347e-02
# [DEBUG] leaving step: T_new=2.27315500, rhs_norm=36125.21286524976, channel_norm=1803.4338085123245, accepted_substeps=4, max_rel_update=0.7849854485612034
# [DEBUG] entering step: T_old=2.27315500, dT=-3.74706180e-02
# [DEBUG] leaving step: T_new=2.23568438, rhs_norm=472035.3673297089, channel_norm=19490.89071852897, accepted_substeps=10, max_rel_update=0.9807655166788326
# history length = 36
# instability record = 35
# ===== Final record =====
# {'accepted_substeps': 10,
#  'channel_norm': 19490.89071852897,
#  'dT': -0.03747061795406159,
#  'diagnosis_payload': {},
#  'instability': True,
#  'instability_reason': 'channel norm=1.949e+04 exceeded '
#                        'channel_divergence_threshold',
#  'leading_Q': None,
#  'leading_channel_name': None,
#  'leading_eigenvalue_abs': None,
#  'leading_order_label': None,
#  'max_rel_update': 0.9807655166788326,
#  'rhs_norm': 472035.3673297089,
#  'step_index': 35,
#  'temperature': 2.235684381993565,
#  'terminated_early': False,
#  'termination_reason': None}

# %%
import numpy as np
import matplotlib.pyplot as plt

Qs_to_check = FLOW_KWARGS["diagnosis_Qs"]
# 如果你想继续测试 Q -> Q+G 不变性，再手动加 reciprocal vector
# Qs_to_check = FLOW_KWARGS["diagnosis_Qs"] + 5*np.array([np.pi, np.pi/np.sqrt(3)]) + np.array([0,2*np.pi/np.sqrt(3)])

solver = pi_result["solver"]

mother_channels = [
    "pp_mother_sz0",
    "ph_mother_longitudinal",
]

print("===== Final-state mother-channel diagnosis across all Q =====")
Q_summary = []

for i, Q in enumerate(Qs_to_check):
    Q = np.asarray(Q, dtype=float)
    mothers = solver.build_mother_kernel_dict(Q)

    print(f"\n===== Q[{i}] = {Q} =====")
    row = {
        "Q_index": i,
        "Q_vec": Q,
    }

    vals_dict = {}
    for name in mother_channels:
        k = mothers[name]
        vals, vecs = k.eig(sort_by="abs")
        eigmax = abs(vals[0])
        vals_dict[name] = eigmax
        row[name] = float(eigmax)
        print(f"{name:24s} |eig|max = {eigmax:.8g}")

    lead_name = max(vals_dict, key=vals_dict.get)
    row["leading_geometry"] = lead_name
    row["leading_value"] = vals_dict[lead_name]
    Q_summary.append(row)

    print(f"--> leading mother channel at this Q: {lead_name}  (|eig|max = {vals_dict[lead_name]:.8g})")

print(Q_summary)
labels = [f"Q{i}" for i in range(len(Q_summary))]
x = np.arange(len(labels))
width = 0.35

pp_vals = [row["pp_mother_sz0"] for row in Q_summary]
ph_vals = [row["ph_mother_longitudinal"] for row in Q_summary]

plt.figure(figsize=(8, 5))
plt.bar(x - width/2, pp_vals, width, label="pp_mother_sz0")
plt.bar(x + width/2, ph_vals, width, label="ph_mother_longitudinal")

plt.xticks(x, labels)
plt.ylabel("|leading eigenvalue|")
plt.title("Final mother-channel diagnosis across Q")
plt.legend()
plt.show()

# ----------------------------------------
Q = np.array([0.0, 0.0])
mothers = solver.build_mother_kernel_dict(Q)

for name in ["pp_mother_sz0", "ph_mother_longitudinal"]:
    k = mothers[name]
    vals, vecs = k.eig(sort_by="abs")
    print(f"\n==== {name} ====")
    print("Q =", k.Q)
    print("|eig|max =", abs(vals[0]))
    print("vec.real =", np.real(vecs[:, 0]))
    print("vec.abs  =", np.abs(vecs[:, 0]))
    print(f"\n==== {name} ====")
    print("Q =", k.Q)
    print("second |eig|max =", abs(vals[1]))
    print("vec.real =", np.real(vecs[:, 1]))
    print("vec.abs  =", np.abs(vecs[:, 1]))
# Out:
# ===== Final-state mother-channel diagnosis across all Q =====
#
# ===== Q[0] = [0. 0.] =====
# pp_mother_sz0            |eig|max = 0.0003423686
# ph_mother_longitudinal   |eig|max = 0.00025657809
# --> leading mother channel at this Q: pp_mother_sz0  (|eig|max = 0.0003423686)
#
# ===== Q[1] = [0.         1.81379936] =====
# pp_mother_sz0            |eig|max = 2930.2913
# ph_mother_longitudinal   |eig|max = 1.4055591
# --> leading mother channel at this Q: pp_mother_sz0  (|eig|max = 2930.2913)
#
# ===== Q[2] = [1.57079633 0.90689968] =====
# pp_mother_sz0            |eig|max = 2930.2913
# ph_mother_longitudinal   |eig|max = 1.4055591
# --> leading mother channel at this Q: pp_mother_sz0  (|eig|max = 2930.2913)
#
# ===== Q[3] = [-1.57079633  0.90689968] =====
# pp_mother_sz0            |eig|max = 2930.2913
# ph_mother_longitudinal   |eig|max = 1.4055591
# --> leading mother channel at this Q: pp_mother_sz0  (|eig|max = 2930.2913)
# [{'Q_index': 0, 'Q_vec': array([0., 0.]), 'pp_mother_sz0': 0.0003423686041654831, 'ph_mother_longitudinal': 0.0002565780928631635, 'leading_geometry': 'pp_mother_sz0', 'leading_value': np.float64(0.0003423686041654831)}, {'Q_index': 1, 'Q_vec': array([0.        , 1.81379936]), 'pp_mother_sz0': 2930.2913438858754, 'ph_mother_longitudinal': 1.4055591384007595, 'leading_geometry': 'pp_mother_sz0', 'leading_value': np.float64(2930.2913438858754)}, {'Q_index': 2, 'Q_vec': array([1.57079633, 0.90689968]), 'pp_mother_sz0': 2930.2913438858805, 'ph_mother_longitudinal': 1.4055591381874222, 'leading_geometry': 'pp_mother_sz0', 'leading_value': np.float64(2930.2913438858805)}, {'Q_index': 3, 'Q_vec': array([-1.57079633,  0.90689968]), 'pp_mother_sz0': 2930.2913438858805, 'ph_mother_longitudinal': 1.4055591382710837, 'leading_geometry': 'pp_mother_sz0', 'leading_value': np.float64(2930.2913438858805)}]
# ==== pp_mother_sz0 ====
# Q = [0. 0.]
# |eig|max = 0.0003423686041654831
# vec.real = [-0.0700181   0.48266152  0.0346683  -0.0700181   0.48266153  0.0346683
#   0.07001811 -0.48266153 -0.0346683   0.07001811 -0.48266153 -0.0346683 ]
# vec.abs  = [0.12584101 0.48266152 0.0346683  0.12584101 0.48266153 0.0346683
#  0.12584101 0.48266153 0.0346683  0.12584101 0.48266153 0.0346683 ]
#
# ==== pp_mother_sz0 ====
# Q = [0. 0.]
# second |eig|max = 0.0003423685999393369
# vec.real = [-0.07001816  0.48266152  0.03466829 -0.07001815  0.48266151  0.03466829
#   0.07001815 -0.48266152 -0.03466829  0.07001815 -0.48266152 -0.03466829]
# vec.abs  = [0.12584105 0.48266152 0.03466829 0.12584104 0.48266151 0.03466829
#  0.12584104 0.48266152 0.03466829 0.12584104 0.48266152 0.03466829]
#
# ==== ph_mother_longitudinal ====
# Q = [0. 0.]
# |eig|max = 0.0002565780928631635
# vec.real = [ 0.00138504  0.01476438 -0.1305668   0.00138503  0.01476438 -0.1305668
#   0.65396024 -0.06979023 -0.22049164  0.65396024 -0.06979023 -0.22049164]
# vec.abs  = [0.00200437 0.01476543 0.1307583  0.00200436 0.01476543 0.1307583
#  0.65396024 0.07981419 0.22055823 0.65396024 0.07981419 0.22055823]
#
# ==== ph_mother_longitudinal ====
# Q = [0. 0.]
# second |eig|max = 0.00025657809137073176
# vec.real = [ 0.00138504  0.01476439 -0.13056681  0.00138505  0.01476438 -0.13056681
#   0.65396023 -0.06979022 -0.22049164  0.65396023 -0.06979022 -0.22049164]
# vec.abs  = [0.00200437 0.01476544 0.13075831 0.00200437 0.01476543 0.13075831
#  0.65396023 0.07981419 0.22055823 0.65396023 0.07981419 0.22055824]

# %%
# ============================================================
# TEST 1: compare different ranking metrics across Q
# ============================================================

import numpy as np
import pandas as pd

solver = pi_result["solver"]
Qs_to_check = [np.asarray(Q, dtype=float) for Q in FLOW_KWARGS["diagnosis_Qs"]]

combined_names = [
    "pp_singlet_sz0",
    "pp_triplet_sz0",
    "ph_charge_longitudinal",
    "ph_spin_longitudinal",
]

def kernel_metrics(k):
    vals_abs, _ = k.eig(sort_by="abs")
    vals_real, _ = k.eig(sort_by="real")
    H = 0.5 * (k.matrix + k.matrix.conjugate().T)
    evals_H = np.linalg.eigvalsh(H)
    return {
        "abs_eigmax": float(np.max(np.abs(vals_abs))),
        "real_eigmax": float(np.max(np.real(vals_real))),
        "herm_eigmax": float(np.max(evals_H)),
        "herm_residual": float(np.max(np.abs(k.matrix - k.matrix.conjugate().T))),
        "fro_norm": float(np.linalg.norm(k.matrix)),
    }

rows = []
for iq, Q in enumerate(Qs_to_check):
    kernels = solver.build_diagnosis_kernel_dict(Q)
    for name in combined_names:
        met = kernel_metrics(kernels[name])
        rows.append({
            "Q_index": iq,
            "Q": np.array2string(Q, precision=6, suppress_small=True),
            "kernel": name,
            **met,
        })

df_metrics = pd.DataFrame(rows)
display(df_metrics)

for metric in ["abs_eigmax", "real_eigmax", "herm_eigmax"]:
    print(f"\n===== leading kernel by {metric} =====")
    for iq, Q in enumerate(Qs_to_check):
        sub = df_metrics[df_metrics["Q_index"] == iq].copy()
        sub = sub.sort_values(metric, ascending=False)
        print(f"\nQ[{iq}] = {Q}")
        print(sub[["kernel", metric, "herm_residual", "fro_norm"]].to_string(index=False))
# Out:
#     Q_index                      Q                  kernel    abs_eigmax  \
# 0         0                [0. 0.]          pp_singlet_sz0  2.990587e-05
# 1         0                [0. 0.]          pp_triplet_sz0  1.717679e-20
# 2         0                [0. 0.]  ph_charge_longitudinal  3.378685e-04
# 3         0                [0. 0.]    ph_spin_longitudinal  3.287166e-04
# 4         1    [0.       1.813799]          pp_singlet_sz0  2.930291e+03
# 5         1    [0.       1.813799]          pp_triplet_sz0  2.930291e+03
# 6         1    [0.       1.813799]  ph_charge_longitudinal  1.405559e+00
# 7         1    [0.       1.813799]    ph_spin_longitudinal  1.136868e-13
# 8         2    [1.570796 0.9069  ]          pp_singlet_sz0  2.930291e+03
# 9         2    [1.570796 0.9069  ]          pp_triplet_sz0  2.930291e+03
# 10        2    [1.570796 0.9069  ]  ph_charge_longitudinal  1.405559e+00
# 11        2    [1.570796 0.9069  ]    ph_spin_longitudinal  1.705303e-13
# 12        3  [-1.570796  0.9069  ]          pp_singlet_sz0  2.930291e+03
# 13        3  [-1.570796  0.9069  ]          pp_triplet_sz0  2.930291e+03
# 14        3  [-1.570796  0.9069  ]  ph_charge_longitudinal  1.405559e+00
# 15        3  [-1.570796  0.9069  ]    ph_spin_longitudinal  1.705303e-13
#
#      real_eigmax   herm_eigmax  herm_residual      fro_norm
# 0   2.990587e-05  4.167418e+04   8.334837e+04  1.443636e+05
# 1   1.717679e-20  1.818989e-12   3.637979e-12  3.637979e-12
# 2   3.287166e-04  2.224132e+04   4.167418e+04  7.226371e+04
# 3   3.287166e-04  2.153921e+04   4.167418e+04  7.226371e+04
# 4   2.930291e+03  3.537175e+03   1.526060e+03  5.076875e+03
# 5   2.930291e+03  3.537175e+03   1.526060e+03  5.076875e+03
# 6   1.382400e-22  1.402826e+03   2.807057e+03  3.969779e+03
# 7   1.905259e-26  7.349855e-11   1.470539e-10  1.503170e-10
# 8   2.930291e+03  3.537175e+03   1.526060e+03  5.076875e+03
# 9   2.930291e+03  3.537175e+03   1.526060e+03  5.076875e+03
# 10  4.822358e-14  1.402826e+03   2.807057e+03  3.969779e+03
# 11  2.720627e-39  2.029318e-11   4.069989e-11  5.184587e-11
# 12  2.930291e+03  3.537175e+03   1.526060e+03  5.076875e+03
# 13  2.930291e+03  3.537175e+03   1.526060e+03  5.076875e+03
# 14  4.822358e-14  1.402826e+03   2.807057e+03  3.969779e+03
# 15  1.705303e-13  4.087046e-11   8.185452e-11  8.936852e-11
# ===== leading kernel by abs_eigmax =====
#
# Q[0] = [0. 0.]
#                 kernel   abs_eigmax  herm_residual     fro_norm
# ph_charge_longitudinal 3.378685e-04   4.167418e+04 7.226371e+04
#   ph_spin_longitudinal 3.287166e-04   4.167418e+04 7.226371e+04
#         pp_singlet_sz0 2.990587e-05   8.334837e+04 1.443636e+05
#         pp_triplet_sz0 1.717679e-20   3.637979e-12 3.637979e-12
#
# Q[1] = [0.         1.81379936]
#                 kernel   abs_eigmax  herm_residual     fro_norm
#         pp_singlet_sz0 2.930291e+03   1.526060e+03 5.076875e+03
#         pp_triplet_sz0 2.930291e+03   1.526060e+03 5.076875e+03
# ph_charge_longitudinal 1.405559e+00   2.807057e+03 3.969779e+03
#   ph_spin_longitudinal 1.136868e-13   1.470539e-10 1.503170e-10
#
# Q[2] = [1.57079633 0.90689968]
#                 kernel   abs_eigmax  herm_residual     fro_norm
#         pp_singlet_sz0 2.930291e+03   1.526060e+03 5.076875e+03
#         pp_triplet_sz0 2.930291e+03   1.526060e+03 5.076875e+03
# ph_charge_longitudinal 1.405559e+00   2.807057e+03 3.969779e+03
#   ph_spin_longitudinal 1.705303e-13   4.069989e-11 5.184587e-11
#
# Q[3] = [-1.57079633  0.90689968]
#                 kernel   abs_eigmax  herm_residual     fro_norm
#         pp_singlet_sz0 2.930291e+03   1.526060e+03 5.076875e+03
#         pp_triplet_sz0 2.930291e+03   1.526060e+03 5.076875e+03
# ph_charge_longitudinal 1.405559e+00   2.807057e+03 3.969779e+03
#   ph_spin_longitudinal 1.705303e-13   8.185452e-11 8.936852e-11
#
# ===== leading kernel by real_eigmax =====
#
# Q[0] = [0. 0.]
#                 kernel  real_eigmax  herm_residual     fro_norm
# ph_charge_longitudinal 3.287166e-04   4.167418e+04 7.226371e+04
#   ph_spin_longitudinal 3.287166e-04   4.167418e+04 7.226371e+04
#         pp_singlet_sz0 2.990587e-05   8.334837e+04 1.443636e+05
#         pp_triplet_sz0 1.717679e-20   3.637979e-12 3.637979e-12
#
# Q[1] = [0.         1.81379936]
#                 kernel  real_eigmax  herm_residual     fro_norm
#         pp_singlet_sz0 2.930291e+03   1.526060e+03 5.076875e+03
#         pp_triplet_sz0 2.930291e+03   1.526060e+03 5.076875e+03
# ph_charge_longitudinal 1.382400e-22   2.807057e+03 3.969779e+03
#   ph_spin_longitudinal 1.905259e-26   1.470539e-10 1.503170e-10
#
# Q[2] = [1.57079633 0.90689968]
#                 kernel  real_eigmax  herm_residual     fro_norm
#         pp_singlet_sz0 2.930291e+03   1.526060e+03 5.076875e+03
#         pp_triplet_sz0 2.930291e+03   1.526060e+03 5.076875e+03
# ph_charge_longitudinal 4.822358e-14   2.807057e+03 3.969779e+03
#   ph_spin_longitudinal 2.720627e-39   4.069989e-11 5.184587e-11
#
# Q[3] = [-1.57079633  0.90689968]
#                 kernel  real_eigmax  herm_residual     fro_norm
#         pp_singlet_sz0 2.930291e+03   1.526060e+03 5.076875e+03
#         pp_triplet_sz0 2.930291e+03   1.526060e+03 5.076875e+03
#   ph_spin_longitudinal 1.705303e-13   8.185452e-11 8.936852e-11
# ph_charge_longitudinal 4.822358e-14   2.807057e+03 3.969779e+03
#
# ===== leading kernel by herm_eigmax =====
#
# Q[0] = [0. 0.]
#                 kernel  herm_eigmax  herm_residual     fro_norm
#         pp_singlet_sz0 4.167418e+04   8.334837e+04 1.443636e+05
# ph_charge_longitudinal 2.224132e+04   4.167418e+04 7.226371e+04
#   ph_spin_longitudinal 2.153921e+04   4.167418e+04 7.226371e+04
#         pp_triplet_sz0 1.818989e-12   3.637979e-12 3.637979e-12
#
# Q[1] = [0.         1.81379936]
#                 kernel  herm_eigmax  herm_residual     fro_norm
#         pp_singlet_sz0 3.537175e+03   1.526060e+03 5.076875e+03
#         pp_triplet_sz0 3.537175e+03   1.526060e+03 5.076875e+03
# ph_charge_longitudinal 1.402826e+03   2.807057e+03 3.969779e+03
#   ph_spin_longitudinal 7.349855e-11   1.470539e-10 1.503170e-10
#
# Q[2] = [1.57079633 0.90689968]
#                 kernel  herm_eigmax  herm_residual     fro_norm
#         pp_singlet_sz0 3.537175e+03   1.526060e+03 5.076875e+03
#         pp_triplet_sz0 3.537175e+03   1.526060e+03 5.076875e+03
# ph_charge_longitudinal 1.402826e+03   2.807057e+03 3.969779e+03
#   ph_spin_longitudinal 2.029318e-11   4.069989e-11 5.184587e-11
#
# Q[3] = [-1.57079633  0.90689968]
#                 kernel  herm_eigmax  herm_residual     fro_norm
#         pp_singlet_sz0 3.537175e+03   1.526060e+03 5.076875e+03
#         pp_triplet_sz0 3.537175e+03   1.526060e+03 5.076875e+03
# ph_charge_longitudinal 1.402826e+03   2.807057e+03 3.969779e+03
#   ph_spin_longitudinal 4.087046e-11   8.185452e-11 8.936852e-11

# %%
# ============================================================
# TEST 2: inspect the four raw pp blocks and their algebra
# ============================================================

import numpy as np
import pandas as pd

solver = pi_result["solver"]
Qs_to_check = [np.asarray(Q, dtype=float) for Q in FLOW_KWARGS["diagnosis_Qs"]]

def rel_norm(X):
    return float(np.linalg.norm(X))

def safe_rel_residual(X, Y):
    denom = max(np.linalg.norm(X), np.linalg.norm(Y), 1e-14)
    return float(np.linalg.norm(X - Y) / denom)

for iq, Q in enumerate(Qs_to_check):
    kernels = solver.build_diagnosis_kernel_dict(Q)

    A = kernels["pp_ud_to_ud"].matrix
    B = kernels["pp_ud_to_du"].matrix
    C = kernels["pp_du_to_ud"].matrix
    D = kernels["pp_du_to_du"].matrix

    S = 0.5 * (A - B - C + D)
    T = 0.5 * (A + B + C + D)

    kS = kernels["pp_singlet_sz0"].matrix
    kT = kernels["pp_triplet_sz0"].matrix

    print(f"\n================ PP raw-block analysis at Q[{iq}] = {Q} ================")
    print("block Frobenius norms:")
    print(f"||A=ud->ud|| = {np.linalg.norm(A):.8e}")
    print(f"||B=ud->du|| = {np.linalg.norm(B):.8e}")
    print(f"||C=du->ud|| = {np.linalg.norm(C):.8e}")
    print(f"||D=du->du|| = {np.linalg.norm(D):.8e}")

    print("\nrelative relations:")
    print(f"A ~ D              : residual = {safe_rel_residual(A, D):.8e}")
    print(f"B ~ C              : residual = {safe_rel_residual(B, C):.8e}")
    print(f"B ~ -C             : residual = {safe_rel_residual(B, -C):.8e}")
    print(f"A ~ 0              : ratio = {np.linalg.norm(A) / max(np.linalg.norm(S), np.linalg.norm(T), 1e-14):.8e}")
    print(f"B ~ 0              : ratio = {np.linalg.norm(B) / max(np.linalg.norm(S), np.linalg.norm(T), 1e-14):.8e}")
    print(f"C ~ 0              : ratio = {np.linalg.norm(C) / max(np.linalg.norm(S), np.linalg.norm(T), 1e-14):.8e}")
    print(f"D ~ 0              : ratio = {np.linalg.norm(D) / max(np.linalg.norm(S), np.linalg.norm(T), 1e-14):.8e}")

    print("\ncheck reconstruction against stored combined kernels:")
    print(f"||S - stored pp_singlet|| / ||stored|| = {np.linalg.norm(S - kS) / max(np.linalg.norm(kS),1e-14):.8e}")
    print(f"||T - stored pp_triplet|| / ||stored|| = {np.linalg.norm(T - kT) / max(np.linalg.norm(kT),1e-14):.8e}")

    # eigen info
    def top_metrics(M):
        vals = np.linalg.eigvals(M)
        H = 0.5 * (M + M.conjugate().T)
        evals_H = np.linalg.eigvalsh(H)
        return (
            float(np.max(np.abs(vals))),
            float(np.max(np.real(vals))),
            float(np.max(evals_H)),
        )

    names_and_mats = [
        ("A=ud->ud", A),
        ("B=ud->du", B),
        ("C=du->ud", C),
        ("D=du->du", D),
        ("S=singlet_raw", S),
        ("T=triplet_raw", T),
    ]

    rows = []
    for name, M in names_and_mats:
        absmax, realmax, hermmax = top_metrics(M)
        rows.append({
            "name": name,
            "abs_eigmax": absmax,
            "real_eigmax": realmax,
            "herm_eigmax": hermmax,
            "fro_norm": float(np.linalg.norm(M)),
            "herm_residual": float(np.max(np.abs(M - M.conjugate().T))),
        })

    df_pp = pd.DataFrame(rows)
    display(df_pp)
# Out:
# ================ PP raw-block analysis at Q[0] = [0. 0.] ================
# block Frobenius norms:
# ||A=ud->ud|| = 7.21818020e+04
# ||B=ud->du|| = 7.21818020e+04
# ||C=du->ud|| = 7.21818020e+04
# ||D=du->du|| = 7.21818020e+04
#
# relative relations:
# A ~ D              : residual = 3.47725004e-15
# B ~ C              : residual = 3.39893354e-15
# B ~ -C             : residual = 2.00000000e+00
# A ~ 0              : ratio = 5.00000000e-01
# B ~ 0              : ratio = 5.00000000e-01
# C ~ 0              : ratio = 5.00000000e-01
# D ~ 0              : ratio = 5.00000000e-01
#
# check reconstruction against stored combined kernels:
# ||S - stored pp_singlet|| / ||stored|| = 0.00000000e+00
# ||T - stored pp_triplet|| / ||stored|| = 0.00000000e+00
#             name    abs_eigmax   real_eigmax   herm_eigmax      fro_norm  \
# 0       A=ud->ud  1.934471e-05  3.239280e-08  2.083709e+04  7.218180e+04
# 1       B=ud->du  3.368733e-06  3.368733e-06  2.083709e+04  7.218180e+04
# 2       C=du->ud  5.630859e-06  7.275958e-12  2.083709e+04  7.218180e+04
# 3       D=du->du  1.449168e-05  1.024223e-11  2.083709e+04  7.218180e+04
# 4  S=singlet_raw  2.990587e-05  2.990587e-05  4.167418e+04  1.443636e+05
# 5  T=triplet_raw  1.717679e-20  1.717679e-20  1.818989e-12  3.637979e-12
#
#    herm_residual
# 0   4.167418e+04
# 1   4.167418e+04
# 2   4.167418e+04
# 3   4.167418e+04
# 4   8.334837e+04
# 5   3.637979e-12
# ================ PP raw-block analysis at Q[1] = [0.         1.81379936] ================
# block Frobenius norms:
# ||A=ud->ud|| = 4.67235844e+03
# ||B=ud->du|| = 1.98588292e+03
# ||C=du->ud|| = 1.98588292e+03
# ||D=du->du|| = 4.67235844e+03
#
# relative relations:
# A ~ D              : residual = 5.87167955e-15
# B ~ C              : residual = 1.35365833e-14
# B ~ -C             : residual = 2.00000000e+00
# A ~ 0              : ratio = 9.20321659e-01
# B ~ 0              : ratio = 3.91162427e-01
# C ~ 0              : ratio = 3.91162427e-01
# D ~ 0              : ratio = 9.20321659e-01
#
# check reconstruction against stored combined kernels:
# ||S - stored pp_singlet|| / ||stored|| = 0.00000000e+00
# ||T - stored pp_triplet|| / ||stored|| = 0.00000000e+00
#             name   abs_eigmax   real_eigmax  herm_eigmax     fro_norm  \
# 0       A=ud->ud  2930.291344  2.930291e+03  3117.073839  4672.358436
# 1       B=ud->du     0.000015  6.016957e-06   702.115640  1985.882921
# 2       C=du->ud     0.000007  2.063872e-10   702.115640  1985.882921
# 3       D=du->du  2930.291344  2.930291e+03  3117.073839  4672.358436
# 4  S=singlet_raw  2930.291344  2.930291e+03  3537.174552  5076.875450
# 5  T=triplet_raw  2930.291344  2.930291e+03  3537.174552  5076.875450
#
#    herm_residual
# 0    1526.060064
# 1    1404.231280
# 2    1404.231280
# 3    1526.060064
# 4    1526.060064
# 5    1526.060064
# ================ PP raw-block analysis at Q[2] = [1.57079633 0.90689968] ================
# block Frobenius norms:
# ||A=ud->ud|| = 4.67235844e+03
# ||B=ud->du|| = 1.98588292e+03
# ||C=du->ud|| = 1.98588292e+03
# ||D=du->du|| = 4.67235844e+03
#
# relative relations:
# A ~ D              : residual = 4.65977575e-15
# B ~ C              : residual = 1.01591335e-14
# B ~ -C             : residual = 2.00000000e+00
# A ~ 0              : ratio = 9.20321659e-01
# B ~ 0              : ratio = 3.91162427e-01
# C ~ 0              : ratio = 3.91162427e-01
# D ~ 0              : ratio = 9.20321659e-01
#
# check reconstruction against stored combined kernels:
# ||S - stored pp_singlet|| / ||stored|| = 0.00000000e+00
# ||T - stored pp_triplet|| / ||stored|| = 0.00000000e+00
#             name    abs_eigmax   real_eigmax  herm_eigmax     fro_norm  \
# 0       A=ud->ud  2.930291e+03  2.930291e+03  3117.073839  4672.358436
# 1       B=ud->du  1.258460e-12  1.255876e-12   702.115640  1985.882921
# 2       C=du->ud  1.293843e-12  1.218423e-12   702.115640  1985.882921
# 3       D=du->du  2.930291e+03  2.930291e+03  3117.073839  4672.358436
# 4  S=singlet_raw  2.930291e+03  2.930291e+03  3537.174552  5076.875450
# 5  T=triplet_raw  2.930291e+03  2.930291e+03  3537.174552  5076.875450
#
#    herm_residual
# 0    1526.060064
# 1    1404.231280
# 2    1404.231280
# 3    1526.060064
# 4    1526.060064
# 5    1526.060064
# ================ PP raw-block analysis at Q[3] = [-1.57079633  0.90689968] ================
# block Frobenius norms:
# ||A=ud->ud|| = 4.67235844e+03
# ||B=ud->du|| = 1.98588292e+03
# ||C=du->ud|| = 1.98588292e+03
# ||D=du->du|| = 4.67235844e+03
#
# relative relations:
# A ~ D              : residual = 2.85274008e-15
# B ~ C              : residual = 1.08619499e-15
# B ~ -C             : residual = 2.00000000e+00
# A ~ 0              : ratio = 9.20321659e-01
# B ~ 0              : ratio = 3.91162427e-01
# C ~ 0              : ratio = 3.91162427e-01
# D ~ 0              : ratio = 9.20321659e-01
#
# check reconstruction against stored combined kernels:
# ||S - stored pp_singlet|| / ||stored|| = 0.00000000e+00
# ||T - stored pp_triplet|| / ||stored|| = 0.00000000e+00
#             name   abs_eigmax  real_eigmax  herm_eigmax     fro_norm  \
# 0       A=ud->ud  2930.291344  2930.291344  3117.073839  4672.358436
# 1       B=ud->du     0.000007     0.000007   702.115640  1985.882921
# 2       C=du->ud     0.000013     0.000013   702.115640  1985.882921
# 3       D=du->du  2930.291344  2930.291344  3117.073839  4672.358436
# 4  S=singlet_raw  2930.291344  2930.291344  3537.174552  5076.875450
# 5  T=triplet_raw  2930.291344  2930.291344  3537.174552  5076.875450
#
#    herm_residual
# 0    1526.060064
# 1    1404.231280
# 2    1404.231280
# 3    1526.060064
# 4    1526.060064
# 5    1526.060064

# %%
# ============================================================
# TEST 3: inspect the four raw ph blocks and compare to combined ph kernels
# ============================================================

import numpy as np
import pandas as pd

solver = pi_result["solver"]
Qs_to_check = [np.asarray(Q, dtype=float) for Q in FLOW_KWARGS["diagnosis_Qs"]]

for iq, Q in enumerate(Qs_to_check):
    kernels = solver.build_diagnosis_kernel_dict(Q)

    A = kernels["phd_uu_to_uu"].matrix
    B = kernels["phd_uu_to_dd"].matrix
    C = kernels["phd_dd_to_uu"].matrix
    D = kernels["phd_dd_to_dd"].matrix

    RHO = 0.5 * (A + B + C + D)
    SZ  = 0.5 * (A - B - C + D)

    kRHO = kernels["ph_charge_longitudinal"].matrix
    kSZ  = kernels["ph_spin_longitudinal"].matrix

    print(f"\n================ PH raw-block analysis at Q[{iq}] = {Q} ================")
    print("block Frobenius norms:")
    print(f"||A=uu->uu|| = {np.linalg.norm(A):.8e}")
    print(f"||B=uu->dd|| = {np.linalg.norm(B):.8e}")
    print(f"||C=dd->uu|| = {np.linalg.norm(C):.8e}")
    print(f"||D=dd->dd|| = {np.linalg.norm(D):.8e}")

    print("\nrelative relations:")
    print(f"A ~ D              : residual = {np.linalg.norm(A - D)/max(np.linalg.norm(A),np.linalg.norm(D),1e-14):.8e}")
    print(f"B ~ C              : residual = {np.linalg.norm(B - C)/max(np.linalg.norm(B),np.linalg.norm(C),1e-14):.8e}")
    print(f"B ~ -C             : residual = {np.linalg.norm(B + C)/max(np.linalg.norm(B),np.linalg.norm(C),1e-14):.8e}")

    print("\ncheck reconstruction against stored combined kernels:")
    print(f"||RHO - stored ph_charge|| / ||stored|| = {np.linalg.norm(RHO - kRHO) / max(np.linalg.norm(kRHO),1e-14):.8e}")
    print(f"||SZ  - stored ph_spin  || / ||stored|| = {np.linalg.norm(SZ  - kSZ ) / max(np.linalg.norm(kSZ ),1e-14):.8e}")

    def top_metrics(M):
        vals = np.linalg.eigvals(M)
        H = 0.5 * (M + M.conjugate().T)
        evals_H = np.linalg.eigvalsh(H)
        return (
            float(np.max(np.abs(vals))),
            float(np.max(np.real(vals))),
            float(np.max(evals_H)),
        )

    names_and_mats = [
        ("A=uu->uu", A),
        ("B=uu->dd", B),
        ("C=dd->uu", C),
        ("D=dd->dd", D),
        ("RHO=charge_raw", RHO),
        ("SZ=spin_raw", SZ),
    ]

    rows = []
    for name, M in names_and_mats:
        absmax, realmax, hermmax = top_metrics(M)
        rows.append({
            "name": name,
            "abs_eigmax": absmax,
            "real_eigmax": realmax,
            "herm_eigmax": hermmax,
            "fro_norm": float(np.linalg.norm(M)),
            "herm_residual": float(np.max(np.abs(M - M.conjugate().T))),
        })

    df_ph = pd.DataFrame(rows)
    display(df_ph)
# Out:
# ================ PH raw-block analysis at Q[0] = [0. 0.] ================
# block Frobenius norms:
# ||A=uu->uu|| = 3.43965012e+03
# ||B=uu->dd|| = 7.21818020e+04
# ||C=dd->uu|| = 7.21818020e+04
# ||D=dd->dd|| = 3.43965012e+03
#
# relative relations:
# A ~ D              : residual = 9.48559621e-15
# B ~ C              : residual = 3.39893354e-15
# B ~ -C             : residual = 2.00000000e+00
#
# check reconstruction against stored combined kernels:
# ||RHO - stored ph_charge|| / ||stored|| = 0.00000000e+00
# ||SZ  - stored ph_spin  || / ||stored|| = 0.00000000e+00
#              name  abs_eigmax   real_eigmax   herm_eigmax      fro_norm  \
# 0        A=uu->uu    0.000015  1.469663e-05   1404.231280   3439.650117
# 1        B=uu->dd    0.000188  3.240010e-08  20837.091412  72181.802016
# 2        C=dd->uu    0.000166  1.660101e-04  20837.091412  72181.802016
# 3        D=dd->dd    0.000009  9.239444e-06   1404.231280   3439.650117
# 4  RHO=charge_raw    0.000338  3.287166e-04  22241.322693  72263.709670
# 5     SZ=spin_raw    0.000329  3.287166e-04  21539.207052  72263.709670
#
#    herm_residual
# 0    1404.231280
# 1   41674.182825
# 2   41674.182825
# 3    1404.231280
# 4   41674.182825
# 5   41674.182825
# ================ PH raw-block analysis at Q[1] = [0.         1.81379936] ================
# block Frobenius norms:
# ||A=uu->uu|| = 1.98488929e+03
# ||B=uu->dd|| = 1.98488929e+03
# ||C=dd->uu|| = 1.98488929e+03
# ||D=dd->dd|| = 1.98488929e+03
#
# relative relations:
# A ~ D              : residual = 1.72970212e-15
# B ~ C              : residual = 1.35885805e-14
# B ~ -C             : residual = 2.00000000e+00
#
# check reconstruction against stored combined kernels:
# ||RHO - stored ph_charge|| / ||stored|| = 0.00000000e+00
# ||SZ  - stored ph_spin  || / ||stored|| = 0.00000000e+00
#              name    abs_eigmax   real_eigmax   herm_eigmax      fro_norm  \
# 0        A=uu->uu  7.027796e-01  4.353038e-23  7.014129e+02  1.984889e+03
# 1        B=uu->dd  7.027796e-01  0.000000e+00  7.014129e+02  1.984889e+03
# 2        C=dd->uu  7.027796e-01  9.018318e-13  7.014129e+02  1.984889e+03
# 3        D=dd->dd  7.027796e-01  1.293238e-13  7.014129e+02  1.984889e+03
# 4  RHO=charge_raw  1.405559e+00  1.382400e-22  1.402826e+03  3.969779e+03
# 5     SZ=spin_raw  1.136868e-13  1.905259e-26  7.349855e-11  1.503170e-10
#
#    herm_residual
# 0   1.403529e+03
# 1   1.403529e+03
# 2   1.403529e+03
# 3   1.403529e+03
# 4   2.807057e+03
# 5   1.470539e-10
# ================ PH raw-block analysis at Q[2] = [1.57079633 0.90689968] ================
# block Frobenius norms:
# ||A=uu->uu|| = 1.98488929e+03
# ||B=uu->dd|| = 1.98488929e+03
# ||C=dd->uu|| = 1.98488929e+03
# ||D=dd->dd|| = 1.98488929e+03
#
# relative relations:
# A ~ D              : residual = 1.38832971e-14
# B ~ C              : residual = 1.01719623e-14
# B ~ -C             : residual = 2.00000000e+00
#
# check reconstruction against stored combined kernels:
# ||RHO - stored ph_charge|| / ||stored|| = 0.00000000e+00
# ||SZ  - stored ph_spin  || / ||stored|| = 0.00000000e+00
#              name    abs_eigmax   real_eigmax   herm_eigmax      fro_norm  \
# 0        A=uu->uu  7.027796e-01  1.347322e-11  7.014129e+02  1.984889e+03
# 1        B=uu->dd  7.027796e-01  6.642893e-11  7.014129e+02  1.984889e+03
# 2        C=dd->uu  7.027796e-01  2.943056e-11  7.014129e+02  1.984889e+03
# 3        D=dd->dd  7.027796e-01  1.353714e-11  7.014129e+02  1.984889e+03
# 4  RHO=charge_raw  1.405559e+00  4.822358e-14  1.402826e+03  3.969779e+03
# 5     SZ=spin_raw  1.705303e-13  2.720627e-39  2.029318e-11  5.184587e-11
#
#    herm_residual
# 0   1.403529e+03
# 1   1.403529e+03
# 2   1.403529e+03
# 3   1.403529e+03
# 4   2.807057e+03
# 5   4.069989e-11
# ================ PH raw-block analysis at Q[3] = [-1.57079633  0.90689968] ================
# block Frobenius norms:
# ||A=uu->uu|| = 1.98488929e+03
# ||B=uu->dd|| = 1.98488929e+03
# ||C=dd->uu|| = 1.98488929e+03
# ||D=dd->dd|| = 1.98488929e+03
#
# relative relations:
# A ~ D              : residual = 9.40027264e-15
# B ~ C              : residual = 1.14265582e-15
# B ~ -C             : residual = 2.00000000e+00
#
# check reconstruction against stored combined kernels:
# ||RHO - stored ph_charge|| / ||stored|| = 0.00000000e+00
# ||SZ  - stored ph_spin  || / ||stored|| = 0.00000000e+00
#              name    abs_eigmax   real_eigmax   herm_eigmax      fro_norm  \
# 0        A=uu->uu  7.027796e-01  1.846193e-14  7.014129e+02  1.984889e+03
# 1        B=uu->dd  7.027796e-01  1.846193e-14  7.014129e+02  1.984889e+03
# 2        C=dd->uu  7.027796e-01  1.605452e-10  7.014129e+02  1.984889e+03
# 3        D=dd->dd  7.027796e-01  2.411179e-14  7.014129e+02  1.984889e+03
# 4  RHO=charge_raw  1.405559e+00  4.822358e-14  1.402826e+03  3.969779e+03
# 5     SZ=spin_raw  1.705303e-13  1.705303e-13  4.087046e-11  8.936852e-11
#
#    herm_residual
# 0   1.403529e+03
# 1   1.403529e+03
# 2   1.403529e+03
# 3   1.403529e+03
# 4   2.807057e+03
# 5   8.185452e-11

# %%
# ============================================================
# TEST 1:
# Decompose the Q1 diagnosis kernels by vertex source
# ============================================================

import numpy as np
import pandas as pd

solver = pi_result["solver"]

# ---------------------------
# choose which Q to inspect
# by default: Q1
# ---------------------------
Q_idx = 1
Q = np.asarray(FLOW_KWARGS["diagnosis_Qs"][Q_idx], dtype=float)

print(f"Using Q[{Q_idx}] = {Q}")

# ------------------------------------------------------------
# helpers: build gamma accessor from selected channel stores
# ------------------------------------------------------------
def make_gamma_from_selected_sources(
    solver,
    *,
    include_bare=True,
    include_pp=False,
    include_phd=False,
    include_phc=False,
):
    """
    Return a gamma accessor:
        gamma(p1,s1,p2,s2,p3,s3,p4,s4)
    reconstructed from a selected subset of:
        bare, pp_corr, phd_corr, phc_corr
    """
    def gamma(p1, s1, p2, s2, p3, s3, p4, s4):
        s1n, s2n, s3n, s4n = canonical_spin_tuple((s1, s2, s3, s4))
        val = 0.0 + 0.0j

        if include_bare:
            val += complex(solver.state.bare_gamma(p1, s1n, p2, s2n, p3, s3n, p4, s4n))

        if include_pp:
            iq_pp = solver._pp_q_index[(s1n, s2n)][p1, p2]
            val += complex(solver.state.pp_corr[(s1n, s2n, s3n, s4n, iq_pp)][p3, p1])

        if include_phd:
            iq_phd = solver._phd_q_index[(s3n, s1n)][p3, p1]
            val += complex(solver.state.phd_corr[(s1n, s2n, s3n, s4n, iq_phd)][p4, p1])

        if include_phc:
            iq_phc = solver._phc_q_index[(s3n, s2n)][p3, p2]
            val += complex(solver.state.phc_corr[(s1n, s2n, s3n, s4n, iq_phc)][p2, p1])

        return val

    return gamma


# ------------------------------------------------------------
# helper: safely evaluate diagnosis kernels under a custom gamma
# ------------------------------------------------------------
def build_diag_with_custom_gamma(solver, Q, gamma_fn):
    old_gamma = solver._fast_gamma
    try:
        solver._fast_gamma = gamma_fn
        out = solver.build_diagnosis_kernel_dict(Q)
    finally:
        solver._fast_gamma = old_gamma
    return out


# ------------------------------------------------------------
# helper: kernel metrics
# ------------------------------------------------------------
def kernel_metrics(kernel):
    vals_abs, _ = kernel.eig(sort_by="abs")
    vals_real, _ = kernel.eig(sort_by="real")

    H = 0.5 * (kernel.matrix + kernel.matrix.conjugate().T)
    evals_H = np.linalg.eigvalsh(H)

    return {
        "abs_eigmax": float(np.max(np.abs(vals_abs))) if len(vals_abs) else np.nan,
        "real_eigmax": float(np.max(np.real(vals_real))) if len(vals_real) else np.nan,
        "herm_eigmax": float(np.max(evals_H)) if len(evals_H) else np.nan,
        "fro_norm": float(np.linalg.norm(kernel.matrix)),
        "herm_residual": float(np.max(np.abs(kernel.matrix - kernel.matrix.conjugate().T))),
    }


# ------------------------------------------------------------
# source sets to compare
# ------------------------------------------------------------
source_cases = {
    "bare_only": dict(include_bare=True,  include_pp=False, include_phd=False, include_phc=False),
    "pp_only":   dict(include_bare=False, include_pp=True,  include_phd=False, include_phc=False),
    "phd_only":  dict(include_bare=False, include_pp=False, include_phd=True,  include_phc=False),
    "phc_only":  dict(include_bare=False, include_pp=False, include_phd=False, include_phc=True),
    "ph_only":   dict(include_bare=False, include_pp=False, include_phd=True,  include_phc=True),
    "bare+pp":   dict(include_bare=True,  include_pp=True,  include_phd=False, include_phc=False),
    "bare+ph":   dict(include_bare=True,  include_pp=False, include_phd=True,  include_phc=True),
    "full":      dict(include_bare=True,  include_pp=True,  include_phd=True,  include_phc=True),
}

# these are the most important combined labels
combined_names = [
    "pp_singlet_sz0",
    "pp_triplet_sz0",
    "ph_charge_longitudinal",
    "ph_spin_longitudinal",
]

# and these raw blocks are useful too
raw_names = [
    "pp_ud_to_ud",
    "pp_ud_to_du",
    "pp_du_to_ud",
    "pp_du_to_du",
    "phd_uu_to_uu",
    "phd_uu_to_dd",
    "phd_dd_to_uu",
    "phd_dd_to_dd",
]

# ------------------------------------------------------------
# run all source cases
# ------------------------------------------------------------
all_kernels = {}
rows_combined = []
rows_raw = []

for label, kw in source_cases.items():
    gamma_fn = make_gamma_from_selected_sources(solver, **kw)
    kernels = build_diag_with_custom_gamma(solver, Q, gamma_fn)
    all_kernels[label] = kernels

    for name in combined_names:
        k = kernels[name]
        met = kernel_metrics(k)
        rows_combined.append({
            "source_case": label,
            "kernel": name,
            **met,
        })

    for name in raw_names:
        k = kernels[name]
        met = kernel_metrics(k)
        rows_raw.append({
            "source_case": label,
            "kernel": name,
            **met,
        })

df_combined = pd.DataFrame(rows_combined)
df_raw = pd.DataFrame(rows_raw)

print("\n================ COMBINED KERNELS ================")
display(df_combined)

print("\n================ RAW KERNELS ================")
display(df_raw)

# ------------------------------------------------------------
# compact ranking printout for combined kernels
# ------------------------------------------------------------
for metric in ["abs_eigmax", "real_eigmax", "herm_eigmax"]:
    print(f"\n\n===== ranking by {metric} at Q[{Q_idx}] = {Q} =====")
    for label in source_cases.keys():
        sub = df_combined[df_combined["source_case"] == label].copy()
        sub = sub.sort_values(metric, ascending=False)
        print(f"\n--- source_case = {label} ---")
        print(sub[["kernel", metric, "fro_norm", "herm_residual"]].to_string(index=False))


# ------------------------------------------------------------
# extra: compare eigenvectors for the leading combined kernels
# ------------------------------------------------------------
def leading_vec(kernel, sort_by="real"):
    vals, vecs = kernel.eig(sort_by=sort_by)
    if len(vals) == 0:
        return None, None
    v = vecs[:, 0]
    nrm = np.linalg.norm(v)
    if nrm > 0:
        v = v / nrm
    return vals[0], v

print("\n\n================ LEADING EIGENVECTORS (combined kernels) ================")
for label in ["ph_only", "bare+ph", "pp_only", "full"]:
    print(f"\n--- {label} ---")
    for name in combined_names:
        lam, v = leading_vec(all_kernels[label][name], sort_by="real")
        if v is None:
            print(f"{name:24s} : no eigenvector")
        else:
            print(f"{name:24s} : lambda_real_sorted = {lam}")
            print("vec.real =", np.real(v))
            print("vec.abs  =", np.abs(v))
# Out:
# Using Q[1] = [0.         1.81379936]
#
# ================ COMBINED KERNELS ================
#    source_case                  kernel    abs_eigmax   real_eigmax  \
# 0    bare_only          pp_singlet_sz0  2.400000e+01  2.400000e+01
# 1    bare_only          pp_triplet_sz0  2.400000e+01  2.400000e+01
# 2    bare_only  ph_charge_longitudinal  4.800000e+01  0.000000e+00
# 3    bare_only    ph_spin_longitudinal  5.486882e-64  5.486882e-64
# 4      pp_only          pp_singlet_sz0  2.906291e+03  2.906291e+03
# 5      pp_only          pp_triplet_sz0  2.906291e+03  2.906291e+03
# 6      pp_only  ph_charge_longitudinal  1.523022e-08  1.600643e-10
# 7      pp_only    ph_spin_longitudinal  1.479179e-23  1.041573e-27
# 8     phd_only          pp_singlet_sz0  4.242910e-06  4.242910e-06
# 9     phd_only          pp_triplet_sz0  4.242910e-06  4.242910e-06
# 10    phd_only  ph_charge_longitudinal  4.659444e+01  4.659444e+01
# 11    phd_only    ph_spin_longitudinal  1.136868e-13  1.362161e-39
# 12    phc_only          pp_singlet_sz0  2.426625e-06  6.869971e-14
# 13    phc_only          pp_triplet_sz0  2.426625e-06  6.869971e-14
# 14    phc_only  ph_charge_longitudinal  1.077862e-05  1.077862e-05
# 15    phc_only    ph_spin_longitudinal  1.044289e-22  3.208374e-23
# 16     ph_only          pp_singlet_sz0  3.058949e-06  3.058949e-06
# 17     ph_only          pp_triplet_sz0  3.058949e-06  3.058949e-06
# 18     ph_only  ph_charge_longitudinal  4.659444e+01  4.659444e+01
# 19     ph_only    ph_spin_longitudinal  1.136868e-13  0.000000e+00
# 20     bare+pp          pp_singlet_sz0  2.930291e+03  2.930291e+03
# 21     bare+pp          pp_triplet_sz0  2.930291e+03  2.930291e+03
# 22     bare+pp  ph_charge_longitudinal  4.800000e+01  2.210348e-16
# 23     bare+pp    ph_spin_longitudinal  1.479179e-23  1.041573e-27
# 24     bare+ph          pp_singlet_sz0  2.400000e+01  2.400000e+01
# 25     bare+ph          pp_triplet_sz0  2.400000e+01  2.400000e+01
# 26     bare+ph  ph_charge_longitudinal  1.405559e+00  4.853030e-26
# 27     bare+ph    ph_spin_longitudinal  1.136868e-13  0.000000e+00
# 28        full          pp_singlet_sz0  2.930291e+03  2.930291e+03
# 29        full          pp_triplet_sz0  2.930291e+03  2.930291e+03
# 30        full  ph_charge_longitudinal  1.405559e+00  1.382400e-22
# 31        full    ph_spin_longitudinal  1.136868e-13  1.905259e-26
#
#      herm_eigmax      fro_norm  herm_residual
# 0   2.897056e+01  4.800000e+01   2.400000e+01
# 1   2.897056e+01  4.800000e+01   2.400000e+01
# 2   4.269487e-16  6.788225e+01   1.223472e-63
# 3   9.447810e-64  1.896282e-63   1.223472e-63
# 4   3.508204e+03  5.083278e+03   1.806744e+03
# 5   3.508204e+03  5.083278e+03   1.806744e+03
# 6   1.099547e+03  3.109988e+03   2.199094e+03
# 7   7.048584e-12  1.421404e-11   1.409717e-11
# 8   5.822631e+02  1.197875e+03   7.226052e+02
# 9   5.822631e+02  1.197875e+03   7.226052e+02
# 10  4.425687e+02  1.185879e+03   8.372474e+02
# 11  6.053928e-12  1.238468e-11   1.217870e-11
# 12  5.822631e+02  1.197875e+03   7.226052e+02
# 13  5.822631e+02  1.197875e+03   7.226052e+02
# 14  7.226052e+02  2.043836e+03   1.445210e+03
# 15  7.256062e-11  1.485108e-10   1.451212e-10
# 16  2.806843e+02  5.613686e+02   2.806843e+02
# 17  2.806843e+02  5.613686e+02   2.806843e+02
# 18  3.281702e+02  8.623110e+02   6.079631e+02
# 19  6.643576e-11  1.361337e-10   1.329425e-10
# 20  3.537175e+03  5.121189e+03   1.806744e+03
# 21  3.537175e+03  5.121189e+03   1.806744e+03
# 22  1.075809e+03  3.110729e+03   2.199094e+03
# 23  7.048584e-12  1.421404e-11   1.409717e-11
# 24  3.049302e+02  5.868428e+02   3.046843e+02
# 25  3.049302e+02  5.868428e+02   3.046843e+02
# 26  3.032796e+02  8.597919e+02   6.079631e+02
# 27  6.643576e-11  1.361337e-10   1.329425e-10
# 28  3.537175e+03  5.076875e+03   1.526060e+03
# 29  3.537175e+03  5.076875e+03   1.526060e+03
# 30  1.402826e+03  3.969779e+03   2.807057e+03
# 31  7.349855e-11  1.503170e-10   1.470539e-10
# ================ RAW KERNELS ================
#    source_case        kernel    abs_eigmax   real_eigmax   herm_eigmax  \
# 0    bare_only   pp_ud_to_ud  2.400000e+01  2.400000e+01  2.400000e+01
# 1    bare_only   pp_ud_to_du  8.569276e-08  8.569276e-08  1.200000e+01
# 2    bare_only   pp_du_to_ud  8.569276e-08  8.569276e-08  1.200000e+01
# 3    bare_only   pp_du_to_du  2.400000e+01  2.400000e+01  2.400000e+01
# 4    bare_only  phd_uu_to_uu  2.400000e+01  0.000000e+00  1.314768e-31
# ..         ...           ...           ...           ...           ...
# 59        full   pp_du_to_du  2.930291e+03  2.930291e+03  3.117074e+03
# 60        full  phd_uu_to_uu  7.027796e-01  4.353038e-23  7.014129e+02
# 61        full  phd_uu_to_dd  7.027796e-01  0.000000e+00  7.014129e+02
# 62        full  phd_dd_to_uu  7.027796e-01  9.018318e-13  7.014129e+02
# 63        full  phd_dd_to_dd  7.027796e-01  1.293238e-13  7.014129e+02
#
#        fro_norm  herm_residual
# 0     33.941125   0.000000e+00
# 1     33.941125   2.400000e+01
# 2     33.941125   2.400000e+01
# 3     33.941125   0.000000e+00
# 4     33.941125   1.223472e-63
# ..          ...            ...
# 59  4672.358436   1.526060e+03
# 60  1984.889290   1.403529e+03
# 61  1984.889290   1.403529e+03
# 62  1984.889290   1.403529e+03
# 63  1984.889290   1.403529e+03
#
# [64 rows x 7 columns]
# ===== ranking by abs_eigmax at Q[1] = [0.         1.81379936] =====
#
# --- source_case = bare_only ---
#                 kernel   abs_eigmax     fro_norm  herm_residual
# ph_charge_longitudinal 4.800000e+01 6.788225e+01   1.223472e-63
#         pp_singlet_sz0 2.400000e+01 4.800000e+01   2.400000e+01
#         pp_triplet_sz0 2.400000e+01 4.800000e+01   2.400000e+01
#   ph_spin_longitudinal 5.486882e-64 1.896282e-63   1.223472e-63
#
# --- source_case = pp_only ---
#                 kernel   abs_eigmax     fro_norm  herm_residual
#         pp_singlet_sz0 2.906291e+03 5.083278e+03   1.806744e+03
#         pp_triplet_sz0 2.906291e+03 5.083278e+03   1.806744e+03
# ph_charge_longitudinal 1.523022e-08 3.109988e+03   2.199094e+03
#   ph_spin_longitudinal 1.479179e-23 1.421404e-11   1.409717e-11
#
# --- source_case = phd_only ---
#                 kernel   abs_eigmax     fro_norm  herm_residual
# ph_charge_longitudinal 4.659444e+01 1.185879e+03   8.372474e+02
#         pp_singlet_sz0 4.242910e-06 1.197875e+03   7.226052e+02
#         pp_triplet_sz0 4.242910e-06 1.197875e+03   7.226052e+02
#   ph_spin_longitudinal 1.136868e-13 1.238468e-11   1.217870e-11
#
# --- source_case = phc_only ---
#                 kernel   abs_eigmax     fro_norm  herm_residual
# ph_charge_longitudinal 1.077862e-05 2.043836e+03   1.445210e+03
#         pp_singlet_sz0 2.426625e-06 1.197875e+03   7.226052e+02
#         pp_triplet_sz0 2.426625e-06 1.197875e+03   7.226052e+02
#   ph_spin_longitudinal 1.044289e-22 1.485108e-10   1.451212e-10
#
# --- source_case = ph_only ---
#                 kernel   abs_eigmax     fro_norm  herm_residual
# ph_charge_longitudinal 4.659444e+01 8.623110e+02   6.079631e+02
#         pp_singlet_sz0 3.058949e-06 5.613686e+02   2.806843e+02
#         pp_triplet_sz0 3.058949e-06 5.613686e+02   2.806843e+02
#   ph_spin_longitudinal 1.136868e-13 1.361337e-10   1.329425e-10
#
# --- source_case = bare+pp ---
#                 kernel   abs_eigmax     fro_norm  herm_residual
#         pp_singlet_sz0 2.930291e+03 5.121189e+03   1.806744e+03
#         pp_triplet_sz0 2.930291e+03 5.121189e+03   1.806744e+03
# ph_charge_longitudinal 4.800000e+01 3.110729e+03   2.199094e+03
#   ph_spin_longitudinal 1.479179e-23 1.421404e-11   1.409717e-11
#
# --- source_case = bare+ph ---
#                 kernel   abs_eigmax     fro_norm  herm_residual
#         pp_singlet_sz0 2.400000e+01 5.868428e+02   3.046843e+02
#         pp_triplet_sz0 2.400000e+01 5.868428e+02   3.046843e+02
# ph_charge_longitudinal 1.405559e+00 8.597919e+02   6.079631e+02
#   ph_spin_longitudinal 1.136868e-13 1.361337e-10   1.329425e-10
#
# --- source_case = full ---
#                 kernel   abs_eigmax     fro_norm  herm_residual
#         pp_singlet_sz0 2.930291e+03 5.076875e+03   1.526060e+03
#         pp_triplet_sz0 2.930291e+03 5.076875e+03   1.526060e+03
# ph_charge_longitudinal 1.405559e+00 3.969779e+03   2.807057e+03
#   ph_spin_longitudinal 1.136868e-13 1.503170e-10   1.470539e-10
#
#
# ===== ranking by real_eigmax at Q[1] = [0.         1.81379936] =====
#
# --- source_case = bare_only ---
#                 kernel  real_eigmax     fro_norm  herm_residual
#         pp_singlet_sz0 2.400000e+01 4.800000e+01   2.400000e+01
#         pp_triplet_sz0 2.400000e+01 4.800000e+01   2.400000e+01
#   ph_spin_longitudinal 5.486882e-64 1.896282e-63   1.223472e-63
# ph_charge_longitudinal 0.000000e+00 6.788225e+01   1.223472e-63
#
# --- source_case = pp_only ---
#                 kernel  real_eigmax     fro_norm  herm_residual
#         pp_singlet_sz0 2.906291e+03 5.083278e+03   1.806744e+03
#         pp_triplet_sz0 2.906291e+03 5.083278e+03   1.806744e+03
# ph_charge_longitudinal 1.600643e-10 3.109988e+03   2.199094e+03
#   ph_spin_longitudinal 1.041573e-27 1.421404e-11   1.409717e-11
#
# --- source_case = phd_only ---
#                 kernel  real_eigmax     fro_norm  herm_residual
# ph_charge_longitudinal 4.659444e+01 1.185879e+03   8.372474e+02
#         pp_singlet_sz0 4.242910e-06 1.197875e+03   7.226052e+02
#         pp_triplet_sz0 4.242910e-06 1.197875e+03   7.226052e+02
#   ph_spin_longitudinal 1.362161e-39 1.238468e-11   1.217870e-11
#
# --- source_case = phc_only ---
#                 kernel  real_eigmax     fro_norm  herm_residual
# ph_charge_longitudinal 1.077862e-05 2.043836e+03   1.445210e+03
#         pp_singlet_sz0 6.869971e-14 1.197875e+03   7.226052e+02
#         pp_triplet_sz0 6.869971e-14 1.197875e+03   7.226052e+02
#   ph_spin_longitudinal 3.208374e-23 1.485108e-10   1.451212e-10
#
# --- source_case = ph_only ---
#                 kernel  real_eigmax     fro_norm  herm_residual
# ph_charge_longitudinal    46.594441 8.623110e+02   6.079631e+02
#         pp_singlet_sz0     0.000003 5.613686e+02   2.806843e+02
#         pp_triplet_sz0     0.000003 5.613686e+02   2.806843e+02
#   ph_spin_longitudinal     0.000000 1.361337e-10   1.329425e-10
#
# --- source_case = bare+pp ---
#                 kernel  real_eigmax     fro_norm  herm_residual
#         pp_singlet_sz0 2.930291e+03 5.121189e+03   1.806744e+03
#         pp_triplet_sz0 2.930291e+03 5.121189e+03   1.806744e+03
# ph_charge_longitudinal 2.210348e-16 3.110729e+03   2.199094e+03
#   ph_spin_longitudinal 1.041573e-27 1.421404e-11   1.409717e-11
#
# --- source_case = bare+ph ---
#                 kernel  real_eigmax     fro_norm  herm_residual
#         pp_singlet_sz0 2.400000e+01 5.868428e+02   3.046843e+02
#         pp_triplet_sz0 2.400000e+01 5.868428e+02   3.046843e+02
# ph_charge_longitudinal 4.853030e-26 8.597919e+02   6.079631e+02
#   ph_spin_longitudinal 0.000000e+00 1.361337e-10   1.329425e-10
#
# --- source_case = full ---
#                 kernel  real_eigmax     fro_norm  herm_residual
#         pp_singlet_sz0 2.930291e+03 5.076875e+03   1.526060e+03
#         pp_triplet_sz0 2.930291e+03 5.076875e+03   1.526060e+03
# ph_charge_longitudinal 1.382400e-22 3.969779e+03   2.807057e+03
#   ph_spin_longitudinal 1.905259e-26 1.503170e-10   1.470539e-10
#
#
# ===== ranking by herm_eigmax at Q[1] = [0.         1.81379936] =====
#
# --- source_case = bare_only ---
#                 kernel  herm_eigmax     fro_norm  herm_residual
#         pp_singlet_sz0 2.897056e+01 4.800000e+01   2.400000e+01
#         pp_triplet_sz0 2.897056e+01 4.800000e+01   2.400000e+01
# ph_charge_longitudinal 4.269487e-16 6.788225e+01   1.223472e-63
#   ph_spin_longitudinal 9.447810e-64 1.896282e-63   1.223472e-63
#
# --- source_case = pp_only ---
#                 kernel  herm_eigmax     fro_norm  herm_residual
#         pp_singlet_sz0 3.508204e+03 5.083278e+03   1.806744e+03
#         pp_triplet_sz0 3.508204e+03 5.083278e+03   1.806744e+03
# ph_charge_longitudinal 1.099547e+03 3.109988e+03   2.199094e+03
#   ph_spin_longitudinal 7.048584e-12 1.421404e-11   1.409717e-11
#
# --- source_case = phd_only ---
#                 kernel  herm_eigmax     fro_norm  herm_residual
#         pp_triplet_sz0 5.822631e+02 1.197875e+03   7.226052e+02
#         pp_singlet_sz0 5.822631e+02 1.197875e+03   7.226052e+02
# ph_charge_longitudinal 4.425687e+02 1.185879e+03   8.372474e+02
#   ph_spin_longitudinal 6.053928e-12 1.238468e-11   1.217870e-11
#
# --- source_case = phc_only ---
#                 kernel  herm_eigmax     fro_norm  herm_residual
# ph_charge_longitudinal 7.226052e+02 2.043836e+03   1.445210e+03
#         pp_triplet_sz0 5.822631e+02 1.197875e+03   7.226052e+02
#         pp_singlet_sz0 5.822631e+02 1.197875e+03   7.226052e+02
#   ph_spin_longitudinal 7.256062e-11 1.485108e-10   1.451212e-10
#
# --- source_case = ph_only ---
#                 kernel  herm_eigmax     fro_norm  herm_residual
# ph_charge_longitudinal 3.281702e+02 8.623110e+02   6.079631e+02
#         pp_singlet_sz0 2.806843e+02 5.613686e+02   2.806843e+02
#         pp_triplet_sz0 2.806843e+02 5.613686e+02   2.806843e+02
#   ph_spin_longitudinal 6.643576e-11 1.361337e-10   1.329425e-10
#
# --- source_case = bare+pp ---
#                 kernel  herm_eigmax     fro_norm  herm_residual
#         pp_singlet_sz0 3.537175e+03 5.121189e+03   1.806744e+03
#         pp_triplet_sz0 3.537175e+03 5.121189e+03   1.806744e+03
# ph_charge_longitudinal 1.075809e+03 3.110729e+03   2.199094e+03
#   ph_spin_longitudinal 7.048584e-12 1.421404e-11   1.409717e-11
#
# --- source_case = bare+ph ---
#                 kernel  herm_eigmax     fro_norm  herm_residual
#         pp_singlet_sz0 3.049302e+02 5.868428e+02   3.046843e+02
#         pp_triplet_sz0 3.049302e+02 5.868428e+02   3.046843e+02
# ph_charge_longitudinal 3.032796e+02 8.597919e+02   6.079631e+02
#   ph_spin_longitudinal 6.643576e-11 1.361337e-10   1.329425e-10
#
# --- source_case = full ---
#                 kernel  herm_eigmax     fro_norm  herm_residual
#         pp_singlet_sz0 3.537175e+03 5.076875e+03   1.526060e+03
#         pp_triplet_sz0 3.537175e+03 5.076875e+03   1.526060e+03
# ph_charge_longitudinal 1.402826e+03 3.969779e+03   2.807057e+03
#   ph_spin_longitudinal 7.349855e-11 1.503170e-10   1.470539e-10
#
#
# ================ LEADING EIGENVECTORS (combined kernels) ================
#
# --- ph_only ---
# pp_singlet_sz0           : lambda_real_sorted = (3.058948774176046e-06-5.931028052411697e-41j)
# vec.real = [0.5        0.         0.5        0.5        0.         0.49999999]
# vec.abs  = [0.5        0.         0.5        0.5        0.         0.49999999]
# pp_triplet_sz0           : lambda_real_sorted = (3.058948774176046e-06-5.931028052411697e-41j)
# vec.real = [ 0.5         0.         -0.5         0.5         0.         -0.49999999]
# vec.abs  = [0.5        0.         0.5        0.5        0.         0.49999999]
# ph_charge_longitudinal   : lambda_real_sorted = (46.59444086179107-2.821838939523994e-35j)
# vec.real = [2.01177963e-47 0.00000000e+00 6.51004829e-01 2.34574110e-47
#  0.00000000e+00 7.59073588e-01]
# vec.abs  = [3.73431638e-35 0.00000000e+00 6.51004829e-01 4.35422413e-35
#  0.00000000e+00 7.59073588e-01]
# ph_spin_longitudinal     : lambda_real_sorted = 0j
# vec.real = [0. 0. 0. 0. 1. 0.]
# vec.abs  = [0. 0. 0. 0. 1. 0.]
#
# --- bare+ph ---
# pp_singlet_sz0           : lambda_real_sorted = (24.000000000000462-1.642146637880645e-47j)
# vec.real = [0.5189155  0.         0.5189155  0.52498703 0.         0.43109397]
# vec.abs  = [0.5189155  0.         0.5189155  0.52498703 0.         0.43109397]
# pp_triplet_sz0           : lambda_real_sorted = (24.000000000000462-1.642146637880645e-47j)
# vec.real = [ 0.5189155   0.         -0.5189155   0.52498703  0.         -0.43109397]
# vec.abs  = [0.5189155  0.         0.5189155  0.52498703 0.         0.43109397]
# ph_charge_longitudinal   : lambda_real_sorted = (4.8530295484599025e-26-2.3595114577509336e-46j)
# vec.real = [ 7.07106781e-001  0.00000000e+000  9.07123713e-065  7.07106781e-001
#   0.00000000e+000 -4.02763374e-135]
# vec.abs  = [7.07106781e-001 0.00000000e+000 9.07123713e-065 7.07106781e-001
#  0.00000000e+000 3.62918231e-100]
# ph_spin_longitudinal     : lambda_real_sorted = 0j
# vec.real = [0. 0. 0. 0. 1. 0.]
# vec.abs  = [0. 0. 0. 0. 1. 0.]
#
# --- pp_only ---
# pp_singlet_sz0           : lambda_real_sorted = (2906.291343885875-1.3897700039488442e-32j)
# vec.real = [-0.31326438  0.         -0.31326438  0.88474823  0.          0.14474607]
# vec.abs  = [0.31326438 0.         0.31326438 0.88474823 0.         0.14474607]
# pp_triplet_sz0           : lambda_real_sorted = (2906.291343885875-1.3897700039488442e-32j)
# vec.real = [-0.31326438  0.          0.31326438  0.88474823  0.         -0.14474607]
# vec.abs  = [0.31326438 0.         0.31326438 0.88474823 0.         0.14474607]
# ph_charge_longitudinal   : lambda_real_sorted = (1.6006427212158978e-10-1.522938001696591e-08j)
# vec.real = [-1.81652343e-32  0.00000000e+00  7.07106781e-01 -1.81652344e-32
#   0.00000000e+00  7.07106781e-01]
# vec.abs  = [8.64878903e-31 0.00000000e+00 7.07106781e-01 8.64878903e-31
#  0.00000000e+00 7.07106781e-01]
# ph_spin_longitudinal     : lambda_real_sorted = (1.0415728675673132e-27+1.4791793034650073e-23j)
# vec.real = [ 7.07106781e-01  0.00000000e+00 -5.82827980e-51  7.07106781e-01
#   0.00000000e+00  6.08793252e-98]
# vec.abs  = [7.07106781e-01 0.00000000e+00 5.82827980e-51 7.07106781e-01
#  0.00000000e+00 2.90130733e-86]
#
# --- full ---
# pp_singlet_sz0           : lambda_real_sorted = (2930.2913438858745-5.768545369428649e-30j)
# vec.real = [-0.41618745  0.         -0.41618745  0.10269958  0.          0.80189078]
# vec.abs  = [0.41618745 0.         0.41618745 0.10269958 0.         0.80189078]
# pp_triplet_sz0           : lambda_real_sorted = (2930.2913438858745-5.768545369428649e-30j)
# vec.real = [ 0.41618745  0.         -0.41618745 -0.10269958  0.          0.80189078]
# vec.abs  = [0.41618745 0.         0.41618745 0.10269958 0.         0.80189078]
# ph_charge_longitudinal   : lambda_real_sorted = (1.382399906794023e-22+3.117945634705127e-45j)
# vec.real = [ 7.07106781e-001  0.00000000e+000 -9.67332127e-066  7.07106781e-001
#   0.00000000e+000  3.81160455e-136]
# vec.abs  = [7.07106781e-001 0.00000000e+000 9.67332127e-066 7.07106781e-001
#  0.00000000e+000 6.73181924e-101]
# ph_spin_longitudinal     : lambda_real_sorted = (1.905258795174164e-26+1.421555611980089e-58j)
# vec.real = [ 7.07106781e-001  0.00000000e+000 -1.84486616e-052  7.07106781e-001
#   0.00000000e+000 -1.26049501e-122]
# vec.abs  = [7.07106781e-01 0.00000000e+00 1.84486616e-52 7.07106781e-01
#  0.00000000e+00 1.28623513e-87]
